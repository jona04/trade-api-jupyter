# %%
for i in range(192):
    print(f"({2+i}, 'Name', 'IN'),")
# Out:
# (2, 'Name', 'IN'),
# (3, 'Name', 'IN'),
# (4, 'Name', 'IN'),
# (5, 'Name', 'IN'),
# (6, 'Name', 'IN'),
# (7, 'Name', 'IN'),
# (8, 'Name', 'IN'),
# (9, 'Name', 'IN'),
# (10, 'Name', 'IN'),
# (11, 'Name', 'IN'),
# (12, 'Name', 'IN'),
# (13, 'Name', 'IN'),
# (14, 'Name', 'IN'),
# (15, 'Name', 'IN'),
# (16, 'Name', 'IN'),
# (17, 'Name', 'IN'),
# (18, 'Name', 'IN'),
# (19, 'Name', 'IN'),
# (20, 'Name', 'IN'),
# (21, 'Name', 'IN'),
# (22, 'Name', 'IN'),
# (23, 'Name', 'IN'),
# (24, 'Name', 'IN'),
# (25, 'Name', 'IN'),
# (26, 'Name', 'IN'),
# (27, 'Name', 'IN'),
# (28, 'Name', 'IN'),
# (29, 'Name', 'IN'),
# (30, 'Name', 'IN'),
# (31, 'Name', 'IN'),
# (32, 'Name', 'IN'),
# (33, 'Name', 'IN'),
# (34, 'Name', 'IN'),
# (35, 'Name', 'IN'),
# (36, 'Name', 'IN'),
# (37, 'Name', 'IN'),
# (38, 'Name', 'IN'),
# (39, 'Name', 'IN'),
# (40, 'Name', 'IN'),
# (41, 'Name', 'IN'),
# (42, 'Name', 'IN'),
# (43, 'Name', 'IN'),
# (44, 'Name', 'IN'),
# (45, 'Name', 'IN'),
# (46, 'Name', 'IN'),
# ...
