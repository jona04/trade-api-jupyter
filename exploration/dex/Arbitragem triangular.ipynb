# %%
import requests

def get_cross_chain_routes(
    src_token_address,
    src_token_blockchain,
    src_token_amount,
    dst_token_address,
    dst_token_blockchain,
    referrer="rubic.exchange",
    slippage=None,
    receiver=None,
    native_blacklist=None,
    show_failed_routes=False,
):
    """
    Consulta rotas de swap cross-chain usando o Rubic API.

    Parâmetros:
        src_token_address (str): Endereço do token de origem.
        src_token_blockchain (str): Blockchain de origem (ex.: "ETH").
        src_token_amount (str): Quantidade do token de origem com decimais.
        dst_token_address (str): Endereço do token de destino.
        dst_token_blockchain (str): Blockchain de destino (ex.: "POLYGON").
        referrer (str): Endereço do referenciador (padrão: "rubic.exchange").
        slippage (float, opcional): Tolerância de slippage em porcentagem (ex.: 0.02 para 2%).
        receiver (str, opcional): Endereço da carteira para envio no destino.
        native_blacklist (list, opcional): Provedores nativos a serem excluídos.
        show_failed_routes (bool, opcional): Incluir rotas falhas na resposta.

    Retorna:
        dict: Dados das rotas obtidas do Rubic API.
    """
    url = "https://api-v2.rubic.exchange/api/routes/quoteAll"
    payload = {
        "srcTokenAddress": src_token_address,
        "srcTokenBlockchain": src_token_blockchain,
        "srcTokenAmount": src_token_amount,
        "dstTokenAddress": dst_token_address,
        "dstTokenBlockchain": dst_token_blockchain,
        "referrer": referrer,
    }

    # Adiciona campos opcionais, se fornecidos
    if slippage is not None:
        payload["slippage"] = slippage
    if receiver is not None:
        payload["receiver"] = receiver
    if native_blacklist is not None:
        payload["nativeBlacklist"] = native_blacklist
    payload["showFailedRoutes"] = show_failed_routes

    try:
        response = requests.post(url, json=payload)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Erro ao acessar o Rubic API: {e}")
        return None

# Exemplo de uso
if __name__ == "__main__":
    src_token_address = "0x0000000000000000000000000000000000000000"  # ETH
    src_token_blockchain = "ETH"
    src_token_amount = "1.05"  # 1.05 ETH
    dst_token_address = "0x0000000000000000000000000000000000000000"  # MATIC
    dst_token_blockchain = "POLYGON"
    
    # Consulta as rotas disponíveis
    routes = get_cross_chain_routes(
        src_token_address=src_token_address,
        src_token_blockchain=src_token_blockchain,
        src_token_amount=src_token_amount,
        dst_token_address=dst_token_address,
        dst_token_blockchain=dst_token_blockchain,
        slippage=0.02,  # 2% de slippage
        show_failed_routes=True,
    )
    
    if routes:
        print("Rotas disponíveis obtidas com sucesso:")
        print(routes)
    else:
        print("Nenhuma rota encontrada ou erro na solicitação.")
# Out:
# Rotas disponíveis obtidas com sucesso:
# {'quote': {'nativeBlacklist': [], 'foreignBlacklist': {'lifi': [], 'rango': []}, 'timeout': 30, 'referrer': 'rubic.exchange', 'enableChecks': False, 'showFailedRoutes': True, 'srcTokenAddress': '0x0000000000000000000000000000000000000000', 'srcTokenBlockchain': 'ETH', 'srcTokenAmount': '1.05', 'dstTokenAddress': '0x0000000000000000000000000000000000000000', 'dstTokenBlockchain': 'POLYGON', 'slippage': 0.02, 'integratorAddress': '0x3fFF9bDEb3147cE13A7FFEf85Dae81874E0AEDbE'}, 'routes': [{'estimate': {'destinationTokenAmount': '7446.183720324592439343', 'destinationTokenMinAmount': '7297.260045918100590556', 'destinationUsdAmount': 3379.16, 'destinationUsdMinAmount': 3311.58, 'destinationWeiAmount': '7446183720324592439343', 'destinationWeiMinAmount': '7297260045918100590556', 'durationInMinutes': 5, 'priceImpact': 0.04, 'slippage': 0.02}, 'fees': {'gasTokenFees': {'nativeToken': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3219.45, 'symbol': 'ETH'}, 'protocol': {'fixedAmount': '0.000591519969714177', 'fixedUsdAmount': 1.9, 'fixedWeiAmount': '591519969714177'}, 'provider': {'fixedAmount': '0', 'fixedUsdAmount': 0, 'fixedWeiAmount': '0'}}, 'percentFees': {'percent': 0, 'token': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3219.45, 'symbol': 'ETH'}}}, 'providerType': 'router', 'routing': [{'path': [{'address': '0x0000000000000000000000000000000000000000', 'amount': '1.05', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'symbol': 'ETH', 'price': 3219.45}, {'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2', 'amount': '1.05', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Wrapped Ether', 'symbol': 'WETH', 'price': 3221.3}], 'provider': 'ROUTER_SWAP', 'type': 'on-chain'}, {'path': [{'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2', 'amount': '1.05', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Wrapped Ether', 'symbol': 'WETH', 'price': 3221.3}, {'address': '0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619', 'amount': '1.04989972445430245', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 18, 'name': 'Wrapped Ether', 'symbol': 'WETH', 'price': 3214.5}], 'provider': 'router', 'type': 'cross-chain'}, {'path': [{'address': '0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619', 'amount': '1.04989972445430245', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 18, 'name': 'Wrapped Ether', 'symbol': 'WETH', 'price': 3214.5}, {'address': '0x0000000000000000000000000000000000000000', 'amount': '7446.183720324592439343', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 18, 'name': 'Matic Network', 'symbol': 'MATIC', 'price': 0.45}], 'provider': 'ROUTER_SWAP', 'type': 'on-chain'}], 'swapType': 'cross-chain', 'tokens': {'from': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3219.45, 'symbol': 'ETH'}, 'to': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 18, 'name': 'Matic Network', 'price': 0.45, 'symbol': 'MATIC'}}, 'transaction': {'approvalAddress': '0x3335733c454805df6a77f825f266e136FB4a3333'}, 'warnings': [], 'id': '9648a901-e116-49e9-b0c3-903d6a968c3f'}, {'estimate': {'destinationTokenAmount': '7445.923029922408763455', 'destinationTokenMinAmount': '7297.004569323960588186', 'destinationUsdAmount': 3379.04, 'destinationUsdMinAmount': 3311.46, 'destinationWeiAmount': '7445923029922408763455', 'destinationWeiMinAmount': '7297004569323960588186', 'durationInMinutes': 5, 'priceImpact': 0.04, 'slippage': 0.02}, 'fees': {'gasTokenFees': {'nativeToken': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3219.45, 'sym ...

# %%
import requests

def get_best_route(
    src_token_address,
    src_token_blockchain,
    src_token_amount,
    dst_token_address,
    dst_token_blockchain,
    referrer="rubic.exchange",
    slippage=None,
    receiver=None,
    native_blacklist=None,
):
    """
    Consulta a melhor rota para swap cross-chain usando o Rubic API.

    Parâmetros:
        src_token_address (str): Endereço do token de origem.
        src_token_blockchain (str): Blockchain de origem (ex.: "ETH").
        src_token_amount (str): Quantidade do token de origem com decimais.
        dst_token_address (str): Endereço do token de destino.
        dst_token_blockchain (str): Blockchain de destino (ex.: "POLYGON").
        referrer (str): Endereço do referenciador (padrão: "rubic.exchange").
        slippage (float, opcional): Tolerância de slippage em porcentagem (ex.: 0.02 para 2%).
        receiver (str, opcional): Endereço da carteira para envio no destino.
        native_blacklist (list, opcional): Provedores nativos a serem excluídos.

    Retorna:
        dict: Dados da melhor rota obtida do Rubic API.
    """
    url = "https://api-v2.rubic.exchange/api/routes/quoteBest"
    payload = {
        "srcTokenAddress": src_token_address,
        "srcTokenBlockchain": src_token_blockchain,
        "srcTokenAmount": src_token_amount,
        "dstTokenAddress": dst_token_address,
        "dstTokenBlockchain": dst_token_blockchain,
        "referrer": referrer,
    }

    # Adiciona campos opcionais, se fornecidos
    if slippage is not None:
        payload["slippage"] = slippage
    if receiver is not None:
        payload["receiver"] = receiver
    if native_blacklist is not None:
        payload["nativeBlacklist"] = native_blacklist

    try:
        response = requests.post(url, json=payload)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Erro ao acessar o Rubic API: {e}")
        return None

# Exemplo de uso
if __name__ == "__main__":
    src_token_address = "0x0000000000000000000000000000000000000000"  # ETH
    src_token_blockchain = "ETH"
    src_token_amount = "1.00"  # 1 ETH
    dst_token_address = "0x0000000000000000000000000000000000000000"  # MATIC
    dst_token_blockchain = "POLYGON"

    # Consulta a melhor rota disponível
    best_route = get_best_route(
        src_token_address=src_token_address,
        src_token_blockchain=src_token_blockchain,
        src_token_amount=src_token_amount,
        dst_token_address=dst_token_address,
        dst_token_blockchain=dst_token_blockchain,
        slippage=0.01,  # 1% de slippage
    )
    
    if best_route:
        print("Melhor rota obtida com sucesso:")
        print(best_route)
    else:
        print("Nenhuma rota encontrada ou erro na solicitação.")
# Out:
# Melhor rota obtida com sucesso:
# {'estimate': {'destinationTokenAmount': '7093.565038910632811006', 'destinationTokenMinAmount': '7022.629388521526482896', 'destinationUsdAmount': 3209.5, 'destinationUsdMinAmount': 3177.4, 'destinationWeiAmount': '7093565038910632811006', 'destinationWeiMinAmount': '7022629388521526482896', 'durationInMinutes': 5, 'priceImpact': 0.02, 'slippage': 0.01}, 'fees': {'gasTokenFees': {'nativeToken': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3210.08, 'symbol': 'ETH'}, 'protocol': {'fixedAmount': '0.000591519969714177', 'fixedUsdAmount': 1.9, 'fixedWeiAmount': '591519969714177'}, 'provider': {'fixedAmount': '0', 'fixedUsdAmount': 0, 'fixedWeiAmount': '0'}}, 'percentFees': {'percent': 0, 'token': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3210.08, 'symbol': 'ETH'}}}, 'providerType': 'xy', 'routing': [{'path': [{'address': '0x0000000000000000000000000000000000000000', 'amount': '1', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'symbol': 'ETH', 'price': 3210.08}, {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48', 'amount': '0', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 6, 'name': 'USD Coin', 'symbol': 'USDC', 'price': 1}], 'provider': 'XY_DEX', 'type': 'on-chain'}, {'path': [{'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48', 'amount': '0', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 6, 'name': 'USD Coin', 'symbol': 'USDC', 'price': 1}, {'address': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'amount': '0', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 6, 'name': 'USD Coin (PoS)', 'symbol': 'USDC', 'price': 1}], 'provider': 'xy', 'type': 'cross-chain'}, {'path': [{'address': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'amount': '0', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 6, 'name': 'USD Coin (PoS)', 'symbol': 'USDC', 'price': 1}, {'address': '0x0000000000000000000000000000000000000000', 'amount': '7093.565038910632811006', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 18, 'name': 'Matic Network', 'symbol': 'MATIC', 'price': 0.45}], 'provider': 'XY_DEX', 'type': 'on-chain'}], 'swapType': 'cross-chain', 'tokens': {'from': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'ETH', 'blockchainId': 1, 'decimals': 18, 'name': 'Ethereum', 'price': 3210.08, 'symbol': 'ETH'}, 'to': {'address': '0x0000000000000000000000000000000000000000', 'blockchain': 'POLYGON', 'blockchainId': 137, 'decimals': 18, 'name': 'Matic Network', 'price': 0.45, 'symbol': 'MATIC'}}, 'transaction': {'approvalAddress': '0x3335733c454805df6a77f825f266e136FB4a3333'}, 'warnings': [], 'id': '62302395-d923-4d59-aa9c-c572eafbe144'}

# %%
import requests

def get_best_route(src_token, src_blockchain, amount, dst_token, dst_blockchain):
    """
    Consulta a melhor rota para um par de tokens usando o Rubic API.

    Parâmetros:
        src_token (str): Endereço do token de origem.
        src_blockchain (str): Blockchain de origem (ex.: "ETH").
        amount (str): Quantidade do token de origem.
        dst_token (str): Endereço do token de destino.
        dst_blockchain (str): Blockchain de destino.

    Retorna:
        dict: Dados da melhor rota.
    """
    url = "https://api-v2.rubic.exchange/api/routes/quoteBest"
    payload = {
        "srcTokenAddress": src_token,
        "srcTokenBlockchain": src_blockchain,
        "srcTokenAmount": amount,
        "dstTokenAddress": dst_token,
        "dstTokenBlockchain": dst_blockchain,
        "referrer": "rubic.exchange",
    }

    try:
        response = requests.post(url, json=payload)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Erro ao consultar a melhor rota: {e}")
        return None

def triangular_arbitrage(token_a, token_b, token_c, blockchain, initial_amount):
    """
    Executa uma estratégia de arbitragem triangular com logs detalhados.

    Parâmetros:
        token_a (str): Endereço do token A.
        token_b (str): Endereço do token B.
        token_c (str): Endereço do token C.
        blockchain (str): Nome do blockchain (ex.: "POLYGON").
        initial_amount (str): Quantidade inicial do token A.

    Retorna:
        None
    """
    # Função auxiliar para conversão
    def to_human_readable(amount, decimals):
        return float(amount) / (10 ** decimals)

    

    # A -> B
    route_ab = get_best_route(token_a, blockchain, initial_amount, token_b, blockchain)
    if not route_ab:
        print("Erro na rota A → B.")
        return
    
    amount_b = route_ab["estimate"]["destinationTokenAmount"]
    

    # B -> C
    route_bc = get_best_route(token_b, blockchain, amount_b, token_c, blockchain)
    if not route_bc:
        print("Erro na rota B → C.")
        return
    
    amount_c = route_bc["estimate"]["destinationTokenAmount"]

    # C -> A
    route_ca = get_best_route(token_c, blockchain, amount_c, token_a, blockchain)
    if not route_ca:
        print("Erro na rota C → A.")
        return
    
    amount_a_final = route_ca["estimate"]["destinationTokenAmount"]
    

    # Conversão para valores legíveis
    initial_amount_float = float(initial_amount)
    amount_a_final_float = float(amount_a_final)

    # Cálculo de lucro
    profit = amount_a_final_float - initial_amount_float
    print(f"Lucro estimado: {profit:.6f} {blockchain}")
    if profit > 1:
        print("Arbitragem identificada! Execute as trocas manualmente ou integre com execução automática.")

        print(f"--- Iniciando Arbitragem Triangular ---")
        print(f"Blockchain: {blockchain}")
        print(f"Quantidade inicial de A: {initial_amount}\n")
        print(f"Consultando rota: A → B")
        print(f"{route_ab['tokens']['from']['name']} -> {route_ab['tokens']['to']['name']}")
        print(f"Quantidade obtida de B: {amount_b} (em WEI)\n")
        print(f"Consultando rota: B → C")
        print(f"{route_bc['tokens']['from']['name']} -> {route_bc['tokens']['to']['name']}")
        print(f"Quantidade obtida de A: {amount_a_final} (em WEI)\n")
        print(f"Consultando rota: C → A")
        print(f"{route_ca['tokens']['from']['name']} -> {route_ca['tokens']['to']['name']}")
        print(f"Quantidade final de A: {amount_a_final} (em WEI)\n")
        
        print(f"Quantidade inicial de A (convertida): {initial_amount_float}")
        print(f"Quantidade final de A (convertida): {amount_a_final_float}\n")

# %%
import itertools

def run_all_triangular_arbitrages(tokens, blockchain, initial_amount):
    """
    Gera todas as combinações possíveis de triangulação para os tokens fornecidos
    e executa a estratégia de arbitragem para cada combinação.

    Parâmetros:
        tokens (list): Lista de endereços de tokens.
        blockchain (str): Nome do blockchain (ex.: "POLYGON").
        initial_amount (str): Quantidade inicial para cada arbitragem.

    Retorna:
        None
    """
    # Gera todas as combinações únicas de 3 tokens
    combinations = itertools.combinations(tokens, 3)

    for token_a, token_b, token_c in combinations:
        print(f"\n--- Testando combinação: A -> {token_a}, B -> {token_b}, C -> {token_c}")
        triangular_arbitrage(token_a, token_b, token_c, blockchain, initial_amount)

while True:
    # Lista de tokens para testar
    tokens = [
        "0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270",  # WPOL
        "0x2791bca1f2de4661ed88a30c99a7a9449aa84174",  # USDC.e
        "0xc2132d05d31c914a87c6611c10748aeb04b58e8f",  # USDT
        "0x8f3cf7ad23cd3cadbd9735aff958023239c6a063",  # DAI
        "0x7ceb23fd6bc0add59e62ac25578270cff1b9f619",  # WETH
        "0xb33eaad8d922b1083446dc23f610c2567fb5180f",  # UNI
        "0x172370d5cd63279efa6d502dab29171933a610af",  # CRV
        "0xb5c064f955d8e7f38fe0460c556a72987494ee17",  # QUICK
        "0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a", # Sushi
        "0x55555555a687343c6ce28c8e1f6641dc71659fad", # XY
        "0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359", # USDC
        "0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39", # LINK
        # "0xd6df932a45c0f255f85145f286ea0b292b21c90b", # AAVE
        "0x61299774020da444af134c82fa83e3810b309991", # RNDR
        "0xc3c7d422809852031b44ab29eec9f1eff2a58756", # LDO
        "0xbbba073c31bf03b8acf7c28ef0738decf3695683", # SAND
        # "0x41b3966b4ff7b427969ddf5da3627d6aeae9a48e", # NEXO
        "0x6f7c932e7684666c9fd1d44527765433e01ff61d", # MKR
    ]

    blockchain = "POLYGON"
    initial_amount = "200"  # 1000 MATIC

    # Executa a arbitragem para todas as combinações possíveis
    run_all_triangular_arbitrages(tokens, blockchain, initial_amount)
# Out:
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f
# Lucro estimado: 0.243677 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063
# Lucro estimado: 0.437674 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# Lucro estimado: 0.502794 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.458055 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -0.885334 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.504065 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -0.578137 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -54.194082 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.440840 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: 0.092787 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.661322 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.019594 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.200041 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.499892 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063
# Lucro estimado: 0.565830 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# Lucro estimado: 0.928979 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.365325 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.010771 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.328974 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.004306 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -54.534297 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.035806 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.123213 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.639340 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.214277 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.305103 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.673762 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# Lucro estimado: -0.105519 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.298350 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.035922 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.320606 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -0.965351 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -40.232719 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.040950 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: 0.155160 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.486472 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: 0.060049 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.245253 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -0.910191 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.395475 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.004524 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.346014 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -0.928312 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -54.459812 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.145389 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.051057 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.480888 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.137664 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.160429 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -0.842500 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.327073 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.666503 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.307691 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -54.591404 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.171946 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.304486 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.863302 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.249491 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.567693 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.747058 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -1.307438 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.991859 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -54.924787 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.826871 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.961062 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.722576 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.796079 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -1.093540 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.447366 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.450202 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -54.735440 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.351850 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.538155 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.992650 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.326234 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.664596 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.725651 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -55.030488 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.548209 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -1.003088 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.550010 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.932934 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -1.259790 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.665089 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -54.537707 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -54.665304 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -54.903876 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -55.301294 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -54.780200 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -55.476775 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.094347 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.725510 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.037520 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.313726 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.406249 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.008097 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.148764 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.412249 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -0.399977 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.703645 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.999195 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.346918 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -1.255492 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.563016 POLYGON
#
# --- Testando combinação: A -> 0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, B -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.884618 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063
# Lucro estimado: 0.012384 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# Lucro estimado: -0.063749 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.665249 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.166122 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Erro ao consultar a melhor rota: 502 Server Error: Bad Gateway for url: https://api-v2.rubic.exchange/api/routes/quoteBest
# Erro na rota A → B.
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.581760 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.501022 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.031682 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.162594 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.740237 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.997105 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.237952 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.923699 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# Lucro estimado: 0.179764 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.414325 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -0.960328 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.193131 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.534041 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -79.228859 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.006385 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.035491 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.651906 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.569759 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: 0.029926 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.669601 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.248990 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -0.743671 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: 0.198443 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.312956 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.424413 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.288514 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: 0.209240 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.851900 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.677851 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: 0.332089 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.567662 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.638596 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.643385 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -2.065197 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.680770 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.246733 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.427269 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.214579 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.466371 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.712502 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.393854 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -1.186684 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -2.663000 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.854122 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.724058 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -1.169597 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.653247 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.843528 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -1.186918 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.747820 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.728339 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.555131 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.199355 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.321793 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.751562 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.123448 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.392499 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.012423 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.967504 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -1.335097 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -1.495234 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.905631 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -2.313321 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -1.509795 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.539499 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -87.391106 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -87.508649 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -87.699790 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -87.776978 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -87.564261 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -88.200894 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: 0.208455 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: 0.136351 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.300562 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: 0.174946 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.298923 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.152836 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.495365 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.442256 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.389303 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.170622 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.549289 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.211295 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.968256 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.255269 POLYGON
#
# --- Testando combinação: A -> 0x2791bca1f2de4661ed88a30c99a7a9449aa84174, B -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.876325 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619
# Lucro estimado: 0.765816 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.383643 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -0.908360 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: 0.064787 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -0.999538 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -79.211010 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 1.516520 POLYGON
# Arbitragem identificada! Execute as trocas manualmente ou integre com execução automática.
# --- Iniciando Arbitragem Triangular ---
# Blockchain: POLYGON
# Quantidade inicial de A: 200
#
# Consultando rota: A → B
# (PoS) Tether USD -> (PoS) Dai Stablecoin
# Quantidade obtida de B: 200.003355169592741443 (em WEI)
#
# Consultando rota: B → C
# (PoS) Dai Stablecoin -> USD Coin
# Quantidade obtida de A: 201.51652 (em WEI)
#
# Consultando rota: C → A
# USD Coin -> (PoS) Tether USD
# Quantidade final de A: 201.51652 (em WEI)
#
# Quantidade inicial de A (convertida): 200.0
# Quantidade final de A (convertida): 201.51652
#
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.214923 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.232163 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.044888 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.271421 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.883244 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f
# Lucro estimado: -0.707069 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.150533 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.441662 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -1.414838 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.493056 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: 0.010669 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.278392 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.707309 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.098890 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.407507 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.871683 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -1.867188 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -0.890805 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -2.131433 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -87.758279 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -0.624012 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -0.755267 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -1.320579 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.785646 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -1.128195 POLYGON
#
# --- Testando combinação: A -> 0xc2132d05d31c914a87c6611c10748aeb04b58e8f, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.556587 POLYGON
#
# ...
# Lucro estimado: -0.303929 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.290210 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.439554 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.618624 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -0.504273 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -0.400071 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.222486 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.774113 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -1.104415 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.765222 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.363898 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -0.808142 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -2.194809 POLYGON
#
# --- Testando combinação: A -> 0x8f3cf7ad23cd3cadbd9735aff958023239c6a063, B -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -1.915547 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x172370d5cd63279efa6d502dab29171933a610af
# Lucro estimado: -155.243289 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -108.224364 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -190.153941 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -199.913587 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -86.433020 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -89.605499 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -100.520764 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -114.228630 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -131.426733 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.241756 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -136.878547 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -190.311435 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -199.913724 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -134.381822 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -135.602218 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -139.400804 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -142.807509 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -151.787781 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.244502 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -190.175934 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -199.913688 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -97.220596 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -100.071895 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -108.932248 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -119.790042 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -135.380750 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.244461 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -199.914284 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -190.084547 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -190.123668 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -190.247830 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -190.304392 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -190.513853 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.244606 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# Lucro estimado: -199.923852 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -199.923957 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -199.924119 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -199.924295 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -199.924099 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x55555555a687343c6ce28c8e1f6641dc71659fad, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -199.924922 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39
# Lucro estimado: -12.239384 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -45.556527 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -92.204166 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -109.836690 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.245865 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x61299774020da444af134c82fa83e3810b309991
# Lucro estimado: -50.895365 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -92.424512 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -111.730510 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.246304 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756
# Lucro estimado: -96.474598 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -119.267521 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0x61299774020da444af134c82fa83e3810b309991, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.246927 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683
# Lucro estimado: -133.804304 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xc3c7d422809852031b44ab29eec9f1eff2a58756, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.247009 POLYGON
#
# --- Testando combinação: A -> 0x7ceb23fd6bc0add59e62ac25578270cff1b9f619, B -> 0xbbba073c31bf03b8acf7c28ef0738decf3695683, C -> 0x6f7c932e7684666c9fd1d44527765433e01ff61d
# Lucro estimado: -198.247051 POLYGON
#
# --- Testando combinação: A -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0xb5c064f955d8e7f38fe0460c556a72987494ee17
# Lucro estimado: -2.760642 POLYGON
#
# --- Testando combinação: A -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a
# Lucro estimado: -10.297778 POLYGON
#
# --- Testando combinação: A -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x55555555a687343c6ce28c8e1f6641dc71659fad
# Lucro estimado: -183.746768 POLYGON
#
# --- Testando combinação: A -> 0xb33eaad8d922b1083446dc23f610c2567fb5180f, B -> 0x172370d5cd63279efa6d502dab29171933a610af, C -> 0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 50
#      47 initial_amount = "200"  # 1000 MATIC
#      49 # Executa a arbitragem para todas as combinações possíveis
# ---> 50 run_all_triangular_arbitrages(tokens, blockchain, initial_amount)
#
# Cell In[9], line 21, in run_all_triangular_arbitrages(tokens, blockchain, initial_amount)
#      19 for token_a, token_b, token_c in combinations:
#      20     print(f"\n--- Testando combinação: A -> {token_a}, B -> {token_b}, C -> {token_c}")
# ---> 21     triangular_arbitrage(token_a, token_b, token_c, blockchain, initial_amount)
#
# Cell In[7], line 61, in triangular_arbitrage(token_a, token_b, token_c, blockchain, initial_amount)
#      58     print("Erro na rota A → B.")
#      59     return
# ---> 61 amount_b = route_ab["estimate"]["destinationTokenAmount"]
#      64 # B -> C
#      65 route_bc = get_best_route(token_b, blockchain, amount_b, token_c, blockchain)
#
# KeyError: 'estimate'

# %%
import requests

def get_best_route(src_token, src_blockchain, amount, dst_token, dst_blockchain):
    """
    Consulta a melhor rota para um par de tokens usando o Rubic API.

    Parâmetros:
        src_token (str): Endereço do token de origem.
        src_blockchain (str): Blockchain de origem (ex.: "ETH").
        amount (str): Quantidade do token de origem.
        dst_token (str): Endereço do token de destino.
        dst_blockchain (str): Blockchain de destino.

    Retorna:
        dict: Dados da melhor rota.
    """
    url = "https://api-v2.rubic.exchange/api/routes/quoteBest"
    payload = {
        "srcTokenAddress": src_token,
        "srcTokenBlockchain": src_blockchain,
        "srcTokenAmount": amount,
        "dstTokenAddress": dst_token,
        "dstTokenBlockchain": dst_blockchain,
        "referrer": "rubic.exchange",
    }

    try:
        response = requests.post(url, json=payload)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Erro ao consultar a melhor rota: {e}")
        return None

def triangular_arbitrage(token_a, token_b, blockchain, initial_amount):
    """
    Executa uma estratégia de arbitragem triangular com logs detalhados.

    Parâmetros:
        token_a (str): Endereço do token A.
        token_b (str): Endereço do token B.
        token_c (str): Endereço do token C.
        blockchain (str): Nome do blockchain (ex.: "POLYGON").
        initial_amount (str): Quantidade inicial do token A.

    Retorna:
        None
    """
    # Função auxiliar para conversão
    def to_human_readable(amount, decimals):
        return float(amount) / (10 ** decimals)

    

    # A -> B
    route_ab = get_best_route(token_a, blockchain, initial_amount, token_b, blockchain)
    if not route_ab:
        print("Erro na rota A → B.")
        return
    
    amount_b = route_ab["estimate"]["destinationTokenAmount"]
    

    # B -> C
    route_ba = get_best_route(token_b, blockchain, amount_b, token_a, blockchain)
    if not route_ba:
        print("Erro na rota B → A.")
        return
    
    amount_a_final = route_ba["estimate"]["destinationTokenAmount"]
    

    amount_a_final_float = float(amount_a_final)

    # Conversão para valores legíveis
    initial_amount_float = float(initial_amount)
    amount_a_final_float = float(amount_a_final)

    # Cálculo de lucro
    profit = amount_a_final_float - initial_amount_float
    print(f"Lucro estimado: {profit:.6f} {blockchain}")
    if profit > 1:
        print("Arbitragem identificada! Execute as trocas manualmente ou integre com execução automática.")

        print(f"--- Iniciando Arbitragem Triangular ---")
        print(f"Token A: {token_a}")
        print(f"Token B: {token_b}")
        print(f"Blockchain: {blockchain}")
        print(f"Quantidade inicial de A: {initial_amount}\n")
        print(f"Consultando rota: A → B")
        print(f"{route_ab['tokens']['from']['name']} -> {route_ab['tokens']['to']['name']}")
        print(f"Quantidade obtida de B: {amount_b} (em WEI)\n")
        print(f"Consultando rota: B → A")
        print(f"{route_ba['tokens']['from']['name']} -> {route_ba['tokens']['to']['name']}")
        print(f"Quantidade obtida de A: {amount_a_final} (em WEI)\n")
    
        
        print(f"Quantidade inicial de A (convertida): {initial_amount_float}")
        print(f"Quantidade final de A (convertida): {amount_a_final_float}\n")

# %%
import itertools

def run_all_triangular_arbitrages(tokens, blockchain, initial_amount):
    """
    Gera todas as combinações possíveis de triangulação para os tokens fornecidos
    e executa a estratégia de arbitragem para cada combinação.

    Parâmetros:
        tokens (list): Lista de endereços de tokens.
        blockchain (str): Nome do blockchain (ex.: "POLYGON").
        initial_amount (str): Quantidade inicial para cada arbitragem.

    Retorna:
        None
    """
    # Gera todas as combinações únicas de 3 tokens
    combinations = itertools.combinations(tokens, 2)

    for token_a, token_b in combinations:
        print(f"\n--- Testando combinação: A -> {token_a}, B -> {token_b}")
        triangular_arbitrage(token_a, token_b, blockchain, initial_amount)

while True:
    # Lista de tokens para testar
    tokens = [
        "0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270",  # WPOL
        "0x2791bca1f2de4661ed88a30c99a7a9449aa84174",  # USDC.e
        "0xc2132d05d31c914a87c6611c10748aeb04b58e8f",  # USDT
        "0x8f3cf7ad23cd3cadbd9735aff958023239c6a063",  # DAI
        "0x7ceb23fd6bc0add59e62ac25578270cff1b9f619",  # WETH
        "0xb33eaad8d922b1083446dc23f610c2567fb5180f",  # UNI
        "0x172370d5cd63279efa6d502dab29171933a610af",  # CRV
        "0xb5c064f955d8e7f38fe0460c556a72987494ee17",  # QUICK
        "0x0b3f868e0be5597d5db7feb59e1cadbb0fdda50a", # Sushi
        "0x55555555a687343c6ce28c8e1f6641dc71659fad", # XY
        "0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359", # USDC
        "0x53e0bca35ec356bd5dddfebbd1fc0fd03fabad39", # LINK
        # "0xd6df932a45c0f255f85145f286ea0b292b21c90b", # AAVE
        "0x61299774020da444af134c82fa83e3810b309991", # RNDR
        "0xc3c7d422809852031b44ab29eec9f1eff2a58756", # LDO
        "0xbbba073c31bf03b8acf7c28ef0738decf3695683", # SAND
        # "0x41b3966b4ff7b427969ddf5da3627d6aeae9a48e", # NEXO
        "0x6f7c932e7684666c9fd1d44527765433e01ff61d", # MKR
    ]

    blockchain = "POLYGON"
    initial_amount = "500"  # 1000 MATIC

    # Executa a arbitragem para todas as combinações possíveis
    run_all_triangular_arbitrages(tokens, blockchain, initial_amount)
