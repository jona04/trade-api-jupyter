# %%
from web3 import Web3
from abi import UNISWAP_FACTORY_ABI, UNISWAP_PAIR_ABI, ERC20_ABI
from itertools import combinations

# %%
# Configuração da rede Polygon
# polygon_rpc_url = "https://polygon-rpc.com"
# web3 = Web3(Web3.HTTPProvider(polygon_rpc_url))

polygon_rpc_url = "https://polygon-mainnet.infura.io/v3/079d35a3c196469191c9accc1d68d25b"
web3 = Web3(Web3.HTTPProvider(polygon_rpc_url))

# Verificando conexão
if not web3.provider.is_connected():
    raise ConnectionError("Falha ao conectar à rede Polygon")

print("Conectado à rede Polygon")

# Endereços das fábricas das DEXs
DEX_FACTORIES = {
    "QuickSwap": web3.to_checksum_address("0x5757371414417b8c6caad45baef941abc7d3ab32"),
    "SushiSwap": web3.to_checksum_address("0xc35dadb65012ec5796536bd9864ed8773abc74c4")
}

# Exemplo de uso do endereço checksum
print("Endereços no formato checksum:")
for name, address in DEX_FACTORIES.items():
    print(f"{name}: {address}")
# Out:
# Conectado à rede Polygon
# Endereços no formato checksum:
# QuickSwap: 0x5757371414417b8C6CAad45bAeF941aBc7d3Ab32
# SushiSwap: 0xc35DADB65012eC5796536bD9864eD8773aBc74C4

# %%
# Função para obter reservas da QuickSwap
def get_token_reserves(factory_address, token_a, token_b):
    try:
        factory = web3.eth.contract(address=factory_address, abi=UNISWAP_FACTORY_ABI)
        pair_address = factory.functions.getPair(token_a, token_b).call()

        if pair_address == "0x0000000000000000000000000000000000000000":
            print(f"Par inexistente para {token_a} e {token_b}.")
            return None
    
        pair = web3.eth.contract(address=pair_address, abi=UNISWAP_PAIR_ABI)
        reserves = pair.functions.getReserves().call()
    
        token0 = pair.functions.token0().call()
        token1 = pair.functions.token1().call()
    
        decimals_token0 = get_decimals(token0)
        decimals_token1 = get_decimals(token1)
    
        if token0.lower() == token_a.lower():
            return (reserves[0] / (10 ** decimals_token0), reserves[1] / (10 ** decimals_token1))
        else:
            return (reserves[1] / (10 ** decimals_token1), reserves[0] / (10 ** decimals_token0))
    except Exception as e:
        print(f"Erro ao consultar o par: {e}")
        return None


# Função para consultar preços na API do SushiSwap
def get_sushi_prices():
    url = "https://api.sushi.com/price/v1/137"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception("Falha ao obter preços da API do SushiSwap.")

# Função para calcular arbitragem com logs detalhados
def calculate_arbitrage(factory_quick, token_a, token_b, investment, fee=0.003):
    # Obter reservas da QuickSwap
    reserves_quick = get_token_reserves(factory_quick, token_a, token_b)
    if not reserves_quick:
        return "Reservas não encontradas para QuickSwap."

    # Obter preços da SushiSwap
    sushi_prices = get_sushi_prices()
    price_a_sushi = sushi_prices.get(token_a)
    price_b_sushi = sushi_prices.get(token_b)

    if not price_a_sushi or not price_b_sushi:
        return "Preços não encontrados para SushiSwap."

    # Calcular razões de preço
    price_ratio_quick = reserves_quick[1] / reserves_quick[0]  # TOKEN_B / TOKEN_A
    price_ratio_sushi = price_a_sushi / price_b_sushi          # TOKEN_A / TOKEN_B

    # Logs informativos
    print(f"\n[INFO] Reservas na QuickSwap: {reserves_quick[0]:.6f} TOKEN_A, {reserves_quick[1]:.6f} TOKEN_B")
    print(f"[INFO] Preços na SushiSwap: {price_a_sushi:.6f} USD/TOKEN_A, {price_b_sushi:.6f} USD/TOKEN_B")
    print(f"[INFO] Razão QuickSwap: {price_ratio_quick:.6f} TOKEN_B/TOKEN_A")
    print(f"[INFO] Razão SushiSwap: {price_ratio_sushi:.6f} TOKEN_B/TOKEN_A")

    # Simulação de swaps
    if price_ratio_sushi > price_ratio_quick:
        # Compre na QuickSwap e venda na SushiSwap
        token_a_received = (investment / price_ratio_quick) * (1 - fee)  # TOKEN_A recebido na QuickSwap
        token_b_received = token_a_received * price_ratio_sushi * (1 - fee)  # TOKEN_B recebido na SushiSwap

        
        print(f"\n[SWAP] Compre na QuickSwap: {investment:.2f} TOKEN_B → {token_a_received:.6f} TOKEN_A")
        print(f"[SWAP] Venda na SushiSwap: {token_a_received:.6f} TOKEN_A → {token_b_received:.2f} TOKEN_B")

        profit = token_b_received - investment
        return f"[RESULTADO] Arbitragem: Lucro de {profit:.2f} TOKEN_B."
    elif price_ratio_quick > price_ratio_sushi:
        # Compre na SushiSwap e venda na QuickSwap
        token_a_received = (investment / price_ratio_sushi) * (1 - fee)  # TOKEN_A recebido na SushiSwap
        token_b_received = token_a_received * price_ratio_quick * (1 - fee)  # TOKEN_B recebido na QuickSwap

        print(f"\n[SWAP] Compre na SushiSwap: {investment:.2f} TOKEN_B → {token_a_received:.6f} TOKEN_A")
        print(f"[SWAP] Venda na QuickSwap: {token_a_received:.6f} TOKEN_A → {token_b_received:.2f} TOKEN_B")

        profit = token_b_received - investment
        return f"[RESULTADO] Arbitragem: Lucro de {profit:.2f} TOKEN_B."
    else:
        return "[RESULTADO] Sem oportunidade de arbitragem."

# %%
# Endereços e exemplo de uso
factory_quick = web3.to_checksum_address("0x5757371414417b8c6caad45baef941abc7d3ab32")  # QuickSwap
factory_uniswap = web3.to_checksum_address("0x1F98431c8aD98523631AE4a59f267346ea31F984")  # UniSwap

# %%
# token_avee = web3.to_checksum_address("0xD6DF932A45C0f255f85145f286eA0b292B21C90B")  # Aave
# token_usdc = web3.to_checksum_address("0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174")  # USDC

# token_weth = web3.to_checksum_address("0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619")

# token_wbtc = web3.to_checksum_address("0x1BFD67037B42Cf73acF2047067bd4F2C47D9BfD6")
# token_wmatic = web3.to_checksum_address("0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270")
# token_link = web3.to_checksum_address("0x53E0bca35eC356BD5ddDFebbD1Fc0fD03FaBad39")
# token_bet = web3.to_checksum_address("0xbF7970D56a150cD0b60BD08388A4A75a27777777")
# token_ldo = web3.to_checksum_address("0xC3C7d422809852031b44ab29EEC9F1EfF2A58756")
# token_falcon = web3.to_checksum_address("0x45b0bF770edAd9b3A8Aaa015B47a1f46a7cF956F")


# investment = 1000  # Investimento em USDC

# # Calcular arbitragem
# result = calculate_arbitrage(factory_uni, token_avee, token_usdc, investment)
# print(result)

# %%
from itertools import product

# Lista de tokens
tokens = [
    {"symbol": "AAVE", "address": web3.to_checksum_address("0xD6DF932A45C0f255f85145f286eA0b292B21C90B")},
    {"symbol": "WETH", "address": web3.to_checksum_address("0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619")},
    {"symbol": "WBTC", "address": web3.to_checksum_address("0x1BFD67037B42Cf73acF2047067bd4F2C47D9BfD6")},
    {"symbol": "WMATIC", "address": web3.to_checksum_address("0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270")},
    {"symbol": "LINK", "address": web3.to_checksum_address("0x53E0bca35eC356BD5ddDFebbD1Fc0fD03FaBad39")},
    {"symbol": "BET", "address": web3.to_checksum_address("0xbF7970D56a150cD0b60BD08388A4A75a27777777")},
    {"symbol": "LDO", "address": web3.to_checksum_address("0xC3C7d422809852031b44ab29EEC9F1EfF2A58756")},
    # {"symbol": "FALCON", "address": web3.to_checksum_address("0x45b0bF770edAd9b3A8Aaa015B47a1f46a7cF956F")},
]

# USDC token
token_usdc = {"symbol": "USDC", "address": web3.to_checksum_address("0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174")}

# Gerar combinações com USDC
pairs = [(token_usdc, token) for token in tokens]

investment = 1000  # Investimento em USDC


# Loop para testar arbitragem com todas as combinações
for pair in pairs:
    token_a = pair[0]
    token_b = pair[1]
    
    print(f"\n[TESTE] Arbitragem entre {token_a['symbol']} e {token_b['symbol']}")
    result = calculate_arbitrage(factory_quick, token_b["address"], token_a["address"], investment)
    print(result)
# Out:
# [TESTE] Arbitragem entre USDC e AAVE
# <web3._utils.datatypes.Contract object at 0x7f6f9aaf9580> 0x7c76B6B3FE14831A39C0fec908DA5f17180df677
#
# [INFO] Reservas na QuickSwap: 4.634022 TOKEN_A, 1353.979801 TOKEN_B
# [INFO] Preços na SushiSwap: 292.922239 USD/TOKEN_A, 1.000486 USD/TOKEN_B
# [INFO] Razão QuickSwap: 292.182451 TOKEN_B/TOKEN_A
# [INFO] Razão SushiSwap: 292.779999 TOKEN_B/TOKEN_A
#
# [SWAP] Compre na QuickSwap: 1000.00 TOKEN_B → 3.412251 TOKEN_A
# [SWAP] Venda na SushiSwap: 3.412251 TOKEN_A → 996.04 TOKEN_B
# [RESULTADO] Arbitragem: Lucro de -3.96 TOKEN_B.
#
# [TESTE] Arbitragem entre USDC e WETH
# <web3._utils.datatypes.Contract object at 0x7f6f9b76b740> 0x853Ee4b2A13f8a742d64C8F088bE7bA2131f670d
#
# [INFO] Reservas na QuickSwap: 380.511963 TOKEN_A, 1225306.506511 TOKEN_B
# [INFO] Preços na SushiSwap: 3220.576761 USD/TOKEN_A, 1.000491 USD/TOKEN_B
# [INFO] Razão QuickSwap: 3220.152385 TOKEN_B/TOKEN_A
# [INFO] Razão SushiSwap: 3218.996168 TOKEN_B/TOKEN_A
#
# [SWAP] Compre na SushiSwap: 1000.00 TOKEN_B → 0.309724 TOKEN_A
# [SWAP] Venda na QuickSwap: 0.309724 TOKEN_A → 994.37 TOKEN_B
# [RESULTADO] Arbitragem: Lucro de -5.63 TOKEN_B.
#
# [TESTE] Arbitragem entre USDC e WBTC
# <web3._utils.datatypes.Contract object at 0x7f6f9af306e0> 0xF6a637525402643B0654a54bEAd2Cb9A83C8B498
#
# [INFO] Reservas na QuickSwap: 1.864827 TOKEN_A, 179833.446306 TOKEN_B
# [INFO] Preços na SushiSwap: 96397.572671 USD/TOKEN_A, 1.000475 USD/TOKEN_B
# [INFO] Razão QuickSwap: 96434.399729 TOKEN_B/TOKEN_A
# [INFO] Razão SushiSwap: 96351.809957 TOKEN_B/TOKEN_A
#
# [SWAP] Compre na SushiSwap: 1000.00 TOKEN_B → 0.010347 TOKEN_A
# [SWAP] Venda na QuickSwap: 0.010347 TOKEN_A → 994.86 TOKEN_B
# [RESULTADO] Arbitragem: Lucro de -5.14 TOKEN_B.
#
# [TESTE] Arbitragem entre USDC e WMATIC
# <web3._utils.datatypes.Contract object at 0x7f6fb51a5880> 0x6e7a5FAFcec6BB1e78bAE2A1F0B612012BF14827
#
# [INFO] Reservas na QuickSwap: 1215837.124114 TOKEN_A, 552885.246349 TOKEN_B
# [INFO] Preços na SushiSwap: 0.454865 USD/TOKEN_A, 1.000475 USD/TOKEN_B
# [INFO] Razão QuickSwap: 0.454736 TOKEN_B/TOKEN_A
# [INFO] Razão SushiSwap: 0.454649 TOKEN_B/TOKEN_A
#
# [SWAP] Compre na SushiSwap: 1000.00 TOKEN_B → 2192.900772 TOKEN_A
# [SWAP] Venda na QuickSwap: 2192.900772 TOKEN_A → 994.20 TOKEN_B
# [RESULTADO] Arbitragem: Lucro de -5.80 TOKEN_B.
#
# [TESTE] Arbitragem entre USDC e LINK
# <web3._utils.datatypes.Contract object at 0x7f6f9ab4eba0> 0x70ceE55c98F6DA2685807611f115eA737d4a248E
#
# [INFO] Reservas na QuickSwap: 1.883662 TOKEN_A, 37.829768 TOKEN_B
# [INFO] Preços na SushiSwap: 20.286691 USD/TOKEN_A, 1.000487 USD/TOKEN_B
# [INFO] Razão QuickSwap: 20.083097 TOKEN_B/TOKEN_A
# [INFO] Razão SushiSwap: 20.276811 TOKEN_B/TOKEN_A
#
# [SWAP] Compre na QuickSwap: 1000.00 TOKEN_B → 49.643738 TOKEN_A
# [SWAP] Venda na SushiSwap: 49.643738 TOKEN_A → 1003.60 TOKEN_B
# [RESULTADO] Arbitragem: Lucro de 3.60 TOKEN_B.
#
# [TESTE] Arbitragem entre USDC e BET
# <web3._utils.datatypes.Contract object at 0x7f6fb437fd40> 0x0000000000000000000000000000000000000000
# Par inexistente para 0xbF7970D56a150cD0b60BD08388A4A75a27777777 e 0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174.
# Reservas não encontradas para QuickSwap.
#
# [TESTE] Arbitragem entre USDC e LDO
# <web3._utils.datatypes.Contract object at 0x7f6fb437fd40> 0x4F2774ce0C8650bf9c2D187b7337D572FCea427C
#
# [INFO] Reservas na QuickSwap: 0.047336 TOKEN_A, 0.077483 TOKEN_B
# [INFO] Preços na SushiSwap: 1.797553 USD/TOKEN_A, 1.000486 USD/TOKEN_B
# [INFO] Razão QuickSwap: 1.636886 TOKEN_B/TOKEN_A
# [INFO] Razão SushiSwap: 1.796681 TOKEN_B/TOKEN_A
#
# [SWAP] Compre na QuickSwap: 1000.00 TOKEN_B → 609.083200 TOKEN_A
# [SWAP] Venda na SushiSwap: 609.083200 TOKEN_A → 1091.04 TOKEN_B
# [RESULTADO] Arbitragem: Lucro de 91.04 TOKEN_B.

# %%
def sort_tokens(token_a, token_b):
    if token_a.lower() > token_b.lower():
        return token_b, token_a
    return token_a, token_b


import hashlib



# Loop para testar arbitragem com todas as combinações
for pair in pairs:
    token_a = pair[0]
    token_b = pair[1]
    
    print(f"\n[TESTE] Arbitragem entre {token_a['symbol']} e {token_b['symbol']}")
    print(result)

    factory = web3.eth.contract(address=factory_uniswap, abi=UNISWAP_FACTORY_ABI)
    
    # Ordenar tokens conforme a lógica do contrato
    token_a, token_b = sort_tokens(token_a["address"], token_b["address"])

    pair_address = factory.functions.getPair(token_b, token_a).call()
# Out:
# [TESTE] Arbitragem entre USDC e AAVE
# [RESULTADO] Arbitragem: Lucro de 91.04 TOKEN_B.
# ---------------------------------------------------------------------------
# ContractLogicError                        Traceback (most recent call last)
# Cell In[73], line 24
#      21 # Ordenar tokens conforme a lógica do contrato
#      22 token_a, token_b = sort_tokens(token_a["address"], token_b["address"])
# ---> 24 pair_address = factory.functions.getPair(token_b, token_a).call()
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/contract/contract.py:404, in ContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     400 block_id = parse_block_identifier(self.w3, block_identifier)
#     402 abi_element_identifier = abi_to_signature(self.abi)
# --> 404 return call_contract_function(
#     405     self.w3,
#     406     self.address,
#     407     self._return_data_normalizers,
#     408     abi_element_identifier,
#     409     call_transaction,
#     410     block_id,
#     411     self.contract_abi,
#     412     self.abi,
#     413     state_override,
#     414     ccip_read_enabled,
#     415     self.decode_tuples,
#     416     *self.args or (),
#     417     **self.kwargs or {},
#     418 )
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/contract/utils.py:154, in call_contract_function(w3, address, normalizers, abi_element_identifier, transaction, block_id, contract_abi, abi_callable, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#     139 """
#     140 Helper function for interacting with a contract function using the
#     141 `eth_call` API.
#     142 """
#     143 call_transaction = prepare_transaction(
#     144     address,
#     145     w3,
#    (...)
#     151     fn_kwargs=kwargs,
#     152 )
# --> 154 return_data = w3.eth.call(
#     155     call_transaction,
#     156     block_identifier=block_id,
#     157     state_override=state_override,
#     158     ccip_read_enabled=ccip_read_enabled,
#     159 )
#     161 if abi_callable is None:
#     162     abi_callable = cast(
#     163         ABIFunction,
#     164         get_abi_element(
#    (...)
#     170         ),
#     171     )
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/eth/eth.py:244, in Eth.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     234 ccip_read_enabled_on_provider = self.w3.provider.global_ccip_read_enabled
#     235 if (
#     236     # default conditions:
#     237     ccip_read_enabled_on_provider
#    (...)
#     242     and ccip_read_enabled is True
#     243 ):
# --> 244     return self._durin_call(transaction, block_identifier, state_override)
#     246 return self._call(transaction, block_identifier, state_override)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/eth/eth.py:263, in Eth._durin_call(self, transaction, block_identifier, state_override)
#     261 for _ in range(max_redirects):
#     262     try:
# --> 263         return self._call(transaction, block_identifier, state_override)
#     264     except OffchainLookup as offchain_lookup:
#     265         durin_calldata = handle_offchain_lookup(
#     266             offchain_lookup.payload,
#     267             transaction,
#     268         )
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/module.py:111, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#     104     return LogFilter(eth_module=module, filter_id=err.filter_id)
#     106 (
#     107     result_formatters,
#     108     error_formatters,
#     109     null_result_formatters,
#     110 ) = response_formatters
# --> 111 result = w3.manager.request_blocking(
#     112     method_str, params, error_formatters, null_result_formatters
#     113 )
#     114 return apply_result_formatters(result_formatters, result)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/manager.py:401, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     397 """
#     398 Make a synchronous request using the provider
#     399 """
#     400 response = self._make_request(method, params)
# --> 401 return self.formatted_response(
#     402     response, params, error_formatters, null_result_formatters
#     403 )
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/manager.py:367, in RequestManager.formatted_response(self, response, params, error_formatters, null_result_formatters)
#     353 def formatted_response(
#     354     self,
#     355     response: RPCResponse,
#    (...)
#     358     null_result_formatters: Optional[Callable[..., Any]] = None,
#     359 ) -> Any:
#     360     is_subscription_response = (
#     361         response.get("method") == "eth_subscription"
#     362         and response.get("params") is not None
#     363         and response["params"].get("subscription") is not None
#     364         and response["params"].get("result") is not None
#     365     )
# --> 367     _validate_response(
#     368         response,
#     369         error_formatters,
#     370         is_subscription_response=is_subscription_response,
#     371         logger=self.logger,
#     372         params=params,
#     373     )
#     375     # format results
#     376     if "result" in response:
#     377         # Null values for result should apply null_result_formatters
#     378         # Skip when result not present in the response (fallback to False)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/manager.py:257, in _validate_response(response, error_formatters, is_subscription_response, logger, params)
#     253 if web3_rpc_error is None:
#     254     # if no condition was met above, raise a more generic `Web3RPCError`
#     255     web3_rpc_error = Web3RPCError(repr(error), rpc_response=response)
# --> 257 response = apply_error_formatters(error_formatters, response)
#     259 logger.error(web3_rpc_error.user_message)
#     260 logger.debug(f"RPC error response: {response}")
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/manager.py:122, in apply_error_formatters(error_formatters, response)
#     117 def apply_error_formatters(
#     118     error_formatters: Callable[..., Any],
#     119     response: RPCResponse,
#     120 ) -> RPCResponse:
#     121     if error_formatters:
# --> 122         formatted_resp = pipe(response, error_formatters)
#     123         return formatted_resp
#     124     else:
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/cytoolz/functoolz.pyx:685, in cytoolz.functoolz.pipe()
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/cytoolz/functoolz.pyx:660, in cytoolz.functoolz.c_pipe()
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/web3/_utils/error_formatters_utils.py:168, in raise_contract_logic_error_on_revert(response)
#     166     # Geth Revert without error message case:
#     167     elif "execution reverted" in message:
# --> 168         raise ContractLogicError("execution reverted", data=data)
#     170 return response
#
# ContractLogicError: ('execution reverted', 'no data')
