# %%
import os
from dotenv import load_dotenv
load_dotenv("../../constants/.env")
# Out:
# True

# %% [markdown]
# # Trading with Python and Binance - Introduction to the API

# %% [markdown]
# __Insert your Credentials here__:

# %%
api_key = os.environ.get('BINANCE_KEY')
secret_key = os.environ.get('BINANCE_SECRET')

# %% [markdown]
# ## Installing required Libraries/Packages

# %% [markdown]
# For most Sections of this course, you should have installed:
# - Updated Anaconda Installation with Python Version 3.10 or higher
# - lastest python-binance Version (1.0.19 or higher)

# %% [markdown]
# ***Action required***:

# %% [markdown]
# __1. If you haven´t updated Anaconda for a while, update with the command:__

# %% [markdown]
# conda update anaconda

# %% [markdown]
# __2a. Install python-binance__

# %% [markdown]
# pip install python-binance

# %% [markdown]
# __2b. In case you have installed python-binance a while ago, make sure you have the latest version installed:__

# %% [markdown]
# pip install python-binance --upgrade

# %% [markdown]
# ## Creating a Connection

# %%
from binance.client import Client

# %% [markdown]
# If you have an account on __Binance.com__ (non-US users)

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
client

# %%
client.get_account() # account details
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00100000',
#   'taker': '0.00100000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1729790306845,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '76.11045422', 'locked': '0.00000000'},
#   {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADA', 'free': '0.00345000', 'locked': '0.00000000'},
#   {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOCK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MATIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TOMO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HBAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MXN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRL', 'free': '0.00703106', 'locked': '0.00000000'},
#   {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CZK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RON', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JPY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVE', 'free': '0.03332431', 'locked': '0.00000000'},
#   {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CKB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DODO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUCTION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLOW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LAZIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASTR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CITY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BDOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#   {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WOO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPINE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'T', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BSW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MULTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEXO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLYX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OSMO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOOK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MAGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LQTY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ID', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEPE', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'FLOKI', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'COMBO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NTRN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FDUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PENDLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARKM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CYBER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SEI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AEUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORDI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MEME', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VANRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1000SATS', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'TON', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BONK', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'AXL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'METIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RONIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AEVO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOME', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ENA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'W', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAGA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TAO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMNI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NOT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'LISTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'G', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BANANA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENDER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGS', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'EURI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNSOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUMIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HMSTR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CATI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEIRO', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'TURBO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1MBABYDOGE', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'EIGEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCR', 'free': '0.00000000', 'locked': '0.00000000'}],
#  'permissions': ['TRD_GRP_066'],
#  'uid': 426735495}

# %% [markdown]
# If you have an account on __Binance.US__ (US residents) <br>
# (If you are using an exchange from the US, Japan or other TLD then make sure pass tld=’us’ when creating the client.)

# %%
# client = Client(api_key = api_key, api_secret = secret_key, tld = "us")

# %%
# client.get_account()  # account details

# %% [markdown]
# ## General account/system Info

# %% [markdown]
# __Official API Documentation Site:__

# %% [markdown]
# https://binance-docs.github.io/apidocs/spot/en/#introduction

# %% [markdown]
# __API Wrapper (python-binance) Documentation Site:__

# %% [markdown]
# https://python-binance.readthedocs.io/en/latest/index.html

# %%
import pandas as pd
from binance.client import Client

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
client.ping() # Test connectivity
# Out:
# {}

# %%
client.get_system_status()
# Out:
# {'status': 0, 'msg': 'normal'}

# %%
account = client.get_account()
account
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00100000',
#   'taker': '0.00100000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1729169906267,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.03036500', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '5.73957972', 'locked': '0.00000000'},
#   {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOCK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MATIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TOMO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HBAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MXN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRL', 'free': '0.00703106', 'locked': '0.00000000'},
#   {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CZK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RON', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JPY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CKB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DODO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUCTION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLOW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LAZIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASTR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CITY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BDOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#   {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WOO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPINE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'T', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BSW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MULTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEXO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLYX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OSMO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOOK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MAGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LQTY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ID', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEPE', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'FLOKI', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'COMBO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NTRN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FDUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PENDLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARKM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CYBER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SEI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AEUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORDI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MEME', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VANRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1000SATS', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'TON', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BONK', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'AXL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'METIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RONIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AEVO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOME', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ENA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'W', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAGA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TAO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMNI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NOT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'LISTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'G', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BANANA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENDER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGS', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'EURI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNSOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUMIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HMSTR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CATI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEIRO', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'TURBO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1MBABYDOGE', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'EIGEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCR', 'free': '0.00000000', 'locked': '0.00000000'}],
#  'permissions': ['TRD_GRP_066'],
#  'uid': 426735495}

# %%
account["accountType"] # account Type (Spot, Futures)
# Out:
# 'SPOT'

# %%
pd.to_datetime(account["updateTime"], unit = "ms") # Last Update -> UTC Time
# Out:
# Timestamp('2024-10-17 12:58:26.267000')

# %%
account["balances"] # asset balances
# Out:
# [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETH', 'free': '0.03036500', 'locked': '0.00000000'},
#  {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDT', 'free': '5.73957972', 'locked': '0.00000000'},
#  {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MANA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XEM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KEY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOCK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CELR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MATIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATOM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TOMO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HBAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MXN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BRL', 'free': '0.00703106', 'locked': '0.00000000'},
#  {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PLN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CZK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RON', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JPY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CKB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DODO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUCTION', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLOW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BETA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LAZIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ASTR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CITY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BDOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#  {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XNO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WOO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALPINE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'T', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NBT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'APE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GMT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BSW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MULTI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEXO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EPX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LDO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUNC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LEVER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POLYX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'APT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OSMO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HOOK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MAGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RPL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SYN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LQTY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ID', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RDNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EDU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WBETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PEPE', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'FLOKI', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'COMBO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NTRN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MAV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FDUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PENDLE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARKM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CYBER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SEI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AEUR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ORDI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MEME', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEAMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BLUR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VANRY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1000SATS', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'TON', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BONK', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'AXL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NFP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MANTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'METIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RONIN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PYTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DYM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PIXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PORTAL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WIF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AEVO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOME', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'ENA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'W', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SAGA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TAO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OMNI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NOT', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'LISTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'G', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BANANA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RENDER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SLF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOGS', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'EURI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNSOL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUMIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HMSTR', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'CATI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEIRO', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'TURBO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1MBABYDOGE', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'EIGEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SCR', 'free': '0.00000000', 'locked': '0.00000000'}]

# %%
df = pd.DataFrame(account["balances"])
df
# Out:
#           asset        free      locked
# 0           BTC  0.00000000  0.00000000
# 1           LTC  0.00000000  0.00000000
# 2           ETH  0.03036500  0.00000000
# 3           NEO  0.00000000  0.00000000
# 4           BNB  0.00000000  0.00000000
# ..          ...         ...         ...
# 609       NEIRO        0.00        0.00
# 610       TURBO  0.00000000  0.00000000
# 611  1MBABYDOGE        0.00        0.00
# 612       EIGEN  0.00000000  0.00000000
# 613         SCR  0.00000000  0.00000000
#
# [614 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   asset   614 non-null    object
#  1   free    614 non-null    object
#  2   locked  614 non-null    object
# dtypes: object(3)
# memory usage: 14.5+ KB

# %%
df.free = pd.to_numeric(df.free, errors="coerce")
df.locked = pd.to_numeric(df.locked, errors="coerce")

# %%
df.loc[df.free > 0]
# Out:
#     asset      free  locked
# 2     ETH  0.030365     0.0
# 11   USDT  5.739580     0.0
# 210   BRL  0.007031     0.0

# %%
client.get_asset_balance(asset = "BTC")
# Out:
# {'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'}

# %%
client.get_asset_balance(asset = "ETH")
# Out:
# {'asset': 'ETH', 'free': '0.03036500', 'locked': '0.00000000'}

# %%
float(client.get_asset_balance(asset="EUR")["free"])
# Out:
# 0.0

# %%
snap = client.get_account_snapshot(type = "SPOT") # daily account snapshot
snap
# Out:
# {'code': 200,
#  'msg': '',
#  'snapshotVos': [{'type': 'spot',
#    'updateTime': 1728691199000,
#    'data': {'totalAssetOfBtc': '0.00127038',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1728777599000,
#    'data': {'totalAssetOfBtc': '0.00127624',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1728863999000,
#    'data': {'totalAssetOfBtc': '0.00127852',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1728950399000,
#    'data': {'totalAssetOfBtc': '0.00129611',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1729036799000,
#    'data': {'totalAssetOfBtc': '0.00126615',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1729123199000,
#    'data': {'totalAssetOfBtc': '0.00125768',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1729209599000,
#    'data': {'totalAssetOfBtc': '0.00125844',
#     'balances': [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.030365', 'locked': '0'},
#      {'asset': 'USDT', 'free': '5.73957972', 'locked': '0'}]}}]}

# %%
snap = pd.json_normalize(snap["snapshotVos"])
snap
# Out:
#    type     updateTime data.totalAssetOfBtc  \
# 0  spot  1728691199000           0.00127038
# 1  spot  1728777599000           0.00127624
# 2  spot  1728863999000           0.00127852
# 3  spot  1728950399000           0.00129611
# 4  spot  1729036799000           0.00126615
# 5  spot  1729123199000           0.00125768
# 6  spot  1729209599000           0.00125844
#
#                                        data.balances
# 0  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 1  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 2  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 3  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 4  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 5  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 6  [{'asset': 'BRL', 'free': '0.00703106', 'locke...

# %%
snap.updateTime = pd.to_datetime(snap["updateTime"], unit = "ms")

# %%
snap
# Out:
#    type          updateTime data.totalAssetOfBtc  \
# 0  spot 2024-10-11 23:59:59           0.00127038
# 1  spot 2024-10-12 23:59:59           0.00127624
# 2  spot 2024-10-13 23:59:59           0.00127852
# 3  spot 2024-10-14 23:59:59           0.00129611
# 4  spot 2024-10-15 23:59:59           0.00126615
# 5  spot 2024-10-16 23:59:59           0.00125768
# 6  spot 2024-10-17 23:59:59           0.00125844
#
#                                        data.balances
# 0  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 1  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 2  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 3  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 4  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 5  [{'asset': 'BRL', 'free': '0.00703106', 'locke...
# 6  [{'asset': 'BRL', 'free': '0.00703106', 'locke...

# %%
snap["data.balances"][0]
# Out:
# [{'asset': 'BRL', 'free': '0.00703106', 'locked': '0'},
#  {'asset': 'ETH', 'free': '0.032565', 'locked': '0'}]

# %%
client.get_exchange_info()["rateLimits"] # API Limits
# Out:
# [{'rateLimitType': 'REQUEST_WEIGHT',
#   'interval': 'MINUTE',
#   'intervalNum': 1,
#   'limit': 6000},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'SECOND',
#   'intervalNum': 10,
#   'limit': 100},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'DAY',
#   'intervalNum': 1,
#   'limit': 200000},
#  {'rateLimitType': 'RAW_REQUESTS',
#   'interval': 'MINUTE',
#   'intervalNum': 5,
#   'limit': 61000}]

# %%
client.get_all_coins_info() # asset/coin Info
# Out:
# [{'coin': 'AGLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Adventure Gold',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AGLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '5.39',
#     'withdrawMin': '10',
#     'withdrawMax': '9999999',
#     'depositDust': '0.0012',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x32353a6c91143bfd6c7d363b546e62a9a2489a20'}]},
#  {'coin': 'MXN',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Mexican Peso',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': True,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'MXN',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 1,
#     'busy': False}]},
#  {'coin': 'STPT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Standard Tokenization Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'STPT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '134',
#     'withdrawMin': '268',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.023',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xde7d85157d9714eadf595045cc12ca4a5f3e2adb'}]},
#  {'coin': 'SCR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Scroll',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'SCROLL',
#     'coin': 'SCR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': 'SCR deposit address is now available for claim. Please note that deposit services of SCR will be available at 2024-10-21 10:00 (UTC).',
#     'specialWithdrawTips': '',
#     'name': 'Scroll',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00000001',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False,
#     'contractAddressUrl': 'https://scrollscan.com/token/',
#     'contractAddress': '0xd29687c813d741e2f938f4ac377128810e217b1b'}]},
#  {'coin': 'MATICUSDCE',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bridged USDC',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'MATIC',
#     'coin': 'MATICUSDCE',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please note that this is the non-native bridged USDC in Polygon network. Please verify the contract address before depositing.',
#     'specialWithdrawTips': 'Please note that this is the non-native bridged USDC in Polygon network. Please verify the contract address before withdrawing.',
#     'name': 'Polygon POS',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.055',
#     'withdrawMin': '0.11',
#     'withdrawMax': '100000000',
#     'depositDust': '0.001',
#     'minConfirm': 200,
#     'unLockConfirm': 300,
#     'sameAddress': False,
#     'estimatedArrivalTime': 8,
#     'busy': False,
#     'contractAddressUrl': 'https://polygonscan.com/token/',
#     'contractAddress': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174'}]},
#  {'coin': 'UGX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Uganda Shilling',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'UGX',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 1,
#     'busy': False}]},
#  {'coin': 'GLM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Golem',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GLM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '18',
#     'withdrawMin': '36',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.003',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x7dd9c5cba05e151c895fde1cf355c9a1d5da6429'}]},
#  {'coin': 'RAY',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Raydium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'SOL',
#     'coin': 'RAY',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The Solana blockchain will retain 0.00203928 SOL for your first token deposit. No fees will be charged by Binance for subsequent deposits.',
#     'specialWithdrawTips': '',
#     'name': 'Solana',
#     'resetAddressStatus': False,
#     'addressRegex': '^[1-9A-HJ-NP-Za-km-z]{32,44}$',
#     'memoRegex': '',
#     'withdrawFee': '0.7',
#     'withdrawMin': '1.4',
#     'withdrawMax': '9999999',
#     'depositDust': '0.0005',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.solana.com/address/',
#     'contractAddress': '4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'}]},
#  {'coin': 'NEAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'NEAR Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.13',
#     'withdrawMin': '0.26',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.00016',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0x1fa4a73a3f0133f0025378af00236f3abdee5d63'},
#    {'network': 'NEAR',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'CAUTION: Ensure the recipient address has been activated; otherwise, your withdrawal will fail.',
#     'name': 'NEAR Protocol',
#     'resetAddressStatus': False,
#     'addressRegex': '^(?!0x)(?!bc1)(?!bnb1)[a-z0-9_-]{1}[a-z0-9_.-]{0,62}[a-z0-9_-]{1}$',
#     'memoRegex': '',
#     'withdrawFee': '0.018',
#     'withdrawMin': '0.6',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.0001',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://nearblocks.io/token/'},
#    {'network': 'BNB',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': 'Both a memo/tag and an address are required to successfully deposit your assets to Binance.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.063',
#     'withdrawMin': '0.13',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.00016',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.bnbchain.org/asset/',
#     'contractAddress': 'NEAR-4FD'}]},
#  {'coin': 'AUDIO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Audius',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AUDIO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '49',
#     'withdrawMin': '98',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.007',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x18aaa7115705e8be94bffebde57af9bfc265b998'}]},
#  {'coin': 'WLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Worldcoin',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'WLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please note that WLD deposits via World Chain network are NOT supported and unretrievable at the moment. Please only deposit via supported networks.',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '2.82',
#     'withdrawMin': '5.64',
#     'withdrawMax': '9999999',
#     'depositDust': '0.0003',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x163f8c2467924be0ae7b5347228cabf260318753'},
#    {'network': 'OPTIMISM',
#     'coin': 'WLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please note that WLD deposits via World Chain network are NOT supported and unretrievable at the moment. Please only deposit via supported networks.',
#     'specialWithdrawTips': '',
#     'name': 'Optimism',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.012',
#     'withdrawMin': '0.024',
#     'withdrawMax': '9999999',
#     'depositDust': '0.0003',
#     'minConfirm': 25,
#     'unLockConfirm': 100,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://optimistic.etherscan.io/token/',
#     'contractAddress': '0xdc6ff44d5d932cbd77b52e5612ba0529dc6226f1'},
#    {'network': 'WLD',
#     'coin': 'WLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Worldchain',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00000001',
#     'minConfirm': 25,
#     'unLockConfirm': 100,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False,
#     'contractAddressUrl': 'https://worldchain-mainnet.explorer.alchemy.com/address/',
#     'contractAddress': '0x2cfc85d8e48f8eab294be644d9e25c3030863003'}]},
#  {'coin': 'ETHFI',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'ether.fi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ARBITRUM',
#     'coin': 'ETHFI',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Arbitrum One',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.066',
#     'withdrawMin': '0.13',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00000001',
#     'minConfirm': 120,
#     'unLockConfirm': 120,
#     'sameAddress': False,
#     'estimatedArrivalTime': 3,
#     'busy': False,
#     'contractAddressUrl': 'https://arbiscan.io/token/',
#     'contractAddress': '0x7189fb5b6504bbff6a852b13b7b82a3c118fdc27'},
#    {'network': 'ETH',
#     'coin': 'ETHFI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '3.83',
#     'withdrawMin': '7.66',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00045',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xfe0c30065b384f05761f15d0cc899d4f9f9cc0eb'}]},
#  {'coin': 'FDUSD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'First Digital USD',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FDUSD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.01',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0xc5f0f7b66764f6ec8c8dff7ba683102295e16409'},
#    {'network': 'ETH',
#     'coin': 'FDUSD',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '4',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.001',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xc5f0f7b66764f6ec8c8dff7ba683102295e16409'},
#    {'network': 'OPBNB',
#     'coin': 'FDUSD',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'opBNB',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '20',
#     'withdrawMax': '9999999',
#     'depositDust': '0.001',
#     'minConfirm': 1,
#     'unLockConfirm': 100,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://opbnbscan.com/token/',
#     'contractAddress': '0x50c5725949a6f0c72e6c4a641f24049a917db0cb'}]},
#  {'coin': 'FARM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Harvest Finance',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.15',
#     'withdrawMin': '0.3',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00002',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xa0246c9032bc3a600820415ae600c6388619a14d'}]},
#  {'coin': 'ZRO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'LayerZero',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AVAXC',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'AVAX C-Chain',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.029',
#     'withdrawMin': '0.058',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://avascan.info/blockchain/c/token/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'},
#    {'network': 'ARBITRUM',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Arbitrum One',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.028',
#     'withdrawMin': '0.056',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 120,
#     'unLockConfirm': 120,
#     'sameAddress': False,
#     'estimatedArrivalTime': 3,
#     'busy': False,
#     'contractAddressUrl': 'https://arbiscan.io/token/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'},
#    {'network': 'BSC',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.16',
#     'withdrawMin': '0.32',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'},
#    {'network': 'BASE',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Base',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.028',
#     'withdrawMin': '0.056',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 1,
#     'unLockConfirm': 100,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False,
#     'contractAddressUrl': 'https://basescan.org/token/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'},
#    {'network': 'ETH',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1.59',
#     'withdrawMin': '3.18',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'},
#    {'network': 'OPTIMISM',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Optimism',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.0069',
#     'withdrawMin': '0.014',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 25,
#     'unLockConfirm': 100,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://optimistic.etherscan.io/token/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'},
#    {'network': 'MATIC',
#     'coin': 'ZRO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Polygon POS',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.015',
#     'withdrawMin': '0.03',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00025',
#     'minConfirm': 200,
#     'unLockConfirm': 300,
#     'sameAddress': False,
#     'estimatedArrivalTime': 8,
#     'busy': False,
#     'contractAddressUrl': 'https://polygonscan.com/token/',
#     'contractAddress': '0x6985884c4392d348587b19cb9eaaf157f13271cd'}]},
#  {'coin': 'SDG',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Sudanese Pound',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'SDG',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 1,
#     'busy': False}]},
#  {'coin': 'XNO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Nano',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'NANO',
#     'coin': 'XNO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Minimum deposit amount: 0.001 XNO. Any deposits less than the minimum deposit amount will not be credited or refunded.',
#     'specialWithdrawTips': '',
#     'name': 'NANO',
#     'resetAddressStatus': False,
#     'addressRegex': '^(xrb_|nano_)[13456789abcdefghijkmnopqrstuwxyz]{60}',
#     'memoRegex': '',
#     'withdrawFee': '0.041',
#     'withdrawMin': '0.082',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.001',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 6,
#     'busy': False}]},
#  {'coin': 'DGB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'DigiByte',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'DGB',
#     'coin': 'DGB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'DigiByte',
#     'resetAddressStatus': False,
#     'addressRegex': '^[DS][a-km-zA-HJ-NP-Z1-9]{25,34}$|^(dgb1)[0-9A-Za-z]{39,59}$',
#     'memoRegex': '',
#     'withdrawFee': '0.004',
#     'withdrawMin': '0.4',
#     'withdrawMax': '30000000000',
#     'depositDust': '0.13',
#     'minConfirm': 10,
#     'unLockConfirm': 50,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False}]},
#  {'coin': 'AVAOLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Travala.com',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BSC',
#     'coin': 'AVAOLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': 'The network you selected is the BEP20 network. Please ensure your deposit is made on the BSC network.',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1.21',
#     'withdrawMin': '2.42',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0x13616f44ba82d63c8c0dc3ff843d36a8ec1c05a9'},
#    {'network': 'BNB',
#     'coin': 'AVAOLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': 'Both a memo/tag and an address are required to successfully deposit your assets to Binance.',
#     'specialWithdrawTips': '',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.61',
#     'withdrawMin': '1.22',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.000001',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.bnbchain.org/asset/',
#     'contractAddress': 'AVA-645'},
#    {'network': 'ETH',
#     'coin': 'AVAOLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '12',
#     'withdrawMin': '24',
#     'withdrawMax': '9999999',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x442b153f6f61c0c99a33aa4170dcb31e1abda1d0'}]},
#  {'coin': 'ZRX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': '0x',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'ZRX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '18',
#     'withdrawMin': '36',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.003',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xe41d2489571d322189246dafa5ebde1f4699f498'}]},
#  {'coin': 'SANTOS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Santos FC Fan Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SANTOS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.17',
#     'withdrawMin': '0.34',
#     'withdrawMax': '9999999',
#     'depositDust': '0.0004',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0xa64455a4553c9034236734faddaddbb64ace4cc7'}]},
#  {'coin': 'WING',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wing Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ONT',
#     'coin': 'WING',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ontology',
#     'resetAddressStatus': False,
#     'addressRegex': '^(A)[A-Za-z0-9]{33}$',
#     'memoRegex': '',
#     'withdrawFee': '0.0035',
#     'withdrawMin': '0.007',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.0002',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.ont.io/contract/all/',
#     'contractAddress': '00c59fcd27a562d6397883eab1f2fff56e58ef80'}]},
#  {'coin': 'WNXM',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Wrapped NXM',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'WNXM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.1',
#     'withdrawMin': '0.2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x0d438f3b5175bebc262bf23753c1e53d03432bde'}]},
#  {'coin': 'BCH',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bitcoin Cash',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.0016',
#     'withdrawMin': '0.0032',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.000003',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0x8ff795a6f4d97e7887c79bea79aba5cc76444adf'},
#    {'network': 'BCH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Bitcoin Cash',
#     'resetAddressStatus': False,
#     'addressRegex': '^[1][a-km-zA-HJ-NP-Z1-9]{25,34}$|^[0-9a-z]{42,42}$',
#     'memoRegex': '',
#     'withdrawFee': '0.0002',
#     'withdrawMin': '0.002',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.000003',
#     'minConfirm': 2,
#     'unLockConfirm': 6,
#     'sameAddress': False,
#     'estimatedArrivalTime': 19,
#     'busy': False},
#    {'network': 'BNB',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': 'Both a memo/tag and an address are required to successfully deposit your assets to Binance.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.0008',
#     'withdrawMin': '0.0016',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.000003',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.bnbchain.org/asset/',
#     'contractAddress': 'BCH-1FD'},
#    {'network': 'ETH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.016',
#     'withdrawMin': '0.032',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.000003',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x85c4edc43724e954e5849caaab61a26a9cb65f1b'}]},
#  {'coin': 'AI',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Sleepless AI',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'AI',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1.39',
#     'withdrawMin': '2.78',
#     'withdrawMax': '9999999',
#     'depositDust': '0.002',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0xbda011d7f8ec00f66c1923b049b94c67d148d8b2'}]},
#  {'coin': 'JST',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'JUST',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '19',
#     'withdrawMin': '38',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.034',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0xea998d307aca04d4f0a3b3036aba84ae2e409c0a'},
#    {'network': 'TRX',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Tron (TRC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^T[1-9A-HJ-NP-Za-km-z]{33}$',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '100',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.034',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://tronscan.org/#/token20/',
#     'contractAddress': 'TCFLL5dx5ZJdKnWuesXxi1VPwjLVmWZZy9'}]},
#  {'coin': 'HOT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Holo',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'HOT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '3833',
#     'withdrawMin': '7666',
#     'withdrawMax': '9900000000',
#     'depositDust': '0.5',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'}]},
#  {'coin': 'XOF',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'West African CFA',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'XOF',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 1,
#     'busy': False}]},
#  {'coin': 'GMT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Green Metaverse Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'GMT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '4.66',
#     'withdrawMin': '9.32',
#     'withdrawMax': '9999999',
#     'depositDust': '0.007',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0x3019bf2a2ef8040c242c9a4c5c4bd4c81678b2a1'},
#    {'network': 'ETH',
#     'coin': 'GMT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please make sure the GMT (Green Metaverse Token) you are depositing ends with the contract address ff740.',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '47',
#     'withdrawMin': '94',
#     'withdrawMax': '1000000000',
#     'depositDust': '0.007',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xe3c408bd53c31c085a1746af401a4042954ff740'},
#    {'network': 'MATIC',
#     'coin': 'GMT',
# ...
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1.85',
#     'withdrawMin': '3.7',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.0025',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0xf4bafaeae73a4a7c8b6479970075e91e641fb1fc'},
#    {'network': 'ETH',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '18',
#     'withdrawMin': '36',
#     'withdrawMax': '9900000000',
#     'depositDust': '0.0025',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xef3a930e1ffffacd2fc13434ac81bd278b0ecc8d'}]},
#  {'coin': 'VIC',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Viction',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'VIC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': 'Both a memo/tag and an address are required to successfully deposit your assets to Binance.',
#     'specialWithdrawTips': '',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.096',
#     'withdrawMin': '0.19',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.003',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.bnbchain.org/asset/',
#     'contractAddress': 'TOMOB-4BC'},
#    {'network': 'ETH',
#     'coin': 'VIC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '16',
#     'withdrawMin': '32',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.003',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x05d3606d5c81eb9b7b18530995ec9b29da05faba'},
#    {'network': 'VIC',
#     'coin': 'VIC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Viction',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.001',
#     'withdrawMin': '0.02',
#     'withdrawMax': '9999999',
#     'depositDust': '0.003',
#     'minConfirm': 150,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False,
#     'contractAddressUrl': 'https://www.vicscan.xyz/token/'}]},
#  {'coin': 'BAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'FC Barcelona Fan Token BAR',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'CHZ2',
#     'coin': 'BAR',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please make sure the token you are depositing ends with the contract address a433b.',
#     'specialWithdrawTips': '',
#     'name': 'Chiliz Chain (CAP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '1',
#     'withdrawMax': '9999999',
#     'minConfirm': 20,
#     'unLockConfirm': 40,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False,
#     'contractAddressUrl': 'https://chiliscan.com/token/',
#     'contractAddress': '0xfd3c73b3b09d418841dd6aff341b2d6e3aba433b'}]},
#  {'coin': 'RAD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Radworks',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RAD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '5.49',
#     'withdrawMin': '10',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.0008',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x31c8eacbffdd875c74b94b077895bd78cf1e64a3'}]},
#  {'coin': 'BAT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Basic Attention Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '3.43',
#     'withdrawMin': '6.86',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.005',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0x101d82428437127bf1608f699cd651e6abf9766e'},
#    {'network': 'BNB',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': 'Both a memo/tag and an address are required to successfully deposit your assets to Binance.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '1.71',
#     'withdrawMin': '3.42',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.005',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.bnbchain.org/asset/',
#     'contractAddress': 'BAT-07A'},
#    {'network': 'ETH',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '34',
#     'withdrawMin': '68',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.005',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x0d8775f648430679a709e98d2b0cb6250d2887ef'}]},
#  {'coin': 'NZD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'New Zealand Dollar',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'NZD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 1,
#     'busy': False}]},
#  {'coin': 'AKRO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Akropolis',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AKRO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1418',
#     'withdrawMin': '2836',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.2',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7'}]},
#  {'coin': 'MOVR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Moonriver',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'MOVR',
#     'coin': 'MOVR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Moonriver',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.003',
#     'withdrawMin': '0.006',
#     'withdrawMax': '9999999',
#     'depositDust': '0.0001',
#     'minConfirm': 30,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False}]},
#  {'coin': 'XMR',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Monero',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'XMR',
#     'coin': 'XMR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Monero',
#     'resetAddressStatus': False,
#     'addressRegex': '^[48][a-zA-Z|\\d]{94}([a-zA-Z|\\d]{11})?$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0.0002',
#     'withdrawMax': '1000000',
#     'depositDust': '0.001',
#     'minConfirm': 3,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 0,
#     'busy': False}]},
#  {'coin': 'COTI',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'COTI',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the BNB Smart Chain network. You will potentially lose your assets if the chosen platform does not support refunds of wrongfully deposited assets.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '6.12',
#     'withdrawMin': '12',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.01',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'contractAddressUrl': 'https://bscscan.com/token/',
#     'contractAddress': '0xadbaf88b39d37dc68775ed1541f1bf83a5a45feb'},
#    {'network': 'BNB',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': 'Both a memo/tag and an address are required to successfully deposit your assets to Binance.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '3.06',
#     'withdrawMin': '6.12',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.000001',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 2,
#     'busy': False,
#     'contractAddressUrl': 'https://explorer.bnbchain.org/asset/',
#     'contractAddress': 'COTI-CBB'},
#    {'network': 'ETH',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '61',
#     'withdrawMin': '122',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.01',
#     'minConfirm': 6,
#     'unLockConfirm': 64,
#     'sameAddress': False,
#     'estimatedArrivalTime': 4,
#     'busy': False,
#     'contractAddressUrl': 'https://etherscan.io/address/',
#     'contractAddress': '0xddb3422497e61e13543bea06989c0789117555c5'}]}]

# %%
coins = pd.DataFrame(client.get_all_coins_info()) # asset/coin Info
coins
# Out:
#            coin  depositAllEnable  withdrawAllEnable  \
# 0          AGLD              True               True
# 1           MXN              True               True
# 2          STPT              True               True
# 3           SCR              True              False
# 4    MATICUSDCE              True               True
# ..          ...               ...                ...
# 543         NZD              True               True
# 544        AKRO              True               True
# 545        MOVR              True               True
# 546         XMR             False               True
# 547        COTI              True               True
#
#                                name free locked freeze withdrawing ipoing  \
# 0                    Adventure Gold    0      0      0           0      0
# 1                      Mexican Peso    0      0      0           0      0
# 2    Standard Tokenization Protocol    0      0      0           0      0
# 3                            Scroll    0      0      0           0      0
# 4                      Bridged USDC    0      0      0           0      0
# ..                              ...  ...    ...    ...         ...    ...
# 543              New Zealand Dollar    0      0      0           0      0
# 544                       Akropolis    0      0      0           0      0
# 545                       Moonriver    0      0      0           0      0
# 546                          Monero    0      0      0           0      0
# 547                            COTI    0      0      0           0      0
#
#     ipoable storage  isLegalMoney  trading  \
# 0         0       0         False     True
# 1         0       0          True     True
# 2         0       0         False     True
# 3         0       0         False     True
# 4         0       0         False    False
# ..      ...     ...           ...      ...
# 543       0       0          True    False
# 544       0       0         False     True
# 545       0       0         False     True
# 546       0       0         False    False
# 547       0       0         False     True
#
#                                            networkList
# 0    [{'network': 'ETH', 'coin': 'AGLD', 'withdrawI...
# 1    [{'network': 'FIAT_MONEY', 'coin': 'MXN', 'wit...
# 2    [{'network': 'ETH', 'coin': 'STPT', 'withdrawI...
# 3    [{'network': 'SCROLL', 'coin': 'SCR', 'withdra...
# 4    [{'network': 'MATIC', 'coin': 'MATICUSDCE', 'w...
# ..                                                 ...
# 543  [{'network': 'FIAT_MONEY', 'coin': 'NZD', 'wit...
# 544  [{'network': 'ETH', 'coin': 'AKRO', 'withdrawI...
# 545  [{'network': 'MOVR', 'coin': 'MOVR', 'withdraw...
# 546  [{'network': 'XMR', 'coin': 'XMR', 'withdrawIn...
# 547  [{'network': 'BSC', 'coin': 'COTI', 'withdrawI...
#
# [548 rows x 14 columns]

# %%
coins.loc[coins.coin == "BTC"]
# Out:
#     coin  depositAllEnable  withdrawAllEnable     name free locked freeze  \
# 319  BTC              True               True  Bitcoin    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 319           0      0       0       0         False     True
#
#                                            networkList
# 319  [{'network': 'BSC', 'coin': 'BTC', 'withdrawIn...

# %%
coins.loc[coins.coin == "EUR"]
# Out:
#     coin  depositAllEnable  withdrawAllEnable  name free locked freeze  \
# 242  EUR              True               True  Euro    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 242           0      0       0       0          True     True
#
#                                            networkList
# 242  [{'network': 'FIAT_MONEY', 'coin': 'EUR', 'wit...

# %%
client.get_trade_fee(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'}]

# %%
client.get_trade_fee(symbol = "BTCEUR")
# Out:
# [{'symbol': 'BTCEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'}]

# %%
client.get_trade_fee(symbol = "BUSDUSDT") # zero commissions for stable coin pairs
# Out:
# [{'symbol': 'BUSDUSDT', 'makerCommission': '0', 'takerCommission': '0'}]

# %%
client.get_symbol_info(symbol = "BTCEUR") # information on symbol / pair
# Out:
# {'symbol': 'BTCEUR',
#  'status': 'TRADING',
#  'baseAsset': 'BTC',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'EUR',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'otoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': False,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00001000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00001000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '22.69957552',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'NOTIONAL',
#    'minNotional': '5.00000000',
#    'applyMinToMarket': True,
#    'maxNotional': '9000000.00000000',
#    'applyMaxToMarket': False,
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': [],
#  'permissionSets': [['SPOT',
#    'TRD_GRP_005',
#    'TRD_GRP_009',
#    'TRD_GRP_010',
#    'TRD_GRP_011',
#    'TRD_GRP_012',
#    'TRD_GRP_013',
#    'TRD_GRP_014',
#    'TRD_GRP_015',
#    'TRD_GRP_016',
#    'TRD_GRP_017',
#    'TRD_GRP_018',
#    'TRD_GRP_019',
#    'TRD_GRP_020',
#    'TRD_GRP_021',
#    'TRD_GRP_022',
#    'TRD_GRP_023',
#    'TRD_GRP_024',
#    'TRD_GRP_025',
#    'TRD_GRP_026',
#    'TRD_GRP_027',
#    'TRD_GRP_028',
#    'TRD_GRP_029',
#    'TRD_GRP_030',
#    'TRD_GRP_031',
#    'TRD_GRP_032',
#    'TRD_GRP_033',
#    'TRD_GRP_034',
#    'TRD_GRP_035',
#    'TRD_GRP_036',
#    'TRD_GRP_037',
#    'TRD_GRP_038',
#    'TRD_GRP_039',
#    'TRD_GRP_040',
#    'TRD_GRP_041',
#    'TRD_GRP_042',
#    'TRD_GRP_043',
#    'TRD_GRP_044',
#    'TRD_GRP_045',
#    'TRD_GRP_046',
#    'TRD_GRP_047',
#    'TRD_GRP_048',
#    'TRD_GRP_049',
#    'TRD_GRP_050',
#    'TRD_GRP_051',
#    'TRD_GRP_052',
#    'TRD_GRP_053',
#    'TRD_GRP_054',
#    'TRD_GRP_055',
#    'TRD_GRP_056',
#    'TRD_GRP_057',
#    'TRD_GRP_058',
#    'TRD_GRP_059',
#    'TRD_GRP_060',
#    'TRD_GRP_061',
#    'TRD_GRP_062',
#    'TRD_GRP_063',
#    'TRD_GRP_064',
#    'TRD_GRP_065',
#    'TRD_GRP_066',
#    'TRD_GRP_067',
#    'TRD_GRP_068',
#    'TRD_GRP_069',
#    'TRD_GRP_070',
#    'TRD_GRP_071',
#    'TRD_GRP_072',
#    'TRD_GRP_073',
#    'TRD_GRP_074',
#    'TRD_GRP_075',
#    'TRD_GRP_076',
#    'TRD_GRP_077',
#    'TRD_GRP_078',
#    'TRD_GRP_079',
#    'TRD_GRP_080',
#    'TRD_GRP_081',
#    'TRD_GRP_082',
#    'TRD_GRP_083',
#    'TRD_GRP_084',
#    'TRD_GRP_085',
#    'TRD_GRP_086',
#    'TRD_GRP_087',
#    'TRD_GRP_088',
#    'TRD_GRP_089',
#    'TRD_GRP_090',
#    'TRD_GRP_091',
#    'TRD_GRP_092',
#    'TRD_GRP_093',
#    'TRD_GRP_094',
#    'TRD_GRP_095',
#    'TRD_GRP_096',
#    'TRD_GRP_097',
#    'TRD_GRP_098',
#    'TRD_GRP_099',
#    'TRD_GRP_100',
#    'TRD_GRP_101',
#    'TRD_GRP_102',
#    'TRD_GRP_103',
#    'TRD_GRP_104',
#    'TRD_GRP_105',
#    'TRD_GRP_106',
#    'TRD_GRP_107',
#    'TRD_GRP_108',
#    'TRD_GRP_109',
#    'TRD_GRP_110',
#    'TRD_GRP_111',
#    'TRD_GRP_112',
#    'TRD_GRP_113',
#    'TRD_GRP_114',
#    'TRD_GRP_115',
#    'TRD_GRP_116',
#    'TRD_GRP_117',
#    'TRD_GRP_118',
#    'TRD_GRP_119',
#    'TRD_GRP_120',
#    'TRD_GRP_121',
#    'TRD_GRP_122',
#    'TRD_GRP_123',
#    'TRD_GRP_124',
#    'TRD_GRP_125',
#    'TRD_GRP_126',
#    'TRD_GRP_127',
#    'TRD_GRP_128',
#    'TRD_GRP_129',
#    'TRD_GRP_130',
#    'TRD_GRP_131',
#    'TRD_GRP_132',
#    'TRD_GRP_133',
#    'TRD_GRP_134',
#    'TRD_GRP_135',
#    'TRD_GRP_136',
#    'TRD_GRP_137',
#    'TRD_GRP_138',
#    'TRD_GRP_139',
#    'TRD_GRP_140',
#    'TRD_GRP_141',
#    'TRD_GRP_142',
#    'TRD_GRP_143',
#    'TRD_GRP_144',
#    'TRD_GRP_145',
#    'TRD_GRP_146',
#    'TRD_GRP_147',
#    'TRD_GRP_148',
#    'TRD_GRP_149',
#    'TRD_GRP_150',
#    'TRD_GRP_151',
#    'TRD_GRP_152',
#    'TRD_GRP_153',
#    'TRD_GRP_154',
#    'TRD_GRP_155',
#    'TRD_GRP_156',
#    'TRD_GRP_157',
#    'TRD_GRP_158',
#    'TRD_GRP_159',
#    'TRD_GRP_160',
#    'TRD_GRP_161',
#    'TRD_GRP_162',
#    'TRD_GRP_163',
#    'TRD_GRP_164',
#    'TRD_GRP_165',
#    'TRD_GRP_166',
#    'TRD_GRP_167',
#    'TRD_GRP_168',
#    'TRD_GRP_169',
#    'TRD_GRP_170',
#    'TRD_GRP_171',
#    'TRD_GRP_172',
#    'TRD_GRP_173',
#    'TRD_GRP_174',
#    'TRD_GRP_175',
#    'TRD_GRP_176',
#    'TRD_GRP_177',
#    'TRD_GRP_178',
#    'TRD_GRP_179',
#    'TRD_GRP_180',
#    'TRD_GRP_181',
#    'TRD_GRP_182',
#    'TRD_GRP_183',
#    'TRD_GRP_184',
#    'TRD_GRP_185',
#    'TRD_GRP_186',
#    'TRD_GRP_187',
#    'TRD_GRP_188',
#    'TRD_GRP_189',
#    'TRD_GRP_190',
#    'TRD_GRP_191',
#    'TRD_GRP_192',
#    'TRD_GRP_193',
#    'TRD_GRP_194',
#    'TRD_GRP_195',
#    'TRD_GRP_196',
#    'TRD_GRP_197',
#    'TRD_GRP_198',
#    'TRD_GRP_199',
#    'TRD_GRP_200',
#    'TRD_GRP_201',
#    'TRD_GRP_202',
#    'TRD_GRP_203',
#    'TRD_GRP_204']],
#  'defaultSelfTradePreventionMode': 'EXPIRE_MAKER',
#  'allowedSelfTradePreventionModes': ['EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %%
client.get_symbol_info(symbol = "ETHUSDT") # information on symbol / pair
# Out:
# {'symbol': 'ETHUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'otoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '3388.22539163',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'NOTIONAL',
#    'minNotional': '5.00000000',
#    'applyMinToMarket': True,
#    'maxNotional': '9000000.00000000',
#    'applyMaxToMarket': False,
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': [],
#  'permissionSets': [['SPOT',
#    'MARGIN',
#    'TRD_GRP_004',
#    'TRD_GRP_005',
#    'TRD_GRP_006',
#    'TRD_GRP_009',
#    'TRD_GRP_010',
#    'TRD_GRP_011',
#    'TRD_GRP_012',
#    'TRD_GRP_013',
#    'TRD_GRP_014',
#    'TRD_GRP_015',
#    'TRD_GRP_016',
#    'TRD_GRP_017',
#    'TRD_GRP_018',
#    'TRD_GRP_019',
#    'TRD_GRP_020',
#    'TRD_GRP_021',
#    'TRD_GRP_022',
#    'TRD_GRP_023',
#    'TRD_GRP_024',
#    'TRD_GRP_025',
#    'TRD_GRP_026',
#    'TRD_GRP_027',
#    'TRD_GRP_028',
#    'TRD_GRP_029',
#    'TRD_GRP_030',
#    'TRD_GRP_031',
#    'TRD_GRP_032',
#    'TRD_GRP_033',
#    'TRD_GRP_034',
#    'TRD_GRP_035',
#    'TRD_GRP_036',
#    'TRD_GRP_037',
#    'TRD_GRP_038',
#    'TRD_GRP_039',
#    'TRD_GRP_040',
#    'TRD_GRP_041',
#    'TRD_GRP_042',
#    'TRD_GRP_043',
#    'TRD_GRP_044',
#    'TRD_GRP_045',
#    'TRD_GRP_046',
#    'TRD_GRP_047',
#    'TRD_GRP_048',
#    'TRD_GRP_049',
#    'TRD_GRP_050',
#    'TRD_GRP_051',
#    'TRD_GRP_052',
#    'TRD_GRP_053',
#    'TRD_GRP_054',
#    'TRD_GRP_055',
#    'TRD_GRP_056',
#    'TRD_GRP_057',
#    'TRD_GRP_058',
#    'TRD_GRP_059',
#    'TRD_GRP_060',
#    'TRD_GRP_061',
#    'TRD_GRP_062',
#    'TRD_GRP_063',
#    'TRD_GRP_064',
#    'TRD_GRP_065',
#    'TRD_GRP_066',
#    'TRD_GRP_067',
#    'TRD_GRP_068',
#    'TRD_GRP_069',
#    'TRD_GRP_070',
#    'TRD_GRP_071',
#    'TRD_GRP_072',
#    'TRD_GRP_073',
#    'TRD_GRP_074',
#    'TRD_GRP_075',
#    'TRD_GRP_076',
#    'TRD_GRP_077',
#    'TRD_GRP_078',
#    'TRD_GRP_079',
#    'TRD_GRP_080',
#    'TRD_GRP_081',
#    'TRD_GRP_082',
#    'TRD_GRP_083',
#    'TRD_GRP_084',
#    'TRD_GRP_085',
#    'TRD_GRP_086',
#    'TRD_GRP_087',
#    'TRD_GRP_088',
#    'TRD_GRP_089',
#    'TRD_GRP_090',
#    'TRD_GRP_091',
#    'TRD_GRP_092',
#    'TRD_GRP_093',
#    'TRD_GRP_094',
#    'TRD_GRP_095',
#    'TRD_GRP_096',
#    'TRD_GRP_097',
#    'TRD_GRP_098',
#    'TRD_GRP_099',
#    'TRD_GRP_100',
#    'TRD_GRP_101',
#    'TRD_GRP_102',
#    'TRD_GRP_103',
#    'TRD_GRP_104',
#    'TRD_GRP_105',
#    'TRD_GRP_106',
#    'TRD_GRP_107',
#    'TRD_GRP_108',
#    'TRD_GRP_109',
#    'TRD_GRP_110',
#    'TRD_GRP_111',
#    'TRD_GRP_112',
#    'TRD_GRP_113',
#    'TRD_GRP_114',
#    'TRD_GRP_115',
#    'TRD_GRP_116',
#    'TRD_GRP_117',
#    'TRD_GRP_118',
#    'TRD_GRP_119',
#    'TRD_GRP_120',
#    'TRD_GRP_121',
#    'TRD_GRP_122',
#    'TRD_GRP_123',
#    'TRD_GRP_124',
#    'TRD_GRP_125',
#    'TRD_GRP_126',
#    'TRD_GRP_127',
#    'TRD_GRP_128',
#    'TRD_GRP_129',
#    'TRD_GRP_130',
#    'TRD_GRP_131',
#    'TRD_GRP_132',
#    'TRD_GRP_133',
#    'TRD_GRP_134',
#    'TRD_GRP_135',
#    'TRD_GRP_136',
#    'TRD_GRP_137',
#    'TRD_GRP_138',
#    'TRD_GRP_139',
#    'TRD_GRP_140',
#    'TRD_GRP_141',
#    'TRD_GRP_142',
#    'TRD_GRP_143',
#    'TRD_GRP_144',
#    'TRD_GRP_145',
#    'TRD_GRP_146',
#    'TRD_GRP_147',
#    'TRD_GRP_148',
#    'TRD_GRP_149',
#    'TRD_GRP_150',
#    'TRD_GRP_151',
#    'TRD_GRP_152',
#    'TRD_GRP_153',
#    'TRD_GRP_154',
#    'TRD_GRP_155',
#    'TRD_GRP_156',
#    'TRD_GRP_157',
#    'TRD_GRP_158',
#    'TRD_GRP_159',
#    'TRD_GRP_160',
#    'TRD_GRP_161',
#    'TRD_GRP_162',
#    'TRD_GRP_163',
#    'TRD_GRP_164',
#    'TRD_GRP_165',
#    'TRD_GRP_166',
#    'TRD_GRP_167',
#    'TRD_GRP_168',
#    'TRD_GRP_169',
#    'TRD_GRP_170',
#    'TRD_GRP_171',
#    'TRD_GRP_172',
#    'TRD_GRP_173',
#    'TRD_GRP_174',
#    'TRD_GRP_175',
#    'TRD_GRP_176',
#    'TRD_GRP_177',
#    'TRD_GRP_178',
#    'TRD_GRP_179',
#    'TRD_GRP_180',
#    'TRD_GRP_181',
#    'TRD_GRP_182',
#    'TRD_GRP_183',
#    'TRD_GRP_184',
#    'TRD_GRP_185',
#    'TRD_GRP_186',
#    'TRD_GRP_187',
#    'TRD_GRP_188',
#    'TRD_GRP_189',
#    'TRD_GRP_190',
#    'TRD_GRP_191',
#    'TRD_GRP_192',
#    'TRD_GRP_193',
#    'TRD_GRP_194',
#    'TRD_GRP_195',
#    'TRD_GRP_196',
#    'TRD_GRP_197',
#    'TRD_GRP_198',
#    'TRD_GRP_199',
#    'TRD_GRP_200',
#    'TRD_GRP_201',
#    'TRD_GRP_202',
#    'TRD_GRP_203',
#    'TRD_GRP_204']],
#  'defaultSelfTradePreventionMode': 'EXPIRE_MAKER',
#  'allowedSelfTradePreventionModes': ['EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# ## Getting (current) Market Data

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %% [markdown]
# __Current Prices__

# %%
client.get_symbol_ticker(symbol = "ETHUSDT") # current price for one symbol
# Out:
# {'symbol': 'ETHUSDT', 'price': '2622.74000000'}

# %%
float(client.get_symbol_ticker(symbol = "BTCEUR")["price"])
# Out:
# 62432.44

# %%
client.get_avg_price(symbol = "ETHUSDT") # current average price
# Out:
# {'mins': 5, 'price': '2623.41836940', 'closeTime': 1729253920365}

# %%
# get current prices for all pairs
prices = client.get_all_tickers()
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.03870000'},
#  {'symbol': 'LTCBTC', 'price': '0.00106400'},
#  {'symbol': 'BNBBTC', 'price': '0.00877300'},
#  {'symbol': 'NEOBTC', 'price': '0.00015370'},
#  {'symbol': 'QTUMETH', 'price': '0.00095000'},
#  {'symbol': 'EOSETH', 'price': '0.00018220'},
#  {'symbol': 'SNTETH', 'price': '0.00001027'},
#  {'symbol': 'BNTETH', 'price': '0.00019520'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00006420'},
#  {'symbol': 'BNBETH', 'price': '0.22680000'},
#  {'symbol': 'BTCUSDT', 'price': '67761.87000000'},
#  {'symbol': 'ETHUSDT', 'price': '2623.00000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000024'},
#  {'symbol': 'WTCETH', 'price': '0.00023700'},
#  {'symbol': 'LRCBTC', 'price': '0.00000181'},
#  {'symbol': 'LRCETH', 'price': '0.00004671'},
#  {'symbol': 'QTUMBTC', 'price': '0.00003691'},
#  {'symbol': 'YOYOBTC', 'price': '0.00000008'},
#  {'symbol': 'OMGBTC', 'price': '0.00003080'},
#  {'symbol': 'OMGETH', 'price': '0.00079100'},
#  {'symbol': 'ZRXBTC', 'price': '0.00000483'},
#  {'symbol': 'ZRXETH', 'price': '0.00009940'},
#  {'symbol': 'STRATBTC', 'price': '0.00003085'},
#  {'symbol': 'STRATETH', 'price': '0.00105300'},
#  {'symbol': 'SNGLSBTC', 'price': '0.00000013'},
#  {'symbol': 'SNGLSETH', 'price': '0.00005306'},
#  {'symbol': 'BQXBTC', 'price': '0.00008703'},
#  {'symbol': 'BQXETH', 'price': '0.00126350'},
#  {'symbol': 'KNCBTC', 'price': '0.00000671'},
#  {'symbol': 'KNCETH', 'price': '0.00039410'},
#  {'symbol': 'FUNBTC', 'price': '0.00000029'},
#  {'symbol': 'FUNETH', 'price': '0.00000146'},
#  {'symbol': 'SNMBTC', 'price': '0.00000057'},
#  {'symbol': 'SNMETH', 'price': '0.00004986'},
#  {'symbol': 'NEOETH', 'price': '0.00477500'},
#  {'symbol': 'IOTABTC', 'price': '0.00000175'},
#  {'symbol': 'IOTAETH', 'price': '0.00004530'},
#  {'symbol': 'LINKBTC', 'price': '0.00016830'},
#  {'symbol': 'LINKETH', 'price': '0.00434600'},
#  {'symbol': 'XVGBTC', 'price': '0.00000015'},
#  {'symbol': 'XVGETH', 'price': '0.00000146'},
#  {'symbol': 'SALTBTC', 'price': '0.00004250'},
#  {'symbol': 'SALTETH', 'price': '0.00113800'},
#  {'symbol': 'MDABTC', 'price': '0.00000382'},
#  {'symbol': 'MDAETH', 'price': '0.00181150'},
#  {'symbol': 'MTLBTC', 'price': '0.00001426'},
#  {'symbol': 'MTLETH', 'price': '0.00068340'},
#  {'symbol': 'SUBBTC', 'price': '0.00000457'},
#  {'symbol': 'SUBETH', 'price': '0.00012334'},
#  {'symbol': 'EOSBTC', 'price': '0.00000706'},
#  {'symbol': 'SNTBTC', 'price': '0.00000040'},
#  {'symbol': 'ETCETH', 'price': '0.00728000'},
#  {'symbol': 'ETCBTC', 'price': '0.00028170'},
#  {'symbol': 'MTHBTC', 'price': '0.00000023'},
#  {'symbol': 'MTHETH', 'price': '0.00004135'},
#  {'symbol': 'ENGBTC', 'price': '0.00006200'},
#  {'symbol': 'ENGETH', 'price': '0.00186480'},
#  {'symbol': 'DNTBTC', 'price': '0.00000186'},
#  {'symbol': 'ZECBTC', 'price': '0.00053750'},
#  {'symbol': 'ZECETH', 'price': '0.01385000'},
#  {'symbol': 'BNTBTC', 'price': '0.00000794'},
#  {'symbol': 'ASTBTC', 'price': '0.00000124'},
#  {'symbol': 'ASTETH', 'price': '0.00006960'},
#  {'symbol': 'DASHBTC', 'price': '0.00034770'},
#  {'symbol': 'DASHETH', 'price': '0.00897000'},
#  {'symbol': 'OAXBTC', 'price': '0.00000209'},
#  {'symbol': 'ICNBTC', 'price': '0.00005742'},
#  {'symbol': 'BTGBTC', 'price': '0.00091300'},
#  {'symbol': 'BTGETH', 'price': '0.05274500'},
#  {'symbol': 'EVXBTC', 'price': '0.00000274'},
#  {'symbol': 'EVXETH', 'price': '0.00062490'},
#  {'symbol': 'REQBTC', 'price': '0.00000142'},
#  {'symbol': 'REQETH', 'price': '0.00004995'},
#  {'symbol': 'VIBBTC', 'price': '0.00000102'},
#  {'symbol': 'VIBETH', 'price': '0.00003450'},
#  {'symbol': 'HSRETH', 'price': '0.01247400'},
#  {'symbol': 'TRXBTC', 'price': '0.00000235'},
#  {'symbol': 'TRXETH', 'price': '0.00006061'},
#  {'symbol': 'POWRBTC', 'price': '0.00000323'},
#  {'symbol': 'POWRETH', 'price': '0.00008380'},
#  {'symbol': 'ARKBTC', 'price': '0.00001679'},
#  {'symbol': 'ARKETH', 'price': '0.00104600'},
#  {'symbol': 'YOYOETH', 'price': '0.00005828'},
#  {'symbol': 'XRPBTC', 'price': '0.00000807'},
#  {'symbol': 'XRPETH', 'price': '0.00020850'},
#  {'symbol': 'MODBTC', 'price': '0.00004280'},
#  {'symbol': 'MODETH', 'price': '0.00116700'},
#  {'symbol': 'ENJBTC', 'price': '0.00000218'},
#  {'symbol': 'ENJETH', 'price': '0.00005640'},
#  {'symbol': 'STORJBTC', 'price': '0.00000940'},
#  {'symbol': 'STORJETH', 'price': '0.00029910'},
#  {'symbol': 'BNBUSDT', 'price': '594.50000000'},
#  {'symbol': 'VENBNB', 'price': '0.14920000'},
#  {'symbol': 'YOYOBNB', 'price': '0.00059800'},
#  {'symbol': 'POWRBNB', 'price': '0.00385000'},
#  {'symbol': 'VENBTC', 'price': '0.00013928'},
#  {'symbol': 'VENETH', 'price': '0.00325194'},
#  {'symbol': 'KMDBTC', 'price': '0.00000371'},
#  {'symbol': 'KMDETH', 'price': '0.00020970'},
#  {'symbol': 'NULSBNB', 'price': '0.01257000'},
#  {'symbol': 'RCNBTC', 'price': '0.00000074'},
#  {'symbol': 'RCNETH', 'price': '0.00037604'},
#  {'symbol': 'RCNBNB', 'price': '0.00347300'},
#  {'symbol': 'NULSBTC', 'price': '0.00000479'},
#  {'symbol': 'NULSETH', 'price': '0.00051926'},
#  {'symbol': 'RDNBTC', 'price': '0.00000447'},
#  {'symbol': 'RDNETH', 'price': '0.00071530'},
#  {'symbol': 'RDNBNB', 'price': '0.00623000'},
#  {'symbol': 'XMRBTC', 'price': '0.00228700'},
#  {'symbol': 'XMRETH', 'price': '0.04032000'},
#  {'symbol': 'DLTBNB', 'price': '0.00240000'},
#  {'symbol': 'WTCBNB', 'price': '0.00180500'},
#  {'symbol': 'DLTBTC', 'price': '0.00000071'},
#  {'symbol': 'DLTETH', 'price': '0.00016807'},
#  {'symbol': 'AMBBTC', 'price': '0.00000010'},
#  {'symbol': 'AMBETH', 'price': '0.00004100'},
#  {'symbol': 'AMBBNB', 'price': '0.00068500'},
#  {'symbol': 'BCCETH', 'price': '2.47246000'},
#  {'symbol': 'BCCUSDT', 'price': '448.70000000'},
#  {'symbol': 'BCCBNB', 'price': '54.29000000'},
#  {'symbol': 'BATBTC', 'price': '0.00000257'},
#  {'symbol': 'BATETH', 'price': '0.00010630'},
#  {'symbol': 'BATBNB', 'price': '0.00183100'},
#  {'symbol': 'BCPTBTC', 'price': '0.00000048'},
#  {'symbol': 'BCPTETH', 'price': '0.00008181'},
#  {'symbol': 'BCPTBNB', 'price': '0.00116200'},
#  {'symbol': 'ARNBTC', 'price': '0.00000761'},
#  {'symbol': 'ARNETH', 'price': '0.00029362'},
#  {'symbol': 'GVTBTC', 'price': '0.00001792'},
#  {'symbol': 'GVTETH', 'price': '0.00384600'},
#  {'symbol': 'CDTBTC', 'price': '0.00000317'},
#  {'symbol': 'CDTETH', 'price': '0.00005119'},
#  {'symbol': 'GXSBTC', 'price': '0.00004581'},
#  {'symbol': 'GXSETH', 'price': '0.00062460'},
#  {'symbol': 'NEOUSDT', 'price': '10.42000000'},
#  {'symbol': 'NEOBNB', 'price': '0.03836000'},
#  {'symbol': 'POEBTC', 'price': '0.00000005'},
#  {'symbol': 'POEETH', 'price': '0.00000664'},
#  {'symbol': 'QSPBTC', 'price': '0.00000076'},
#  {'symbol': 'QSPETH', 'price': '0.00002249'},
#  {'symbol': 'QSPBNB', 'price': '0.00052350'},
#  {'symbol': 'BTSBTC', 'price': '0.00000043'},
#  {'symbol': 'BTSETH', 'price': '0.00009498'},
#  {'symbol': 'BTSBNB', 'price': '0.00144800'},
#  {'symbol': 'XZCBTC', 'price': '0.00013550'},
#  {'symbol': 'XZCETH', 'price': '0.00310000'},
#  {'symbol': 'XZCBNB', 'price': '0.26750000'},
#  {'symbol': 'LSKBTC', 'price': '0.00001204'},
#  {'symbol': 'LSKETH', 'price': '0.00033730'},
#  {'symbol': 'LSKBNB', 'price': '0.06494000'},
#  {'symbol': 'TNTBTC', 'price': '0.00000261'},
#  {'symbol': 'TNTETH', 'price': '0.00000920'},
#  {'symbol': 'FUELBTC', 'price': '0.00000026'},
#  {'symbol': 'FUELETH', 'price': '0.00002221'},
#  {'symbol': 'MANABTC', 'price': '0.00000443'},
#  {'symbol': 'MANAETH', 'price': '0.00011450'},
#  {'symbol': 'BCDBTC', 'price': '0.00001351'},
#  {'symbol': 'BCDETH', 'price': '0.00251000'},
#  {'symbol': 'DGDBTC', 'price': '0.00393100'},
#  {'symbol': 'DGDETH', 'price': '0.19260000'},
#  {'symbol': 'IOTABNB', 'price': '0.00071700'},
#  {'symbol': 'ADXBTC', 'price': '0.00000237'},
#  {'symbol': 'ADXETH', 'price': '0.00006092'},
#  {'symbol': 'ADXBNB', 'price': '0.00492900'},
#  {'symbol': 'ADABTC', 'price': '0.00000511'},
#  {'symbol': 'ADAETH', 'price': '0.00013200'},
#  {'symbol': 'PPTBTC', 'price': '0.00001855'},
#  {'symbol': 'PPTETH', 'price': '0.00141000'},
#  {'symbol': 'CMTBTC', 'price': '0.00000028'},
#  {'symbol': 'CMTETH', 'price': '0.00000625'},
#  {'symbol': 'CMTBNB', 'price': '0.00057700'},
#  {'symbol': 'XLMBTC', 'price': '0.00000142'},
#  {'symbol': 'XLMETH', 'price': '0.00003662'},
#  {'symbol': 'XLMBNB', 'price': '0.00030360'},
#  {'symbol': 'CNDBTC', 'price': '0.00000006'},
#  {'symbol': 'CNDETH', 'price': '0.00002599'},
#  {'symbol': 'CNDBNB', 'price': '0.00033990'},
#  {'symbol': 'LENDBTC', 'price': '0.00004512'},
#  {'symbol': 'LENDETH', 'price': '0.00137174'},
#  {'symbol': 'WABIBTC', 'price': '0.00000030'},
#  {'symbol': 'WABIETH', 'price': '0.00040308'},
#  {'symbol': 'WABIBNB', 'price': '0.00024130'},
#  {'symbol': 'LTCETH', 'price': '0.02747000'},
#  {'symbol': 'LTCUSDT', 'price': '72.12000000'},
#  {'symbol': 'LTCBNB', 'price': '0.12130000'},
#  {'symbol': 'TNBBTC', 'price': '0.00000007'},
#  {'symbol': 'TNBETH', 'price': '0.00000752'},
#  {'symbol': 'WAVESBTC', 'price': '0.00001626'},
#  {'symbol': 'WAVESETH', 'price': '0.00029800'},
#  {'symbol': 'WAVESBNB', 'price': '0.00513000'},
#  {'symbol': 'GTOBTC', 'price': '0.00000077'},
#  {'symbol': 'GTOETH', 'price': '0.00003197'},
#  {'symbol': 'GTOBNB', 'price': '0.00035200'},
#  {'symbol': 'ICXBTC', 'price': '0.00000206'},
#  {'symbol': 'ICXETH', 'price': '0.00011790'},
#  {'symbol': 'ICXBNB', 'price': '0.00465400'},
#  {'symbol': 'OSTBTC', 'price': '0.00000032'},
#  {'symbol': 'OSTETH', 'price': '0.00000225'},
#  {'symbol': 'OSTBNB', 'price': '0.00052500'},
#  {'symbol': 'ELFBTC', 'price': '0.00000556'},
#  {'symbol': 'ELFETH', 'price': '0.00014430'},
#  {'symbol': 'AIONBTC', 'price': '0.00000139'},
#  {'symbol': 'AIONETH', 'price': '0.00002645'},
#  {'symbol': 'AIONBNB', 'price': '0.00261300'},
#  {'symbol': 'NEBLBTC', 'price': '0.00001200'},
#  {'symbol': 'NEBLBNB', 'price': '0.01356000'},
#  {'symbol': 'BRDBTC', 'price': '0.00000127'},
#  {'symbol': 'BRDETH', 'price': '0.00001688'},
#  {'symbol': 'BRDBNB', 'price': '0.00247000'},
#  {'symbol': 'MCOBNB', 'price': '0.26837000'},
#  {'symbol': 'EDOBTC', 'price': '0.00005609'},
#  {'symbol': 'EDOETH', 'price': '0.00226600'},
#  {'symbol': 'WINGSBTC', 'price': '0.00001193'},
#  {'symbol': 'WINGSETH', 'price': '0.00033460'},
#  {'symbol': 'NAVBTC', 'price': '0.00000277'},
#  {'symbol': 'NAVETH', 'price': '0.00011870'},
#  {'symbol': 'NAVBNB', 'price': '0.00423700'},
#  {'symbol': 'LUNBTC', 'price': '0.00008510'},
#  {'symbol': 'LUNETH', 'price': '0.00489100'},
#  {'symbol': 'TRIGBTC', 'price': '0.00001980'},
#  {'symbol': 'TRIGETH', 'price': '0.00059400'},
#  {'symbol': 'TRIGBNB', 'price': '0.01218000'},
#  {'symbol': 'APPCBTC', 'price': '0.00000055'},
#  {'symbol': 'APPCETH', 'price': '0.00014600'},
#  {'symbol': 'APPCBNB', 'price': '0.00189100'},
#  {'symbol': 'VIBEBTC', 'price': '0.00000042'},
#  {'symbol': 'VIBEETH', 'price': '0.00005720'},
#  {'symbol': 'RLCBTC', 'price': '0.00002209'},
#  {'symbol': 'RLCETH', 'price': '0.00056970'},
#  {'symbol': 'RLCBNB', 'price': '0.03344000'},
#  {'symbol': 'INSBTC', 'price': '0.00000618'},
#  {'symbol': 'INSETH', 'price': '0.00050100'},
#  {'symbol': 'PIVXBTC', 'price': '0.00000297'},
#  {'symbol': 'PIVXBNB', 'price': '0.01660000'},
#  {'symbol': 'IOSTBTC', 'price': '0.00000010'},
#  {'symbol': 'IOSTETH', 'price': '0.00000372'},
#  {'symbol': 'CHATBTC', 'price': '0.00000195'},
#  {'symbol': 'CHATETH', 'price': '0.00006585'},
#  {'symbol': 'STEEMBTC', 'price': '0.00000263'},
#  {'symbol': 'STEEMETH', 'price': '0.00006780'},
#  {'symbol': 'STEEMBNB', 'price': '0.00448000'},
#  {'symbol': 'NANOBTC', 'price': '0.00006280'},
#  {'symbol': 'NANOETH', 'price': '0.00090500'},
#  {'symbol': 'NANOBNB', 'price': '0.05589000'},
#  {'symbol': 'VIABTC', 'price': '0.00000681'},
#  {'symbol': 'VIAETH', 'price': '0.00085600'},
#  {'symbol': 'VIABNB', 'price': '0.00958000'},
#  {'symbol': 'BLZBTC', 'price': '0.00000185'},
#  {'symbol': 'BLZETH', 'price': '0.00004159'},
#  {'symbol': 'BLZBNB', 'price': '0.00062190'},
#  {'symbol': 'AEBTC', 'price': '0.00000292'},
#  {'symbol': 'AEETH', 'price': '0.00021900'},
#  {'symbol': 'AEBNB', 'price': '0.00777000'},
#  {'symbol': 'RPXBTC', 'price': '0.00000224'},
#  {'symbol': 'RPXETH', 'price': '0.00005449'},
#  {'symbol': 'RPXBNB', 'price': '0.00145700'},
#  {'symbol': 'NCASHBTC', 'price': '0.00000005'},
#  {'symbol': 'NCASHETH', 'price': '0.00000013'},
#  {'symbol': 'NCASHBNB', 'price': '0.00006790'},
#  {'symbol': 'POABTC', 'price': '0.00000041'},
#  {'symbol': 'POAETH', 'price': '0.00004891'},
#  {'symbol': 'POABNB', 'price': '0.00092100'},
#  {'symbol': 'ZILBTC', 'price': '0.00000022'},
#  {'symbol': 'ZILETH', 'price': '0.00000560'},
#  {'symbol': 'ZILBNB', 'price': '0.00008858'},
#  {'symbol': 'ONTBTC', 'price': '0.00000281'},
#  {'symbol': 'ONTETH', 'price': '0.00012530'},
#  {'symbol': 'ONTBNB', 'price': '0.00246200'},
#  {'symbol': 'STORMBTC', 'price': '0.00000035'},
#  {'symbol': 'STORMETH', 'price': '0.00001398'},
#  {'symbol': 'STORMBNB', 'price': '0.00006550'},
#  {'symbol': 'QTUMBNB', 'price': '0.09597000'},
#  {'symbol': 'QTUMUSDT', 'price': '2.50300000'},
#  {'symbol': 'XEMBTC', 'price': '0.00000192'},
#  {'symbol': 'XEMETH', 'price': '0.00003593'},
#  {'symbol': 'XEMBNB', 'price': '0.00244100'},
#  {'symbol': 'WANBTC', 'price': '0.00000262'},
#  {'symbol': 'WANETH', 'price': '0.00009270'},
#  {'symbol': 'WANBNB', 'price': '0.00181000'},
#  {'symbol': 'WPRBTC', 'price': '0.00000027'},
#  {'symbol': 'WPRETH', 'price': '0.00004020'},
#  {'symbol': 'QLCBTC', 'price': '0.00000021'},
#  {'symbol': 'QLCETH', 'price': '0.00000603'},
#  {'symbol': 'SYSBTC', 'price': '0.00000151'},
#  {'symbol': 'SYSETH', 'price': '0.00011047'},
#  {'symbol': 'SYSBNB', 'price': '0.00163500'},
#  {'symbol': 'QLCBNB', 'price': '0.00092200'},
#  {'symbol': 'GRSBTC', 'price': '0.00001649'},
#  {'symbol': 'GRSETH', 'price': '0.00076455'},
#  {'symbol': 'ADAUSDT', 'price': '0.34620000'},
#  {'symbol': 'ADABNB', 'price': '0.00058100'},
#  {'symbol': 'CLOAKBTC', 'price': '0.00015550'},
#  {'symbol': 'CLOAKETH', 'price': '0.00414200'},
#  {'symbol': 'GNTBTC', 'price': '0.00000678'},
#  {'symbol': 'GNTETH', 'price': '0.00022071'},
#  {'symbol': 'GNTBNB', 'price': '0.00243900'},
#  {'symbol': 'LOOMBTC', 'price': '0.00000075'},
#  {'symbol': 'LOOMETH', 'price': '0.00003231'},
#  {'symbol': 'LOOMBNB', 'price': '0.00088500'},
#  {'symbol': 'XRPUSDT', 'price': '0.54690000'},
#  {'symbol': 'BCNBTC', 'price': '0.00000022'},
#  {'symbol': 'BCNETH', 'price': '0.00000707'},
#  {'symbol': 'BCNBNB', 'price': '0.00002000'},
#  {'symbol': 'REPBTC', 'price': '0.00034130'},
#  {'symbol': 'REPBNB', 'price': '0.44670000'},
#  {'symbol': 'BTCTUSD', 'price': '67897.30000000'},
#  {'symbol': 'TUSDBTC', 'price': '0.00025971'},
#  {'symbol': 'ETHTUSD', 'price': '2627.76000000'},
#  {'symbol': 'TUSDETH', 'price': '0.00762097'},
#  {'symbol': 'TUSDBNB', 'price': '0.06777000'},
#  {'symbol': 'ZENBTC', 'price': '0.00011850'},
#  {'symbol': 'ZENETH', 'price': '0.00305200'},
#  {'symbol': 'ZENBNB', 'price': '0.03290000'},
#  {'symbol': 'SKYBTC', 'price': '0.00000829'},
#  {'symbol': 'SKYETH', 'price': '0.00222000'},
#  {'symbol': 'SKYBNB', 'price': '0.03022000'},
#  {'symbol': 'EOSUSDT', 'price': '0.47800000'},
#  {'symbol': 'EOSBNB', 'price': '0.00258300'},
#  {'symbol': 'CVCBTC', 'price': '0.00000566'},
#  {'symbol': 'CVCETH', 'price': '0.00009930'},
#  {'symbol': 'CVCBNB', 'price': '0.00211200'},
#  {'symbol': 'THETABTC', 'price': '0.00001875'},
#  {'symbol': 'THETAETH', 'price': '0.00048470'},
#  {'symbol': 'THETABNB', 'price': '0.00273600'},
#  {'symbol': 'XRPBNB', 'price': '0.00091960'},
#  {'symbol': 'TUSDUSDT', 'price': '0.99800000'},
#  {'symbol': 'IOTAUSDT', 'price': '0.11850000'},
#  {'symbol': 'XLMUSDT', 'price': '0.09620000'},
#  {'symbol': 'IOTXBTC', 'price': '0.00000060'},
#  {'symbol': 'IOTXETH', 'price': '0.00001551'},
#  {'symbol': 'QKCBTC', 'price': '0.00000012'},
#  {'symbol': 'QKCETH', 'price': '0.00000430'},
#  {'symbol': 'AGIBTC', 'price': '0.00000668'},
#  {'symbol': 'AGIETH', 'price': '0.00007363'},
#  {'symbol': 'AGIBNB', 'price': '0.00077200'},
#  {'symbol': 'NXSBTC', 'price': '0.00000284'},
#  {'symbol': 'NXSETH', 'price': '0.00077300'},
#  {'symbol': 'NXSBNB', 'price': '0.01087000'},
#  {'symbol': 'ENJBNB', 'price': '0.00136800'},
#  {'symbol': 'DATABTC', 'price': '0.00000053'},
#  {'symbol': 'DATAETH', 'price': '0.00002034'},
#  {'symbol': 'ONTUSDT', 'price': '0.19030000'},
#  {'symbol': 'TRXBNB', 'price': '0.00026730'},
#  {'symbol': 'TRXUSDT', 'price': '0.15910000'},
#  {'symbol': 'ETCUSDT', 'price': '19.08000000'},
#  {'symbol': 'ETCBNB', 'price': '0.03213000'},
#  {'symbol': 'ICXUSDT', 'price': '0.13910000'},
#  {'symbol': 'SCBTC', 'price': '0.00000017'},
#  {'symbol': 'SCETH', 'price': '0.00000188'},
#  {'symbol': 'NPXSBTC', 'price': '0.00000003'},
#  {'symbol': 'NPXSETH', 'price': '0.00000345'},
#  {'symbol': 'VENUSDT', 'price': '0.00010000'},
#  {'symbol': 'KEYBTC', 'price': '0.00000013'},
#  {'symbol': 'KEYETH', 'price': '0.00000227'},
#  {'symbol': 'NASBTC', 'price': '0.00000228'},
#  {'symbol': 'NASETH', 'price': '0.00004047'},
#  {'symbol': 'NASBNB', 'price': '0.02337000'},
#  {'symbol': 'MFTBTC', 'price': '0.00000008'},
#  {'symbol': 'MFTETH', 'price': '0.00000433'},
#  {'symbol': 'MFTBNB', 'price': '0.00001485'},
#  {'symbol': 'DENTBTC', 'price': '0.00000004'},
#  {'symbol': 'DENTETH', 'price': '0.00000033'},
#  {'symbol': 'ARDRBTC', 'price': '0.00000124'},
#  {'symbol': 'ARDRETH', 'price': '0.00018870'},
#  {'symbol': 'ARDRBNB', 'price': '0.00316800'},
#  {'symbol': 'NULSUSDT', 'price': '0.32500000'},
#  {'symbol': 'HOTBTC', 'price': '0.00000002'},
#  {'symbol': 'HOTETH', 'price': '0.00000061'},
#  {'symbol': 'VETBTC', 'price': '0.00000033'},
#  {'symbol': 'VETETH', 'price': '0.00000869'},
#  {'symbol': 'VETUSDT', 'price': '0.02287000'},
#  {'symbol': 'VETBNB', 'price': '0.00003840'},
#  {'symbol': 'DOCKBTC', 'price': '0.00000005'},
#  {'symbol': 'DOCKETH', 'price': '0.00003283'},
#  {'symbol': 'POLYBTC', 'price': '0.00001384'},
#  {'symbol': 'POLYBNB', 'price': '0.00145900'},
#  {'symbol': 'PHXBTC', 'price': '0.00000180'},
#  {'symbol': 'PHXETH', 'price': '0.00005617'},
#  {'symbol': 'PHXBNB', 'price': '0.00045600'},
#  {'symbol': 'HCBTC', 'price': '0.00002000'},
#  {'symbol': 'HCETH', 'price': '0.00513400'},
#  {'symbol': 'GOBTC', 'price': '0.00000043'},
#  {'symbol': 'GOBNB', 'price': '0.00069230'},
#  {'symbol': 'PAXBTC', 'price': '0.00025175'},
#  {'symbol': 'PAXBNB', 'price': '0.20121000'},
#  {'symbol': 'PAXUSDT', 'price': '0.99960000'},
#  {'symbol': 'PAXETH', 'price': '0.00888047'},
#  {'symbol': 'RVNBTC', 'price': '0.00000024'},
#  {'symbol': 'DCRBTC', 'price': '0.00018600'},
#  {'symbol': 'DCRBNB', 'price': '0.78100000'},
#  {'symbol': 'USDCBNB', 'price': '0.21755000'},
#  {'symbol': 'MITHBTC', 'price': '0.00000080'},
#  {'symbol': 'MITHBNB', 'price': '0.00004410'},
#  {'symbol': 'BCHABCBTC', 'price': '0.02933000'},
#  {'symbol': 'BCHSVBTC', 'price': '0.01117900'},
#  {'symbol': 'BCHABCUSDT', 'price': '220.08000000'},
#  {'symbol': 'BCHSVUSDT', 'price': '58.90000000'},
#  {'symbol': 'BNBPAX', 'price': '495.10000000'},
#  {'symbol': 'BTCPAX', 'price': '51529.15000000'},
#  {'symbol': 'ETHPAX', 'price': '3904.41000000'},
#  {'symbol': 'XRPPAX', 'price': '0.88960000'},
#  {'symbol': 'EOSPAX', 'price': '2.58450000'},
#  {'symbol': 'XLMPAX', 'price': '0.04221000'},
#  {'symbol': 'RENBTC', 'price': '0.00000054'},
#  {'symbol': 'RENBNB', 'price': '0.00458500'},
#  {'symbol': 'BNBTUSD', 'price': '595.80000000'},
#  {'symbol': 'XRPTUSD', 'price': '0.54780000'},
#  {'symbol': 'EOSTUSD', 'price': '4.11590000'},
#  {'symbol': 'XLMTUSD', 'price': '0.06833000'},
#  {'symbol': 'BNBUSDC', 'price': '594.30000000'},
#  {'symbol': 'BTCUSDC', 'price': '67748.85000000'},
#  {'symbol': 'ETHUSDC', 'price': '2622.40000000'},
#  {'symbol': 'XRPUSDC', 'price': '0.54680000'},
#  {'symbol': 'EOSUSDC', 'price': '0.47800000'},
#  {'symbol': 'XLMUSDC', 'price': '0.04970000'},
#  {'symbol': 'USDCUSDT', 'price': '1.00020000'},
#  {'symbol': 'ADATUSD', 'price': '0.38470000'},
#  {'symbol': 'TRXTUSD', 'price': '0.05986000'},
#  {'symbol': 'NEOTUSD', 'price': '11.81800000'},
#  {'symbol': 'TRXXRP', 'price': '0.29040000'},
#  {'symbol': 'XZCXRP', 'price': '20.79200000'},
#  {'symbol': 'PAXTUSD', 'price': '0.99950000'},
#  {'symbol': 'USDCTUSD', 'price': '1.00000000'},
#  {'symbol': 'USDCPAX', 'price': '1.00020000'},
#  {'symbol': 'LINKUSDT', 'price': '11.40000000'},
#  {'symbol': 'LINKTUSD', 'price': '14.42300000'},
#  {'symbol': 'LINKPAX', 'price': '3.98340000'},
#  {'symbol': 'LINKUSDC', 'price': '11.40000000'},
#  {'symbol': 'WAVESUSDT', 'price': '1.07600000'},
#  {'symbol': 'WAVESTUSD', 'price': '1.07200000'},
#  {'symbol': 'WAVESPAX', 'price': '0.80290000'},
#  {'symbol': 'WAVESUSDC', 'price': '1.20360000'},
#  {'symbol': 'BCHABCTUSD', 'price': '220.20000000'},
#  {'symbol': 'BCHABCPAX', 'price': '221.20000000'},
#  {'symbol': 'BCHABCUSDC', 'price': '220.30000000'},
#  {'symbol': 'BCHSVTUSD', 'price': '59.17000000'},
#  {'symbol': 'BCHSVPAX', 'price': '58.18000000'},
#  {'symbol': 'BCHSVUSDC', 'price': '57.50000000'},
#  {'symbol': 'LTCTUSD', 'price': '83.07000000'},
#  {'symbol': 'LTCPAX', 'price': '171.13000000'},
#  {'symbol': 'LTCUSDC', 'price': '72.08000000'},
#  {'symbol': 'TRXPAX', 'price': '0.07661000'},
#  {'symbol': 'TRXUSDC', 'price': '0.15890000'},
#  {'symbol': 'BTTBTC', 'price': '0.00000005'},
#  {'symbol': 'BTTBNB', 'price': '0.00000573'},
#  {'symbol': 'BTTUSDT', 'price': '0.00277700'},
#  {'symbol': 'BNBUSDS', 'price': '22.27880000'},
#  {'symbol': 'BTCUSDS', 'price': '9604.59000000'},
#  {'symbol': 'USDSUSDT', 'price': '0.99680000'},
#  {'symbol': 'USDSPAX', 'price': '1.00020000'},
#  {'symbol': 'USDSTUSD', 'price': '1.00000000'},
#  {'symbol': 'USDSUSDC', 'price': '1.00000000'},
#  {'symbol': 'BTTPAX', 'price': '0.00038660'},
#  {'symbol': 'BTTTUSD', 'price': '0.00277000'},
#  {'symbol': 'BTTUSDC', 'price': '0.00277600'},
#  {'symbol': 'ONGBNB', 'price': '0.00545000'},
#  {'symbol': 'ONGBTC', 'price': '0.00000465'},
#  {'symbol': 'ONGUSDT', 'price': '0.31540000'},
#  {'symbol': 'HOTBNB', 'price': '0.00000862'},
#  {'symbol': 'HOTUSDT', 'price': '0.00159000'},
#  {'symbol': 'ZILUSDT', 'price': '0.01470000'},
#  {'symbol': 'ZRXBNB', 'price': '0.01045000'},
#  {'symbol': 'ZRXUSDT', 'price': '0.32670000'},
#  {'symbol': 'FETBNB', 'price': '0.00234500'},
#  {'symbol': 'FETBTC', 'price': '0.00002057'},
#  {'symbol': 'FETUSDT', 'price': '1.39400000'},
#  {'symbol': 'BATUSDT', 'price': '0.17390000'},
#  {'symbol': 'XMRBNB', 'price': '0.33210000'},
#  {'symbol': 'XMRUSDT', 'price': '118.70000000'},
#  {'symbol': 'ZECBNB', 'price': '0.10260000'},
#  {'symbol': 'ZECUSDT', 'price': '36.43000000'},
#  {'symbol': 'ZECPAX', 'price': '42.10000000'},
#  {'symbol': 'ZECTUSD', 'price': '51.48000000'},
#  {'symbol': 'ZECUSDC', 'price': '55.80000000'},
#  {'symbol': 'IOSTUSDT', 'price': '0.00502000'},
#  {'symbol': 'CELRBNB', 'price': '0.00005294'},
#  {'symbol': 'CELRBTC', 'price': '0.00000019'},
#  {'symbol': 'CELRUSDT', 'price': '0.01279000'},
#  {'symbol': 'ADAPAX', 'price': '0.03257000'},
#  {'symbol': 'ADAUSDC', 'price': '0.34600000'},
#  {'symbol': 'NEOPAX', 'price': '11.12200000'},
#  {'symbol': 'NEOUSDC', 'price': '10.42000000'},
#  {'symbol': 'DASHBNB', 'price': '0.11830000'},
#  {'symbol': 'DASHUSDT', 'price': '23.54000000'},
#  {'symbol': 'NANOUSDT', 'price': '2.22400000'},
#  {'symbol': 'OMGBNB', 'price': '0.03938000'},
#  {'symbol': 'OMGUSDT', 'price': '0.38300000'},
#  {'symbol': 'THETAUSDT', 'price': '1.27000000'},
#  {'symbol': 'ENJUSDT', 'price': '0.14770000'},
#  {'symbol': 'MITHUSDT', 'price': '0.00345000'},
#  {'symbol': 'MATICBNB', 'price': '0.00073400'},
#  {'symbol': 'MATICBTC', 'price': '0.00000667'},
#  {'symbol': 'MATICUSDT', 'price': '0.37940000'},
#  {'symbol': 'ATOMBNB', 'price': '0.00739000'},
#  {'symbol': 'ATOMBTC', 'price': '0.00006410'},
#  {'symbol': 'ATOMUSDT', 'price': '4.34400000'},
#  {'symbol': 'ATOMUSDC', 'price': '4.34300000'},
#  {'symbol': 'ATOMPAX', 'price': '3.17800000'},
#  {'symbol': 'ATOMTUSD', 'price': '2.59800000'},
#  {'symbol': 'ETCUSDC', 'price': '4.71000000'},
#  {'symbol': 'ETCPAX', 'price': '4.83800000'},
#  {'symbol': 'ETCTUSD', 'price': '3.79500000'},
#  {'symbol': 'BATUSDC', 'price': '0.63130000'},
#  {'symbol': 'BATPAX', 'price': '0.25560000'},
#  {'symbol': 'BATTUSD', 'price': '0.22220000'},
#  {'symbol': 'PHBBNB', 'price': '0.00013700'},
#  {'symbol': 'PHBBTC', 'price': '0.00002832'},
#  {'symbol': 'PHBUSDC', 'price': '0.00587000'},
#  {'symbol': 'PHBTUSD', 'price': '0.22900000'},
#  {'symbol': 'PHBPAX', 'price': '0.00639000'},
#  {'symbol': 'TFUELBNB', 'price': '0.00012590'},
#  {'symbol': 'TFUELBTC', 'price': '0.00000090'},
#  {'symbol': 'TFUELUSDT', 'price': '0.06072000'},
#  {'symbol': 'TFUELUSDC', 'price': '0.00356500'},
#  {'symbol': 'TFUELTUSD', 'price': '0.00307700'},
#  {'symbol': 'TFUELPAX', 'price': '0.00348700'},
#  {'symbol': 'ONEBNB', 'price': '0.00004537'},
#  {'symbol': 'ONEBTC', 'price': '0.00000021'},
#  {'symbol': 'ONEUSDT', 'price': '0.01365000'},
#  {'symbol': 'ONETUSD', 'price': '0.00472000'},
#  {'symbol': 'ONEPAX', 'price': '0.00496000'},
#  {'symbol': 'ONEUSDC', 'price': '0.00520000'},
#  {'symbol': 'FTMBNB', 'price': '0.00119700'},
#  {'symbol': 'FTMBTC', 'price': '0.00001050'},
#  {'symbol': 'FTMUSDT', 'price': '0.71130000'},
#  {'symbol': 'FTMTUSD', 'price': '0.01095000'},
#  {'symbol': 'FTMPAX', 'price': '0.01028000'},
#  {'symbol': 'FTMUSDC', 'price': '0.71110000'},
#  {'symbol': 'BTCBBTC', 'price': '1.00000000'},
#  {'symbol': 'BCPTTUSD', 'price': '0.02606000'},
#  {'symbol': 'BCPTPAX', 'price': '0.02761000'},
#  {'symbol': 'BCPTUSDC', 'price': '0.02728000'},
#  {'symbol': 'ALGOBNB', 'price': '0.00058250'},
#  {'symbol': 'ALGOBTC', 'price': '0.00000180'},
#  {'symbol': 'ALGOUSDT', 'price': '0.12180000'},
#  {'symbol': 'ALGOTUSD', 'price': '1.01700000'},
#  {'symbol': 'ALGOPAX', 'price': '0.20390000'},
#  {'symbol': 'ALGOUSDC', 'price': '0.12180000'},
#  {'symbol': 'USDSBUSDT', 'price': '0.99970000'},
#  {'symbol': 'USDSBUSDS', 'price': '0.99990000'},
#  {'symbol': 'GTOUSDT', 'price': '0.01233000'},
#  {'symbol': 'GTOPAX', 'price': '0.01361000'},
#  {'symbol': 'GTOTUSD', 'price': '0.01236000'},
#  {'symbol': 'GTOUSDC', 'price': '0.01196000'},
#  {'symbol': 'ERDBNB', 'price': '0.00083273'},
#  {'symbol': 'ERDBTC', 'price': '0.00000168'},
#  {'symbol': 'ERDUSDT', 'price': '0.01971000'},
#  {'symbol': 'ERDPAX', 'price': '0.00125270'},
#  {'symbol': 'ERDUSDC', 'price': '0.00135730'},
#  {'symbol': 'DOGEBNB', 'price': '0.00015270'},
#  {'symbol': 'DOGEBTC', 'price': '0.00000198'},
#  {'symbol': 'DOGEUSDT', 'price': '0.13387000'},
#  {'symbol': 'DOGEPAX', 'price': '0.00216820'},
#  {'symbol': 'DOGEUSDC', 'price': '0.13387000'},
#  {'symbol': 'DUSKBNB', 'price': '0.00118000'},
#  {'symbol': 'DUSKBTC', 'price': '0.00000291'},
#  {'symbol': 'DUSKUSDT', 'price': '0.19680000'},
#  {'symbol': 'DUSKUSDC', 'price': '0.01790000'},
#  {'symbol': 'DUSKPAX', 'price': '0.01890000'},
#  {'symbol': 'BGBPUSDC', 'price': '1.39000000'},
#  {'symbol': 'ANKRBNB', 'price': '0.00008560'},
#  {'symbol': 'ANKRBTC', 'price': '0.00000039'},
#  {'symbol': 'ANKRUSDT', 'price': '0.02683000'},
#  {'symbol': 'ANKRTUSD', 'price': '0.00212800'},
#  {'symbol': 'ANKRPAX', 'price': '0.00209300'},
#  {'symbol': 'ANKRUSDC', 'price': '0.00209700'},
#  {'symbol': 'ONTPAX', 'price': '0.84510000'},
#  {'symbol': 'ONTUSDC', 'price': '0.19050000'},
#  {'symbol': 'WINBNB', 'price': '0.00000015'},
#  {'symbol': 'WINBTC', 'price': '0.00000001'},
#  {'symbol': 'WINUSDT', 'price': '0.00008570'},
#  {'symbol': 'WINUSDC', 'price': '0.00009730'},
#  {'symbol': 'COSBNB', 'price': '0.00002678'},
#  {'symbol': 'COSBTC', 'price': '0.00000011'},
#  {'symbol': 'COSUSDT', 'price': '0.00733100'},
#  {'symbol': 'TUSDBTUSD', 'price': '0.99750000'},
#  {'symbol': 'NPXSUSDT', 'price': '0.00703010'},
#  {'symbol': 'NPXSUSDC', 'price': '0.00017020'},
#  {'symbol': 'COCOSBNB', 'price': '0.00559000'},
#  {'symbol': 'COCOSBTC', 'price': '0.00000003'},
#  {'symbol': 'COCOSUSDT', 'price': '1.75460000'},
#  {'symbol': 'MTLUSDT', 'price': '0.96700000'},
#  {'symbol': 'TOMOBNB', 'price': '0.03255000'},
#  {'symbol': 'TOMOBTC', 'price': '0.00003699'},
#  {'symbol': 'TOMOUSDT', 'price': '1.38190000'},
#  {'symbol': 'TOMOUSDC', 'price': '0.36700000'},
#  {'symbol': 'PERLBNB', 'price': '0.00007180'},
#  {'symbol': 'PERLBTC', 'price': '0.00000113'},
#  {'symbol': 'PERLUSDC', 'price': '0.02447000'},
#  {'symbol': 'PERLUSDT', 'price': '0.00460000'},
#  {'symbol': 'DENTUSDT', 'price': '0.00087600'},
#  {'symbol': 'MFTUSDT', 'price': '0.00525400'},
#  {'symbol': 'KEYUSDT', 'price': '0.00380100'},
#  {'symbol': 'STORMUSDT', 'price': '0.00339700'},
#  {'symbol': 'DOCKUSDT', 'price': '0.00390000'},
#  {'symbol': 'WANUSDT', 'price': '0.17750000'},
#  {'symbol': 'FUNUSDT', 'price': '0.00338200'},
#  {'symbol': 'CVCUSDT', 'price': '0.13930000'},
#  {'symbol': 'BTTTRX', 'price': '0.03945000'},
#  {'symbol': 'WINTRX', 'price': '0.00053900'},
#  {'symbol': 'CHZBNB', 'price': '0.00012590'},
#  {'symbol': 'CHZBTC', 'price': '0.00000111'},
#  {'symbol': 'CHZUSDT', 'price': '0.07450000'},
#  {'symbol': 'BANDBNB', 'price': '0.02248000'},
#  {'symbol': 'BANDBTC', 'price': '0.00001652'},
#  {'symbol': 'BANDUSDT', 'price': '1.11900000'},
#  {'symbol': 'BNBBUSD', 'price': '251.80000000'},
#  {'symbol': 'BTCBUSD', 'price': '42769.40000000'},
#  {'symbol': 'BUSDUSDT', 'price': '1.00030000'},
#  {'symbol': 'BEAMBNB', 'price': '0.02177000'},
#  {'symbol': 'BEAMBTC', 'price': '0.00000716'},
#  {'symbol': 'BEAMUSDT', 'price': '0.06520000'},
#  {'symbol': 'XTZBNB', 'price': '0.00288300'},
#  {'symbol': 'XTZBTC', 'price': '0.00001007'},
#  {'symbol': 'XTZUSDT', 'price': '0.68300000'},
#  {'symbol': 'RENUSDT', 'price': '0.03588000'},
#  {'symbol': 'RVNUSDT', 'price': '0.01667000'},
#  {'symbol': 'HCUSDT', 'price': '0.84230000'},
#  {'symbol': 'HBARBNB', 'price': '0.00008600'},
#  {'symbol': 'HBARBTC', 'price': '0.00000075'},
#  {'symbol': 'HBARUSDT', 'price': '0.05110000'},
#  {'symbol': 'NKNBNB', 'price': '0.00074700'},
#  {'symbol': 'NKNBTC', 'price': '0.00000106'},
#  {'symbol': 'NKNUSDT', 'price': '0.07170000'},
#  {'symbol': 'XRPBUSD', 'price': '0.63450000'},
#  {'symbol': 'ETHBUSD', 'price': '2281.12000000'},
#  {'symbol': 'BCHABCBUSD', 'price': '220.16000000'},
#  {'symbol': 'LTCBUSD', 'price': '72.37000000'},
#  {'symbol': 'LINKBUSD', 'price': '14.07100000'},
#  {'symbol': 'ETCBUSD', 'price': '19.03000000'},
#  {'symbol': 'STXBNB', 'price': '0.00315300'},
#  {'symbol': 'STXBTC', 'price': '0.00002772'},
#  {'symbol': 'STXUSDT', 'price': '1.87800000'},
#  {'symbol': 'KAVABNB', 'price': '0.00276000'},
#  {'symbol': 'KAVABTC', 'price': '0.00000531'},
#  {'symbol': 'KAVAUSDT', 'price': '0.35890000'},
#  {'symbol': 'BUSDNGN', 'price': '462.64000000'},
#  {'symbol': 'BNBNGN', 'price': '43608.00000000'},
#  {'symbol': 'BTCNGN', 'price': '99822596.00000000'},
#  {'symbol': 'ARPABNB', 'price': '0.00015470'},
#  {'symbol': 'ARPABTC', 'price': '0.00000061'},
#  {'symbol': 'ARPAUSDT', 'price': '0.04088000'},
#  {'symbol': 'TRXBUSD', 'price': '0.10329000'},
#  {'symbol': 'EOSBUSD', 'price': '0.63400000'},
#  {'symbol': 'IOTXUSDT', 'price': '0.04065000'},
#  {'symbol': 'RLCUSDT', 'price': '1.50000000'},
#  {'symbol': 'MCOUSDT', 'price': '2.74400000'},
#  {'symbol': 'XLMBUSD', 'price': '0.11970000'},
#  {'symbol': 'ADABUSD', 'price': '0.63740000'},
#  {'symbol': 'CTXCBNB', 'price': '0.00412200'},
#  {'symbol': 'CTXCBTC', 'price': '0.00000313'},
#  {'symbol': 'CTXCUSDT', 'price': '0.21240000'},
#  {'symbol': 'BCHBNB', 'price': '0.61500000'},
#  {'symbol': 'BCHBTC', 'price': '0.00540300'},
#  {'symbol': 'BCHUSDT', 'price': '366.30000000'},
#  {'symbol': 'BCHUSDC', 'price': '366.20000000'},
#  {'symbol': 'BCHTUSD', 'price': '322.00000000'},
#  {'symbol': 'BCHPAX', 'price': '617.72000000'},
#  {'symbol': 'BCHBUSD', 'price': '236.00000000'},
#  {'symbol': 'BTCRUB', 'price': '3900027.00000000'},
#  {'symbol': 'ETHRUB', 'price': '181477.60000000'},
#  {'symbol': 'XRPRUB', 'price': '56.31000000'},
#  {'symbol': 'BNBRUB', 'price': '22422.22000000'},
#  {'symbol': 'TROYBNB', 'price': '0.00001060'},
#  {'symbol': 'TROYBTC', 'price': '0.00000018'},
#  {'symbol': 'TROYUSDT', 'price': '0.00143700'},
#  {'symbol': 'BUSDRUB', 'price': '90.39000000'},
#  {'symbol': 'QTUMBUSD', 'price': '2.53700000'},
#  {'symbol': 'VETBUSD', 'price': '0.02120000'},
#  {'symbol': 'VITEBNB', 'price': '0.00070700'},
#  {'symbol': 'VITEBTC', 'price': '0.00000019'},
#  {'symbol': 'VITEUSDT', 'price': '0.01252000'},
#  {'symbol': 'FTTBNB', 'price': '0.00513000'},
#  {'symbol': 'FTTBTC', 'price': '0.00008560'},
#  {'symbol': 'FTTUSDT', 'price': '1.93940000'},
#  {'symbol': 'BTCTRY', 'price': '2319560.00000000'},
#  {'symbol': 'BNBTRY', 'price': '20346.00000000'},
#  {'symbol': 'BUSDTRY', 'price': '29.33000000'},
#  {'symbol': 'ETHTRY', 'price': '89779.00000000'},
#  {'symbol': 'XRPTRY', 'price': '18.73000000'},
#  {'symbol': 'USDTTRY', 'price': '34.23000000'},
#  {'symbol': 'USDTRUB', 'price': '91.10000000'},
#  {'symbol': 'BTCEUR', 'price': '62435.49000000'},
#  {'symbol': 'ETHEUR', 'price': '2417.00000000'},
#  {'symbol': 'BNBEUR', 'price': '547.70000000'},
#  {'symbol': 'XRPEUR', 'price': '0.50420000'},
#  {'symbol': 'EURBUSD', 'price': '1.07570000'},
#  {'symbol': 'EURUSDT', 'price': '1.08530000'},
#  {'symbol': 'OGNBNB', 'price': '0.00038300'},
#  {'symbol': 'OGNBTC', 'price': '0.00000129'},
#  {'symbol': 'OGNUSDT', 'price': '0.08760000'},
#  {'symbol': 'DREPBNB', 'price': '0.00009380'},
#  {'symbol': 'DREPBTC', 'price': '0.00000039'},
#  {'symbol': 'DREPUSDT', 'price': '0.02560000'},
#  {'symbol': 'BULLUSDT', 'price': '1370.28000000'},
#  {'symbol': 'BULLBUSD', 'price': '1368.56000000'},
#  {'symbol': 'BEARUSDT', 'price': '11.16000000'},
#  {'symbol': 'BEARBUSD', 'price': '11.14000000'},
#  {'symbol': 'ETHBULLUSDT', 'price': '79.18000000'},
#  {'symbol': 'ETHBULLBUSD', 'price': '78.46000000'},
#  {'symbol': 'ETHBEARUSDT', 'price': '12.20000000'},
#  {'symbol': 'ETHBEARBUSD', 'price': '12.24000000'},
#  {'symbol': 'TCTBNB', 'price': '0.00041860'},
#  {'symbol': 'TCTBTC', 'price': '0.00000016'},
#  {'symbol': 'TCTUSDT', 'price': '0.00312000'},
#  {'symbol': 'WRXBNB', 'price': '0.00039800'},
#  {'symbol': 'WRXBTC', 'price': '0.00000455'},
#  {'symbol': 'WRXUSDT', 'price': '0.12030000'},
#  {'symbol': 'ICXBUSD', 'price': '0.16420000'},
#  {'symbol': 'BTSUSDT', 'price': '0.00540000'},
#  {'symbol': 'BTSBUSD', 'price': '0.01930000'},
#  {'symbol': 'LSKUSDT', 'price': '0.81300000'},
#  {'symbol': 'BNTUSDT', 'price': '0.51130000'},
#  {'symbol': 'BNTBUSD', 'price': '0.35990000'},
#  {'symbol': 'LTOBNB', 'price': '0.00248000'},
#  {'symbol': 'LTOBTC', 'price': '0.00000178'},
#  {'symbol': 'LTOUSDT', 'price': '0.12010000'},
#  {'symbol': 'ATOMBUSD', 'price': '11.21900000'},
#  {'symbol': 'DASHBUSD', 'price': '25.83000000'},
#  {'symbol': 'NEOBUSD', 'price': '6.73000000'},
#  {'symbol': 'WAVESBUSD', 'price': '2.21600000'},
#  {'symbol': 'XTZBUSD', 'price': '0.67100000'},
#  {'symbol': 'EOSBULLUSDT', 'price': '3.85000000'},
#  {'symbol': 'EOSBULLBUSD', 'price': '3.90000000'},
#  {'symbol': 'EOSBEARUSDT', 'price': '30.21000000'},
#  {'symbol': 'EOSBEARBUSD', 'price': '29.81000000'},
#  {'symbol': 'XRPBULLUSDT', 'price': '8.74000000'},
#  {'symbol': 'XRPBULLBUSD', 'price': '8.78000000'},
#  {'symbol': 'XRPBEARUSDT', 'price': '548.55000000'},
#  {'symbol': 'XRPBEARBUSD', 'price': '547.33000000'},
#  {'symbol': 'BATBUSD', 'price': '0.17090000'},
#  {'symbol': 'ENJBUSD', 'price': '0.26070000'},
#  {'symbol': 'NANOBUSD', 'price': '2.22500000'},
#  {'symbol': 'ONTBUSD', 'price': '0.15740000'},
#  {'symbol': 'RVNBUSD', 'price': '0.01525000'},
#  {'symbol': 'STRATBUSD', 'price': '0.49150000'},
#  {'symbol': 'STRATBNB', 'price': '0.01900000'},
#  {'symbol': 'STRATUSDT', 'price': '0.49040000'},
#  {'symbol': 'AIONBUSD', 'price': '0.07210000'},
#  {'symbol': 'AIONUSDT', 'price': '0.00943000'},
#  {'symbol': 'MBLBNB', 'price': '0.00001202'},
#  {'symbol': 'MBLBTC', 'price': '0.00000005'},
#  {'symbol': 'MBLUSDT', 'price': '0.00280400'},
#  {'symbol': 'COTIBNB', 'price': '0.00021230'},
#  {'symbol': 'COTIBTC', 'price': '0.00000145'},
#  {'symbol': 'COTIUSDT', 'price': '0.09776000'},
#  {'symbol': 'ALGOBUSD', 'price': '0.20710000'},
#  {'symbol': 'BTTBUSD', 'price': '0.00277800'},
#  {'symbol': 'TOMOBUSD', 'price': '1.78070000'},
#  {'symbol': 'XMRBUSD', 'price': '170.20000000'},
#  {'symbol': 'ZECBUSD', 'price': '25.50000000'},
#  {'symbol': 'BNBBULLUSDT', 'price': '57.21000000'},
#  {'symbol': 'BNBBULLBUSD', 'price': '58.37000000'},
#  {'symbol': 'BNBBEARUSDT', 'price': '58.61000000'},
#  {'symbol': 'BNBBEARBUSD', 'price': '57.21000000'},
#  {'symbol': 'STPTBNB', 'price': '0.00067000'},
#  {'symbol': 'STPTBTC', 'price': '0.00000066'},
#  {'symbol': 'STPTUSDT', 'price': '0.04421000'},
#  {'symbol': 'BTCZAR', 'price': '1214717.00000000'},
#  {'symbol': 'ETHZAR', 'price': '47015.00000000'},
#  {'symbol': 'BNBZAR', 'price': '5000.00000000'},
#  {'symbol': 'USDTZAR', 'price': '17.92000000'},
#  {'symbol': 'BUSDZAR', 'price': '18.85000000'},
#  {'symbol': 'BTCBKRW', 'price': '42029197.00000000'},
#  {'symbol': 'ETHBKRW', 'price': '1277799.00000000'},
#  {'symbol': 'BNBBKRW', 'price': '44687.00000000'},
#  {'symbol': 'WTCUSDT', 'price': '0.01030000'},
#  {'symbol': 'DATABUSD', 'price': '0.02344000'},
#  {'symbol': 'DATAUSDT', 'price': '0.03602000'},
#  {'symbol': 'XZCUSDT', 'price': '4.44600000'},
#  {'symbol': 'SOLBNB', 'price': '0.25770000'},
#  {'symbol': 'SOLBTC', 'price': '0.00225970'},
#  {'symbol': 'SOLUSDT', 'price': '153.09000000'},
#  {'symbol': 'SOLBUSD', 'price': '74.62000000'},
#  {'symbol': 'BTCIDRT', 'price': '693891182.00'},
#  {'symbol': 'BNBIDRT', 'price': '4286985.00'},
#  {'symbol': 'USDTIDRT', 'price': '15515.00'},
#  {'symbol': 'BUSDIDRT', 'price': '14389.00'},
#  {'symbol': 'CTSIBTC', 'price': '0.00000189'},
#  {'symbol': 'CTSIUSDT', 'price': '0.12760000'},
#  {'symbol': 'CTSIBNB', 'price': '0.00079830'},
#  {'symbol': 'CTSIBUSD', 'price': '0.16420000'},
#  {'symbol': 'HIVEBNB', 'price': '0.00429000'},
#  {'symbol': 'HIVEBTC', 'price': '0.00000293'},
#  {'symbol': 'HIVEUSDT', 'price': '0.19790000'},
#  {'symbol': 'CHRBNB', 'price': '0.00043770'},
#  {'symbol': 'CHRBTC', 'price': '0.00000268'},
#  {'symbol': 'CHRUSDT', 'price': '0.18210000'},
#  {'symbol': 'BTCUPUSDT', 'price': '16.60000000'},
#  {'symbol': 'BTCDOWNUSDT', 'price': '0.00118500'},
#  {'symbol': 'GXSUSDT', 'price': '1.79230000'},
#  {'symbol': 'ARDRUSDT', 'price': '0.08372000'},
#  {'symbol': 'ERDBUSD', 'price': '0.01966100'},
#  {'symbol': 'LENDUSDT', 'price': '0.51431000'},
#  {'symbol': 'HBARBUSD', 'price': '0.06020000'},
#  {'symbol': 'MATICBUSD', 'price': '0.86590000'},
#  {'symbol': 'WRXBUSD', 'price': '0.11050000'},
#  {'symbol': 'ZILBUSD', 'price': '0.01583000'},
#  {'symbol': 'MDTBNB', 'price': '0.00073720'},
#  {'symbol': 'MDTBTC', 'price': '0.00000064'},
#  {'symbol': 'MDTUSDT', 'price': '0.04302000'},
#  {'symbol': 'STMXBTC', 'price': '0.00000016'},
#  {'symbol': 'STMXETH', 'price': '0.00000292'},
#  {'symbol': 'STMXUSDT', 'price': '0.00560300'},
#  {'symbol': 'KNCBUSD', 'price': '0.63700000'},
#  {'symbol': 'KNCUSDT', 'price': '0.45490000'},
#  {'symbol': 'REPBUSD', 'price': '13.67300000'},
#  {'symbol': 'REPUSDT', 'price': '4.73000000'},
#  {'symbol': 'LRCBUSD', 'price': '0.17280000'},
#  {'symbol': 'LRCUSDT', 'price': '0.12230000'},
#  {'symbol': 'IQBNB', 'price': '0.00002243'},
#  {'symbol': 'IQBUSD', 'price': '0.00502000'},
#  {'symbol': 'PNTBTC', 'price': '0.00000864'},
#  {'symbol': 'PNTUSDT', 'price': '0.03500000'},
#  {'symbol': 'BTCGBP', 'price': '35986.75000000'},
#  {'symbol': 'ETHGBP', 'price': '1974.32000000'},
#  {'symbol': 'XRPGBP', 'price': '0.52570000'},
#  {'symbol': 'BNBGBP', 'price': '267.40000000'},
#  {'symbol': 'GBPBUSD', 'price': '1.23900000'},
#  {'symbol': 'DGBBTC', 'price': '0.00000009'},
#  {'symbol': 'DGBBUSD', 'price': '0.00632000'},
#  {'symbol': 'BTCUAH', 'price': '2965700.00000000'},
#  {'symbol': 'USDTUAH', 'price': '43.75000000'},
#  {'symbol': 'COMPBTC', 'price': '0.00066000'},
#  {'symbol': 'COMPBNB', 'price': '5.71900000'},
#  {'symbol': 'COMPBUSD', 'price': '45.79000000'},
#  {'symbol': 'COMPUSDT', 'price': '44.39000000'},
#  {'symbol': 'BTCBIDR', 'price': '1042508253.00'},
#  {'symbol': 'ETHBIDR', 'price': '47041943.00'},
#  {'symbol': 'BNBBIDR', 'price': '3335250.00'},
#  {'symbol': 'BUSDBIDR', 'price': '15559.00'},
#  {'symbol': 'USDTBIDR', 'price': '15980.00'},
#  {'symbol': 'BKRWUSDT', 'price': '0.00084530'},
#  {'symbol': 'BKRWBUSD', 'price': '0.00084550'},
#  {'symbol': 'SCUSDT', 'price': '0.00493600'},
#  {'symbol': 'ZENUSDT', 'price': '8.03000000'},
#  {'symbol': 'SXPBTC', 'price': '0.00000380'},
#  {'symbol': 'SXPBNB', 'price': '0.00044000'},
#  {'symbol': 'SXPBUSD', 'price': '0.37210000'},
#  {'symbol': 'SNXBTC', 'price': '0.00002142'},
#  {'symbol': 'SNXBNB', 'price': '0.01057000'},
#  {'symbol': 'SNXBUSD', 'price': '1.93600000'},
#  {'symbol': 'SNXUSDT', 'price': '1.44900000'},
#  {'symbol': 'ETHUPUSDT', 'price': '11.65100000'},
#  {'symbol': 'ETHDOWNUSDT', 'price': '0.04570000'},
#  {'symbol': 'ADAUPUSDT', 'price': '0.10400000'},
#  {'symbol': 'ADADOWNUSDT', 'price': '0.00191700'},
#  {'symbol': 'LINKUPUSDT', 'price': '0.00608000'},
#  {'symbol': 'LINKDOWNUSDT', 'price': '0.00089500'},
#  {'symbol': 'VTHOBNB', 'price': '0.00000673'},
#  {'symbol': 'VTHOBUSD', 'price': '0.00071800'},
#  {'symbol': 'VTHOUSDT', 'price': '0.00183200'},
#  {'symbol': 'DCRBUSD', 'price': '16.03500000'},
#  {'symbol': 'DGBUSDT', 'price': '0.00663000'},
#  {'symbol': 'GBPUSDT', 'price': '1.18000000'},
#  {'symbol': 'STORJBUSD', 'price': '0.23710000'},
#  {'symbol': 'SXPUSDT', 'price': '0.25630000'},
#  {'symbol': 'IRISBNB', 'price': '0.00166200'},
#  {'symbol': 'IRISBTC', 'price': '0.00000022'},
#  {'symbol': 'IRISBUSD', 'price': '0.06080000'},
#  {'symbol': 'MKRBNB', 'price': '6.90300000'},
#  {'symbol': 'MKRBTC', 'price': '0.01782000'},
#  {'symbol': 'MKRUSDT', 'price': '1205.00000000'},
#  {'symbol': 'MKRBUSD', 'price': '1293.00000000'},
#  {'symbol': 'DAIBNB', 'price': '0.04876000'},
#  {'symbol': 'DAIBTC', 'price': '0.00008966'},
#  {'symbol': 'DAIUSDT', 'price': '1.01890000'},
#  {'symbol': 'DAIBUSD', 'price': '1.01810000'},
#  {'symbol': 'RUNEBNB', 'price': '0.00820900'},
#  {'symbol': 'RUNEBTC', 'price': '0.00007196'},
#  {'symbol': 'RUNEBUSD', 'price': '5.46200000'},
#  {'symbol': 'MANABUSD', 'price': '0.43880000'},
#  {'symbol': 'DOGEBUSD', 'price': '0.09742000'},
#  {'symbol': 'LENDBUSD', 'price': '0.51530000'},
#  {'symbol': 'ZRXBUSD', 'price': '0.16890000'},
#  {'symbol': 'DCRUSDT', 'price': '12.59000000'},
#  {'symbol': 'STORJUSDT', 'price': '0.63660000'},
#  {'symbol': 'XRPBKRW', 'price': '319.76000000'},
#  {'symbol': 'ADABKRW', 'price': '327.55000000'},
#  {'symbol': 'BTCAUD', 'price': '37210.08000000'},
#  {'symbol': 'ETHAUD', 'price': '2565.09000000'},
#  {'symbol': 'AUDBUSD', 'price': '0.72550000'},
#  {'symbol': 'FIOBNB', 'price': '0.00017080'},
#  {'symbol': 'FIOBTC', 'price': '0.00000045'},
#  {'symbol': 'FIOBUSD', 'price': '0.01922000'},
#  {'symbol': 'BNBUPUSDT', 'price': '61.80000000'},
#  {'symbol': 'BNBDOWNUSDT', 'price': '0.00215100'},
#  {'symbol': 'XTZUPUSDT', 'price': '0.00255100'},
#  {'symbol': 'XTZDOWNUSDT', 'price': '2.60010000'},
#  {'symbol': 'AVABNB', 'price': '0.00218800'},
#  {'symbol': 'AVABTC', 'price': '0.00000728'},
#  {'symbol': 'AVABUSD', 'price': '0.47000000'},
#  {'symbol': 'USDTBKRW', 'price': '1125.00000000'},
#  {'symbol': 'BUSDBKRW', 'price': '1097.18000000'},
#  {'symbol': 'IOTABUSD', 'price': '0.14310000'},
#  {'symbol': 'MANAUSDT', 'price': '0.30010000'},
#  {'symbol': 'XRPAUD', 'price': '0.70000000'},
#  {'symbol': 'BNBAUD', 'price': '421.10000000'},
#  {'symbol': 'AUDUSDT', 'price': '0.72520000'},
#  {'symbol': 'BALBNB', 'price': '0.42580000'},
#  {'symbol': 'BALBTC', 'price': '0.00003122'},
#  {'symbol': 'BALBUSD', 'price': '3.15000000'},
#  {'symbol': 'YFIBNB', 'price': '82.19000000'},
#  {'symbol': 'YFIBTC', 'price': '0.07270000'},
#  {'symbol': 'YFIBUSD', 'price': '5325.00000000'},
#  {'symbol': 'YFIUSDT', 'price': '4925.00000000'},
#  {'symbol': 'BLZBUSD', 'price': '0.05530000'},
#  {'symbol': 'KMDBUSD', 'price': '0.46760000'},
#  {'symbol': 'BALUSDT', 'price': '2.02300000'},
#  {'symbol': 'BLZUSDT', 'price': '0.12520000'},
#  {'symbol': 'IRISUSDT', 'price': '0.01464000'},
#  {'symbol': 'KMDUSDT', 'price': '0.25050000'},
#  {'symbol': 'BTCDAI', 'price': '67823.42000000'},
#  {'symbol': 'ETHDAI', 'price': '2617.59000000'},
#  {'symbol': 'BNBDAI', 'price': '561.90000000'},
#  {'symbol': 'USDTDAI', 'price': '0.99990000'},
#  {'symbol': 'BUSDDAI', 'price': '1.00000000'},
#  {'symbol': 'JSTBNB', 'price': '0.00021850'},
#  {'symbol': 'JSTBTC', 'price': '0.00000044'},
#  {'symbol': 'JSTBUSD', 'price': '0.02103000'},
#  {'symbol': 'JSTUSDT', 'price': '0.03026000'},
#  {'symbol': 'SRMBNB', 'price': '0.00084000'},
#  {'symbol': 'SRMBTC', 'price': '0.00001523'},
#  {'symbol': 'SRMBUSD', 'price': '0.03530000'},
#  {'symbol': 'SRMUSDT', 'price': '0.24442000'},
#  {'symbol': 'ANTBNB', 'price': '0.01764000'},
#  {'symbol': 'ANTBTC', 'price': '0.00014320'},
#  {'symbol': 'ANTBUSD', 'price': '4.30300000'},
#  {'symbol': 'ANTUSDT', 'price': '7.40700000'},
#  {'symbol': 'CRVBNB', 'price': '0.00687000'},
#  {'symbol': 'CRVBTC', 'price': '0.00000391'},
#  {'symbol': 'CRVBUSD', 'price': '0.50410000'},
#  {'symbol': 'CRVUSDT', 'price': '0.26480000'},
#  {'symbol': 'SANDBNB', 'price': '0.00066800'},
#  {'symbol': 'SANDBTC', 'price': '0.00000384'},
#  {'symbol': 'SANDUSDT', 'price': '0.25980000'},
#  {'symbol': 'SANDBUSD', 'price': '0.32610000'},
#  {'symbol': 'OCEANBNB', 'price': '0.00104400'},
#  {'symbol': 'OCEANBTC', 'price': '0.00000964'},
#  {'symbol': 'OCEANBUSD', 'price': '0.28480000'},
#  {'symbol': 'OCEANUSDT', 'price': '0.61230000'},
#  {'symbol': 'NMRBTC', 'price': '0.00021750'},
#  {'symbol': 'NMRBUSD', 'price': '11.43000000'},
#  {'symbol': 'NMRUSDT', 'price': '14.67000000'},
#  {'symbol': 'DOTBNB', 'price': '0.00708000'},
#  {'symbol': 'DOTBTC', 'price': '0.00006220'},
#  {'symbol': 'DOTBUSD', 'price': '7.37300000'},
#  {'symbol': 'DOTUSDT', 'price': '4.21600000'},
#  {'symbol': 'LUNABNB', 'price': '0.00000019'},
#  {'symbol': 'LUNABTC', 'price': '0.00000001'},
#  {'symbol': 'LUNABUSD', 'price': '0.94420000'},
#  {'symbol': 'LUNAUSDT', 'price': '0.36440000'},
#  {'symbol': 'IDEXBTC', 'price': '0.00000054'},
#  {'symbol': 'IDEXBUSD', 'price': '0.04879000'},
#  {'symbol': 'RSRBNB', 'price': '0.00000852'},
#  {'symbol': 'RSRBTC', 'price': '0.00000016'},
#  {'symbol': 'RSRBUSD', 'price': '0.00184000'},
#  {'symbol': 'RSRUSDT', 'price': '0.00702400'},
#  {'symbol': 'PAXGBNB', 'price': '6.46900000'},
#  {'symbol': 'PAXGBTC', 'price': '0.04012000'},
#  {'symbol': 'PAXGBUSD', 'price': '1941.00000000'},
#  {'symbol': 'PAXGUSDT', 'price': '2720.00000000'},
#  {'symbol': 'WNXMBNB', 'price': '0.17350000'},
#  {'symbol': 'WNXMBTC', 'price': '0.00067200'},
#  {'symbol': 'WNXMBUSD', 'price': '22.16500000'},
#  {'symbol': 'WNXMUSDT', 'price': '73.26000000'},
#  {'symbol': 'TRBBNB', 'price': '0.51700000'},
#  {'symbol': 'TRBBTC', 'price': '0.00094600'},
#  {'symbol': 'TRBBUSD', 'price': '90.12000000'},
#  {'symbol': 'TRBUSDT', 'price': '63.95000000'},
#  {'symbol': 'ETHNGN', 'price': '805670.00000000'},
#  {'symbol': 'DOTBIDR', 'price': '72297.00'},
#  {'symbol': 'LINKAUD', 'price': '7.98600000'},
#  {'symbol': 'SXPAUD', 'price': '1.86800000'},
#  {'symbol': 'BZRXBNB', 'price': '0.00514000'},
#  {'symbol': 'BZRXBTC', 'price': '0.00000463'},
#  {'symbol': 'BZRXBUSD', 'price': '0.21640000'},
#  {'symbol': 'BZRXUSDT', 'price': '0.21560000'},
#  {'symbol': 'WBTCBTC', 'price': '0.99850000'},
#  {'symbol': 'WBTCETH', 'price': '25.83000000'},
#  {'symbol': 'SUSHIBNB', 'price': '0.00269800'},
#  {'symbol': 'SUSHIBTC', 'price': '0.00001038'},
#  {'symbol': 'SUSHIBUSD', 'price': '0.56600000'},
#  {'symbol': 'SUSHIUSDT', 'price': '0.70300000'},
#  {'symbol': 'YFIIBNB', 'price': '4.42000000'},
#  {'symbol': 'YFIIBTC', 'price': '0.07249000'},
#  {'symbol': 'YFIIBUSD', 'price': '1192.00000000'},
#  {'symbol': 'YFIIUSDT', 'price': '435.50000000'},
#  {'symbol': 'KSMBNB', 'price': '0.09080000'},
#  {'symbol': 'KSMBTC', 'price': '0.00026540'},
#  {'symbol': 'KSMBUSD', 'price': '18.87000000'},
#  {'symbol': 'KSMUSDT', 'price': '17.96000000'},
#  {'symbol': 'EGLDBNB', 'price': '0.04360000'},
#  ...]

# %%
df = pd.DataFrame(prices)
df
# Out:
#          symbol         price
# 0        ETHBTC    0.03870000
# 1        LTCBTC    0.00106400
# 2        BNBBTC    0.00877300
# 3        NEOBTC    0.00015370
# 4       QTUMETH    0.00095000
# ...         ...           ...
# 2761    SCRUSDT    1.25800000
# 2762     SUIBRL   11.74000000
# 2763   TURBOTRY    0.35900000
# 2764  BNSOLUSDT  154.30000000
# 2765  LUMIAUSDT    1.68100000
#
# [2766 rows x 2 columns]

# %%
df[df.symbol.str.contains("ETH")]
# Out:
#           symbol             price
# 0         ETHBTC        0.03870000
# 4        QTUMETH        0.00095000
# 5         EOSETH        0.00018220
# 6         SNTETH        0.00001027
# 7         BNTETH        0.00019520
# ...          ...               ...
# 2545  ETHFIFDUSD        1.61200000
# 2546    ETHFITRY       55.07000000
# 2586   ETHFIUSDC        1.60500000
# 2684      ETHARS  3176794.00000000
# 2730      POLETH        0.00013930
#
# [267 rows x 2 columns]

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("USD")]
# Out:
#            symbol           price
# 11        BTCUSDT  67761.87000000
# 312       BTCTUSD  67897.30000000
# 313       TUSDBTC      0.00025971
# 417       BTCUSDC  67748.85000000
# 454       BTCUSDS   9604.59000000
# 614       BTCBUSD  42769.40000000
# 795     BTCUPUSDT     16.60000000
# 796   BTCDOWNUSDT      0.00118500
# 1190      SUSDBTC      0.00002065
# 1240    BTCSTBUSD      1.16000000
# 1241    BTCSTUSDT      5.35000000
# 1621      BTCUSDP  19435.03000000
# 2070     WBTCBUSD  40760.13000000
# 2198     WBTCUSDT  67653.35000000
# 2268     BTCFDUSD  67822.39000000

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("EUR")]
# Out:
#        symbol           price
# 689    BTCEUR  62435.49000000
# 2376  BTCAEUR  51466.50000000
# 2747  BTCEURI  62520.72000000

# %%
last24 = client.get_ticker(symbol = "ETHUSDT") # 24H Price change statistic
last24
# Out:
# {'symbol': 'ETHUSDT',
#  'priceChange': '65.75000000',
#  'priceChangePercent': '2.535',
#  'weightedAvgPrice': '2634.10312044',
#  'prevClosePrice': '2593.89000000',
#  'lastPrice': '2659.65000000',
#  'lastQty': '1.03930000',
#  'bidPrice': '2659.64000000',
#  'bidQty': '20.78090000',
#  'askPrice': '2659.65000000',
#  'askQty': '82.57140000',
#  'openPrice': '2593.90000000',
#  'highPrice': '2675.58000000',
#  'lowPrice': '2591.00000000',
#  'volume': '283545.36520000',
#  'quoteVolume': '746887731.25912600',
#  'openTime': 1729193197817,
#  'closeTime': 1729279597817,
#  'firstId': 1653114313,
#  'lastId': 1655896200,
#  'count': 2781888}

# %%
last24["openTime"]
# Out:
# 1729167693992

# %%
pd.to_datetime(last24["openTime"], unit = "ms")
# Out:
# Timestamp('2024-10-17 12:21:33.992000')

# %%
pd.to_datetime(last24["closeTime"], unit = "ms")
# Out:
# Timestamp('2024-10-18 12:21:33.992000')

# %%
open_price = float(last24["openPrice"])
open_price
# Out:
# 2610.39

# %%
high_price = float(last24["highPrice"])
high_price
# Out:
# 2651.66

# %%
low_price = float(last24["lowPrice"])
low_price
# Out:
# 2575.4

# %%
close_price = float(last24["lastPrice"])
close_price
# Out:
# 2622.1

# %%
close_price - open_price
# Out:
# 11.710000000000036

# %%
(close_price/open_price - 1) * 100
# Out:
# 0.44859197284696783

# %% [markdown]
# ## Getting Historical Data (OHLC & Volume) - Part 1

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
timestamp = client._get_earliest_valid_timestamp(symbol = "BTCUSDT", interval = "1d")
timestamp # earliest data available on Binance
# Out:
# 1502928000000

# %%
pd.to_datetime(timestamp, unit = "ms") # earliest data available on Binance
# Out:
# Timestamp('2017-08-17 00:00:00')

# %%
bars = client.get_historical_klines(symbol = "ADAUSDT",
                                    interval = "1d", start_str = timestamp, limit = 1000)
bars
# Out:
# [[1523923200000,
#   '0.25551000',
#   '0.28800000',
#   '0.23983000',
#   '0.24260000',
#   '67462293.24000000',
#   1524009599999,
#   '17411823.57157960',
#   42568,
#   '28228665.39000000',
#   '7281513.06137010',
#   '0'],
#  [1524009600000,
#   '0.24260000',
#   '0.26460000',
#   '0.24201000',
#   '0.26200000',
#   '31328095.79000000',
#   1524095999999,
#   '7922134.28304330',
#   21684,
#   '15082512.84000000',
#   '3818068.82632840',
#   '0'],
#  [1524096000000,
#   '0.26199000',
#   '0.27500000',
#   '0.25777000',
#   '0.27004000',
#   '50859980.22000000',
#   1524182399999,
#   '13609907.89978870',
#   32600,
#   '23934593.69000000',
#   '6408750.31190170',
#   '0'],
#  [1524182400000,
#   '0.27004000',
#   '0.30442000',
#   '0.26648000',
#   '0.30108000',
#   '71084276.49000000',
#   1524268799999,
#   '20270887.70351350',
#   46506,
#   '35262790.18000000',
#   '10040840.12777730',
#   '0'],
#  [1524268800000,
#   '0.30161000',
#   '0.30700000',
#   '0.26509000',
#   '0.28668000',
#   '92719842.91000000',
#   1524355199999,
#   '26539390.12720960',
#   55256,
#   '43517191.79000000',
#   '12413648.37070700',
#   '0'],
#  [1524355200000,
#   '0.28669000',
#   '0.29730000',
#   '0.27716000',
#   '0.28160000',
#   '48693828.46000000',
#   1524441599999,
#   '13995484.40681160',
#   31512,
#   '23214895.86000000',
#   '6679180.53730580',
#   '0'],
#  [1524441600000,
#   '0.28160000',
#   '0.28867000',
#   '0.28064000',
#   '0.28788000',
#   '34341260.85000000',
#   1524527999999,
#   '9788784.21676100',
#   22695,
#   '13692447.50000000',
#   '3904591.52166740',
#   '0'],
#  [1524528000000,
#   '0.28798000',
#   '0.32000000',
#   '0.28593000',
#   '0.30853000',
#   '90526059.79000000',
#   1524614399999,
#   '27728564.26935270',
#   59339,
#   '43507259.85000000',
#   '13294488.19719800',
#   '0'],
#  [1524614400000,
#   '0.30850000',
#   '0.31099000',
#   '0.25730000',
#   '0.26870000',
#   '124688510.26000000',
#   1524700799999,
#   '34935280.91710510',
#   75613,
#   '53116874.13000000',
#   '14847651.65233860',
#   '0'],
#  [1524700800000,
#   '0.26870000',
#   '0.29390000',
#   '0.25500000',
#   '0.29326000',
#   '68109625.26000000',
#   1524787199999,
#   '18704063.46005310',
#   46981,
#   '31814747.97000000',
#   '8746078.16855260',
#   '0'],
#  [1524787200000,
#   '0.29326000',
#   '0.30643000',
#   '0.28145000',
#   '0.28445000',
#   '69781321.86000000',
#   1524873599999,
#   '20504315.28290510',
#   46133,
#   '34026765.74000000',
#   '10013836.69712220',
#   '0'],
#  [1524873600000,
#   '0.28440000',
#   '0.36498000',
#   '0.28170000',
#   '0.35676000',
#   '168937876.23000000',
#   1524959999999,
#   '56407387.72753420',
#   103617,
#   '89831223.31000000',
#   '29871051.66850670',
#   '0'],
#  [1524960000000,
#   '0.35675000',
#   '0.38660000',
#   '0.34150000',
#   '0.36254000',
#   '162840221.99000000',
#   1525046399999,
#   '59607359.48185200',
#   103067,
#   '79911394.87000000',
#   '29289779.12516260',
#   '0'],
#  [1525046400000,
#   '0.36251000',
#   '0.36370000',
#   '0.33000000',
#   '0.34145000',
#   '93142615.39000000',
#   1525132799999,
#   '32338238.10860640',
#   71564,
#   '40477907.58000000',
#   '14067204.94713020',
#   '0'],
#  [1525132800000,
#   '0.34145000',
#   '0.36034000',
#   '0.31870000',
#   '0.35504000',
#   '120368721.75000000',
#   1525219199999,
#   '40859083.99584130',
#   71249,
#   '56496967.88000000',
#   '19249295.83064260',
#   '0'],
#  [1525219200000,
#   '0.35498000',
#   '0.37586000',
#   '0.34500000',
#   '0.37199000',
#   '65457686.29000000',
#   1525305599999,
#   '23759298.72861260',
#   54666,
#   '34084267.41000000',
#   '12386872.99135150',
#   '0'],
#  [1525305600000,
#   '0.37199000',
#   '0.38850000',
#   '0.36402000',
#   '0.36716000',
#   '88326409.65000000',
#   1525391999999,
#   '32983955.92400440',
#   68511,
#   '37735576.74000000',
#   '14118032.42835880',
#   '0'],
#  [1525392000000,
#   '0.36683000',
#   '0.36897000',
#   '0.34650000',
#   '0.35800000',
#   '56069269.37000000',
#   1525478399999,
#   '20199051.78382620',
#   44209,
#   '26029367.87000000',
#   '9365192.77335090',
#   '0'],
#  [1525478400000,
#   '0.35840000',
#   '0.37434000',
#   '0.35771000',
#   '0.36502000',
#   '46962690.28000000',
#   1525564799999,
#   '17211963.40023110',
#   37709,
#   '19905635.98000000',
#   '7303836.40030630',
#   '0'],
#  [1525564800000,
#   '0.36502000',
#   '0.36641000',
#   '0.33538000',
#   '0.34654000',
#   '63926868.16000000',
#   1525651199999,
#   '22202800.22710520',
#   45636,
#   '27676267.84000000',
#   '9566932.91087640',
#   '0'],
#  [1525651200000,
#   '0.34599000',
#   '0.34740000',
#   '0.29100000',
#   '0.33046000',
#   '64060938.79000000',
#   1525737599999,
#   '20855267.85060130',
#   45899,
#   '29922663.51000000',
#   '9738982.25201350',
#   '0'],
#  [1525737600000,
#   '0.33079000',
#   '0.34559000',
#   '0.31630000',
#   '0.32213000',
#   '45105012.01000000',
#   1525823999999,
#   '14851982.50779050',
#   36389,
#   '21315327.90000000',
#   '7019394.55230880',
#   '0'],
#  [1525824000000,
#   '0.32213000',
#   '0.32547000',
#   '0.29800000',
#   '0.31884000',
#   '60635549.24000000',
#   1525910399999,
#   '18957201.22022620',
#   40624,
#   '27673515.06000000',
#   '8653246.94053100',
#   '0'],
#  [1525910400000,
#   '0.31884000',
#   '0.32210000',
#   '0.29100000',
#   '0.29121000',
#   '38210521.24000000',
#   1525996799999,
#   '11849062.06166730',
#   33669,
#   '16174022.91000000',
#   '5021601.92107810',
#   '0'],
#  [1525996800000,
#   '0.29121000',
#   '0.29349000',
#   '0.24880000',
#   '0.25573000',
#   '141274876.67000000',
#   1526083199999,
#   '37716105.25114700',
#   87880,
#   '62311865.76000000',
#   '16625795.60604480',
#   '0'],
#  [1526083200000,
#   '0.25574000',
#   '0.27898000',
#   '0.23402000',
#   '0.26550000',
#   '145891622.18000000',
#   1526169599999,
#   '37755754.09387690',
#   75721,
#   '66419359.07000000',
#   '17156522.08308550',
#   '0'],
#  [1526169600000,
#   '0.26497000',
#   '0.28500000',
#   '0.25600000',
#   '0.27718000',
#   '80814388.52000000',
#   1526255999999,
#   '21946942.40714350',
#   47969,
#   '41444236.40000000',
#   '11264384.73173870',
#   '0'],
#  [1526256000000,
#   '0.27718000',
#   '0.27815000',
#   '0.25123000',
#   '0.26655000',
#   '91273066.64000000',
#   1526342399999,
#   '24211870.75738980',
#   52143,
#   '43694904.03000000',
#   '11601713.32198880',
#   '0'],
#  [1526342400000,
#   '0.26631000',
#   '0.27500000',
#   '0.25130000',
#   '0.25394000',
#   '45482311.92000000',
#   1526428799999,
#   '12032089.90217380',
#   31261,
#   '21628076.34000000',
#   '5725403.74509200',
#   '0'],
#  [1526428800000,
#   '0.25394000',
#   '0.25580000',
#   '0.23700000',
#   '0.25237000',
#   '52406357.98000000',
#   1526515199999,
#   '12799326.87994190',
#   31751,
#   '25975882.74000000',
#   '6335097.21217880',
#   '0'],
#  [1526515200000,
#   '0.25237000',
#   '0.26054000',
#   '0.23666000',
#   '0.23919000',
#   '40168712.80000000',
#   1526601599999,
#   '10013492.93809120',
#   26905,
#   '18305510.75000000',
#   '4574417.20449570',
#   '0'],
#  [1526601600000,
#   '0.23915000',
#   '0.24500000',
#   '0.23037000',
#   '0.24324000',
#   '42061886.81000000',
#   1526687999999,
#   '9979718.32849220',
#   27682,
#   '20837646.58000000',
#   '4950074.58447220',
#   '0'],
#  [1526688000000,
#   '0.24382000',
#   '0.24750000',
#   '0.23580000',
#   '0.24116000',
#   '32607149.46000000',
#   1526774399999,
#   '7905841.55264420',
#   18969,
#   '16856271.64000000',
#   '4088634.68558410',
#   '0'],
#  [1526774400000,
#   '0.24151000',
#   '0.26006000',
#   '0.23832000',
#   '0.25556000',
#   '47300696.99000000',
#   1526860799999,
#   '11840033.99397390',
#   28039,
#   '23621647.57000000',
#   '5920486.27866630',
#   '0'],
#  [1526860800000,
#   '0.25556000',
#   '0.25999000',
#   '0.24301000',
#   '0.24563000',
#   '41754180.20000000',
#   1526947199999,
#   '10487356.69863590',
#   25176,
#   '17230436.60000000',
#   '4320120.91424380',
#   '0'],
#  [1526947200000,
#   '0.24588000',
#   '0.24730000',
#   '0.21841000',
#   '0.22000000',
#   '46428678.88000000',
#   1527033599999,
#   '10824531.94805320',
#   28214,
#   '17986111.37000000',
#   '4198058.01806350',
#   '0'],
#  [1527033600000,
#   '0.22000000',
#   '0.22310000',
#   '0.19270000',
#   '0.19780000',
#   '109714442.60000000',
#   1527119999999,
#   '22651868.63899230',
#   55284,
#   '49355026.84000000',
#   '10170853.57246110',
#   '0'],
#  [1527120000000,
#   '0.19767000',
#   '0.21040000',
#   '0.18865000',
#   '0.20730000',
#   '77927006.83000000',
#   1527206399999,
#   '15619668.83935670',
#   38792,
#   '38118631.43000000',
#   '7641972.06083610',
#   '0'],
#  [1527206400000,
#   '0.20731000',
#   '0.20900000',
#   '0.19351000',
#   '0.19788000',
#   '75352005.68000000',
#   1527292799999,
#   '15042769.69928570',
#   31890,
#   '40941992.03000000',
#   '8157314.60197910',
#   '0'],
#  [1527292800000,
#   '0.19798000',
#   '0.20400000',
#   '0.19380000',
#   '0.19504000',
#   '75181277.32000000',
#   1527379199999,
#   '15025229.88266650',
#   28481,
#   '43837266.81000000',
#   '8770441.88825200',
#   '0'],
#  [1527379200000,
#   '0.19506000',
#   '0.19580000',
#   '0.19010000',
#   '0.19186000',
#   '69065730.80000000',
#   1527465599999,
#   '13321221.37406130',
#   27380,
#   '40895901.19000000',
#   '7890817.51712770',
#   '0'],
#  [1527465600000,
#   '0.19198000',
#   '0.19400000',
#   '0.17125000',
#   '0.17249000',
#   '97552880.14000000',
#   1527551999999,
#   '17761407.22864790',
#   38916,
#   '50494412.04000000',
#   '9186407.54894230',
#   '0'],
#  [1527552000000,
#   '0.17249000',
#   '0.20896000',
#   '0.17055000',
#   '0.20164000',
#   '152230373.78000000',
#   1527638399999,
#   '29484111.34533620',
#   55599,
#   '82300400.74000000',
#   '15910605.00006430',
#   '0'],
#  [1527638400000,
#   '0.20176000',
#   '0.21683000',
#   '0.19689000',
#   '0.20779000',
#   '170042582.10000000',
#   1527724799999,
#   '35159335.41655670',
#   64428,
#   '92544844.47000000',
#   '19126795.64991300',
#   '0'],
#  [1527724800000,
#   '0.20846000',
#   '0.22879000',
#   '0.20321000',
#   '0.22330000',
#   '168752746.02000000',
#   1527811199999,
#   '36816251.26825660',
#   64531,
#   '87493821.37000000',
#   '19073176.33884440',
#   '0'],
#  [1527811200000,
#   '0.22331000',
#   '0.22850000',
#   '0.21347000',
#   '0.22038000',
#   '120335358.80000000',
#   1527897599999,
#   '26449032.07696200',
#   46951,
#   '65988189.81000000',
#   '14508851.02058650',
#   '0'],
#  [1527897600000,
#   '0.22038000',
#   '0.23000000',
#   '0.21666000',
#   '0.22648000',
#   '112561553.74000000',
#   1527983999999,
#   '25188851.97862370',
#   43345,
#   '63973002.57000000',
#   '14320371.36099160',
#   '0'],
#  [1527984000000,
#   '0.22647000',
#   '0.23677000',
#   '0.22259000',
#   '0.22659000',
#   '118516861.04000000',
#   1528070399999,
#   '27239878.84461350',
#   42996,
#   '66048939.44000000',
#   '15185781.74730500',
#   '0'],
#  [1528070400000,
#   '0.22660000',
#   '0.23030000',
#   '0.20882000',
#   '0.21243000',
#   '117544611.93000000',
#   1528156799999,
#   '25442053.91972180',
#   43191,
#   '63995141.93000000',
#   '13855139.23668850',
#   '0'],
#  [1528156800000,
#   '0.21217000',
#   '0.22160000',
#   '0.20221000',
#   '0.21839000',
#   '126062349.89000000',
#   1528243199999,
#   '26603749.02644660',
#   44089,
#   '69558211.67000000',
#   '14685925.62107210',
#   '0'],
#  [1528243200000,
#   '0.21835000',
#   '0.21949000',
#   '0.20799000',
#   '0.21452000',
#   '95597932.00000000',
#   1528329599999,
#   '20492327.43219650',
#   35295,
#   '52692455.59000000',
#   '11298397.52344580',
#   '0'],
#  [1528329600000,
#   '0.21470000',
#   '0.21863000',
#   '0.20800000',
#   '0.21019000',
#   '88495885.67000000',
#   1528415999999,
#   '18813214.98958100',
#   31834,
#   '51171630.51000000',
#   '10882371.88787380',
#   '0'],
#  [1528416000000,
#   '0.21034000',
#   '0.21053000',
#   '0.20025000',
#   '0.20430000',
#   '88036857.34000000',
#   1528502399999,
#   '18054928.07137570',
#   30863,
#   '50046061.03000000',
#   '10266841.05493890',
#   '0'],
#  [1528502400000,
#   '0.20430000',
#   '0.21000000',
#   '0.20031000',
#   '0.20110000',
#   '77594290.31000000',
#   1528588799999,
#   '15907932.17801280',
#   23821,
#   '45740763.96000000',
#   '9383829.46551580',
#   '0'],
#  [1528588800000,
#   '0.20108000',
#   '0.20108000',
#   '0.16806000',
#   '0.17346000',
#   '142220130.36000000',
#   1528675199999,
#   '26299148.26787050',
#   52191,
#   '71899370.12000000',
#   '13308946.24432500',
#   '0'],
#  [1528675200000,
#   '0.17346000',
#   '0.18067000',
#   '0.16404000',
#   '0.17897000',
#   '89060527.57000000',
#   1528761599999,
#   '15313409.38806980',
#   33296,
#   '50681132.33000000',
#   '8713463.41700940',
#   '0'],
#  [1528761600000,
#   '0.17910000',
#   '0.18130000',
#   '0.15800000',
#   '0.16297000',
#   '92630936.01000000',
#   1528847999999,
#   '15698398.07287850',
#   32901,
#   '49471919.48000000',
#   '8389329.09088310',
#   '0'],
#  [1528848000000,
#   '0.16309000',
#   '0.16609000',
#   '0.14500000',
#   '0.15791000',
#   '123774555.35000000',
#   1528934399999,
#   '19368912.27304410',
#   40956,
#   '63921014.21000000',
#   '10020594.95296730',
#   '0'],
#  [1528934400000,
#   '0.15798000',
#   '0.17700000',
#   '0.15300000',
#   '0.17062000',
#   '201282329.40000000',
#   1529020799999,
#   '33697548.92901200',
#   58839,
#   '99732343.80000000',
#   '16675494.98508600',
#   '0'],
#  [1529020800000,
#   '0.17091000',
#   '0.17100000',
#   '0.15997000',
#   '0.16097000',
#   '114391790.30000000',
#   1529107199999,
#   '18948487.00028400',
#   34656,
#   '65753977.10000000',
#   '10903551.28296900',
#   '0'],
#  [1529107200000,
#   '0.16098000',
#   '0.16436000',
#   '0.15762000',
#   '0.16191000',
#   '78883976.90000000',
#   1529193599999,
#   '12764446.97373800',
#   23527,
#   '47331464.00000000',
#   '7662280.79499800',
#   '0'],
#  [1529193600000,
#   '0.16209000',
#   '0.16436000',
#   '0.15962000',
#   '0.16044000',
#   '83655537.20000000',
#   1529279999999,
#   '13575832.10095200',
#   21580,
#   '50923772.40000000',
#   '8268315.77218800',
#   '0'],
#  [1529280000000,
#   '0.16047000',
#   '0.16810000',
#   '0.15540000',
#   '0.16370000',
#   '106510458.50000000',
#   1529366399999,
#   '17174549.76808000',
#   30114,
#   '58885643.00000000',
#   '9498170.40521000',
#   '0'],
#  [1529366400000,
#   '0.16370000',
#   '0.17149000',
#   '0.16120000',
#   '0.16700000',
#   '92579516.20000000',
#   1529452799999,
#   '15231501.32004100',
#   26289,
#   '49036347.20000000',
#   '8070311.29333000',
#   '0'],
#  [1529452800000,
#   '0.16675000',
#   '0.16768000',
#   '0.15675000',
#   '0.16182000',
#   '101010133.40000000',
#   1529539199999,
#   '16214788.57784000',
#   27526,
#   '52657027.40000000',
#   '8461105.73240700',
#   '0'],
#  [1529539200000,
#   '0.16181000',
#   '0.16369000',
#   '0.15670000',
#   '0.15779000',
#   '81701394.90000000',
#   1529625599999,
#   '13030421.87728100',
#   22368,
#   '48190788.60000000',
#   '7688240.22988100',
#   '0'],
#  [1529625600000,
#   '0.15773000',
#   '0.15861000',
#   '0.13429000',
#   '0.13843000',
#   '130675681.78000000',
#   1529711999999,
#   '18900553.62224570',
#   40049,
#   '66570894.06000000',
#   '9634732.07352920',
#   '0'],
#  [1529712000000,
#   '0.13786000',
#   '0.14189000',
#   '0.13345000',
#   '0.13710000',
#   '87709847.30000000',
#   1529798399999,
#   '12031629.06486800',
#   23011,
#   '50372663.34000000',
#   '6910664.12880800',
#   '0'],
#  [1529798400000,
#   '0.13708000',
#   '0.13828000',
#   '0.11910000',
#   '0.13093000',
#   '143899464.51000000',
#   1529884799999,
#   '18339842.44636290',
#   39084,
#   '75982890.79000000',
#   '9674165.30078750',
#   '0'],
#  [1529884800000,
#   '0.13085000',
#   '0.13889000',
#   '0.12619000',
#   '0.13521000',
#   '112684748.80000000',
#   1529971199999,
#   '15029140.80290600',
#   29650,
#   '60536367.80000000',
#   '8077521.84091600',
#   '0'],
#  [1529971200000,
#   '0.13521000',
#   '0.13571000',
#   '0.12458000',
#   '0.12519000',
#   '64025933.40000000',
#   1530057599999,
#   '8332822.36776500',
#   15638,
#   '36028907.60000000',
#   '4688207.02836800',
#   '0'],
#  [1530057600000,
#   '0.12512000',
#   '0.12832000',
#   '0.12271000',
#   '0.12752000',
#   '94123430.10000000',
#   1530143999999,
#   '11836952.24402700',
#   21051,
#   '54405905.10000000',
#   '6846445.19094700',
#   '0'],
#  [1530144000000,
#   '0.12753000',
#   '0.12891000',
#   '0.11742000',
#   '0.11825000',
#   '98846440.60000000',
#   1530230399999,
#   '12274562.79504300',
#   25411,
#   '53623031.60000000',
#   '6669419.91639900',
#   '0'],
#  [1530230400000,
#   '0.11818000',
#   '0.12700000',
#   '0.11359000',
#   '0.12534000',
#   '127501994.70000000',
#   1530316799999,
#   '15077120.15054400',
#   31922,
#   '72354099.50000000',
#   '8549657.69405100',
#   '0'],
#  [1530316800000,
#   '0.12541000',
#   '0.13880000',
#   '0.12533000',
#   '0.13784000',
#   '165385662.30000000',
#   1530403199999,
#   '22119921.03666700',
#   36917,
#   '94734964.70000000',
#   '12664678.39404000',
#   '0'],
#  [1530403200000,
#   '0.13783000',
#   '0.14590000',
#   '0.13303000',
#   '0.14211000',
#   '154425115.80000000',
#   1530489599999,
#   '21470960.33226500',
#   36356,
#   '84244065.20000000',
#   '11717546.54561800',
#   '0'],
#  [1530489600000,
#   '0.14196000',
#   '0.16209000',
#   '0.13760000',
#   '0.15448000',
#   '188333609.60000000',
#   1530575999999,
#   '28182795.04611400',
#   45262,
#   '97437403.40000000',
#   '14581127.56543600',
#   '0'],
#  [1530576000000,
#   '0.15448000',
#   '0.16054000',
#   '0.14811000',
#   '0.14966000',
#   '185062896.20000000',
#   1530662399999,
#   '28543767.43225800',
#   42996,
#   '100902869.00000000',
#   '15560309.78229500',
#   '0'],
#  [1530662400000,
#   '0.14973000',
#   '0.15999000',
#   '0.14586000',
#   '0.15112000',
#   '102961027.20000000',
#   1530748799999,
#   '15877090.21493600',
#   24390,
#   '57408686.30000000',
#   '8861307.98248900',
#   '0'],
#  [1530748800000,
#   '0.15122000',
#   '0.15598000',
#   '0.14300000',
#   '0.14736000',
#   '124928340.70000000',
#   1530835199999,
#   '18668509.69914000',
#   35260,
#   '65854049.40000000',
#   '9855100.00722500',
#   '0'],
#  [1530835200000,
#   '0.14735000',
#   '0.14759000',
#   '0.13803000',
#   '0.14501000',
#   '95720066.50000000',
#   1530921599999,
#   '13705010.59452400',
#   31236,
#   '53160997.50000000',
#   '7618140.49788300',
#   '0'],
#  [1530921600000,
#   '0.14528000',
#   '0.14842000',
#   '0.13698000',
#   '0.14783000',
#   '90194782.40000000',
#   1531007999999,
#   '12733744.37412100',
#   27656,
#   '48898489.20000000',
#   '6900360.01062200',
#   '0'],
#  [1531008000000,
#   '0.14775000',
#   '0.15000000',
#   '0.14405000',
#   '0.14481000',
#   '92832130.70000000',
#   1531094399999,
#   '13605680.52268500',
#   27217,
#   '51356658.30000000',
#   '7530867.31676200',
#   '0'],
#  [1531094400000,
#   '0.14482000',
#   '0.14575000',
#   '0.13876000',
#   '0.13935000',
#   '75579037.60000000',
#   1531180799999,
#   '10806388.55799500',
#   23157,
#   '39948105.70000000',
#   '5714368.33761700',
#   '0'],
#  [1531180800000,
#   '0.13934000',
#   '0.13972000',
#   '0.12711000',
#   '0.12814000',
#   '111283154.20000000',
#   1531267199999,
#   '14705036.46882100',
#   32000,
#   '56355186.70000000',
#   '7451751.52454400',
#   '0'],
#  [1531267200000,
#   '0.12807000',
#   '0.13376000',
#   '0.12467000',
#   '0.13144000',
#   '99990240.30000000',
#   1531353599999,
#   '12938143.57647100',
#   29173,
#   '52462174.00000000',
#   '6789112.41661900',
#   '0'],
#  [1531353600000,
#   '0.13145000',
#   '0.13149000',
#   '0.12200000',
#   '0.12750000',
#   '86139318.30000000',
#   1531439999999,
#   '10826108.82134500',
#   25414,
#   '46313837.30000000',
#   '5825496.23285700',
#   '0'],
#  [1531440000000,
#   '0.12747000',
#   '0.14356000',
#   '0.12458000',
#   '0.13768000',
#   '152719307.50000000',
#   1531526399999,
#   '20386084.27519800',
#   41108,
#   '77583185.30000000',
#   '10347228.27224100',
#   '0'],
#  [1531526400000,
#   '0.13735000',
#   '0.14117000',
#   '0.13303000',
#   '0.13650000',
#   '115057588.40000000',
#   1531612799999,
#   '15709436.49005900',
#   32807,
#   '63572903.20000000',
#   '8679594.19645900',
#   '0'],
#  [1531612800000,
#   '0.13664000',
#   '0.14594000',
#   '0.13459000',
#   '0.14227000',
#   '109368381.50000000',
#   1531699199999,
#   '15336572.62772100',
#   25077,
#   '62188385.40000000',
#   '8718961.56305100',
#   '0'],
#  [1531699200000,
#   '0.14231000',
#   '0.15855000',
#   '0.14037000',
#   '0.15655000',
#   '149953484.00000000',
#   1531785599999,
#   '22530513.27225400',
#   36411,
#   '82994529.20000000',
#   '12461732.81888900',
#   '0'],
#  [1531785600000,
#   '0.15655000',
#   '0.17644000',
#   '0.15002000',
#   '0.17136000',
#   '213123360.60000000',
#   1531871999999,
#   '34486695.68454300',
#   53089,
#   '111022078.90000000',
#   '17945864.74596500',
#   '0'],
#  [1531872000000,
#   '0.17136000',
#   '0.19701000',
#   '0.17109000',
#   '0.18053000',
#   '416309853.99000000',
#   1531958399999,
#   '76064597.38811340',
#   97110,
#   '207638595.99000000',
#   '37960639.83795660',
#   '0'],
#  [1531958400000,
#   '0.18061000',
#   '0.19217000',
#   '0.17149000',
#   '0.18191000',
#   '282232209.80000000',
#   1532044799999,
#   '51344983.97771800',
#   70480,
#   '146842631.50000000',
#   '26717956.01480400',
#   '0'],
#  [1532044800000,
#   '0.18164000',
#   '0.18348000',
#   '0.15900000',
#   '0.16129000',
#   '253384617.50000000',
#   1532131199999,
#   '43743580.19006800',
#   70861,
#   '126722923.80000000',
#   '21881587.38632300',
#   '0'],
#  [1532131200000,
#   '0.16112000',
#   '0.16998000',
#   '0.15388000',
#   '0.16327000',
#   '174968628.30000000',
#   1532217599999,
#   '28648235.15712100',
#   50525,
#   '86917938.70000000',
#   '14233328.19824300',
#   '0'],
#  [1532217600000,
#   '0.16340000',
#   '0.17920000',
#   '0.16164000',
#   '0.16916000',
#   '189326194.20000000',
#   1532303999999,
#   '32449318.57801700',
#   52538,
#   '98474148.80000000',
#   '16882379.55993200',
#   '0'],
#  [1532304000000,
#   '0.16937000',
#   '0.18057000',
#   '0.16409000',
#   '0.16423000',
#   '194302721.30000000',
#   1532390399999,
#   '33628174.78472000',
#   56695,
#   '93551514.20000000',
#   '16182932.69954200',
#   '0'],
#  [1532390400000,
#   '0.16411000',
#   '0.17868000',
#   '0.16001000',
#   '0.17349000',
#   '240608913.20000000',
#   1532476799999,
#   '41008030.20779200',
#   70441,
#   '122921518.40000000',
#   '20980639.47375000',
#   '0'],
#  [1532476800000,
#   '0.17360000',
#   '0.17728000',
#   '0.16644000',
#   '0.17275000',
#   '176309661.40000000',
#   1532563199999,
#   '30296987.58020900',
#   54621,
#   '89884702.80000000',
#   '15463015.36402100',
#   '0'],
#  [1532563200000,
#   '0.17274000',
#   '0.17550000',
#   '0.16160000',
#   '0.16400000',
#   '148549658.70000000',
#   1532649599999,
#   '25320711.34422400',
#   45036,
#   '75995892.90000000',
#   '12960793.47072300',
#   '0'],
#  [1532649600000,
#   '0.16397000',
#   '0.16930000',
#   '0.15510000',
#   '0.16590000',
#   '166105202.20000000',
#   1532735999999,
#   '27037783.02730600',
#   48578,
#   '83807877.30000000',
#   '13655672.30653600',
#   '0'],
#  [1532736000000,
#   '0.16586000',
#   '0.16662000',
#   '0.15915000',
#   '0.16410000',
#   '93577557.90000000',
#   1532822399999,
#   '15278409.55939000',
#   27857,
#   '50692452.80000000',
#   '8282854.84416400',
#   '0'],
#  [1532822400000,
#   '0.16387000',
#   '0.16560000',
#   '0.15954000',
#   '0.16268000',
#   '86539098.90000000',
#   1532908799999,
#   '14038575.98084800',
#   24027,
#   '48716326.60000000',
#   '7906368.18636300',
#   '0'],
#  [1532908800000,
#   '0.16274000',
#   '0.16300000',
#   '0.14716000',
#   '0.15327000',
#   '117831615.30000000',
#   1532995199999,
#   '18356726.94746200',
#   35384,
#   '59053387.50000000',
#   '9204750.93755900',
#   '0'],
#  [1532995200000,
#   '0.15323000',
#   '0.15349000',
#   '0.13900000',
#   '0.14175000',
#   '139280124.80000000',
#   1533081599999,
#   '20066629.30408900',
#   40893,
#   '72702503.30000000',
#   '10482478.34728000',
#   '0'],
#  [1533081600000,
#   '0.14152000',
#   '0.14474000',
#   '0.13500000',
#   '0.13984000',
#   '125588838.30000000',
#   1533167999999,
#   '17478129.62057700',
#   37142,
#   '66315029.20000000',
#   '9235155.75975600',
#   '0'],
#  [1533168000000,
#   '0.13983000',
#   '0.14149000',
#   '0.12850000',
#   '0.13039000',
#   '131792025.00000000',
#   1533254399999,
#   '17601744.11083100',
#   34817,
#   '76468646.00000000',
#   '10196004.84521800',
#   '0'],
#  [1533254400000,
#   '0.13079000',
#   '0.13473000',
#   '0.12290000',
#   '0.12947000',
#   '138792398.40000000',
#   1533340799999,
#   '17849122.11939000',
#   39754,
#   '71676460.90000000',
#   '9213237.63136300',
#   '0'],
#  [1533340800000,
#   '0.12941000',
#   '0.13358000',
#   '0.12353000',
#   '0.12639000',
#   '101749830.70000000',
#   1533427199999,
#   '13088694.25848500',
#   28602,
#   '55122751.50000000',
#   '7098630.22207300',
#   '0'],
#  [1533427200000,
#   '0.12622000',
#   '0.13130000',
#   '0.12440000',
#   '0.13024000',
#   '96484560.40000000',
#   1533513599999,
#   '12348494.26462800',
#   24856,
#   '51552809.50000000',
#   '6596621.97620100',
#   '0'],
#  [1533513600000,
#   '0.13050000',
#   '0.13618000',
#   '0.12644000',
#   '0.12937000',
#   '103522434.80000000',
#   1533599999999,
#   '13503375.36929200',
#   33019,
#   '54430922.00000000',
#   '7099255.25032000',
#   '0'],
#  [1533600000000,
#   '0.12937000',
#   '0.13227000',
#   '0.12252000',
#   '0.12365000',
#   '117382777.30000000',
#   1533686399999,
#   '15089313.73888100',
#   36526,
#   '63704241.00000000',
#   '8207221.86327700',
#   '0'],
#  [1533686400000,
#   '0.12380000',
#   '0.12387000',
#   '0.10855000',
#   '0.11292000',
#   '165723801.65000000',
#   1533772799999,
#   '19137563.24468320',
#   50222,
#   '83193352.57000000',
#   '9602948.61576300',
#   '0'],
#  [1533772800000,
#   '0.11281000',
#   '0.12631000',
#   '0.11272000',
#   '0.12213000',
#   '177290775.90000000',
#   1533859199999,
#   '21251907.06306100',
#   52337,
#   '91836380.60000000',
#   '10993709.07736800',
#   '0'],
#  [1533859200000,
#   '0.12213000',
#   '0.12380000',
#   '0.11132000',
#   '0.11485000',
#   '163283852.60000000',
#   1533945599999,
#   '19258388.58849200',
#   50645,
#   '80868651.70000000',
#   '9545556.41557800',
#   '0'],
#  [1533945600000,
#   '0.11461000',
#   '0.11633000',
#   '0.10713000',
#   '0.11022000',
#   '132856521.30000000',
#   1534031999999,
#   '14807890.29808800',
#   48423,
#   '67662931.10000000',
#   '7545037.03021500',
#   '0'],
#  [1534032000000,
#   '0.11022000',
#   '0.11450000',
#   '0.10859000',
#   '0.11153000',
#   '84899955.50000000',
#   1534118399999,
#   '9497076.50477500',
#   29129,
#   '43715491.80000000',
#   '4891967.70289400',
#   '0'],
#  [1534118400000,
#   '0.11152000',
#   '0.11415000',
#   '0.10100000',
#   '0.10104000',
#   '117825288.07000000',
#   1534204799999,
#   '12797213.38988870',
#   36739,
#   '56532087.47000000',
#   '6166356.92195970',
#   '0'],
#  [1534204800000,
#   '0.10102000',
#   '0.10113000',
#   '0.08400000',
#   '0.09350000',
#   '178829259.07000000',
#   1534291199999,
#   '16208312.72853380',
#   53519,
#   '87982211.90000000',
#   '7957744.88049900',
#   '0'],
#  [1534291200000,
#   '0.09350000',
#   '0.10131000',
#   '0.09339000',
#   '0.09361000',
#   '184857078.80000000',
#   1534377599999,
#   '17948100.30897900',
#   52155,
#   '90020727.80000000',
#   '8748591.68321600',
#   '0'],
#  [1534377600000,
#   '0.09361000',
#   '0.09820000',
#   '0.09138000',
#   '0.09460000',
#   '124134745.30000000',
#   1534463999999,
#   '11758177.21882600',
#   31747,
#   '61451631.00000000',
#   '5822451.59737800',
#   '0'],
#  [1534464000000,
#   '0.09460000',
#   '0.11000000',
#   '0.09370000',
#   '0.11000000',
#   '234081259.80000000',
#   1534550399999,
#   '23758690.35483000',
#   60394,
#   '125138414.00000000',
#   '12695038.91123500',
#   '0'],
#  [1534550400000,
#   '0.11000000',
#   '0.11247000',
#   '0.09514000',
#   '0.09831000',
#   '213897957.50000000',
#   1534636799999,
#   '22016591.83222000',
#   57730,
#   '111116073.10000000',
#   '11432209.47041600',
#   '0'],
#  [1534636800000,
#   '0.09832000',
#   '0.10356000',
#   '0.09633000',
#   '0.10143000',
#   '123775994.10000000',
#   1534723199999,
#   '12386039.55291700',
#   35479,
#   '68282675.10000000',
#   '6831671.72037700',
#   '0'],
#  [1534723200000,
#   '0.10131000',
#   '0.10299000',
#   '0.09159000',
#   '0.09174000',
#   '135267717.60000000',
#   1534809599999,
#   '13220183.10017000',
#   36008,
#   '68979337.60000000',
#   '6751477.29730900',
#   '0'],
#  [1534809600000,
#   '0.09203000',
#   '0.09541000',
#   '0.09001000',
#   '0.09469000',
#   '132327843.80000000',
#   1534895999999,
#   '12298393.66681800',
#   31231,
#   '75169037.70000000',
#   '6988104.20319400',
#   '0'],
#  [1534896000000,
#   '0.09469000',
#   '0.10082000',
#   '0.08682000',
#   '0.08955000',
#   '188859218.10000000',
#   1534982399999,
#   '17793823.92420000',
#   43273,
#   '101457303.30000000',
#   '9572260.72645200',
#   '0'],
#  [1534982400000,
#   '0.08926000',
#   '0.09420000',
#   '0.08835000',
#   '0.09232000',
#   '127991686.60000000',
#   1535068799999,
#   '11585684.67594100',
#   31074,
#   '72921168.90000000',
#   '6600042.70142300',
#   '0'],
#  [1535068800000,
#   '0.09222000',
#   '0.09450000',
#   '0.09030000',
#   '0.09381000',
#   '122264201.20000000',
#   1535155199999,
#   '11280118.48744700',
#   25954,
#   '72618519.50000000',
#   '6701075.97065200',
#   '0'],
#  [1535155200000,
#   '0.09372000',
#   '0.09496000',
#   '0.09177000',
#   '0.09413000',
#   '122813941.70000000',
#   1535241599999,
#   '11474799.32916600',
#   27542,
#   '69470657.80000000',
#   '6492905.24187000',
#   '0'],
#  [1535241600000,
#   '0.09420000',
#   '0.09467000',
#   '0.09050000',
#   '0.09306000',
#   '106480637.60000000',
#   1535327999999,
#   '9831305.25192700',
#   22445,
#   '59518864.60000000',
#   '5498436.64993400',
#   '0'],
#  [1535328000000,
#   '0.09306000',
#   '0.10157000',
#   '0.09206000',
#   '0.10051000',
#   '167559247.90000000',
#   1535414399999,
#   '16093712.16932400',
#   39315,
#   '94841674.60000000',
#   '9115163.19400000',
#   '0'],
#  [1535414400000,
#   '0.10050000',
#   '0.10749000',
#   '0.09960000',
#   '0.10555000',
#   '216112224.00000000',
#   1535500799999,
#   '22262997.83130600',
#   52680,
#   '112624756.10000000',
#   '11602127.62061000',
#   '0'],
#  [1535500800000,
#   '0.10555000',
#   '0.10919000',
#   '0.10121000',
#   '0.10535000',
#   '223271747.10000000',
#   1535587199999,
#   '23388925.13455800',
#   51620,
#   '114401903.40000000',
#   '11983103.24695800',
#   '0'],
#  [1535587200000,
#   '0.10535000',
#   '0.10753000',
#   '0.09661000',
#   '0.10066000',
#   '192982516.50000000',
#   1535673599999,
#   '19408874.82242300',
#   45043,
#   '98112141.40000000',
#   '9848670.08303800',
#   '0'],
#  [1535673600000,
#   '0.10083000',
#   '0.10343000',
#   '0.09851000',
#   '0.10170000',
#   '150820489.40000000',
#   1535759999999,
#   '15184451.10833800',
#   33805,
#   '82464193.80000000',
#   '8301912.83394600',
#   '0'],
#  [1535760000000,
#   '0.10158000',
#   '0.11032000',
#   '0.10131000',
#   '0.10699000',
#   '197881916.20000000',
#   1535846399999,
#   '21017943.90854100',
#   44736,
#   '109392806.30000000',
#   '11619610.75988000',
#   '0'],
#  [1535846400000,
#   '0.10699000',
#   '0.10771000',
#   '0.10200000',
#   '0.10499000',
#   '160240191.30000000',
#   1535932799999,
#   '16827126.40231600',
#   38531,
#   '83843697.60000000',
#   '8804393.31779700',
#   '0'],
#  [1535932800000,
#   '0.10471000',
#   '0.10550000',
#   '0.10215000',
#   '0.10352000',
#   '112188192.60000000',
#   1536019199999,
#   '11665701.89932700',
#   27578,
#   '61780224.10000000',
#   '6425999.03862400',
#   '0'],
#  [1536019200000,
#   '0.10360000',
#   '0.10709000',
#   '0.10334000',
#   '0.10521000',
#   '140038510.00000000',
#   1536105599999,
#   '14732214.84780800',
#   29692,
#   '76774134.30000000',
#   '8074639.71232100',
#   '0'],
#  [1536105600000,
#   '0.10522000',
#   '0.10621000',
#   '0.08561000',
#   '0.08637000',
#   '235189147.40000000',
#   1536191999999,
#   '22488281.26884600',
#   53547,
#   '116440815.10000000',
#   '11185918.01679600',
#   '0'],
#  [1536192000000,
#   '0.08637000',
#   '0.08877000',
#   '0.08085000',
#   '0.08840000',
#   '183458796.30000000',
#   1536278399999,
#   '15557382.53381900',
#   43553,
#   '96161203.95000000',
#   '8159277.81434800',
#   '0'],
#  [1536278400000,
#   '0.08835000',
#   '0.08946000',
#   '0.08130000',
#   '0.08287000',
#   '135249064.30000000',
#   1536364799999,
#   '11494798.96272000',
#   29613,
#   '72511030.30000000',
#   '6155937.46127900',
#   '0'],
#  [1536364800000,
#   '0.08285000',
#   '0.08440000',
#   '0.07654000',
#   '0.07749000',
#   '131933174.10000000',
#   1536451199999,
#   '10678960.45395800',
#   29126,
#   '70162805.30000000',
#   '5699361.61107900',
#   '0'],
#  [1536451200000,
#   '0.07737000',
#   '0.08097000',
#   '0.07353000',
#   '0.07601000',
#   '160703125.00000000',
#   1536537599999,
#   '12434244.16007800',
#   34851,
#   '85955624.20000000',
#   '6658115.89885100',
#   '0'],
#  [1536537600000,
#   '0.07592000',
#   '0.07867000',
#   '0.06660000',
#   '0.07343000',
#   '173188426.70000000',
#   1536623999999,
#   '12854477.93601700',
#   32840,
#   '92927029.50000000',
#   '6909707.61327200',
#   '0'],
#  [1536624000000,
#   '0.07345000',
#   '0.07475000',
#   '0.06574000',
#   '0.07010000',
#   '181972671.90000000',
#   1536710399999,
#   '12749350.50506100',
#   35625,
#   '95857441.40000000',
#   '6724472.18546700',
#   '0'],
#  [1536710400000,
#   '0.06999000',
#   '0.07036000',
#   '0.06089000',
#   '0.06627000',
#   '283607640.70000000',
#   1536796799999,
#   '18112357.74507000',
#   50834,
#   '141375381.90000000',
#   '9032453.52084500',
#   '0'],
#  [1536796800000,
#   '0.06628000',
#   '0.07181000',
#   '0.06497000',
#   '0.06951000',
#   '317801481.50000000',
#   1536883199999,
#   '21681012.73213800',
#   55956,
#   '162099776.10000000',
#   '11065529.50391400',
#   '0'],
#  [1536883200000,
#   '0.06957000',
#   '0.07077000',
#   '0.06541000',
#   '0.06749000',
#   '234221654.60000000',
#   1536969599999,
#   '15967296.01441500',
#   42982,
#   '119066455.20000000',
#   '8124976.46147000',
#   '0'],
#  [1536969600000,
#   '0.06743000',
#   '0.07068000',
#   '0.06732000',
#   '0.06895000',
#   '154219827.10000000',
#   1537055999999,
#   '10670168.25745300',
#   29132,
#   '85260661.70000000',
#   '5898024.70013700',
#   '0'],
#  [1537056000000,
#   '0.06889000',
#   '0.07000000',
#   '0.06568000',
#   '0.06988000',
#   '141868349.30000000',
#   1537142399999,
#   '9662422.85105300',
#   27985,
#   '78428058.30000000',
#   '5347238.09040300',
#   '0'],
#  [1537142400000,
#   '0.06988000',
#   '0.07023000',
#   '0.06256000',
#   '0.06347000',
#   '203297571.70000000',
#   1537228799999,
#   '13546342.67303600',
#   36438,
#   '106447983.90000000',
#   '7105885.90075900',
#   '0'],
#  [1537228800000,
#   '0.06332000',
#   '0.07012000',
#   '0.06193000',
#   '0.06900000',
#   '236846149.50000000',
#   1537315199999,
#   '15744126.55020900',
#   41182,
#   '125067687.40000000',
#   '8313129.17047800',
#   '0'],
#  [1537315200000,
#   '0.06892000',
#   '0.07441000',
#   '0.06622000',
#   '0.07218000',
#   '365958539.10000000',
#   1537401599999,
#   '25819092.37093500',
#   55820,
#   '183222054.40000000',
#   '12919496.09174100',
#   '0'],
#  [1537401600000,
#   '0.07218000',
#   '0.08389000',
#   '0.07111000',
#   '0.08089000',
#   '330838102.60000000',
#   1537487999999,
#   '24953393.72820100',
#   52731,
#   '168596643.90000000',
#   '12708369.69900800',
#   '0'],
#  [1537488000000,
#   '0.08086000',
#   '0.09035000',
#   '0.08065000',
#   '0.08773000',
#   '551641826.00000000',
#   1537574399999,
#   '47146894.07210200',
#   88838,
#   '280014831.30000000',
#   '23922613.78230600',
#   '0'],
#  [1537574400000,
#   '0.08767000',
#   '0.08913000',
#   '0.07920000',
#   '0.08338000',
#   '227327697.60000000',
#   1537660799999,
#   '18918465.52135300',
#   39063,
#   '108627934.70000000',
#   '9036751.73647900',
#   '0'],
#  [1537660800000,
#   '0.08331000',
#   '0.09390000',
#   '0.08281000',
#   '0.08986000',
#   '424470856.10000000',
#   1537747199999,
#   '38081791.60410100',
#   70294,
#   '216321389.50000000',
#   '19377314.59923200',
#   '0'],
#  [1537747200000,
#   '0.08985000',
#   '0.09197000',
#   '0.08146000',
#   '0.08241000',
#   '323249784.20000000',
#   1537833599999,
#   '27749292.24940000',
#   55453,
#   '159165848.90000000',
#   '13678653.58235900',
#   '0'],
#  [1537833600000,
#   '0.08245000',
#   '0.08246000',
#   '0.07425000',
#   '0.08108000',
#   '328241867.00000000',
#   1537919999999,
#   '25610886.77549900',
#   61222,
#   '163598734.70000000',
#   '12767771.61478200',
#   '0'],
#  [1537920000000,
#   '0.08114000',
#   '0.08311000',
#   '0.07648000',
#   '0.07913000',
#   '254963273.10000000',
#   1538006399999,
#   '20418673.88967900',
#   49378,
#   '132684481.90000000',
#   '10618720.97774400',
#   '0'],
#  [1538006400000,
#   '0.07912000',
#   '0.08890000',
#   '0.07777000',
#   '0.08629000',
#   '346873558.60000000',
#   1538092799999,
#   '28942790.15268200',
#   58775,
#   '177890764.50000000',
#   '14826923.39689100',
#   '0'],
#  [1538092800000,
#   '0.08630000',
#   '0.08850000',
#   '0.08100000',
#   '0.08390000',
#   '316240861.20000000',
#   1538179199999,
#   '26831854.15537300',
#   57741,
#   '157977373.90000000',
#   '13416060.20297100',
#   '0'],
#  [1538179200000,
#   '0.08390000',
#   '0.08680000',
#   '0.08106000',
#   '0.08446000',
#   '208369497.30000000',
#   1538265599999,
#   '17474246.03848900',
#   40621,
#   '108368557.70000000',
#   '9092913.84744700',
#   '0'],
#  [1538265600000,
#   '0.08444000',
#   '0.08740000',
#   '0.08250000',
#   '0.08511000',
#   '189401740.90000000',
#   1538351999999,
#   '16135637.35389800',
#   36726,
#   '102215532.40000000',
#   '8713813.35454400',
#   '0'],
#  [1538352000000,
#   '0.08511000',
#   '0.08700000',
#   '0.08203000',
#   '0.08467000',
#   '136128526.60000000',
#   1538438399999,
#   '11499178.36881900',
#   29182,
#   '74691608.60000000',
#   '6315667.01895900',
#   '0'],
#  [1538438400000,
#   '0.08451000',
#   '0.08510000',
#   '0.08151000',
#   '0.08224000',
#   '133043293.20000000',
#   1538524799999,
#   '11104554.95605200',
#   27511,
#   '76428688.20000000',
#   '6383615.81689700',
#   '0'],
#  [1538524800000,
#   '0.08221000',
#   '0.08248000',
#   '0.07820000',
#   '0.08088000',
#   '146109517.90000000',
#   1538611199999,
#   '11751915.19069700',
#   29928,
#   '78275167.40000000',
#   '6296468.18406700',
#   '0'],
#  [1538611200000,
#   '0.08082000',
#   '0.08319000',
#   '0.08044000',
#   '0.08164000',
#   '123500312.20000000',
#   1538697599999,
#   '10142882.79612100',
#   24701,
#   '69763589.10000000',
#   '5729571.23699700',
#   '0'],
#  [1538697600000,
#   '0.08161000',
#   '0.08450000',
#   '0.08029000',
#   '0.08339000',
#   '117646712.90000000',
#   1538783999999,
#   '9644648.12299400',
#   23905,
#   '68878987.70000000',
#   '5647414.46609300',
#   '0'],
#  [1538784000000,
#   '0.08339000',
#   '0.08411000',
#   '0.08080000',
#   '0.08151000',
#   '110744781.90000000',
#   1538870399999,
#   '9106937.66941300',
#   21086,
#   '63523797.50000000',
#   '5223472.44458200',
#   '0'],
#  [1538870400000,
#   '0.08156000',
#   '0.08558000',
#   '0.08033000',
#   '0.08464000',
#   '128627175.20000000',
#   1538956799999,
#   '10628605.71119800',
#   24006,
#   '71130358.30000000',
#   '5877032.32165400',
#   '0'],
#  [1538956800000,
#   '0.08465000',
#   '0.08890000',
#   '0.08348000',
#   '0.08698000',
#   '182425366.60000000',
#   1539043199999,
#   '15702721.36304100',
#   36931,
#   '99112195.10000000',
#   '8538563.12292500',
#   '0'],
#  [1539043200000,
#   '0.08698000',
#   '0.08808000',
#   '0.08480000',
#   '0.08659000',
#   '134872526.00000000',
#   1539129599999,
#   '11653933.72082900',
#   28492,
#   '70411543.40000000',
#   '6088559.42291200',
#   '0'],
#  [1539129600000,
#   '0.08655000',
#   '0.08690000',
#   '0.08359000',
#   '0.08542000',
#   '131687962.60000000',
#   1539215999999,
#   '11185503.39554500',
#   27328,
#   '69654503.10000000',
#   '5919172.14080700',
#   '0'],
#  [1539216000000,
#   '0.08547000',
#   '0.08547000',
#   '0.06920000',
#   '0.07079000',
#   '264191236.50000000',
#   1539302399999,
#   '20154848.27815500',
#   54100,
#   '123879419.00000000',
#   '9441337.00389200',
#   '0'],
#  [1539302400000,
#   '0.07079000',
#   '0.07660000',
#   '0.06950000',
#   '0.07320000',
#   '163124680.70000000',
#   1539388799999,
#   '12076830.52584500',
#   35749,
#   '93836179.60000000',
#   '6947928.19164300',
#   '0'],
#  [1539388800000,
#   '0.07314000',
#   '0.07545000',
#   '0.07258000',
#   '0.07374000',
#   '110544712.70000000',
#   1539475199999,
#   '8200029.62397800',
#   24159,
#   '62689848.20000000',
#   '4652063.43346800',
#   '0'],
#  [1539475200000,
#   '0.07374000',
#   '0.07459000',
#   '0.07098000',
#   '0.07170000',
#   '126401158.70000000',
#   1539561599999,
#   '9291731.95288600',
#   23942,
#   '64401145.30000000',
#   '4734483.61856300',
#   '0'],
#  [1539561600000,
#   '0.07164000',
#   '0.08497000',
#   '0.07000000',
#   '0.07671000',
#   '301872201.80000000',
#   1539647999999,
#   '23342361.10613800',
#   58520,
#   '158169345.90000000',
#   '12236074.34571400',
#   '0'],
#  [1539648000000,
#   '0.07670000',
#   '0.07884000',
#   '0.07565000',
#   '0.07777000',
#   '115794153.40000000',
#   1539734399999,
#   '8947700.33146700',
#   27071,
#   '65560649.30000000',
#   '5064340.48917100',
#   '0'],
#  [1539734400000,
#   '0.07772000',
#   '0.08132000',
#   '0.07701000',
#   '0.07994000',
#   '131284053.00000000',
#   1539820799999,
#   '10372819.68963900',
#   30241,
#   '73864988.00000000',
#   '5834825.33407800',
#   '0'],
#  [1539820800000,
#   '0.07994000',
#   '0.08069000',
#   '0.07500000',
#   '0.07668000',
#   '127667976.10000000',
#   1539907199999,
#   '10003399.97736200',
#   28786,
#   '69428553.30000000',
#   '5446348.58492200',
#   '0'],
#  [1539907200000,
#   '0.07668000',
#   '0.07790000',
#   '0.07577000',
#   '0.07683000',
#   '79407741.30000000',
#   1539993599999,
#   '6094608.15711800',
#   18842,
#   '49274381.20000000',
#   '3782456.27421500',
#   '0'],
#  [1539993600000,
#   '0.07691000',
#   '0.07876000',
#   '0.07610000',
#   '0.07768000',
#   '97554451.00000000',
#   1540079999999,
#   '7585569.13204500',
#   23306,
#   '58044838.60000000',
#   '4512252.03880400',
#   '0'],
#  [1540080000000,
#   '0.07769000',
#   '0.07908000',
#   '0.07691000',
#   '0.07721000',
#   '97607480.60000000',
#   1540166399999,
#   '7634851.10075300',
#   21431,
#   '57859595.00000000',
#   '4526432.28279200',
#   '0'],
#  [1540166400000,
#   '0.07722000',
#   '0.07785000',
#   '0.07610000',
#   '0.07731000',
#   '65297281.20000000',
#   1540252799999,
#   '5037407.47127300',
#   16180,
#   '37881365.90000000',
#   '2923454.71694500',
#   '0'],
#  [1540252800000,
#   '0.07730000',
#   '0.07757000',
#   '0.07350000',
#   '0.07597000',
#   '55448274.00000000',
#   1540339199999,
#   '4197037.58431500',
#   15748,
#   '28365296.10000000',
#   '2148836.99103800',
#   '0'],
#  [1540339200000,
#   '0.07597000',
#   '0.07708000',
#   '0.07530000',
#   '0.07539000',
#   '41098558.10000000',
#   1540425599999,
#   '3131207.86772000',
#   12667,
#   '23071644.80000000',
#   '1758265.21948300',
#   '0'],
#  [1540425600000,
#   '0.07537000',
#   '0.07564000',
#   '0.07370000',
#   '0.07478000',
#   '32103956.70000000',
#   1540511999999,
#   '2402661.50956200',
#   10320,
#   '14463713.60000000',
#   '1083513.06971000',
#   '0'],
#  [1540512000000,
#   '0.07485000',
#   '0.07540000',
#   '0.07348000',
#   '0.07471000',
#   '29996800.20000000',
#   1540598399999,
#   '2235986.19115000',
#   10601,
#   '15614223.70000000',
#   '1164320.59777500',
#   '0'],
#  [1540598400000,
#   '0.07471000',
#   '0.07487000',
#   '0.07329000',
#   '0.07352000',
#   '25730010.70000000',
#   1540684799999,
#   '1903561.80844800',
#   8364,
#   '13507111.80000000',
#   '999896.03147400',
#   '0'],
#  [1540684800000,
#   '0.07352000',
#   '0.07392000',
#   '0.07255000',
#   '0.07364000',
#   '25407915.50000000',
#   1540771199999,
#   '1862439.04581200',
#   7677,
#   '12887529.40000000',
#   '944952.69222000',
#   '0'],
#  [1540771200000,
#   '0.07358000',
#   '0.07379000',
#   '0.06900000',
#   '0.07019000',
#   '59442955.10000000',
#   1540857599999,
#   '4218854.64010900',
#   15639,
#   '28277949.10000000',
#   '2008725.89239000',
#   '0'],
#  [1540857600000,
#   '0.07018000',
#   '0.07077000',
#   '0.06963000',
#   '0.07007000',
#   '28837088.00000000',
#   1540943999999,
#   '2025340.37643200',
#   8436,
#   '14805180.30000000',
#   '1040735.54735200',
#   '0'],
#  [1540944000000,
#   '0.07007000',
#   '0.07199000',
#   '0.06773000',
#   '0.07061000',
#   '45075801.20000000',
#   1541030399999,
#   '3141750.37169800',
#   13949,
#   '22857879.50000000',
#   '1593660.39706500',
#   '0'],
#  [1541030400000,
#   '0.07051000',
#   '0.07198000',
#   '0.06966000',
#   '0.07127000',
#   '30472543.20000000',
#   1541116799999,
#   '2150049.55796900',
#   11719,
#   '16540167.60000000',
#   '1167492.09160700',
#   '0'],
#  [1541116800000,
#   '0.07127000',
#   '0.07380000',
#   '0.07060000',
#   '0.07311000',
#   '39046967.20000000',
#   1541203199999,
#   '2818219.51298900',
#   16706,
#   '20243070.10000000',
#   '1461071.81491900',
#   '0'],
#  [1541203200000,
#   '0.07311000',
#   '0.07331000',
#   '0.07080000',
#   '0.07177000',
#   '32565529.00000000',
#   1541289599999,
#   '2341982.63660100',
#   11588,
#   '16202161.70000000',
#   '1164969.01152700',
#   '0'],
#  [1541289600000,
#   '0.07177000',
#   '0.07857000',
#   '0.07120000',
#   '0.07730000',
#   '113670531.60000000',
#   1541375999999,
#   '8593513.73363500',
#   28380,
#   '56183192.70000000',
#   '4248402.08946100',
#   '0'],
#  [1541376000000,
#   '0.07730000',
#   '0.07946000',
#   '0.07499000',
#   '0.07685000',
#   '64247590.00000000',
#   1541462399999,
#   '4930039.43193900',
#   21447,
#   '31544463.00000000',
#   '2419040.05568200',
#   '0'],
#  [1541462400000,
#   '0.07678000',
#   '0.08198000',
#   '0.07678000',
#   '0.08168000',
#   '104955381.90000000',
#   1541548799999,
#   '8327429.93583200',
#   31655,
#   '55069860.00000000',
#   '4371252.09542700',
#   '0'],
#  [1541548800000,
#   '0.08165000',
#   '0.08260000',
#   '0.07812000',
#   '0.07900000',
#   '100250219.00000000',
#   1541635199999,
#   '8034071.09630000',
#   29294,
#   '48351949.30000000',
#   '3875192.76339700',
#   '0'],
#  [1541635200000,
#   '0.07903000',
#   '0.08000000',
#   '0.07647000',
#   '0.07684000',
#   '94093833.30000000',
#   1541721599999,
#   '7324704.97401300',
#   26918,
#   '47486249.40000000',
#   '3698747.34322900',
#   '0'],
#  [1541721600000,
#   '0.07682000',
#   '0.07820000',
#   '0.07401000',
#   '0.07463000',
#   '61234405.10000000',
#   1541807999999,
#   '4650961.42560400',
#   18848,
#   '27321328.80000000',
#   '2074716.37720600',
#   '0'],
#  [1541808000000,
#   '0.07460000',
#   '0.07657000',
#   '0.07419000',
#   '0.07548000',
#   '30553646.60000000',
#   1541894399999,
#   '2304643.36984900',
#   10721,
#   '14487656.70000000',
#   '1092856.34412300',
#   '0'],
#  [1541894400000,
#   '0.07549000',
#   '0.07798000',
#   '0.07460000',
#   '0.07700000',
#   '50981007.50000000',
#   1541980799999,
#   '3883177.13059000',
#   16925,
#   '27446110.40000000',
#   '2090291.07065500',
#   '0'],
#  [1541980800000,
#   '0.07698000',
#   '0.07800000',
#   '0.07552000',
#   '0.07687000',
#   '49381671.40000000',
#   1542067199999,
#   '3797242.37184800',
#   16039,
#   '23659486.90000000',
#   '1820559.16169600',
#   '0'],
#  [1542067200000,
#   '0.07690000',
#   '0.07715000',
#   '0.07440000',
#   '0.07465000',
#   '46946579.50000000',
#   1542153599999,
#   '3565039.11326100',
#   15587,
#   '21512894.10000000',
#   '1634519.50035500',
#   '0'],
#  [1542153600000,
#   '0.07465000',
#   '0.07470000',
#   '0.06241000',
#   '0.06657000',
#   '158251244.20000000',
#   1542239999999,
#   '10655305.10532900',
#   36216,
#   '68770690.70000000',
#   '4624350.69017800',
#   '0'],
#  [1542240000000,
#   '0.06650000',
#   '0.06690000',
#   '0.05811000',
#   '0.06435000',
#   '191874027.00000000',
#   1542326399999,
#   '11956558.53868400',
#   48878,
#   '90612799.60000000',
#   '5646602.56067500',
#   '0'],
#  [1542326400000,
#   '0.06431000',
#   '0.06499000',
#   '0.06030000',
#   '0.06145000',
#   '91253392.00000000',
#   1542412799999,
#   '5693309.86461400',
#   23651,
#   '46232043.10000000',
#   '2887311.92333300',
#   '0'],
#  [1542412800000,
#   '0.06148000',
#   '0.06157000',
#   '0.05960000',
#   '0.06123000',
#   '55504074.80000000',
#   1542499199999,
#   '3370869.02690200',
#   15154,
#   '28498466.60000000',
#   '1731167.27899200',
#   '0'],
#  [1542499200000,
#   '0.06122000',
#   '0.06354000',
#   '0.06115000',
#   '0.06234000',
#   '57846589.30000000',
#   1542585599999,
#   '3604377.94582700',
#   13469,
#   '28816037.50000000',
#   '1795693.26935700',
#   '0'],
#  [1542585600000,
#   '0.06235000',
#   '0.06246000',
#   '0.05112000',
#   '0.05270000',
#   '212725809.10000000',
#   1542671999999,
#   '11624561.60174400',
#   42121,
#   '98126133.90000000',
#   '5360160.17967300',
#   '0'],
#  [1542672000000,
#   '0.05265000',
#   '0.05334000',
#   '0.04270000',
#   '0.04587000',
#   '368762662.40000000',
#   1542758399999,
#   '17529273.54856300',
#   60749,
#   '167607769.90000000',
#   '7974064.83650800',
#   '0'],
#  [1542758400000,
#   '0.04582000',
#   '0.04971000',
#   '0.04332000',
#   '0.04839000',
#   '215533431.50000000',
#   1542844799999,
#   '10017106.02141600',
#   35090,
#   '115365533.50000000',
#   '5356050.17112600',
#   '0'],
#  [1542844800000,
#   '0.04843000',
#   '0.04914000',
#   '0.04366000',
#   '0.04407000',
#   '105720802.80000000',
#   1542931199999,
#   '4963962.99732700',
#   17558,
#   '50695091.10000000',
#   '2382057.67386900',
#   '0'],
#  [1542931200000,
#   '0.04409000',
#   '0.04510000',
#   '0.04160000',
#   '0.04380000',
#   '136540568.70000000',
#   1543017599999,
#   '5914728.89704000',
#   22410,
#   '71943619.70000000',
#   '3115079.62593300',
#   '0'],
#  [1543017600000,
#   '0.04390000',
#   '0.04540000',
#   '0.03699000',
#   '0.03900000',
#   '177954815.00000000',
#   1543103999999,
#   '7271683.38721800',
#   22035,
#   '74250920.60000000',
#   '3064077.79382700',
#   '0'],
#  [1543104000000,
#   '0.03900000',
#   '0.03965000',
#   '0.03315000',
#   '0.03832000',
#   '260385525.80000000',
#   1543190399999,
#   '9470723.11540400',
#   33370,
#   '134942298.50000000',
#   '4908153.81518100',
#   '0'],
#  [1543190400000,
#   '0.03832000',
#   '0.04017000',
#   '0.03453000',
#   '0.03652000',
#   '267212196.50000000',
#   1543276799999,
#   '9982083.16319800',
#   36457,
#   '135929050.30000000',
#   '5074970.01433600',
#   '0'],
#  [1543276800000,
#   '0.03655000',
#   '0.03778000',
#   '0.03401000',
#   '0.03693000',
#   '156122026.10000000',
#   1543363199999,
#   '5574331.48913300',
#   22022,
#   '75479200.30000000',
#   '2695656.80050600',
#   '0'],
#  [1543363200000,
#   '0.03695000',
#   '0.04420000',
#   '0.03691000',
#   '0.04222000',
#   '327311575.70000000',
#   1543449599999,
#   '13155676.55528100',
#   41280,
#   '181859118.30000000',
#   '7272078.32179000',
#   '0'],
#  [1543449600000,
#   '0.04214000',
#   '0.04487000',
#   '0.03957000',
#   '0.04194000',
#   '243467555.50000000',
#   1543535999999,
#   '10246342.84806300',
#   37294,
#   '123598751.20000000',
#   '5201904.01011000',
#   '0'],
#  [1543536000000,
#   '0.04198000',
#   '0.04250000',
#   '0.03765000',
#   '0.03907000',
#   '186391587.50000000',
#   1543622399999,
#   '7386293.27388600',
#   28494,
#   '88895740.00000000',
#   '3522477.24159800',
#   '0'],
#  [1543622400000,
#   '0.03907000',
#   '0.04240000',
#   '0.03804000',
#   '0.04138000',
#   '125557616.10000000',
#   1543708799999,
#   '5104465.05899200',
#   20785,
#   '65220243.40000000',
#   '2650765.62218800',
#   '0'],
#  [1543708800000,
#   '0.04133000',
#   '0.04340000',
#   '0.04057000',
#   '0.04187000',
#   '143922734.40000000',
#   1543795199999,
#   '6014693.61186100',
#   22226,
#   '70092220.30000000',
#   '2931435.26829500',
#   '0'],
#  [1543795200000,
#   '0.04184000',
#   '0.04214000',
#   '0.03785000',
#   '0.03848000',
#   '145293533.50000000',
#   1543881599999,
#   '5762925.68463900',
#   23224,
#   '69778723.40000000',
#   '2771550.17588800',
#   '0'],
#  [1543881600000,
#   '0.03849000',
#   '0.04019000',
#   '0.03700000',
#   '0.03752000',
#   '162431792.00000000',
#   1543967999999,
#   '6244944.50633019',
#   24786,
#   '80689281.20000000',
#   '3105901.27685012',
#   '0'],
# ...
#   '0'],
#  [1603756800000,
#   '0.10300000',
#   '0.10568000',
#   '0.10178000',
#   '0.10256000',
#   '184291093.80000000',
#   1603843199999,
#   '19148597.63616600',
#   44887,
#   '86900020.90000000',
#   '9030259.29665200',
#   '0'],
#  [1603843200000,
#   '0.10254000',
#   '0.10331000',
#   '0.09501000',
#   '0.09869000',
#   '282164120.80000000',
#   1603929599999,
#   '27843309.87612500',
#   61146,
#   '131958546.20000000',
#   '13013390.82988800',
#   '0'],
#  [1603929600000,
#   '0.09872000',
#   '0.10082000',
#   '0.09484000',
#   '0.09531000',
#   '257269193.80000000',
#   1604015999999,
#   '25185522.59947900',
#   53112,
#   '130960803.30000000',
#   '12829063.42609900',
#   '0'],
#  [1604016000000,
#   '0.09527000',
#   '0.09569000',
#   '0.08915000',
#   '0.09330000',
#   '278450826.00000000',
#   1604102399999,
#   '25752587.65077300',
#   59140,
#   '142169919.30000000',
#   '13153533.78760000',
#   '0'],
#  [1604102400000,
#   '0.09326000',
#   '0.09555000',
#   '0.09196000',
#   '0.09300000',
#   '165418867.70000000',
#   1604188799999,
#   '15510001.57801300',
#   39997,
#   '79999218.30000000',
#   '7501404.24797600',
#   '0'],
#  [1604188800000,
#   '0.09296000',
#   '0.09868000',
#   '0.09241000',
#   '0.09827000',
#   '138991316.10000000',
#   1604275199999,
#   '13268230.33605100',
#   33696,
#   '73666699.50000000',
#   '7033791.25367800',
#   '0'],
#  [1604275200000,
#   '0.09827000',
#   '0.10004000',
#   '0.09151000',
#   '0.09221000',
#   '250365831.60000000',
#   1604361599999,
#   '23937317.22868300',
#   56812,
#   '123453093.50000000',
#   '11809776.17580900',
#   '0'],
#  [1604361600000,
#   '0.09222000',
#   '0.09417000',
#   '0.08793000',
#   '0.09357000',
#   '244514002.70000000',
#   1604447999999,
#   '22310146.75443000',
#   60952,
#   '124470217.80000000',
#   '11359088.16865300',
#   '0'],
#  [1604448000000,
#   '0.09360000',
#   '0.09628000',
#   '0.09155000',
#   '0.09550000',
#   '256317711.90000000',
#   1604534399999,
#   '24074287.53743600',
#   64713,
#   '129664157.10000000',
#   '12181386.33332600',
#   '0'],
#  [1604534400000,
#   '0.09553000',
#   '0.09810000',
#   '0.09207000',
#   '0.09752000',
#   '332802061.70000000',
#   1604620799999,
#   '31727134.72502700',
#   72246,
#   '171240705.00000000',
#   '16317407.82196200',
#   '0'],
#  [1604620800000,
#   '0.09749000',
#   '0.11000000',
#   '0.09706000',
#   '0.10910000',
#   '451716971.60000000',
#   1604707199999,
#   '47427482.92103400',
#   129308,
#   '240617256.60000000',
#   '25254767.35908800',
#   '0'],
#  [1604707200000,
#   '0.10912000',
#   '0.11387000',
#   '0.09861000',
#   '0.10128000',
#   '647454529.20000000',
#   1604793599999,
#   '68824996.44569700',
#   163067,
#   '320847395.90000000',
#   '34143383.10655000',
#   '0'],
#  [1604793600000,
#   '0.10131000',
#   '0.10832000',
#   '0.09970000',
#   '0.10655000',
#   '270595831.00000000',
#   1604879999999,
#   '28449684.67741600',
#   81231,
#   '134617410.40000000',
#   '14150360.56043800',
#   '0'],
#  [1604880000000,
#   '0.10652000',
#   '0.10799000',
#   '0.10114000',
#   '0.10561000',
#   '310077984.40000000',
#   1604966399999,
#   '32470998.37674600',
#   91304,
#   '159044796.80000000',
#   '16668901.81582700',
#   '0'],
#  [1604966400000,
#   '0.10555000',
#   '0.10915000',
#   '0.10355000',
#   '0.10590000',
#   '303777358.80000000',
#   1605052799999,
#   '32285456.14504000',
#   92669,
#   '144433113.80000000',
#   '15352069.22245900',
#   '0'],
#  [1605052800000,
#   '0.10590000',
#   '0.10890000',
#   '0.10541000',
#   '0.10599000',
#   '251231387.10000000',
#   1605139199999,
#   '26998072.99359700',
#   83826,
#   '127245280.20000000',
#   '13675926.53301100',
#   '0'],
#  [1605139200000,
#   '0.10597000',
#   '0.10667000',
#   '0.10254000',
#   '0.10460000',
#   '223674122.10000000',
#   1605225599999,
#   '23422636.26305400',
#   72476,
#   '110021906.40000000',
#   '11519438.07552700',
#   '0'],
#  [1605225600000,
#   '0.10462000',
#   '0.10798000',
#   '0.10401000',
#   '0.10629000',
#   '237407048.50000000',
#   1605311999999,
#   '25204728.43660100',
#   78935,
#   '122028039.40000000',
#   '12957199.99141100',
#   '0'],
#  [1605312000000,
#   '0.10633000',
#   '0.10730000',
#   '0.10142000',
#   '0.10411000',
#   '228682972.00000000',
#   1605398399999,
#   '23742897.25161500',
#   67849,
#   '121313589.40000000',
#   '12588504.42313800',
#   '0'],
#  [1605398400000,
#   '0.10411000',
#   '0.10527000',
#   '0.09850000',
#   '0.10046000',
#   '201375366.60000000',
#   1605484799999,
#   '20647920.49770700',
#   60583,
#   '97214052.10000000',
#   '9976334.87674900',
#   '0'],
#  [1605484800000,
#   '0.10045000',
#   '0.10499000',
#   '0.09950000',
#   '0.10387000',
#   '215990529.70000000',
#   1605571199999,
#   '22246202.72904400',
#   71450,
#   '111600367.30000000',
#   '11493576.50079300',
#   '0'],
#  [1605571200000,
#   '0.10387000',
#   '0.11246000',
#   '0.10354000',
#   '0.10947000',
#   '422358548.50000000',
#   1605657599999,
#   '46065393.68678500',
#   133129,
#   '218457167.10000000',
#   '23820824.58295700',
#   '0'],
#  [1605657600000,
#   '0.10944000',
#   '0.11161000',
#   '0.10171000',
#   '0.10658000',
#   '434138632.20000000',
#   1605743999999,
#   '46348194.86073600',
#   109490,
#   '210571609.40000000',
#   '22494883.49660000',
#   '0'],
#  [1605744000000,
#   '0.10662000',
#   '0.10816000',
#   '0.10435000',
#   '0.10590000',
#   '237807123.00000000',
#   1605830399999,
#   '25258809.56880200',
#   66459,
#   '114185511.50000000',
#   '12136027.06770000',
#   '0'],
#  [1605830400000,
#   '0.10590000',
#   '0.11900000',
#   '0.10549000',
#   '0.11828000',
#   '437634200.70000000',
#   1605916799999,
#   '48645520.07286600',
#   127423,
#   '230840678.30000000',
#   '25662935.67170100',
#   '0'],
#  [1605916800000,
#   '0.11826000',
#   '0.13472000',
#   '0.11605000',
#   '0.13334000',
#   '1071722949.30000000',
#   1606003199999,
#   '134223347.73080000',
#   265512,
#   '544134394.30000000',
#   '68218586.82355700',
#   '0'],
#  [1606003200000,
#   '0.13335000',
#   '0.15352000',
#   '0.12000000',
#   '0.14599000',
#   '1960688777.50000000',
#   1606089599999,
#   '265147097.86978800',
#   448124,
#   '1011295660.80000000',
#   '136790324.25293500',
#   '0'],
#  [1606089600000,
#   '0.14593000',
#   '0.15925000',
#   '0.14100000',
#   '0.15445000',
#   '1389843989.70000000',
#   1606175999999,
#   '210177734.52179900',
#   399986,
#   '706855168.80000000',
#   '106964177.97732500',
#   '0'],
#  [1606176000000,
#   '0.15451000',
#   '0.18300000',
#   '0.15000000',
#   '0.16721000',
#   '1689043010.10000000',
#   1606262399999,
#   '281406313.97044600',
#   515388,
#   '862355808.20000000',
#   '143728215.87402100',
#   '0'],
#  [1606262400000,
#   '0.16722000',
#   '0.17549000',
#   '0.14702000',
#   '0.15473000',
#   '1078036852.70000000',
#   1606348799999,
#   '177884968.93659600',
#   335752,
#   '537298545.50000000',
#   '88777809.12758600',
#   '0'],
#  [1606348800000,
#   '0.15474000',
#   '0.16085000',
#   '0.11230000',
#   '0.13843000',
#   '1645992625.90000000',
#   1606435199999,
#   '223129884.02621500',
#   413242,
#   '831076644.30000000',
#   '112733199.67803500',
#   '0'],
#  [1606435200000,
#   '0.13835000',
#   '0.14559000',
#   '0.13070000',
#   '0.14178000',
#   '714401286.70000000',
#   1606521599999,
#   '97878697.61369600',
#   212382,
#   '362902028.60000000',
#   '49751283.21538000',
#   '0'],
#  [1606521600000,
#   '0.14178000',
#   '0.17233000',
#   '0.13878000',
#   '0.16489000',
#   '1087688653.50000000',
#   1606607999999,
#   '171712019.15517800',
#   312532,
#   '545934196.20000000',
#   '86110632.60880100',
#   '0'],
#  [1606608000000,
#   '0.16487000',
#   '0.17136000',
#   '0.15712000',
#   '0.16663000',
#   '764061575.30000000',
#   1606694399999,
#   '125044829.83945700',
#   240569,
#   '385706076.60000000',
#   '63177817.95846900',
#   '0'],
#  [1606694400000,
#   '0.16666000',
#   '0.17399000',
#   '0.16011000',
#   '0.17204000',
#   '810673450.80000000',
#   1606780799999,
#   '136237545.66296700',
#   229177,
#   '404769496.40000000',
#   '68053601.58771400',
#   '0'],
#  [1606780800000,
#   '0.17207000',
#   '0.17456000',
#   '0.14132000',
#   '0.15562000',
#   '1039771812.10000000',
#   1606867199999,
#   '166639130.74054500',
#   289501,
#   '508680921.60000000',
#   '81596966.67044200',
#   '0'],
#  [1606867200000,
#   '0.15554000',
#   '0.15997000',
#   '0.15065000',
#   '0.15845000',
#   '435020305.60000000',
#   1606953599999,
#   '67918215.15658600',
#   114336,
#   '219753593.10000000',
#   '34298842.46357000',
#   '0'],
#  [1606953600000,
#   '0.15841000',
#   '0.16842000',
#   '0.15532000',
#   '0.16398000',
#   '413504395.20000000',
#   1607039999999,
#   '66943835.32852100',
#   139922,
#   '208266858.20000000',
#   '33728330.04231100',
#   '0'],
#  [1607040000000,
#   '0.16395000',
#   '0.16464000',
#   '0.14600000',
#   '0.14781000',
#   '466897814.70000000',
#   1607126399999,
#   '73072575.78105300',
#   181178,
#   '220841912.60000000',
#   '34571548.92675800',
#   '0'],
#  [1607126400000,
#   '0.14779000',
#   '0.16198000',
#   '0.14608000',
#   '0.15993000',
#   '350995852.10000000',
#   1607212799999,
#   '54873141.57189600',
#   134044,
#   '179999675.30000000',
#   '28148799.93702600',
#   '0'],
#  [1607212800000,
#   '0.15996000',
#   '0.16288000',
#   '0.15301000',
#   '0.15873000',
#   '290105225.60000000',
#   1607299199999,
#   '45667813.04387600',
#   116907,
#   '142941628.90000000',
#   '22510221.37998300',
#   '0'],
#  [1607299200000,
#   '0.15875000',
#   '0.15906000',
#   '0.15132000',
#   '0.15401000',
#   '213173504.20000000',
#   1607385599999,
#   '33055652.74585800',
#   64151,
#   '101604875.10000000',
#   '15754280.61062100',
#   '0'],
#  [1607385600000,
#   '0.15401000',
#   '0.15520000',
#   '0.13756000',
#   '0.14120000',
#   '431926292.30000000',
#   1607471999999,
#   '63198666.26735400',
#   136736,
#   '202253120.60000000',
#   '29590155.00779100',
#   '0'],
#  [1607472000000,
#   '0.14117000',
#   '0.15025000',
#   '0.12924000',
#   '0.14796000',
#   '538859167.10000000',
#   1607558399999,
#   '75432291.63920500',
#   167539,
#   '273176994.80000000',
#   '38290183.24587200',
#   '0'],
#  [1607558400000,
#   '0.14796000',
#   '0.14865000',
#   '0.13906000',
#   '0.14188000',
#   '282799496.30000000',
#   1607644799999,
#   '40687535.72393900',
#   97346,
#   '140349542.40000000',
#   '20183378.98660900',
#   '0'],
#  [1607644800000,
#   '0.14188000',
#   '0.14291000',
#   '0.13473000',
#   '0.13926000',
#   '299140983.70000000',
#   1607731199999,
#   '41561549.16847400',
#   96159,
#   '147980433.40000000',
#   '20563486.53859900',
#   '0'],
#  [1607731200000,
#   '0.13927000',
#   '0.14736000',
#   '0.13876000',
#   '0.14438000',
#   '236440057.40000000',
#   1607817599999,
#   '34221271.35396000',
#   91320,
#   '119276884.90000000',
#   '17263992.46893000',
#   '0'],
#  [1607817600000,
#   '0.14439000',
#   '0.15669000',
#   '0.14290000',
#   '0.15406000',
#   '327839004.50000000',
#   1607903999999,
#   '49816857.99481600',
#   123350,
#   '166254562.80000000',
#   '25253982.92288100',
#   '0'],
#  [1607904000000,
#   '0.15404000',
#   '0.15880000',
#   '0.14953000',
#   '0.15877000',
#   '267003605.00000000',
#   1607990399999,
#   '40943801.06038500',
#   100732,
#   '137360366.00000000',
#   '21066767.41810200',
#   '0'],
#  [1607990400000,
#   '0.15877000',
#   '0.16000000',
#   '0.15261000',
#   '0.15381000',
#   '272831838.60000000',
#   1608076799999,
#   '42449979.30038200',
#   106861,
#   '135066075.90000000',
#   '21016363.75075000',
#   '0'],
#  [1608076800000,
#   '0.15385000',
#   '0.16844000',
#   '0.14903000',
#   '0.16814000',
#   '496276026.70000000',
#   1608163199999,
#   '79083716.81930100',
#   173866,
#   '257815485.30000000',
#   '41139015.41626900',
#   '0'],
#  [1608163200000,
#   '0.16806000',
#   '0.17628000',
#   '0.16052000',
#   '0.16336000',
#   '770340713.90000000',
#   1608249599999,
#   '129542865.73732200',
#   233697,
#   '374945084.20000000',
#   '63096812.29903100',
#   '0'],
#  [1608249600000,
#   '0.16339000',
#   '0.16942000',
#   '0.15821000',
#   '0.16502000',
#   '404588707.00000000',
#   1608335999999,
#   '66380846.14211900',
#   145567,
#   '196727298.30000000',
#   '32289623.53161900',
#   '0'],
#  [1608336000000,
#   '0.16502000',
#   '0.17082000',
#   '0.16286000',
#   '0.16433000',
#   '342041141.90000000',
#   1608422399999,
#   '57248498.40441300',
#   138007,
#   '166091288.30000000',
#   '27804605.01820500',
#   '0'],
#  [1608422400000,
#   '0.16421000',
#   '0.16900000',
#   '0.15600000',
#   '0.16201000',
#   '336692485.20000000',
#   1608508799999,
#   '55276607.60878600',
#   140413,
#   '159611898.30000000',
#   '26210084.06567500',
#   '0'],
#  [1608508800000,
#   '0.16196000',
#   '0.16714000',
#   '0.14680000',
#   '0.15278000',
#   '430322921.00000000',
#   1608595199999,
#   '67151902.25624900',
#   159210,
#   '202574688.00000000',
#   '31607013.03278900',
#   '0'],
#  [1608595200000,
#   '0.15279000',
#   '0.16124000',
#   '0.14879000',
#   '0.15646000',
#   '472974503.20000000',
#   1608681599999,
#   '73764999.87558600',
#   188714,
#   '237250380.60000000',
#   '37018568.69402400',
#   '0'],
#  [1608681600000,
#   '0.15645000',
#   '0.15786000',
#   '0.12630000',
#   '0.13635000',
#   '818577125.10000000',
#   1608767999999,
#   '118904127.93182200',
#   262757,
#   '388103310.10000000',
#   '56396411.05078400',
#   '0'],
#  [1608768000000,
#   '0.13631000',
#   '0.15477000',
#   '0.13132000',
#   '0.15304000',
#   '738995663.20000000',
#   1608854399999,
#   '104882009.45582500',
#   232837,
#   '379498841.10000000',
#   '53915845.66468100',
#   '0'],
#  [1608854400000,
#   '0.15305000',
#   '0.16700000',
#   '0.15006000',
#   '0.15761000',
#   '589176673.80000000',
#   1608940799999,
#   '93288393.37839100',
#   196476,
#   '299045680.70000000',
#   '47397621.16846700',
#   '0'],
#  [1608940800000,
#   '0.15763000',
#   '0.16242000',
#   '0.14880000',
#   '0.15839000',
#   '563232604.10000000',
#   1609027199999,
#   '87540978.45993000',
#   192288,
#   '276596193.80000000',
#   '43026695.77744200',
#   '0'],
#  [1609027200000,
#   '0.15839000',
#   '0.16642000',
#   '0.14936000',
#   '0.15467000',
#   '798134617.20000000',
#   1609113599999,
#   '126512838.10009600',
#   241054,
#   '390198312.20000000',
#   '61916704.08615300',
#   '0'],
#  [1609113600000,
#   '0.15467000',
#   '0.18057000',
#   '0.15280000',
#   '0.17627000',
#   '881547663.50000000',
#   1609199999999,
#   '147754102.86798300',
#   278089,
#   '454049195.00000000',
#   '76127999.36938700',
#   '0'],
#  [1609200000000,
#   '0.17630000',
#   '0.19725000',
#   '0.17304000',
#   '0.19067000',
#   '1475500719.50000000',
#   1609286399999,
#   '273970430.80280800',
#   483117,
#   '741286331.80000000',
#   '137761628.52670300',
#   '0'],
#  [1609286400000,
#   '0.19069000',
#   '0.19389000',
#   '0.17511000',
#   '0.18389000',
#   '670221026.80000000',
#   1609372799999,
#   '122388423.33323500',
#   281329,
#   '326627077.50000000',
#   '59651215.85207300',
#   '0'],
#  [1609372800000,
#   '0.18389000',
#   '0.18640000',
#   '0.17443000',
#   '0.18134000',
#   '447672619.80000000',
#   1609459199999,
#   '80709170.33697000',
#   171189,
#   '219985244.80000000',
#   '39681174.48067000',
#   '0'],
#  [1609459200000,
#   '0.18134000',
#   '0.18473000',
#   '0.17000000',
#   '0.17509000',
#   '462201570.90000000',
#   1609545599999,
#   '82720467.01026700',
#   178824,
#   '221710271.10000000',
#   '39724496.65606100',
#   '0'],
#  [1609545600000,
#   '0.17505000',
#   '0.18457000',
#   '0.16793000',
#   '0.17742000',
#   '660303281.20000000',
#   1609631999999,
#   '117077280.52655400',
#   231432,
#   '327472160.00000000',
#   '58116623.05151200',
#   '0'],
#  [1609632000000,
#   '0.17740000',
#   '0.20960000',
#   '0.17255000',
#   '0.20615000',
#   '1201451449.30000000',
#   1609718399999,
#   '230834619.47617280',
#   403926,
#   '611459758.00000000',
#   '117568344.87888480',
#   '0'],
#  [1609718400000,
#   '0.20625000',
#   '0.23992000',
#   '0.19203000',
#   '0.22528000',
#   '1463415575.60000000',
#   1609804799999,
#   '315299480.49144570',
#   548636,
#   '741563107.18000000',
#   '159905398.51120390',
#   '0'],
#  [1609804800000,
#   '0.22518000',
#   '0.26429000',
#   '0.20696000',
#   '0.25873000',
#   '1478887679.33000000',
#   1609891199999,
#   '349709110.76222260',
#   614385,
#   '747144703.73000000',
#   '176799587.31708880',
#   '0'],
#  [1609891200000,
#   '0.25889000',
#   '0.34772000',
#   '0.25347000',
#   '0.33309000',
#   '2059110042.76000000',
#   1609977599999,
#   '611715688.06061450',
#   893919,
#   '1049946737.78000000',
#   '311900901.75920320',
#   '0'],
#  [1609977600000,
#   '0.33311000',
#   '0.35530000',
#   '0.27850000',
#   '0.29928000',
#   '1411321698.55000000',
#   1610063999999,
#   '453119832.63003480',
#   654373,
#   '701607379.05000000',
#   '225491548.60790380',
#   '0'],
#  [1610064000000,
#   '0.29917000',
#   '0.32165000',
#   '0.26175000',
#   '0.30389000',
#   '1284205249.40000000',
#   1610150399999,
#   '380368302.98094100',
#   531917,
#   '639446571.60000000',
#   '189619553.80690200',
#   '0'],
#  [1610150400000,
#   '0.30392000',
#   '0.33851000',
#   '0.29583000',
#   '0.33062000',
#   '820267450.70000000',
#   1610236799999,
#   '259644112.08064400',
#   364494,
#   '422907767.90000000',
#   '133886167.63989400',
#   '0'],
#  [1610236800000,
#   '0.33062000',
#   '0.34120000',
#   '0.27948000',
#   '0.30153000',
#   '908667596.00000000',
#   1610323199999,
#   '285668888.34135600',
#   409748,
#   '449616246.00000000',
#   '141572360.47113600',
#   '0'],
#  ...]

# %%
df = pd.DataFrame(bars)
df
# Out:
#                  0           1           2           3           4   \
# 0     1523923200000  0.25551000  0.28800000  0.23983000  0.24260000
# 1     1524009600000  0.24260000  0.26460000  0.24201000  0.26200000
# 2     1524096000000  0.26199000  0.27500000  0.25777000  0.27004000
# 3     1524182400000  0.27004000  0.30442000  0.26648000  0.30108000
# 4     1524268800000  0.30161000  0.30700000  0.26509000  0.28668000
# ...             ...         ...         ...         ...         ...
# 2375  1729123200000  0.35220000  0.35510000  0.33930000  0.34320000
# 2376  1729209600000  0.34320000  0.35300000  0.34260000  0.35070000
# 2377  1729296000000  0.35070000  0.35700000  0.34920000  0.35130000
# 2378  1729382400000  0.35130000  0.36580000  0.34820000  0.36490000
# 2379  1729468800000  0.36490000  0.37290000  0.35310000  0.35680000
#
#                       5              6                  7       8   \
# 0      67462293.24000000  1524009599999  17411823.57157960   42568
# 1      31328095.79000000  1524095999999   7922134.28304330   21684
# 2      50859980.22000000  1524182399999  13609907.89978870   32600
# 3      71084276.49000000  1524268799999  20270887.70351350   46506
# 4      92719842.91000000  1524355199999  26539390.12720960   55256
# ...                  ...            ...                ...     ...
# 2375  110730558.50000000  1729209599999  38422451.35969000   99975
# 2376   56351424.90000000  1729295999999  19618163.29776000   69870
# 2377   41140586.40000000  1729382399999  14502635.43403000   59718
# 2378   58891202.70000000  1729468799999  21035718.72340000   87724
# 2379   78488001.00000000  1729555199999  28544836.21483000  108960
#
#                      9                  10 11
# 0     28228665.39000000   7281513.06137010  0
# 1     15082512.84000000   3818068.82632840  0
# 2     23934593.69000000   6408750.31190170  0
# 3     35262790.18000000  10040840.12777730  0
# 4     43517191.79000000  12413648.37070700  0
# ...                 ...                ... ..
# 2375  54846887.60000000  19039970.91483000  0
# 2376  28157451.20000000   9801542.20985000  0
# 2377  19432375.80000000   6849017.92291000  0
# 2378  28691255.90000000  10245010.42530000  0
# 2379  39227393.90000000  14283760.26976000  0
#
# [2380 rows x 12 columns]

# %%
df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")

# %%
df
# Out:
#                   0           1           2           3           4  \
# 0     1523923200000  0.25551000  0.28800000  0.23983000  0.24260000
# 1     1524009600000  0.24260000  0.26460000  0.24201000  0.26200000
# 2     1524096000000  0.26199000  0.27500000  0.25777000  0.27004000
# 3     1524182400000  0.27004000  0.30442000  0.26648000  0.30108000
# 4     1524268800000  0.30161000  0.30700000  0.26509000  0.28668000
# ...             ...         ...         ...         ...         ...
# 2375  1729123200000  0.35220000  0.35510000  0.33930000  0.34320000
# 2376  1729209600000  0.34320000  0.35300000  0.34260000  0.35070000
# 2377  1729296000000  0.35070000  0.35700000  0.34920000  0.35130000
# 2378  1729382400000  0.35130000  0.36580000  0.34820000  0.36490000
# 2379  1729468800000  0.36490000  0.37290000  0.35310000  0.35680000
#
#                        5              6                  7       8  \
# 0      67462293.24000000  1524009599999  17411823.57157960   42568
# 1      31328095.79000000  1524095999999   7922134.28304330   21684
# 2      50859980.22000000  1524182399999  13609907.89978870   32600
# 3      71084276.49000000  1524268799999  20270887.70351350   46506
# 4      92719842.91000000  1524355199999  26539390.12720960   55256
# ...                  ...            ...                ...     ...
# 2375  110730558.50000000  1729209599999  38422451.35969000   99975
# 2376   56351424.90000000  1729295999999  19618163.29776000   69870
# 2377   41140586.40000000  1729382399999  14502635.43403000   59718
# 2378   58891202.70000000  1729468799999  21035718.72340000   87724
# 2379   78488001.00000000  1729555199999  28544836.21483000  108960
#
#                       9                 10 11       Date
# 0     28228665.39000000   7281513.06137010  0 2018-04-17
# 1     15082512.84000000   3818068.82632840  0 2018-04-18
# 2     23934593.69000000   6408750.31190170  0 2018-04-19
# 3     35262790.18000000  10040840.12777730  0 2018-04-20
# 4     43517191.79000000  12413648.37070700  0 2018-04-21
# ...                 ...                ... ..        ...
# 2375  54846887.60000000  19039970.91483000  0 2024-10-17
# 2376  28157451.20000000   9801542.20985000  0 2024-10-18
# 2377  19432375.80000000   6849017.92291000  0 2024-10-19
# 2378  28691255.90000000  10245010.42530000  0 2024-10-20
# 2379  39227393.90000000  14283760.26976000  0 2024-10-21
#
# [2380 rows x 13 columns]

# %%
df.columns = ["Open Time", "Open", "High", "Low", "Close",
              "Volume", "Clos Time", "Quote Asset Volume", 
              "Number of Trades", "Taker Buy Base Asset Volume",
              "Taker Buy Quote Asset Volume", "Ignore", "Date" ]

# %%
df
# Out:
#           Open Time        Open        High         Low       Close  \
# 0     1523923200000  0.25551000  0.28800000  0.23983000  0.24260000
# 1     1524009600000  0.24260000  0.26460000  0.24201000  0.26200000
# 2     1524096000000  0.26199000  0.27500000  0.25777000  0.27004000
# 3     1524182400000  0.27004000  0.30442000  0.26648000  0.30108000
# 4     1524268800000  0.30161000  0.30700000  0.26509000  0.28668000
# ...             ...         ...         ...         ...         ...
# 2375  1729123200000  0.35220000  0.35510000  0.33930000  0.34320000
# 2376  1729209600000  0.34320000  0.35300000  0.34260000  0.35070000
# 2377  1729296000000  0.35070000  0.35700000  0.34920000  0.35130000
# 2378  1729382400000  0.35130000  0.36580000  0.34820000  0.36490000
# 2379  1729468800000  0.36490000  0.37290000  0.35310000  0.35680000
#
#                   Volume      Clos Time Quote Asset Volume  Number of Trades  \
# 0      67462293.24000000  1524009599999  17411823.57157960             42568
# 1      31328095.79000000  1524095999999   7922134.28304330             21684
# 2      50859980.22000000  1524182399999  13609907.89978870             32600
# 3      71084276.49000000  1524268799999  20270887.70351350             46506
# 4      92719842.91000000  1524355199999  26539390.12720960             55256
# ...                  ...            ...                ...               ...
# 2375  110730558.50000000  1729209599999  38422451.35969000             99975
# 2376   56351424.90000000  1729295999999  19618163.29776000             69870
# 2377   41140586.40000000  1729382399999  14502635.43403000             59718
# 2378   58891202.70000000  1729468799999  21035718.72340000             87724
# 2379   78488001.00000000  1729555199999  28544836.21483000            108960
#
#      Taker Buy Base Asset Volume Taker Buy Quote Asset Volume Ignore  \
# 0              28228665.39000000             7281513.06137010      0
# 1              15082512.84000000             3818068.82632840      0
# 2              23934593.69000000             6408750.31190170      0
# 3              35262790.18000000            10040840.12777730      0
# 4              43517191.79000000            12413648.37070700      0
# ...                          ...                          ...    ...
# 2375           54846887.60000000            19039970.91483000      0
# 2376           28157451.20000000             9801542.20985000      0
# 2377           19432375.80000000             6849017.92291000      0
# 2378           28691255.90000000            10245010.42530000      0
# 2379           39227393.90000000            14283760.26976000      0
#
#            Date
# 0    2018-04-17
# 1    2018-04-18
# 2    2018-04-19
# 3    2018-04-20
# 4    2018-04-21
# ...         ...
# 2375 2024-10-17
# 2376 2024-10-18
# 2377 2024-10-19
# 2378 2024-10-20
# 2379 2024-10-21
#
# [2380 rows x 13 columns]

# %%
df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()

# %%
df
# Out:
#            Date        Open        High         Low       Close  \
# 0    2018-04-17  0.25551000  0.28800000  0.23983000  0.24260000
# 1    2018-04-18  0.24260000  0.26460000  0.24201000  0.26200000
# 2    2018-04-19  0.26199000  0.27500000  0.25777000  0.27004000
# 3    2018-04-20  0.27004000  0.30442000  0.26648000  0.30108000
# 4    2018-04-21  0.30161000  0.30700000  0.26509000  0.28668000
# ...         ...         ...         ...         ...         ...
# 2375 2024-10-17  0.35220000  0.35510000  0.33930000  0.34320000
# 2376 2024-10-18  0.34320000  0.35300000  0.34260000  0.35070000
# 2377 2024-10-19  0.35070000  0.35700000  0.34920000  0.35130000
# 2378 2024-10-20  0.35130000  0.36580000  0.34820000  0.36490000
# 2379 2024-10-21  0.36490000  0.37290000  0.35310000  0.35680000
#
#                   Volume
# 0      67462293.24000000
# 1      31328095.79000000
# 2      50859980.22000000
# 3      71084276.49000000
# 4      92719842.91000000
# ...                  ...
# 2375  110730558.50000000
# 2376   56351424.90000000
# 2377   41140586.40000000
# 2378   58891202.70000000
# 2379   78488001.00000000
#
# [2380 rows x 6 columns]

# %%
df.set_index("Date", inplace = True)

# %%
df
# Out:
#                       Open            High             Low           Close  \
# Date
# 2017-08-17   4261.48000000   4485.39000000   4200.74000000   4285.08000000
# 2017-08-18   4285.08000000   4371.52000000   3938.77000000   4108.37000000
# 2017-08-19   4108.37000000   4184.69000000   3850.00000000   4139.98000000
# 2017-08-20   4120.98000000   4211.08000000   4032.62000000   4086.29000000
# 2017-08-21   4069.13000000   4119.62000000   3911.79000000   4016.00000000
# ...                    ...             ...             ...             ...
# 2024-10-14  62870.02000000  66500.00000000  62457.81000000  66083.99000000
# 2024-10-15  66084.00000000  67950.00000000  64800.01000000  67074.14000000
# 2024-10-16  67074.14000000  68424.00000000  66750.49000000  67620.01000000
# 2024-10-17  67620.00000000  67939.40000000  66666.00000000  67421.78000000
# 2024-10-18  67421.78000000  68378.95000000  67192.36000000  67732.00000000
#
#                     Volume
# Date
# 2017-08-17    795.15037700
# 2017-08-18   1199.88826400
# 2017-08-19    381.30976300
# 2017-08-20    467.08302200
# 2017-08-21    691.74306000
# ...                    ...
# 2024-10-14  37669.95222000
# 2024-10-15  43683.95423000
# 2024-10-16  29938.25544000
# 2024-10-17  25328.22861000
# 2024-10-18  13122.50072000
#
# [2620 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2620 entries, 2017-08-17 to 2024-10-18
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2620 non-null   object
#  1   High    2620 non-null   object
#  2   Low     2620 non-null   object
#  3   Close   2620 non-null   object
#  4   Volume  2620 non-null   object
# dtypes: object(5)
# memory usage: 122.8+ KB

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors = "coerce")

# %% [markdown]
# ## Getting Historical Data (OHLC & Volume) - Part 2

# %%
def get_history(symbol, interval, start, end = None):
    bars = client.get_historical_klines(symbol = symbol, interval = interval,
                                        start_str = start, end_str = end, limit = 1000)
    df = pd.DataFrame(bars)
    df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
    df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                  "Clos Time", "Quote Asset Volume", "Number of Trades",
                  "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
    df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
    df.set_index("Date", inplace = True)
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors = "coerce")
    
    return df

# %%
timestamp
# Out:
# 1502928000000

# %% [markdown]
# __Daily Data until Today/Now__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1d", start = timestamp)
df
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2017-08-17   4261.48   4485.39   4200.74   4285.08    795.150377
# 2017-08-18   4285.08   4371.52   3938.77   4108.37   1199.888264
# 2017-08-19   4108.37   4184.69   3850.00   4139.98    381.309763
# 2017-08-20   4120.98   4211.08   4032.62   4086.29    467.083022
# 2017-08-21   4069.13   4119.62   3911.79   4016.00    691.743060
# ...              ...       ...       ...       ...           ...
# 2024-10-17  67620.00  67939.40  66666.00  67421.78  25328.228610
# 2024-10-18  67421.78  69000.00  67192.36  68428.00  28725.635000
# 2024-10-19  68427.99  68693.26  68010.00  68378.00   8193.667370
# 2024-10-20  68377.99  69400.00  68100.00  69031.99  12442.473780
# 2024-10-21  69032.00  69519.52  66840.67  67214.01  27425.676030
#
# [2623 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2623 entries, 2017-08-17 to 2024-10-21
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2623 non-null   float64
#  1   High    2623 non-null   float64
#  2   Low     2623 non-null   float64
#  3   Close   2623 non-null   float64
#  4   Volume  2623 non-null   float64
# dtypes: float64(5)
# memory usage: 123.0 KB

# %% [markdown]
# __Daily Data for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1d", start = "2021-01-01", end = "2021-06-30")
df
# Out:
#                 Open      High       Low     Close         Volume
# Date
# 2021-01-01  28923.63  29600.00  28624.57  29331.69   54182.925011
# 2021-01-02  29331.70  33300.00  28946.53  32178.33  129993.873362
# 2021-01-03  32176.45  34778.11  31962.99  33000.05  120957.566750
# 2021-01-04  33000.05  33600.00  28130.00  31988.71  140899.885690
# 2021-01-05  31989.75  34360.00  29900.00  33949.53  116049.997038
# ...              ...       ...       ...       ...            ...
# 2021-06-26  31576.09  32730.00  30151.00  32283.65  107820.375287
# 2021-06-27  32283.65  34749.00  31973.45  34700.34   96613.244211
# 2021-06-28  34702.49  35297.71  33862.72  34494.89   82222.267819
# 2021-06-29  34494.89  36600.00  34225.43  35911.73   90788.796220
# 2021-06-30  35911.72  36100.00  34017.55  35045.00   77152.197634
#
# [181 rows x 5 columns]

# %% [markdown]
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

# %% [markdown]
# __Weekly Data for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1w", start = "2021-01-01", end = "2021-06-30")
df
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2021-01-04  33000.05  41950.00  28130.00  38150.02  8.507003e+05
# 2021-01-11  38150.02  40100.00  30420.00  35828.61  8.973397e+05
# 2021-01-18  35824.99  37850.00  28850.00  32259.90  6.402269e+05
# 2021-01-25  32259.45  38531.90  29241.72  33092.98  7.474635e+05
# 2021-02-01  33092.97  40955.51  32296.16  38795.69  5.834423e+05
# 2021-02-08  38795.69  49707.43  37988.89  48577.79  6.641863e+05
# 2021-02-15  48580.47  58352.80  45570.79  57408.57  5.334878e+05
# 2021-02-22  57412.35  57508.47  43000.00  45135.66  7.371257e+05
# 2021-03-01  45134.11  52640.00  44950.53  50971.75  4.908196e+05
# 2021-03-08  50959.11  61844.00  49274.67  58968.31  5.145597e+05
# 2021-03-15  58976.08  60633.43  53271.34  57351.56  4.631942e+05
# 2021-03-22  57351.56  58430.73  50427.56  55777.63  4.462786e+05
# 2021-03-29  55777.65  60200.00  54800.01  58202.01  3.674779e+05
# 2021-04-05  58202.01  61500.00  55473.00  60002.43  3.758656e+05
# 2021-04-12  59998.80  64854.00  50931.30  56150.01  5.490483e+05
# 2021-04-19  56150.01  57526.81  46930.00  49066.77  5.684629e+05
# 2021-04-26  49066.76  58458.07  48753.44  56578.21  3.959835e+05
# 2021-05-03  56578.21  59500.00  52900.00  58240.84  5.044789e+05
# 2021-05-10  58240.83  59500.00  43825.39  46431.50  6.848801e+05
# 2021-05-17  46426.83  46686.00  30000.00  34655.25  1.386781e+06
# 2021-05-24  34681.44  40841.00  33379.00  35641.27  7.865312e+05
# 2021-05-31  35641.26  39476.00  34153.84  35796.31  5.282995e+05
# 2021-06-07  35796.31  39380.00  31000.00  39020.57  7.000656e+05
# 2021-06-14  39020.56  41330.00  33336.00  35600.16  6.103340e+05
# 2021-06-21  35600.17  35750.00  28805.00  34700.34  9.070737e+05
# 2021-06-28  34702.49  36600.00  32699.00  35286.51  4.647918e+05

# %% [markdown]
# __Monthly Data for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1M", start = "2021-01-01", end = "2021-06-15")
df
# Out:
#                 Open     High       Low     Close        Volume
# Date
# 2021-01-01  28923.63  41950.0  28130.00  33092.98  3.440865e+06
# 2021-02-01  33092.97  58352.8  32296.16  45135.66  2.518242e+06
# 2021-03-01  45134.11  61844.0  44950.53  58740.55  2.098808e+06
# 2021-04-01  58739.46  64854.0  46930.00  57694.27  1.993469e+06
# 2021-05-01  57697.25  59500.0  30000.00  37253.81  3.536245e+06
# 2021-06-01  37253.82  41330.0  28805.00  35045.00  2.901775e+06

# %% [markdown]
# __Most recent Monthly Data (until today/now)__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1M", start = "2021-01-01")
df
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2021-01-01  28923.63  41950.00  28130.00  33092.98  3.440865e+06
# 2021-02-01  33092.97  58352.80  32296.16  45135.66  2.518242e+06
# 2021-03-01  45134.11  61844.00  44950.53  58740.55  2.098808e+06
# 2021-04-01  58739.46  64854.00  46930.00  57694.27  1.993469e+06
# 2021-05-01  57697.25  59500.00  30000.00  37253.81  3.536245e+06
# 2021-06-01  37253.82  41330.00  28805.00  35045.00  2.901775e+06
# 2021-07-01  35045.00  42448.00  29278.00  41461.83  1.778463e+06
# 2021-08-01  41461.84  50500.00  37332.70  47100.89  1.635403e+06
# 2021-09-01  47100.89  52920.00  39600.00  43824.10  1.527800e+06
# 2021-10-01  43820.01  67000.00  43283.03  61299.80  1.565556e+06
# 2021-11-01  61299.81  69000.00  53256.64  56950.56  1.291900e+06
# 2021-12-01  56950.56  59053.55  42000.30  46216.93  1.233746e+06
# 2022-01-01  46216.93  47990.00  32917.17  38466.90  1.279407e+06
# 2022-02-01  38466.90  45821.00  34322.28  43160.00  1.253514e+06
# 2022-03-01  43160.00  48189.84  37155.00  45510.34  1.501399e+06
# 2022-04-01  45510.35  47444.11  37578.20  37630.80  1.267656e+06
# 2022-05-01  37630.80  40023.77  26700.00  31801.04  2.387840e+06
# 2022-06-01  31801.05  31982.97  17622.00  19942.21  2.816058e+06
# 2022-07-01  19942.21  24668.00  18781.00  23293.32  4.983279e+06
# 2022-08-01  23296.36  25211.32  19520.00  20050.02  5.692462e+06
# 2022-09-01  20048.44  22799.00  18125.98  19422.61  9.838931e+06
# 2022-10-01  19422.61  21085.00  18190.00  20490.74  7.499122e+06
# 2022-11-01  20490.74  21480.65  15476.00  17163.64  9.127694e+06
# 2022-12-01  17165.53  18387.95  16256.30  16542.40  5.803834e+06
# 2023-01-01  16541.77  23960.54  16499.01  23125.13  7.977029e+06
# 2023-02-01  23125.13  25250.00  21351.07  23141.57  8.642691e+06
# 2023-03-01  23141.57  29184.68  19549.09  28465.36  9.516189e+06
# 2023-04-01  28465.36  31000.00  26942.82  29233.21  1.626746e+06
# 2023-05-01  29233.20  29820.00  25811.46  27210.35  1.302000e+06
# 2023-06-01  27210.36  31431.94  24800.00  30472.00  1.387207e+06
# 2023-07-01  30471.99  31804.20  28861.90  29232.25  9.257738e+05
# 2023-08-01  29232.26  30244.00  25166.00  25940.78  1.025867e+06
# 2023-09-01  25940.77  27483.57  24901.00  26962.56  8.093290e+05
# 2023-10-01  26962.57  35280.00  26538.66  34639.77  1.141404e+06
# 2023-11-01  34639.78  38450.00  34097.39  37723.96  1.055691e+06
# 2023-12-01  37723.97  44700.00  37615.86  42283.58  1.195410e+06
# 2024-01-01  42283.58  48969.48  38555.00  42580.00  1.403409e+06
# 2024-02-01  42580.00  64000.00  41884.28  61130.98  1.206113e+06
# 2024-03-01  61130.99  73777.00  59005.00  71280.01  1.706807e+06
# 2024-04-01  71280.00  72797.99  59191.60  60672.00  1.201501e+06
# 2024-05-01  60672.01  71979.00  56552.82  67540.01  9.450310e+05
# 2024-06-01  67540.01  71997.02  58402.00  62772.01  6.968182e+05
# 2024-07-01  62772.01  70079.99  53485.93  64628.00  9.080043e+05
# 2024-08-01  64628.01  65659.78  49000.00  58973.99  1.010291e+06
# 2024-09-01  58974.00  66498.00  52550.00  63327.59  7.341171e+05
# 2024-10-01  63327.60  68424.00  58946.00  67692.00  4.253892e+05

# %% [markdown]
# __Intraday Data (1H) for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1h", start = "2017-01-01", end = "2017-10-05")
df
# Out:
#                         Open     High      Low    Close     Volume
# Date
# 2017-08-17 04:00:00  4261.48  4313.62  4261.32  4308.83  47.181009
# 2017-08-17 05:00:00  4308.83  4328.69  4291.37  4315.32  23.234916
# 2017-08-17 06:00:00  4330.29  4345.45  4309.37  4324.35   7.229691
# 2017-08-17 07:00:00  4316.62  4349.99  4287.41  4349.99   4.443249
# 2017-08-17 08:00:00  4333.32  4377.85  4333.32  4360.69   0.972807
# ...                      ...      ...      ...      ...        ...
# 2017-10-04 20:00:00  4170.05  4173.11  4156.00  4162.55  29.138233
# 2017-10-04 21:00:00  4165.00  4215.89  4158.08  4199.99  37.252348
# 2017-10-04 22:00:00  4187.56  4220.00  4185.63  4215.00  23.896519
# 2017-10-04 23:00:00  4215.00  4236.63  4193.07  4208.59  17.673534
# 2017-10-05 00:00:00  4208.59  4235.00  4197.04  4215.00  19.881657
#
# [1167 rows x 5 columns]

# %%
df = get_history(symbol = "BTCUSDT", interval = "1h",
                 start = "2021-10-01 10:00:00", end = "2021-10-05 16:00:00")
df
# Out:
#                          Open      High       Low     Close       Volume
# Date
# 2021-10-01 10:00:00  44905.99  47786.70  44829.40  47081.46  12252.88214
# 2021-10-01 11:00:00  47081.47  47659.32  46957.48  47488.08   4669.20863
# 2021-10-01 12:00:00  47488.07  47886.11  47170.23  47214.37   5156.10571
# 2021-10-01 13:00:00  47214.37  47379.99  46957.14  46980.94   2595.13896
# 2021-10-01 14:00:00  46980.94  47347.53  46763.68  47130.00   3479.22010
# ...                       ...       ...       ...       ...          ...
# 2021-10-05 12:00:00  49877.06  50110.00  49705.00  50000.00   2161.32487
# 2021-10-05 13:00:00  50000.00  50320.00  49772.63  50207.96   2108.42441
# 2021-10-05 14:00:00  50207.96  50388.00  49575.94  49841.79   3331.24836
# 2021-10-05 15:00:00  49841.78  50205.21  49700.00  49793.57   2394.23691
# 2021-10-05 16:00:00  49793.57  50115.24  49640.36  50103.85   1616.06606
#
# [103 rows x 5 columns]

# %% [markdown]
# __Intraday Data (1m) for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1m",
                 start = "2017-01-01 10:29:00", end = "2017-10-05 16:55:00")
df
# Out:
#                         Open     High      Low    Close    Volume
# Date
# 2017-08-17 04:00:00  4261.48  4261.48  4261.48  4261.48  1.775183
# 2017-08-17 04:01:00  4261.48  4261.48  4261.48  4261.48  0.000000
# 2017-08-17 04:02:00  4280.56  4280.56  4280.56  4280.56  0.261074
# 2017-08-17 04:03:00  4261.48  4261.48  4261.48  4261.48  0.012008
# 2017-08-17 04:04:00  4261.48  4261.48  4261.48  4261.48  0.140796
# ...                      ...      ...      ...      ...       ...
# 2017-10-05 16:51:00  4299.50  4299.50  4299.50  4299.50  0.127887
# 2017-10-05 16:52:00  4299.50  4299.50  4299.50  4299.50  0.000000
# 2017-10-05 16:53:00  4299.50  4299.50  4299.50  4299.50  0.000000
# 2017-10-05 16:54:00  4299.50  4299.50  4299.50  4299.50  0.000000
# 2017-10-05 16:55:00  4299.50  4299.50  4299.50  4299.50  0.000000
#
# [70917 rows x 5 columns]

# %% [markdown]
# __Most recent (last 2 hours) Intraday Data (1m)__

# %%
from datetime import datetime, timedelta
import datetime as dt # newly added

# %%
# now = datetime.utcnow() # old
# now

# %%
now = datetime.now(dt.UTC) # new
now
# Out:
# datetime.datetime(2024, 10, 18, 13, 12, 33, 176062, tzinfo=datetime.timezone.utc)

# %%
two_hours_before = now - timedelta(hours = 2)
two_hours_before
# Out:
# datetime.datetime(2024, 10, 18, 11, 12, 33, 176062, tzinfo=datetime.timezone.utc)

# %%
str(two_hours_before)
# Out:
# '2024-10-18 11:12:33.176062+00:00'

# %%
df = get_history(symbol = "BTCUSDT", interval = "1m", start = str(two_hours_before))
df
# Out:
#                          Open      High       Low     Close    Volume
# Date
# 2024-10-18 11:13:00  67966.17  67982.88  67945.47  67982.88  26.03068
# 2024-10-18 11:14:00  67982.88  68020.00  67982.88  68019.99  64.40110
# 2024-10-18 11:15:00  68019.99  68028.44  67964.00  67969.99  26.66761
# 2024-10-18 11:16:00  67969.99  67999.57  67969.99  67999.56  11.82319
# 2024-10-18 11:17:00  67999.57  67999.57  67966.25  67974.84  17.75202
# ...                       ...       ...       ...       ...       ...
# 2024-10-18 13:08:00  67792.80  67804.00  67784.41  67804.00   7.79142
# 2024-10-18 13:09:00  67803.99  67844.43  67803.99  67837.36   9.13814
# 2024-10-18 13:10:00  67837.37  67841.77  67820.00  67820.01   7.61891
# 2024-10-18 13:11:00  67820.00  67824.00  67786.91  67793.99  18.54731
# 2024-10-18 13:12:00  67793.99  67810.00  67790.00  67810.00   3.22169
#
# [120 rows x 5 columns]

# %% [markdown]
# ## Excursus: Loading Historical Data (csv) from the Website

# %%
import pandas as pd

# %%
url = "ETHTUSD-1m-2024-03.csv" # insert your filepath here
url
# Out:
# 'ETHTUSD-1m-2024-03.csv'

# %%
df = pd.read_csv(url, header = None)
df
# Out:
#                   0        1        2        3        4       5   \
# 0      1709251200000  3340.70  3343.69  3336.79  3342.08  5.5220
# 1      1709251260000  3345.00  3345.94  3340.23  3343.17  2.4339
# 2      1709251320000  3345.24  3345.24  3341.54  3343.18  5.6318
# 3      1709251380000  3340.00  3340.75  3340.00  3340.08  0.0634
# 4      1709251440000  3341.31  3341.31  3341.00  3341.00  0.0600
# ...              ...      ...      ...      ...      ...     ...
# 44635  1711929300000  3646.79  3646.79  3646.79  3646.79  0.0300
# 44636  1711929360000  3647.82  3647.82  3647.82  3647.82  0.0300
# 44637  1711929420000  3648.53  3648.53  3648.53  3648.53  0.0300
# 44638  1711929480000  3649.30  3649.30  3649.04  3649.04  0.0600
# 44639  1711929540000  3648.46  3648.46  3648.46  3648.46  0.0300
#
#                   6             7   8       9            10  11
# 0      1709251259999  18448.171112  46  1.1986  4004.494914   0
# 1      1709251319999   8140.862169  15  0.0638   213.356924   0
# 2      1709251379999  18833.443810  26  0.0320   106.996120   0
# 3      1709251439999    211.780900   3  0.0600   200.424900   0
# 4      1709251499999    200.469300   2  0.0600   200.469300   0
# ...              ...           ...  ..     ...          ...  ..
# 44635  1711929359999    109.403700   1  0.0000     0.000000   0
# 44636  1711929419999    109.434600   1  0.0300   109.434600   0
# 44637  1711929479999    109.455900   1  0.0000     0.000000   0
# 44638  1711929539999    218.950200   2  0.0300   109.471200   0
# 44639  1711929599999    109.453800   1  0.0000     0.000000   0
#
# [44640 rows x 12 columns]

# %%
df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
df
# Out:
#                    0        1        2        3        4       5  \
# 0      1709251200000  3340.70  3343.69  3336.79  3342.08  5.5220
# 1      1709251260000  3345.00  3345.94  3340.23  3343.17  2.4339
# 2      1709251320000  3345.24  3345.24  3341.54  3343.18  5.6318
# 3      1709251380000  3340.00  3340.75  3340.00  3340.08  0.0634
# 4      1709251440000  3341.31  3341.31  3341.00  3341.00  0.0600
# ...              ...      ...      ...      ...      ...     ...
# 44635  1711929300000  3646.79  3646.79  3646.79  3646.79  0.0300
# 44636  1711929360000  3647.82  3647.82  3647.82  3647.82  0.0300
# 44637  1711929420000  3648.53  3648.53  3648.53  3648.53  0.0300
# 44638  1711929480000  3649.30  3649.30  3649.04  3649.04  0.0600
# 44639  1711929540000  3648.46  3648.46  3648.46  3648.46  0.0300
#
#                    6             7   8       9           10  11  \
# 0      1709251259999  18448.171112  46  1.1986  4004.494914   0
# 1      1709251319999   8140.862169  15  0.0638   213.356924   0
# 2      1709251379999  18833.443810  26  0.0320   106.996120   0
# 3      1709251439999    211.780900   3  0.0600   200.424900   0
# 4      1709251499999    200.469300   2  0.0600   200.469300   0
# ...              ...           ...  ..     ...          ...  ..
# 44635  1711929359999    109.403700   1  0.0000     0.000000   0
# 44636  1711929419999    109.434600   1  0.0300   109.434600   0
# 44637  1711929479999    109.455900   1  0.0000     0.000000   0
# 44638  1711929539999    218.950200   2  0.0300   109.471200   0
# 44639  1711929599999    109.453800   1  0.0000     0.000000   0
#
#                      Date
# 0     2024-03-01 00:00:00
# 1     2024-03-01 00:01:00
# 2     2024-03-01 00:02:00
# 3     2024-03-01 00:03:00
# 4     2024-03-01 00:04:00
# ...                   ...
# 44635 2024-03-31 23:55:00
# 44636 2024-03-31 23:56:00
# 44637 2024-03-31 23:57:00
# 44638 2024-03-31 23:58:00
# 44639 2024-03-31 23:59:00
#
# [44640 rows x 13 columns]

# %%
df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                  "Clos Time", "Quote Asset Volume", "Number of Trades",
                  "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
df
# Out:
#            Open Time     Open     High      Low    Close  Volume  \
# 0      1709251200000  3340.70  3343.69  3336.79  3342.08  5.5220
# 1      1709251260000  3345.00  3345.94  3340.23  3343.17  2.4339
# 2      1709251320000  3345.24  3345.24  3341.54  3343.18  5.6318
# 3      1709251380000  3340.00  3340.75  3340.00  3340.08  0.0634
# 4      1709251440000  3341.31  3341.31  3341.00  3341.00  0.0600
# ...              ...      ...      ...      ...      ...     ...
# 44635  1711929300000  3646.79  3646.79  3646.79  3646.79  0.0300
# 44636  1711929360000  3647.82  3647.82  3647.82  3647.82  0.0300
# 44637  1711929420000  3648.53  3648.53  3648.53  3648.53  0.0300
# 44638  1711929480000  3649.30  3649.30  3649.04  3649.04  0.0600
# 44639  1711929540000  3648.46  3648.46  3648.46  3648.46  0.0300
#
#            Clos Time  Quote Asset Volume  Number of Trades  \
# 0      1709251259999        18448.171112                46
# 1      1709251319999         8140.862169                15
# 2      1709251379999        18833.443810                26
# 3      1709251439999          211.780900                 3
# 4      1709251499999          200.469300                 2
# ...              ...                 ...               ...
# 44635  1711929359999          109.403700                 1
# 44636  1711929419999          109.434600                 1
# 44637  1711929479999          109.455900                 1
# 44638  1711929539999          218.950200                 2
# 44639  1711929599999          109.453800                 1
#
#        Taker Buy Base Asset Volume  Taker Buy Quote Asset Volume  Ignore  \
# 0                           1.1986                   4004.494914       0
# 1                           0.0638                    213.356924       0
# 2                           0.0320                    106.996120       0
# 3                           0.0600                    200.424900       0
# 4                           0.0600                    200.469300       0
# ...                            ...                           ...     ...
# 44635                       0.0000                      0.000000       0
# 44636                       0.0300                    109.434600       0
# 44637                       0.0000                      0.000000       0
# 44638                       0.0300                    109.471200       0
# 44639                       0.0000                      0.000000       0
#
#                      Date
# 0     2024-03-01 00:00:00
# 1     2024-03-01 00:01:00
# 2     2024-03-01 00:02:00
# 3     2024-03-01 00:03:00
# 4     2024-03-01 00:04:00
# ...                   ...
# 44635 2024-03-31 23:55:00
# 44636 2024-03-31 23:56:00
# 44637 2024-03-31 23:57:00
# 44638 2024-03-31 23:58:00
# 44639 2024-03-31 23:59:00
#
# [44640 rows x 13 columns]

# %%
df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
df.set_index("Date", inplace = True)

#not required:
#for column in df.columns:
    #df[column] = pd.to_numeric(df[column], errors = "coerce")

# %%
df
# Out:
#                         Open     High      Low    Close  Volume
# Date
# 2024-03-01 00:00:00  3340.70  3343.69  3336.79  3342.08  5.5220
# 2024-03-01 00:01:00  3345.00  3345.94  3340.23  3343.17  2.4339
# 2024-03-01 00:02:00  3345.24  3345.24  3341.54  3343.18  5.6318
# 2024-03-01 00:03:00  3340.00  3340.75  3340.00  3340.08  0.0634
# 2024-03-01 00:04:00  3341.31  3341.31  3341.00  3341.00  0.0600
# ...                      ...      ...      ...      ...     ...
# 2024-03-31 23:55:00  3646.79  3646.79  3646.79  3646.79  0.0300
# 2024-03-31 23:56:00  3647.82  3647.82  3647.82  3647.82  0.0300
# 2024-03-31 23:57:00  3648.53  3648.53  3648.53  3648.53  0.0300
# 2024-03-31 23:58:00  3649.30  3649.30  3649.04  3649.04  0.0600
# 2024-03-31 23:59:00  3648.46  3648.46  3648.46  3648.46  0.0300
#
# [44640 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44640 entries, 2024-03-01 00:00:00 to 2024-03-31 23:59:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    44640 non-null  float64
#  1   High    44640 non-null  float64
#  2   Low     44640 non-null  float64
#  3   Close   44640 non-null  float64
#  4   Volume  44640 non-null  float64
# dtypes: float64(5)
# memory usage: 2.0 MB

# %% [markdown]
# ## Streaming Market Data (Part 1)

# %% [markdown]
# ### ++++++ Update (August 2023) ++++++++

# %% [markdown]
# There are two alternatives to stream live data with python-binance:
# - using __ThreadedWebsocketManager__ -or-
# - using __BinanceSocketManager (newly added to the course)__

# %% [markdown]
# __ThreadedWebsocketManager:__
# - Code is simpler
# - worked with Python Version 3.7/3.8/3.9 __and__ python-binance Version <= 1.0.15 in __Jupyter Notebooks and Scripts__
# - __no longer works in Juypter Notebooks__ if Python Version >= 3.10 __or__ python-binance Version > 1.0.15
# - important: still works in any case in Python scripts!!! __-> We´ll use it in Scripts (later in the course).__

# %% [markdown]
# __BinanceSocketManager (NEW):__
# - Code is more complex
# - Works in Jupyter Notebooks and Scripts
# - __We´ll use it here in Jupyter Notebooks as an executable alternative__

# %% [markdown]
# __What´s the benefit of covering both options?__<br>
# -> We can now __run Trading Bots in Jupyter and as a Script__ with the __latest Versions__ for Python and Python-Binance. No need to care about Versions and Installations anymore!

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# ### Option 1: ThreadedWebsocketManager (only executable in scripts, not in Jupyter!):

# %%
from binance import ThreadedWebsocketManager
import time

# %%
def stream_data(msg):
    ''' define how to process incoming WebSocket messages '''
    print(msg)

# %%
# initialize and start the WebSocket
twm = ThreadedWebsocketManager()
twm.start()
# Out:
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/jonatas/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/threaded_stream.py", line 59, in run
#     self._loop.run_until_complete(self.socket_listener())
#   File "/usr/lib64/python3.12/asyncio/base_events.py", line 663, in run_until_complete
#     self._check_running()
#   File "/usr/lib64/python3.12/asyncio/base_events.py", line 622, in _check_running
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running
# /usr/lib64/python3.12/threading.py:1077: RuntimeWarning: coroutine 'ThreadedApiManager.socket_listener' was never awaited
#   self._invoke_excepthook(self)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# If you have an account on __Binance.US__ (US residents) <br>
# (If you are using an exchange from the US, Japan or other TLD then make sure pass tld=’us’ when initializing the TWM.)

# %%
# initialize and start the WebSocket in the us
# twm = ThreadedWebsocketManager(tld = "us")
# twm.start()

# %%
twm

# %% [markdown]
# __Different Market Streams available:__ https://binance-docs.github.io/apidocs/spot/en/#websocket-market-streams

# %% [markdown]
# __Individual Symbol Mini Ticker:__ 24hr rolling window mini-ticker statistics. These are NOT the statistics of the UTC day, but a 24hr rolling window for the previous 24hrs.

# %%
# subscribe to the stream
twm.start_symbol_miniticker_socket(callback = stream_data, symbol = "BTCUSDT")

# %%
# stop the Websocket/Stream after 20 seconds
while True:
    time.sleep(20)
    twm.stop()
    break

# %% [markdown]
# __Individual Symbol Mini Ticker Output/Message:__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# ### Option2: BinanceSocketManager (executable in Jupyter!):

# %%
import asyncio
from binance import AsyncClient, BinanceSocketManager

# %%
def stream_data(msg):
    ''' define how to process incoming WebSocket messages '''
    print(msg)

# %%
async def main():
    client = await AsyncClient.create()
    bm = BinanceSocketManager(client)
    ts = bm.symbol_miniticker_socket(symbol="BTCUSDT")
    
    async with ts as tscm:
        for _ in range(n):  # This is just an example to limit the number of messages. Remove or adjust as needed.
            res = await tscm.recv()
            stream_data(res)

    await client.close_connection()

# %%
n = 10 # stop stream after 10 messages

# %%
await main() # start stream in Jupyter
# Out:
# {'e': '24hrMiniTicker', 'E': 1729267816234, 's': 'BTCUSDT', 'c': '68533.99000000', 'o': '67373.99000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29706.34817000', 'q': '2015883231.15147120'}
# {'e': '24hrMiniTicker', 'E': 1729267817870, 's': 'BTCUSDT', 'c': '68544.00000000', 'o': '67381.37000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29709.43842000', 'q': '2016095674.22971040'}
# {'e': '24hrMiniTicker', 'E': 1729267818884, 's': 'BTCUSDT', 'c': '68544.00000000', 'o': '67381.37000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29709.43812000', 'q': '2016095655.16630170'}
# {'e': '24hrMiniTicker', 'E': 1729267819888, 's': 'BTCUSDT', 'c': '68544.00000000', 'o': '67381.37000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29709.45143000', 'q': '2016096573.42784540'}
# {'e': '24hrMiniTicker', 'E': 1729267820933, 's': 'BTCUSDT', 'c': '68544.00000000', 'o': '67386.35000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29708.79212000', 'q': '2016052171.10810480'}
# {'e': '24hrMiniTicker', 'E': 1729267821814, 's': 'BTCUSDT', 'c': '68543.99000000', 'o': '67386.35000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29708.80232000', 'q': '2016052870.54623660'}
# {'e': '24hrMiniTicker', 'E': 1729267822934, 's': 'BTCUSDT', 'c': '68532.33000000', 'o': '67386.36000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29710.31147000', 'q': '2016156317.97864120'}
# {'e': '24hrMiniTicker', 'E': 1729267823505, 's': 'BTCUSDT', 'c': '68532.33000000', 'o': '67390.00000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29709.71032000', 'q': '2016115816.38032680'}
# {'e': '24hrMiniTicker', 'E': 1729267824480, 's': 'BTCUSDT', 'c': '68532.00000000', 'o': '67393.99000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29709.73787000', 'q': '2016117804.53565200'}
# {'e': '24hrMiniTicker', 'E': 1729267825973, 's': 'BTCUSDT', 'c': '68526.01000000', 'o': '67331.97000000', 'h': '68870.68000000', 'l': '66720.00000000', 'v': '29679.32097000', 'q': '2014069727.94137930'}

# %%
# asyncio.run(main()) # start stream in Script!!!

# %% [markdown]
# If you have an account on __Binance.US__ (US residents) <br>
# (If you are using an exchange from the US, Japan or other TLD then make sure pass tld=’us’ when initializing the client.)

# %%
async def main():
    client = await AsyncClient.create(tld = "us")
    bm = BinanceSocketManager(client)
    ts = bm.symbol_miniticker_socket(symbol = "BTCUSD") # USD instead of USDT
    
    async with ts as tscm:
        for _ in range(n):  # This is just an example to limit the number of messages. Remove or adjust as needed.
            res = await tscm.recv()
            stream_data(res)

    await client.close_connection()

# %%
await main()

# %% [markdown]
# __Troubleshooting (October 2024)__

# %% [markdown]
# In case you get a RuntimeError: aiodns needs a SelectorEventLoop in Windows (see screenshot below), please downgrade aiohttp to from version 3.10 to 3.9.5 with the following command:

# %% [markdown]
# conda install aiohttp==3.9.5

# %% [markdown]
# ![aiohttp.png](attachment:e9ddd54c-07d3-4d66-b56a-fe115a2bc4e5.png)

# %% [markdown]
# ## Streaming Market Data (Part 2)

# %% [markdown]
# ### Option 1: ThreadedWebsocketManager (only executable in scripts, not in Jupyter!):

# %%
from binance import ThreadedWebsocketManager
import pandas as pd
import time

# %%
# process data (not just printing)
def stream_data(msg):
    ''' define how to process incoming WebSocket messages '''
    
    time = pd.to_datetime(msg["E"], unit = "ms")
    price = msg["c"]
    
    print("Time: {} | Price: {}".format(time, price))

# %%
twm = ThreadedWebsocketManager()
twm.start()
# Out:
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/jonatas/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/threaded_stream.py", line 59, in run
#     self._loop.run_until_complete(self.socket_listener())
#   File "/usr/lib64/python3.12/asyncio/base_events.py", line 663, in run_until_complete
#     self._check_running()
#   File "/usr/lib64/python3.12/asyncio/base_events.py", line 622, in _check_running
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running

# %%
twm.start_symbol_miniticker_socket(callback = stream_data, symbol = "BTCUSDT")

# %%
while True:
    time.sleep(20)
    twm.stop()
    break

# %% [markdown]
# -----------------------------------------------

# %% [markdown]
# ### Option 2: BinanceSocketManager (executable in Jupyter!):

# %%
stream_data
# Out:
# <function __main__.stream_data(msg)>

# %%
import asyncio
from binance import AsyncClient, BinanceSocketManager
import pandas as pd

# %%
async def main():
    client = await AsyncClient.create()
    bm = BinanceSocketManager(client)
    ts = bm.symbol_miniticker_socket(symbol = "BTCUSDT")
    
    async with ts as tscm:
        for _ in range(10):
            res = await tscm.recv()
            stream_data(res)

    await client.close_connection()
await main()
# Out:
# Time: 2024-10-18 16:18:22.929000 | Price: 68534.88000000
# Time: 2024-10-18 16:18:23.968000 | Price: 68534.88000000
# Time: 2024-10-18 16:18:24.654000 | Price: 68534.87000000
# Time: 2024-10-18 16:18:25.881000 | Price: 68534.88000000
# Time: 2024-10-18 16:18:26.764000 | Price: 68534.88000000
# Time: 2024-10-18 16:18:27.964000 | Price: 68538.15000000
# Time: 2024-10-18 16:18:28.982000 | Price: 68540.00000000
# Time: 2024-10-18 16:18:29.754000 | Price: 68541.76000000
# Time: 2024-10-18 16:18:30.774000 | Price: 68535.00000000
# Time: 2024-10-18 16:18:31.951000 | Price: 68544.60000000

# %% [markdown]
# ## Streaming and Collecting Real-Time Candles

# %% [markdown]
# __Kline/Candlestick Stream:__ push updates to the current klines/candlestick every second.

# %% [markdown]
# https://binance-docs.github.io/apidocs/spot/en/#kline-candlestick-streams

# %% [markdown]
# __Output/Message:__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Option 1: ThreadedWebsocketManager (only executable in scripts, not in Jupyter!):

# %%
from binance import ThreadedWebsocketManager
import pandas as pd
import time

# %%
df = pd.DataFrame(columns = ["Open", "High", "Low", "Close", "Volume", "Complete"])
df
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Complete]
# Index: []

# %%
def stream_candles(msg):
    ''' define how to process incoming WebSocket messages '''
    
    # extract the required items from msg
    event_time = pd.to_datetime(msg["E"], unit = "ms")
    start_time = pd.to_datetime(msg["k"]["t"], unit = "ms")
    first   = float(msg["k"]["o"])
    high    = float(msg["k"]["h"])
    low     = float(msg["k"]["l"])
    close   = float(msg["k"]["c"])
    volume  = float(msg["k"]["v"])
    complete=       msg["k"]["x"]
    
    # print out
    print("Time: {} | Price: {}".format(event_time, close))
    
    # feed df (add new bar / update latest bar)
    df.loc[start_time] = [first, high, low, close, volume, complete]

# %%
twm = ThreadedWebsocketManager()
twm.start()
# Out:
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/jonatas/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/threaded_stream.py", line 59, in run
#     self._loop.run_until_complete(self.socket_listener())
#   File "/usr/lib64/python3.12/asyncio/base_events.py", line 663, in run_until_complete
#     self._check_running()
#   File "/usr/lib64/python3.12/asyncio/base_events.py", line 622, in _check_running
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running
# /usr/lib64/python3.12/threading.py:1077: RuntimeWarning: coroutine 'ThreadedApiManager.socket_listener' was never awaited
#   self._invoke_excepthook(self)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

# %%
# twm.start_kline_socket(callback = stream_candles, symbol = "BTCUSDT", interval = "1m")

# %%
while True:
    time.sleep(120) # stop after 2 minutes
    twm.stop()
    break

# %%
print(df)

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# ### Option 2: BinanceSocketManager (executable in Jupyter!):

# %%
import asyncio
from binance import AsyncClient, BinanceSocketManager
import pandas as pd

# %%
df = pd.DataFrame(columns = ["Open", "High", "Low", "Close", "Volume", "Complete"])
df
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Complete]
# Index: []

# %%
stream_candles
# Out:
# <function __main__.stream_candles(msg)>

# %%
async def main():
    client = await AsyncClient.create()
    bm = BinanceSocketManager(client)
    ts = bm.kline_socket(symbol = "BTCUSDT", interval = "1m")
    
    async with ts as tscm:
        for _ in range(150):  # This is just an example to limit the number of messages. Remove or adjust as needed.
            res = await tscm.recv()
            stream_candles(res)

    await client.close_connection()
await main()
# Out:
# Time: 2024-10-18 16:24:17.361000 | Price: 68663.98
# Time: 2024-10-18 16:24:20.969000 | Price: 68663.99
# Time: 2024-10-18 16:24:23.066000 | Price: 68663.99
# Time: 2024-10-18 16:24:25.199000 | Price: 68663.98
# Time: 2024-10-18 16:24:27.227000 | Price: 68663.99
# Time: 2024-10-18 16:24:29.337000 | Price: 68663.98
# Time: 2024-10-18 16:24:31.451000 | Price: 68663.99
# Time: 2024-10-18 16:24:33.473000 | Price: 68663.98
# Time: 2024-10-18 16:24:35.653000 | Price: 68663.98
# Time: 2024-10-18 16:24:38.200000 | Price: 68669.5
# Time: 2024-10-18 16:24:40.452000 | Price: 68670.0
# Time: 2024-10-18 16:24:42.867000 | Price: 68670.0
# Time: 2024-10-18 16:24:44.967000 | Price: 68670.0
# Time: 2024-10-18 16:24:46.969000 | Price: 68670.0
# Time: 2024-10-18 16:24:48.969000 | Price: 68670.0
# Time: 2024-10-18 16:24:51.201000 | Price: 68670.0
# Time: 2024-10-18 16:24:53.748000 | Price: 68669.99
# Time: 2024-10-18 16:24:56.201000 | Price: 68669.99
# Time: 2024-10-18 16:24:58.695000 | Price: 68669.99
# Time: 2024-10-18 16:25:00.008000 | Price: 68669.5
# Time: 2024-10-18 16:25:02.142000 | Price: 68669.49
# Time: 2024-10-18 16:25:04.396000 | Price: 68669.5
# Time: 2024-10-18 16:25:06.411000 | Price: 68669.49
# Time: 2024-10-18 16:25:08.426000 | Price: 68679.89
# Time: 2024-10-18 16:25:10.446000 | Price: 68684.0
# Time: 2024-10-18 16:25:12.500000 | Price: 68687.99
# Time: 2024-10-18 16:25:14.674000 | Price: 68673.36
# Time: 2024-10-18 16:25:16.791000 | Price: 68673.36
# Time: 2024-10-18 16:25:19.119000 | Price: 68673.36
# Time: 2024-10-18 16:25:21.865000 | Price: 68673.37
# Time: 2024-10-18 16:25:23.916000 | Price: 68680.96
# Time: 2024-10-18 16:25:25.928000 | Price: 68668.0
# Time: 2024-10-18 16:25:27.931000 | Price: 68660.0
# Time: 2024-10-18 16:25:30.194000 | Price: 68660.0
# Time: 2024-10-18 16:25:32.286000 | Price: 68654.39
# Time: 2024-10-18 16:25:34.306000 | Price: 68643.99
# Time: 2024-10-18 16:25:36.322000 | Price: 68650.0
# Time: 2024-10-18 16:25:38.579000 | Price: 68649.99
# Time: 2024-10-18 16:25:40.862000 | Price: 68650.0
# Time: 2024-10-18 16:25:43.204000 | Price: 68650.0
# Time: 2024-10-18 16:25:45.359000 | Price: 68650.0
# Time: 2024-10-18 16:25:47.397000 | Price: 68655.45
# Time: 2024-10-18 16:25:49.535000 | Price: 68645.48
# Time: 2024-10-18 16:25:51.645000 | Price: 68644.78
# Time: 2024-10-18 16:25:54.160000 | Price: 68644.78
# Time: 2024-10-18 16:25:56.204000 | Price: 68634.01
# Time: 2024-10-18 16:25:58.420000 | Price: 68634.0
# Time: 2024-10-18 16:26:00.007000 | Price: 68634.0
# Time: 2024-10-18 16:26:02.016000 | Price: 68626.72
# Time: 2024-10-18 16:26:04.058000 | Price: 68634.83
# Time: 2024-10-18 16:26:06.361000 | Price: 68634.83
# Time: 2024-10-18 16:26:08.367000 | Price: 68641.78
# Time: 2024-10-18 16:26:11.207000 | Price: 68649.99
# Time: 2024-10-18 16:26:13.916000 | Price: 68650.0
# Time: 2024-10-18 16:26:16.189000 | Price: 68655.81
# Time: 2024-10-18 16:26:18.579000 | Price: 68655.81
# Time: 2024-10-18 16:26:20.719000 | Price: 68655.62
# Time: 2024-10-18 16:26:22.838000 | Price: 68655.61
# Time: 2024-10-18 16:26:25.086000 | Price: 68655.61
# Time: 2024-10-18 16:26:27.207000 | Price: 68655.61
# Time: 2024-10-18 16:26:29.255000 | Price: 68655.61
# Time: 2024-10-18 16:26:31.517000 | Price: 68655.62
# Time: 2024-10-18 16:26:33.555000 | Price: 68655.62
# Time: 2024-10-18 16:26:35.635000 | Price: 68653.75
# Time: 2024-10-18 16:26:37.646000 | Price: 68653.75
# Time: 2024-10-18 16:26:39.647000 | Price: 68653.75
# Time: 2024-10-18 16:26:41.918000 | Price: 68653.76
# Time: 2024-10-18 16:26:43.977000 | Price: 68653.76
# Time: 2024-10-18 16:26:46.901000 | Price: 68653.76
# Time: 2024-10-18 16:26:49.166000 | Price: 68653.75
# Time: 2024-10-18 16:26:51.218000 | Price: 68687.98
# Time: 2024-10-18 16:26:53.225000 | Price: 68691.15
# Time: 2024-10-18 16:26:56.013000 | Price: 68696.96
# Time: 2024-10-18 16:26:58.053000 | Price: 68696.97
# Time: 2024-10-18 16:27:00.008000 | Price: 68692.01
# Time: 2024-10-18 16:27:02.179000 | Price: 68692.01
# Time: 2024-10-18 16:27:04.210000 | Price: 68695.99
# Time: 2024-10-18 16:27:06.322000 | Price: 68695.98
# Time: 2024-10-18 16:27:08.477000 | Price: 68695.99
# Time: 2024-10-18 16:27:10.717000 | Price: 68695.99
# Time: 2024-10-18 16:27:12.967000 | Price: 68695.98
# Time: 2024-10-18 16:27:15.210000 | Price: 68695.99
# Time: 2024-10-18 16:27:17.284000 | Price: 68695.99
# Time: 2024-10-18 16:27:19.375000 | Price: 68695.98
# Time: 2024-10-18 16:27:21.439000 | Price: 68695.98
# Time: 2024-10-18 16:27:23.757000 | Price: 68695.99
# Time: 2024-10-18 16:27:25.769000 | Price: 68695.99
# Time: 2024-10-18 16:27:27.863000 | Price: 68695.98
# Time: 2024-10-18 16:27:30.073000 | Price: 68696.96
# Time: 2024-10-18 16:27:32.274000 | Price: 68696.97
# Time: 2024-10-18 16:27:34.714000 | Price: 68696.97
# Time: 2024-10-18 16:27:37.212000 | Price: 68696.97
# Time: 2024-10-18 16:27:39.822000 | Price: 68696.96
# Time: 2024-10-18 16:27:42.067000 | Price: 68696.96
# Time: 2024-10-18 16:27:44.067000 | Price: 68689.94
# Time: 2024-10-18 16:27:46.271000 | Price: 68688.67
# Time: 2024-10-18 16:27:48.811000 | Price: 68671.74
# Time: 2024-10-18 16:27:51.059000 | Price: 68664.19
# Time: 2024-10-18 16:27:54.213000 | Price: 68660.0
# Time: 2024-10-18 16:27:57.213000 | Price: 68667.14
# Time: 2024-10-18 16:27:59.801000 | Price: 68667.15
# Time: 2024-10-18 16:28:00.006000 | Price: 68667.15
# Time: 2024-10-18 16:28:02.216000 | Price: 68669.99
# Time: 2024-10-18 16:28:04.360000 | Price: 68669.99
# Time: 2024-10-18 16:28:06.394000 | Price: 68660.01
# Time: 2024-10-18 16:28:08.701000 | Price: 68660.02
# Time: 2024-10-18 16:28:10.868000 | Price: 68663.99
# Time: 2024-10-18 16:28:13.130000 | Price: 68663.98
# Time: 2024-10-18 16:28:15.347000 | Price: 68663.98
# Time: 2024-10-18 16:28:17.752000 | Price: 68663.99
# Time: 2024-10-18 16:28:19.935000 | Price: 68663.98
# Time: 2024-10-18 16:28:22.214000 | Price: 68663.99
# Time: 2024-10-18 16:28:24.216000 | Price: 68658.01
# Time: 2024-10-18 16:28:26.220000 | Price: 68644.41
# Time: 2024-10-18 16:28:28.424000 | Price: 68630.0
# Time: 2024-10-18 16:28:30.425000 | Price: 68636.51
# Time: 2024-10-18 16:28:32.822000 | Price: 68647.99
# Time: 2024-10-18 16:28:35.188000 | Price: 68658.0
# Time: 2024-10-18 16:28:37.225000 | Price: 68659.98
# Time: 2024-10-18 16:28:39.563000 | Price: 68659.99
# Time: 2024-10-18 16:28:41.564000 | Price: 68659.99
# Time: 2024-10-18 16:28:44.216000 | Price: 68659.98
# Time: 2024-10-18 16:28:46.251000 | Price: 68659.99
# Time: 2024-10-18 16:28:48.267000 | Price: 68659.98
# Time: 2024-10-18 16:28:50.603000 | Price: 68659.99
# Time: 2024-10-18 16:28:52.633000 | Price: 68659.98
# Time: 2024-10-18 16:28:54.652000 | Price: 68659.99
# Time: 2024-10-18 16:28:57.217000 | Price: 68659.99
# Time: 2024-10-18 16:28:59.718000 | Price: 68659.98
# Time: 2024-10-18 16:29:00.006000 | Price: 68659.98
# Time: 2024-10-18 16:29:02.192000 | Price: 68659.99
# Time: 2024-10-18 16:29:04.217000 | Price: 68659.98
# Time: 2024-10-18 16:29:06.498000 | Price: 68659.98
# Time: 2024-10-18 16:29:08.579000 | Price: 68659.99
# Time: 2024-10-18 16:29:10.634000 | Price: 68656.84
# Time: 2024-10-18 16:29:12.700000 | Price: 68650.01
# Time: 2024-10-18 16:29:15.167000 | Price: 68656.81
# Time: 2024-10-18 16:29:17.218000 | Price: 68659.45
# Time: 2024-10-18 16:29:19.248000 | Price: 68653.41
# Time: 2024-10-18 16:29:21.610000 | Price: 68653.4
# Time: 2024-10-18 16:29:24.056000 | Price: 68653.41
# Time: 2024-10-18 16:29:26.122000 | Price: 68653.41
# Time: 2024-10-18 16:29:28.209000 | Price: 68653.41
# Time: 2024-10-18 16:29:30.218000 | Price: 68653.4
# Time: 2024-10-18 16:29:32.225000 | Price: 68653.4
# Time: 2024-10-18 16:29:34.319000 | Price: 68653.41
# Time: 2024-10-18 16:29:36.340000 | Price: 68653.41
# Time: 2024-10-18 16:29:38.459000 | Price: 68653.4
# Time: 2024-10-18 16:29:40.551000 | Price: 68646.97
# Time: 2024-10-18 16:29:42.718000 | Price: 68646.28

# %%
df
# Out:
#                          Open      High       Low     Close    Volume  \
# 2024-10-18 16:19:00  68582.02  68630.64  68582.02  68628.26  24.98507
# 2024-10-18 16:20:00  68628.26  68735.32  68628.26  68712.64  42.57523
# 2024-10-18 16:24:00  68649.99  68670.00  68649.99  68669.50  11.99485
# 2024-10-18 16:25:00  68669.50  68688.00  68634.00  68634.00  24.26436
# 2024-10-18 16:26:00  68634.01  68696.97  68626.71  68692.01  23.87734
# 2024-10-18 16:27:00  68692.01  68696.97  68660.00  68667.15  13.49507
# 2024-10-18 16:28:00  68667.14  68670.00  68630.00  68659.98  14.69892
# 2024-10-18 16:29:00  68659.98  68659.99  68646.27  68646.28   6.78566
#
#                      Complete
# 2024-10-18 16:19:00      True
# 2024-10-18 16:20:00     False
# 2024-10-18 16:24:00      True
# 2024-10-18 16:25:00      True
# 2024-10-18 16:26:00      True
# 2024-10-18 16:27:00      True
# 2024-10-18 16:28:00      True
# 2024-10-18 16:29:00     False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2 entries, 2024-10-18 16:19:00 to 2024-10-18 16:20:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Open      2 non-null      float64
#  1   High      2 non-null      float64
#  2   Low       2 non-null      float64
#  3   Close     2 non-null      float64
#  4   Volume    2 non-null      float64
#  5   Complete  2 non-null      bool
# dtypes: bool(1), float64(5)
# memory usage: 206.0 bytes

# %% [markdown]
# ## Creating a Test Order

# %%
from binance.client import Client

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %% [markdown]
# __Note: The next code may return an BinanceAPIException Error. No problem as we do Paper Trading in the Spot Testnet anyway.__

# %%
# place a test market buy order, to place an actual order use the create_order function
order = client.create_test_order(symbol = "BTCEUR", side = "BUY", type = "MARKET", quantity = 0.1)

# %%
order
# Out:
# {}

# %% [markdown]
# -> Paper Trading in the __Spot Testnet__ (see next Lectures)!!!
