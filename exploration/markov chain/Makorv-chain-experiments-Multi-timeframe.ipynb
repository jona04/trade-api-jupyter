# %%
import os
from dotenv import load_dotenv 
load_dotenv("../../constants/.env")

api_key = os.environ.get('BINANCE_KEY')
secret_key = os.environ.get('BINANCE_SECRET')

# %%
import pandas as pd

# %%
pair='BTCUSDT'
granularity = '1h'

# %%
df = pd.read_pickle(f"crypto/{pair}_{granularity}.pkl")

# %%
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#                  Time     Open     High      Low    Close      Volume
# 0 2020-01-01 00:00:00  7195.24  7196.25  7175.46  7177.02  511.814901
# 1 2020-01-01 01:00:00  7176.47  7230.00  7175.71  7216.27  883.052603
# 2 2020-01-01 02:00:00  7215.52  7244.87  7211.41  7242.85  655.156809
# 3 2020-01-01 03:00:00  7242.66  7245.00  7220.00  7225.01  783.724867
# 4 2020-01-01 04:00:00  7225.00  7230.00  7215.03  7217.27  467.812578

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

def analisar_distribuicao(df, coluna='Close', k=1, remover_outliers=True):
    """
    Analisa a distribuição normal das variações percentuais de preços e remove outliers, se necessário.
    
    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os preços.
        coluna (str): Nome da coluna com os preços de fechamento.
        k (float): Fator multiplicador para definir os limites (kσ).
                   - Exemplo de valores e implicações:
                     - k=1: Captura aproximadamente 68% dos dados (limite ±1σ).
                     - k=2: Captura aproximadamente 95% dos dados (limite ±2σ).
                     - k=3: Captura aproximadamente 99.7% dos dados (limite ±3σ).
        remover_outliers (bool): Se True, remove valores fora dos limites definidos por kσ.
        
    Retorna:
        dict: Contendo média, desvio padrão e limites baseados na distribuição.
    """
    # Calcular variação percentual
    df['var_percentual'] = df[coluna].pct_change() * 100
    variacoes = df['var_percentual'].dropna()
    
    # Calcular média e desvio padrão
    media = variacoes.mean()
    desvio_padrao = variacoes.std()
    
    # Definir limites baseado no multiplicador k
    limite_alta = media + k * desvio_padrao
    limite_baixa = media - k * desvio_padrao
    
    # Remover outliers, se ativado
    if remover_outliers:
        variacoes = variacoes[(variacoes >= 5*limite_baixa) & (variacoes <= 5*limite_alta)]
    
    # Gerar dados para a curva normal
    x = np.linspace(variacoes.min(), variacoes.max(), 1000)
    curva = norm.pdf(x, media, desvio_padrao)
    
    # Plotar histograma e curva
    plt.figure(figsize=(10, 6))
    plt.hist(variacoes, bins=30, density=True, alpha=0.6, color='skyblue', label='Histograma')
    plt.plot(x, curva, color='red', label='Distribuição Normal')
    plt.axvline(media, color='black', linestyle='--', label='Média (μ)')
    plt.axvline(limite_alta, color='green', linestyle='--', label=f'+{k}σ ({limite_alta:.2f})')
    plt.axvline(limite_baixa, color='green', linestyle='--', label=f'-{k}σ ({limite_baixa:.2f})')
    plt.title('Distribuição Normal das Variações Percentuais')
    plt.xlabel('Variação Percentual (%)')
    plt.ylabel('Densidade')
    plt.legend()
    plt.show()
    
    # Retornar estatísticas
    return {
        'media': media,
        'desvio_padrao': desvio_padrao,
        'limite_alta': limite_alta,
        'limite_baixa': limite_baixa
    }

# %%
resultados = analisar_distribuicao(df)
print("Resultados da Distribuição:")
print(resultados)
# Out:
# Resultados da Distribuição:
# {'media': np.float64(0.00788415301027244), 'desvio_padrao': np.float64(0.7060002815776664), 'limite_alta': np.float64(0.7138844345879388), 'limite_baixa': np.float64(-0.6981161285673939)}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

def analisar_distribuicao_e_plotar(df, coluna='Close', k=1, remover_outliers=True):
    """
    Analisa a distribuição normal das variações percentuais, inclui porcentagens no gráfico e remove outliers.
    
    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os preços.
        coluna (str): Nome da coluna com os preços de fechamento.
        k (float): Fator multiplicador para definir os limites (kσ).
                   - Exemplo de valores e implicações:
                     - k=1: Captura aproximadamente 68% dos dados (limite ±1σ).
                     - k=2: Captura aproximadamente 95% dos dados (limite ±2σ).
                     - k=3: Captura aproximadamente 99.7% dos dados (limite ±3σ).
        remover_outliers (bool): Se True, remove valores fora dos limites definidos por kσ.
    """
    # Calcular variação percentual
    df['var_percentual'] = df[coluna].pct_change() * 100
    variacoes = df['var_percentual'].dropna()
    
    # Calcular média e desvio padrão
    media = variacoes.mean()
    desvio_padrao = variacoes.std()

    k=0.5
    # Definir limites baseado no multiplicador k
    limite_alta = media + k * desvio_padrao
    limite_baixa = media - k * desvio_padrao
    
    # Remover outliers, se ativado
    if remover_outliers:
        variacoes = variacoes[(variacoes >= 5*limite_baixa) & (variacoes <= 5*limite_alta)]
    
    # Gerar dados para a curva normal
    x = np.linspace(variacoes.min(), variacoes.max(), 1000)
    curva = norm.pdf(x, media, desvio_padrao)
    
    # Plotar histograma e curva
    plt.figure(figsize=(12, 6))
    plt.hist(variacoes, bins=30, density=True, alpha=0.6, color='skyblue', label='Histograma')
    plt.plot(x, curva, color='red', label='Distribuição Normal')
    
    # Adicionar linhas verticais para média e desvios padrão
    plt.axvline(media, color='black', linestyle='--', label='Média (μ)')
    plt.axvline(media + k * desvio_padrao, color='green', linestyle='--', label=f'+{k}σ ({limite_alta:.2f})')
    plt.axvline(media - k * desvio_padrao, color='green', linestyle='--', label=f'-{k}σ ({limite_baixa:.2f})')
    plt.axvline(media + 2 * desvio_padrao, color='orange', linestyle='--', label=f'+2σ ({media + 2 * desvio_padrao:.2f})')
    plt.axvline(media - 2 * desvio_padrao, color='orange', linestyle='--', label=f'-2σ ({media - 2 * desvio_padrao:.2f})')
    plt.axvline(media + 3 * desvio_padrao, color='purple', linestyle='--', label=f'+3σ ({media + 3 * desvio_padrao:.2f})')
    plt.axvline(media - 3 * desvio_padrao, color='purple', linestyle='--', label=f'-3σ ({media - 3 * desvio_padrao:.2f})')
    
    # Adicionar texto explicativo das porcentagens
    plt.text(media, 0.02, f"68%", color='green', fontsize=10, ha='center')
    plt.text(media + 1.5 * desvio_padrao, 0.01, "95%", color='orange', fontsize=10, ha='center')
    plt.text(media + 2.5 * desvio_padrao, 0.005, "99.7%", color='purple', fontsize=10, ha='center')
    
    # Configurar título e legendas
    plt.title(f'Distribuição Normal das Variações Percentuais com k={k}')
    plt.xlabel('Variação Percentual (%)')
    plt.ylabel('Densidade')
    plt.legend()
    plt.show()
    
    # Retornar estatísticas
    return {
        'media': media,
        'desvio_padrao': desvio_padrao,
        'limite_alta': limite_alta,
        'limite_baixa': limite_baixa
    }


# Exemplo de uso
# Suponha que você tenha um DataFrame `df` com uma coluna 'Close'
analisar_distribuicao_e_plotar(df)
# Out:
# {'media': np.float64(0.00788415301027244),
#  'desvio_padrao': np.float64(0.7060002815776664),
#  'limite_alta': np.float64(0.36088429379910564),
#  'limite_baixa': np.float64(-0.34511598777856073)}

# %%
df.head()
# Out:
#                  Time     Open     High      Low    Close      Volume  \
# 0 2020-01-01 00:00:00  7195.24  7196.25  7175.46  7177.02  511.814901
# 1 2020-01-01 01:00:00  7176.47  7230.00  7175.71  7216.27  883.052603
# 2 2020-01-01 02:00:00  7215.52  7244.87  7211.41  7242.85  655.156809
# 3 2020-01-01 03:00:00  7242.66  7245.00  7220.00  7225.01  783.724867
# 4 2020-01-01 04:00:00  7225.00  7230.00  7215.03  7217.27  467.812578
#
#    var_percentual
# 0             NaN
# 1        0.546884
# 2        0.368334
# 3       -0.246312
# 4       -0.107128

# %%
def classificar_variacao_com_distribuicao(var, media, desvio_padrao):
    limite_alta = media + 0.5*desvio_padrao
    limite_baixa = media - 0.5*desvio_padrao
    
    if var > limite_alta:
        return "Alta"
    elif var < limite_baixa:
        return "Baixa"
    elif var < limite_alta and var > 0:
        return "Leve Alta"
    elif var > limite_baixa and var <= 0:
        return "Leve Baixa"

# Aplicar classificação ao DataFrame
media = resultados['media']
desvio_padrao = resultados['desvio_padrao']
df['classificacao'] = df['var_percentual'].apply(
    lambda var: classificar_variacao_com_distribuicao(var, media, desvio_padrao)
)

# %%
df.head()
# Out:
#                  Time     Open     High      Low    Close      Volume  \
# 0 2020-01-01 00:00:00  7195.24  7196.25  7175.46  7177.02  511.814901
# 1 2020-01-01 01:00:00  7176.47  7230.00  7175.71  7216.27  883.052603
# 2 2020-01-01 02:00:00  7215.52  7244.87  7211.41  7242.85  655.156809
# 3 2020-01-01 03:00:00  7242.66  7245.00  7220.00  7225.01  783.724867
# 4 2020-01-01 04:00:00  7225.00  7230.00  7215.03  7217.27  467.812578
#
#    var_percentual classificacao
# 0             NaN          None
# 1        0.546884          Alta
# 2        0.368334          Alta
# 3       -0.246312    Leve Baixa
# 4       -0.107128    Leve Baixa

# %%
df.classificacao.value_counts()
# Out:
# classificacao
# Leve Alta     13384
# Leve Baixa    12854
# Alta           8148
# Baixa          7966
# Name: count, dtype: int64

# %%
def calcular_classificacao_por_janela(df, coluna_close='Close', janela=10, limite=2):
    """
    Calcula a classificação da variação percentual com base nos últimos `janela` candles.

    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os preços.
        coluna_close (str): Nome da coluna com os preços de fechamento.
        janela (int): Número de candles para calcular a variação percentual.
        limite (float): Multiplicador do desvio padrão para definir os limites de classificação.

    Retorna:
        list: Lista com as classificações ('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa') para cada candle.
    """
    classificacoes = []
    variacoes_list = []

    # Criar o novo timeframe (preço de fechamento do último candle em cada janela)
    agrupado = df[coluna_close].groupby(df.index // janela).last()
    
    # Calcular variações percentuais do novo timeframe
    variacoes = agrupado.pct_change() * 100  # Variação percentual entre os novos candles
    media = variacoes.mean()
    desvio_padrao = variacoes.std()
    
    for i in range(len(df)):
        if i < janela:  # Não é possível calcular para os primeiros `janela` candles
            classificacoes.append(None)
            variacoes_list.append(None)
            continue
        
        # Calcular a variação percentual entre o primeiro e o último candle da janela
        preco_inicial = df[coluna_close].iloc[i - janela]
        preco_final = df[coluna_close].iloc[i]
        variacao = (preco_final - preco_inicial) / preco_inicial * 100

        # Classificar com base nos limites
        limite_alta = media + limite * desvio_padrao
        limite_baixa = media - limite * desvio_padrao
        if variacao > limite_alta:
            classificacoes.append('Alta')
            variacoes_list.append(variacao)
        elif variacao < limite_baixa:
            classificacoes.append('Baixa')
            variacoes_list.append(variacao)
        elif variacao > 0:
            classificacoes.append('Leve Alta')
            variacoes_list.append(variacao)
        else:
            classificacoes.append('Leve Baixa')
            variacoes_list.append(variacao)
    
    return classificacoes, variacoes_list

# %%
# Exemplo de uso

df['classificacao_x'], df['variacao_x'] = calcular_classificacao_por_janela(df, coluna_close='Close', janela=24, limite=0.5)
df['classificacao_n'], df['variacao_n'] = calcular_classificacao_por_janela(df, coluna_close='Close', janela=15, limite=0.5)
df['classificacao_p'], df['variacao_p'] = calcular_classificacao_por_janela(df, coluna_close='Close', janela=9, limite=0.5)
df['classificacao_z'], df['variacao_z'] = calcular_classificacao_por_janela(df, coluna_close='Close', janela=3, limite=0.5)

# %%
df.head(10)
# Out:
#                   Time     Open     High      Low    Close       Volume  \
# 24 2020-01-02 00:00:00  7200.77  7212.50  7185.46  7211.02   391.352377
# 25 2020-01-02 01:00:00  7211.04  7211.16  7185.11  7190.99   402.660139
# 26 2020-01-02 02:00:00  7190.99  7191.00  7155.35  7169.02  1387.377886
# 27 2020-01-02 03:00:00  7169.04  7169.06  7120.37  7129.61  1557.964430
# 28 2020-01-02 04:00:00  7129.25  7161.00  7116.70  7142.21  1252.447877
# 29 2020-01-02 05:00:00  7142.61  7152.05  7126.93  7138.93   569.508990
# 30 2020-01-02 06:00:00  7138.93  7149.02  7121.43  7135.97   687.600665
# 31 2020-01-02 07:00:00  7136.04  7140.63  7105.00  7110.57  1548.403823
# 32 2020-01-02 08:00:00  7110.98  7157.48  7109.11  7154.36  1114.825128
# 33 2020-01-02 09:00:00  7153.57  7165.00  7135.36  7162.01   840.001328
#
#     var_percentual classificacao classificacao_x  variacao_x classificacao_n  \
# 24        0.141233     Leve Alta            None         NaN            None
# 25       -0.277769    Leve Baixa            None         NaN            None
# 26       -0.305521    Leve Baixa            None         NaN            None
# 27       -0.549726         Baixa            None         NaN            None
# 28        0.176728     Leve Alta            None         NaN            None
# 29       -0.045924    Leve Baixa            None         NaN            None
# 30       -0.041463    Leve Baixa            None         NaN            None
# 31       -0.355943         Baixa            None         NaN            None
# 32        0.615844          Alta            None         NaN            None
# 33        0.106928     Leve Alta            None         NaN            None
#
#     variacao_n classificacao_p  variacao_p classificacao_z  variacao_z  \
# 24         NaN            None         NaN            None         NaN
# 25         NaN            None         NaN            None         NaN
# 26         NaN            None         NaN            None         NaN
# 27         NaN            None         NaN           Baixa   -1.128966
# 28         NaN            None         NaN           Baixa   -0.678349
# 29         NaN            None         NaN      Leve Baixa   -0.419723
# 30         NaN            None         NaN       Leve Alta    0.089205
# 31         NaN            None         NaN      Leve Baixa   -0.443000
# 32         NaN            None         NaN       Leve Alta    0.216139
# 33         NaN      Leve Baixa   -0.679654       Leve Alta    0.364912
#
#       alvos
# 24       EB
# 25       EB
# 26  Estavel
# 27  Estavel
# 28  Estavel
# 29  Estavel
# 30  Estavel
# 31  Estavel
# 32  Estavel
# 33  Estavel

# %%
def calcular_alvo_candle(df, coluna_close='Close', coluna_high='High', coluna_low='Low', n=5, limite=2):
    """
    Calcula os alvos para cada candle baseado em uma janela de n candles, considerando High, Low e Close.

    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os preços.
        coluna_close (str): Nome da coluna com os preços de fechamento.
        coluna_high (str): Nome da coluna com os preços máximos.
        coluna_low (str): Nome da coluna com os preços mínimos.
        n (int): Janela de candles para análise do alvo.
        limite (float): Percentual limite para classificar os alvos (ex.: 2%).

    Retorna:
        list: Lista com os alvos (`PS`, `NS`, `EA`, `EB`) para cada candle.
    """
    alvos = []
    variacoes = df[coluna_close].pct_change() * 100  # Variação percentual entre candles
    
    for i in range(len(df)):
        if i + n >= len(df):  # Não é possível calcular para as últimas janelas incompletas
            alvos.append(None)
            continue

        # Valor de fechamento atual como referência
        close_atual = df[coluna_close].iloc[i]

        janela = variacoes[i + 1:i + n + 1]  # Próximos n candles
        
        # Calcular variações percentuais máximas e mínimas usando High e Low em relação ao Close atual
        janela_high = df[coluna_high].iloc[i + 1:i + n + 1]
        janela_low = df[coluna_low].iloc[i + 1:i + n + 1]

        max_alta = (janela_high.max() - close_atual) / close_atual * 100
        max_baixa = (janela_low.min() - close_atual) / close_atual * 100

        # Classificar os alvos com base nos limites
        # if max_alta >= limite:  # Subiu 2% ou mais
        #     alvos.append('EA')
        # elif max_baixa <= -limite:  # Caiu 2% ou mais
        #     alvos.append('EB')
        # els:  # Percentual positivo sem ultrapassar limite
        #     alvos.append('Estavel')
        elif janela.sum() < 0:
            alvos.append('NS')
        else:  # Percentual negativo sem ultrapassar limite
            alvos.append('PS')
        
    return alvos

# %%
df['alvos'] = calcular_alvo_candle(df, coluna_close='Close', coluna_high='High', coluna_low='Low', n=3, limite=1)

# %%
df.alvos.value_counts()
# Out:
# alvos
# PS    11764
# NS    10834
# EA    10635
# EB     9054
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)
df.head(10)
# Out:
#                   Time     Open     High      Low    Close       Volume  \
# 48 2020-01-03 00:00:00  6965.49  6966.47  6912.88  6937.00  1106.732043
# 49 2020-01-03 01:00:00  6937.00  6946.07  6878.19  6888.85  2402.581684
# 50 2020-01-03 02:00:00  6888.26  6966.80  6871.04  6956.88  2869.993553
# 51 2020-01-03 03:00:00  6957.66  6966.36  6940.00  6952.04  1246.589508
# 52 2020-01-03 04:00:00  6952.04  7264.71  6948.64  7210.19  9560.897697
# 53 2020-01-03 05:00:00  7210.20  7249.00  7168.48  7220.47  3575.770965
# 54 2020-01-03 06:00:00  7220.49  7225.00  7190.14  7202.22  2075.259160
# 55 2020-01-03 07:00:00  7202.06  7232.00  7185.04  7203.21  2185.376884
# 56 2020-01-03 08:00:00  7202.28  7297.29  7202.28  7260.60  3976.534509
# 57 2020-01-03 09:00:00  7260.64  7358.88  7256.56  7348.42  5469.030632
#
#     var_percentual classificacao classificacao_x  variacao_x classificacao_n  \
# 48       -0.412162         Baixa           Baixa   -3.800017           Baixa
# 49       -0.694104         Baixa           Baixa   -4.201647           Baixa
# 50        0.987538          Alta           Baixa   -2.959121           Baixa
# 51       -0.069571    Leve Baixa           Baixa   -2.490599           Baixa
# 52        3.713299          Alta       Leve Alta    0.951806       Leve Alta
# 53        0.142576     Leve Alta       Leve Alta    1.142188       Leve Alta
# 54       -0.252754    Leve Baixa       Leve Alta    0.928395       Leve Alta
# 55        0.013746     Leve Alta       Leve Alta    1.302849            Alta
# 56        0.796728          Alta       Leve Alta    1.484969            Alta
# 57        1.209542          Alta            Alta    2.602761            Alta
#
#     variacao_n classificacao_p  variacao_p classificacao_z  variacao_z alvos
# 48   -3.141716           Baixa   -2.720243           Baixa   -0.583714    PS
# 49   -3.811596           Baixa   -2.317961           Baixa   -1.232293    EA
# 50   -2.561840      Leve Baixa   -0.188808      Leve Baixa   -0.126764    EA
# 51   -2.881275      Leve Baixa   -0.315170       Leve Alta    0.216808    EA
# 52    1.108377            Alta    3.249481            Alta    4.664639    NS
# 53    1.189530            Alta    3.914232            Alta    3.788911    EA
# 54    0.999021            Alta    3.217235            Alta    3.598656    EA
# 55    2.139580            Alta    3.274789      Leve Baixa   -0.096807    EA
# 56    4.168699            Alta    4.233452       Leve Alta    0.555781    EA
# 57    5.368496            Alta    5.930806            Alta    2.029930    NS

# %%
def criar_tuplas(df, coluna='classificacao', coluna_alvo='alvos'):
    """
    Cria tuplas de 3 estados consecutivos e adiciona os 2 próximos estados como alvo.

    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os dados classificados.
        coluna (str): Nome da coluna com as classificações (Alta, Baixa).

    Retorna:
        list: Lista de tuplas no formato [(estado_atual, alvo), ...].
    """
    
    alvos = df[coluna_alvo].values
    estados = df[coluna].values
    estados_x = df['classificacao_x'].values
    estados_n = df['classificacao_n'].values
    estados_p = df['classificacao_p'].values
    estados_z = df['classificacao_z'].values
    
    tuplas = []

    for i in range(len(estados)):  # Garantir que há espaço para o estado atual e os 2 próximos
        estado_atual = (estados_x[i],estados_n[i],estados_p[i], estados_z[i])
        alvo = alvos[i]  # Próximos 2 estados
        tuplas.append((estado_atual, alvo))

    return tuplas

# %%
from sklearn.model_selection import train_test_split

# Divisão do DataFrame
df_treino, df_teste = train_test_split(df, test_size=0.2, shuffle=False)

# Criar tuplas de 3 estados para treinamento e teste
tuplas_treino = criar_tuplas(df_treino)
tuplas_teste = criar_tuplas(df_teste)

# %%
df_treino['tuplas'] = [None] * len(df_treino)  # Inicializar a coluna com None
tt = tuplas_treino
df_treino['tuplas'] = tt  # Preencher as tuplas a partir da 3ª linha (índice 2)

df_treino.shape
# Out:
# (33829, 18)

# %%
df_treino.dropna(inplace=True)

# %%
df_treino.head(50)[['Close','var_percentual','classificacao','classificacao_n','variacao_n','classificacao_x','variacao_x','alvos','tuplas']]
# Out:
#       Close  var_percentual classificacao classificacao_n  variacao_n  \
# 48  6937.00       -0.412162         Baixa           Baixa   -3.141716
# 49  6888.85       -0.694104         Baixa           Baixa   -3.811596
# 50  6956.88        0.987538          Alta           Baixa   -2.561840
# 51  6952.04       -0.069571    Leve Baixa           Baixa   -2.881275
# 52  7210.19        3.713299          Alta       Leve Alta    1.108377
# 53  7220.47        0.142576     Leve Alta       Leve Alta    1.189530
# 54  7202.22       -0.252754    Leve Baixa       Leve Alta    0.999021
# 55  7203.21        0.013746     Leve Alta            Alta    2.139580
# 56  7260.60        0.796728          Alta            Alta    4.168699
# 57  7348.42        1.209542          Alta            Alta    5.368496
# 58  7312.25       -0.492215         Baixa            Alta    4.710974
# 59  7340.46        0.385791          Alta            Alta    5.641082
# 60  7322.78       -0.240857    Leve Baixa            Alta    4.945018
# 61  7348.87        0.356285     Leve Alta            Alta    5.363165
# 62  7254.73       -1.281013         Baixa            Alta    4.149182
# 63  7320.18        0.902170          Alta            Alta    5.523713
# 64  7386.03        0.899568          Alta            Alta    7.217170
# 65  7355.26       -0.416597         Baixa            Alta    5.726418
# 66  7342.96       -0.167227    Leve Baixa            Alta    5.623098
# 67  7343.08        0.001634     Leve Alta            Alta    1.843086
# 68  7316.99       -0.355301         Baixa       Leve Alta    1.336755
# 69  7283.00       -0.464535         Baixa       Leve Alta    1.121599
# 70  7300.56        0.241109     Leve Alta       Leve Alta    1.351481
# 71  7344.96        0.608173          Alta       Leve Alta    1.161887
# 72  7302.24       -0.581623         Baixa      Leve Baixa   -0.628434
# 73  7309.16        0.094765     Leve Alta      Leve Baixa   -0.042258
# 74  7327.83        0.255433     Leve Alta      Leve Baixa   -0.172060
# 75  7333.11        0.072054     Leve Alta       Leve Alta    0.141067
# 76  7334.86        0.023864     Leve Alta      Leve Baixa   -0.190642
# 77  7344.69        0.134018     Leve Alta       Leve Alta    1.240019
# 78  7354.96        0.139829     Leve Alta       Leve Alta    0.475125
# 79  7348.11       -0.093134    Leve Baixa      Leve Baixa   -0.513402
# 80  7346.59       -0.020686    Leve Baixa      Leve Baixa   -0.117875
# 81  7363.88        0.235347     Leve Alta       Leve Alta    0.284899
# 82  7318.30       -0.618967         Baixa      Leve Baixa   -0.337461
# 83  7336.45        0.248008     Leve Alta       Leve Alta    0.265956
# 84  7312.89       -0.321136    Leve Baixa       Leve Alta    0.410408
# 85  7303.88       -0.123207    Leve Baixa       Leve Alta    0.045476
# 86  7316.72        0.175797     Leve Alta      Leve Baixa   -0.384481
# 87  7318.99        0.031025     Leve Alta       Leve Alta    0.229382
# 88  7307.11       -0.162317    Leve Baixa      Leve Baixa   -0.028047
# 89  7351.99        0.614196          Alta       Leve Alta    0.329702
# 90  7306.92       -0.613031         Baixa      Leve Baixa   -0.357147
# 91  7334.83        0.381967          Alta      Leve Baixa   -0.000409
# 92  7341.06        0.084937     Leve Alta      Leve Baixa   -0.049423
# 93  7350.68        0.131044     Leve Alta      Leve Baixa   -0.058192
# 94  7350.24       -0.005986    Leve Baixa       Leve Alta    0.028987
# 95  7354.11        0.052651     Leve Alta       Leve Alta    0.102360
# 96  7373.48        0.263390     Leve Alta       Leve Alta    0.130366
# 97  7459.18        1.162273          Alta            Alta    1.925037
#
#    classificacao_x  variacao_x alvos  \
# 48           Baixa   -3.800017    PS
# 49           Baixa   -4.201647    EA
# 50           Baixa   -2.959121    EA
# 51           Baixa   -2.490599    EA
# 52       Leve Alta    0.951806    NS
# 53       Leve Alta    1.142188    EA
# 54       Leve Alta    0.928395    EA
# 55       Leve Alta    1.302849    EA
# 56       Leve Alta    1.484969    EA
# 57            Alta    2.602761    NS
# 58            Alta    2.100301    PS
# 59            Alta    2.810587    EB
# 60            Alta    2.297895    EB
# 61            Alta    3.053084    EB
# 62       Leve Alta    1.669659    EA
# 63            Alta    2.653212    EA
# 64            Alta    4.731918    EB
# 65            Alta    5.526798    EB
# 66            Alta    5.290206    EB
# 67            Alta    5.152457    EB
# 68            Alta    5.303311    PS
# 69            Alta    4.374918    PS
# 70            Alta    4.670528    PS
# 71            Alta    5.444528    NS
# 72            Alta    5.265100    PS
# 73            Alta    6.101309    PS
# 74            Alta    5.332132    PS
# 75            Alta    5.481413    PS
# 76       Leve Alta    1.729081    PS
# 77       Leve Alta    1.720387    PS
# 78            Alta    2.120735    PS
# 79            Alta    2.011603    NS
# 80       Leve Alta    1.184337    NS
# 81       Leve Alta    0.210385    NS
# 82       Leve Alta    0.082738    NS
# 83      Leve Baixa   -0.054629    NS
# 84      Leve Baixa   -0.135058    PS
# 85      Leve Baixa   -0.612203    PS
# 86       Leve Alta    0.854477    PS
# 87      Leve Baixa   -0.016256    EA
# 88      Leve Baixa   -1.068504    EA
# 89      Leve Baixa   -0.044458    EB
# 90      Leve Baixa   -0.490810    PS
# 91      Leve Baixa   -0.112351    PS
# 92       Leve Alta    0.328960    PS
# 93       Leve Alta    0.929287    PS
# 94       Leve Alta    0.680496    EA
# 95       Leve Alta    0.124575    EA
# 96       Leve Alta    0.975591    EA
# 97            Alta    2.052493    NS
#
#                                                tuplas
# 48                 ((Baixa, Baixa, Baixa, Baixa), PS)
# 49                 ((Baixa, Baixa, Baixa, Baixa), EA)
# 50       ((Baixa, Baixa, Leve Baixa, Leve Baixa), EA)
# 51        ((Baixa, Baixa, Leve Baixa, Leve Alta), EA)
# 52           ((Leve Alta, Leve Alta, Alta, Alta), NS)
# 53           ((Leve Alta, Leve Alta, Alta, Alta), EA)
# 54           ((Leve Alta, Leve Alta, Alta, Alta), EA)
# 55          ((Leve Alta, Alta, Alta, Leve Baixa), EA)
# 56           ((Leve Alta, Alta, Alta, Leve Alta), EA)
# 57                     ((Alta, Alta, Alta, Alta), NS)
# 58                     ((Alta, Alta, Alta, Alta), PS)
# 59                     ((Alta, Alta, Alta, Alta), EB)
# 60               ((Alta, Alta, Alta, Leve Baixa), EB)
# 61                ((Alta, Alta, Alta, Leve Alta), EB)
# 62          ((Leve Alta, Alta, Leve Alta, Baixa), EA)
# 63               ((Alta, Alta, Alta, Leve Baixa), EA)
# 64                ((Alta, Alta, Alta, Leve Alta), EB)
# 65                     ((Alta, Alta, Alta, Alta), EB)
# 66          ((Alta, Alta, Leve Baixa, Leve Alta), EB)
# 67               ((Alta, Alta, Leve Alta, Baixa), EB)
# 68    ((Alta, Leve Alta, Leve Baixa, Leve Baixa), PS)
# 69         ((Alta, Leve Alta, Leve Baixa, Baixa), PS)
# 70         ((Alta, Leve Alta, Leve Baixa, Baixa), PS)
# 71           ((Alta, Leve Alta, Alta, Leve Alta), NS)
# 72    ((Alta, Leve Baixa, Leve Baixa, Leve Alta), PS)
# 73         ((Alta, Leve Baixa, Baixa, Leve Alta), PS)
# 74   ((Alta, Leve Baixa, Leve Baixa, Leve Baixa), PS)
# 75     ((Alta, Leve Alta, Leve Baixa, Leve Alta), PS)
# 76  ((Leve Alta, Leve Baixa, Leve Baixa, Leve Alta...
# 77  ((Leve Alta, Leve Alta, Leve Alta, Leve Alta),...
# 78      ((Alta, Leve Alta, Leve Alta, Leve Alta), PS)
# 79     ((Alta, Leve Baixa, Leve Alta, Leve Alta), NS)
# 80  ((Leve Alta, Leve Baixa, Leve Alta, Leve Alta)...
# 81  ((Leve Alta, Leve Alta, Leve Alta, Leve Alta),...
# 82  ((Leve Alta, Leve Baixa, Leve Alta, Leve Baixa...
# 83  ((Leve Baixa, Leve Alta, Leve Alta, Leve Baixa...
# 84   ((Leve Baixa, Leve Alta, Leve Baixa, Baixa), PS)
# 85  ((Leve Baixa, Leve Alta, Leve Baixa, Leve Baix...
# 86  ((Leve Alta, Leve Baixa, Leve Baixa, Leve Baix...
# 87  ((Leve Baixa, Leve Alta, Leve Baixa, Leve Alta...
# 88  ((Leve Baixa, Leve Baixa, Leve Baixa, Leve Alt...
# 89  ((Leve Baixa, Leve Alta, Leve Alta, Leve Alta)...
# 90  ((Leve Baixa, Leve Baixa, Leve Baixa, Leve Bai...
# 91  ((Leve Baixa, Leve Baixa, Leve Alta, Leve Alta...
# 92  ((Leve Alta, Leve Baixa, Leve Alta, Leve Baixa...
# 93  ((Leve Alta, Leve Baixa, Leve Alta, Leve Alta)...
# 94  ((Leve Alta, Leve Alta, Leve Alta, Leve Alta),...
# 95  ((Leve Alta, Leve Alta, Leve Alta, Leve Alta),...
# 96  ((Leve Alta, Leve Alta, Leve Alta, Leve Alta),...
# 97                     ((Alta, Alta, Alta, Alta), NS)

# %%
df_treino.tuplas.values[0]
# Out:
# (('Baixa', 'Baixa', 'Baixa', 'Baixa'), 'PS')

# %%
df_teste.shape
# Out:
# (8458, 17)

# %%
df_teste.head()
# Out:
#                      Time      Open      High       Low     Close      Volume  \
# 33877 2023-11-13 21:00:00  36785.18  36788.79  36333.00  36480.00  3676.83596
# 33878 2023-11-13 22:00:00  36480.01  36605.47  36443.59  36467.25  1068.97234
# 33879 2023-11-13 23:00:00  36467.24  36596.35  36462.93  36462.93   970.41635
# 33880 2023-11-14 00:00:00  36462.93  36470.00  36190.17  36245.49  2448.68056
# 33881 2023-11-14 01:00:00  36245.49  36427.02  36221.96  36323.84   990.93945
#
#        var_percentual classificacao classificacao_x  variacao_x  \
# 33877       -0.829628         Baixa           Baixa   -1.822818
# 33878       -0.034951    Leve Baixa           Baixa   -1.852799
# 33879       -0.011846    Leve Baixa           Baixa   -1.622053
# 33880       -0.596332         Baixa           Baixa   -2.293991
# 33881        0.216165     Leve Alta           Baixa   -2.336786
#
#       classificacao_n  variacao_n classificacao_p  variacao_p classificacao_z  \
# 33877           Baixa   -1.306579           Baixa   -1.217371           Baixa
# 33878           Baixa   -1.333972           Baixa   -0.977537           Baixa
# 33879           Baixa   -1.513640      Leve Baixa   -0.881556           Baixa
# 33880           Baixa   -2.006057           Baixa   -1.618863           Baixa
# 33881           Baixa   -1.761321           Baixa   -1.448516      Leve Baixa
#
#        variacao_z alvos
# 33877   -0.726563    NS
# 33878   -1.025187    NS
# 33879   -0.876032    NS
# 33880   -0.642845    PS
# 33881   -0.393257    PS

# %%
# Contar frequência de cada tupla
from collections import Counter
tupla_frequencias = Counter(tuplas_treino)

# Exibir as tuplas mais frequentes
print("Tuplas mais frequentes:")
for tupla, frequencia in tupla_frequencias.most_common(1000):
    print(f"{tupla}: {frequencia}")
# Out:
# Tuplas mais frequentes:
# (('Baixa', 'Baixa', 'Baixa', 'Baixa'), 'EA'): 988
# (('Alta', 'Alta', 'Alta', 'Alta'), 'EA'): 857
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 695
# (('Baixa', 'Baixa', 'Baixa', 'Baixa'), 'EB'): 684
# (('Alta', 'Alta', 'Alta', 'Alta'), 'EB'): 603
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 590
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 469
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 396
# (('Alta', 'Alta', 'Alta', 'Alta'), 'NS'): 366
# (('Baixa', 'Baixa', 'Baixa', 'Baixa'), 'PS'): 363
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 332
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 322
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 282
# (('Alta', 'Alta', 'Alta', 'Alta'), 'PS'): 273
# (('Alta', 'Alta', 'Alta', 'Leve Alta'), 'EA'): 258
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 249
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 242
# (('Alta', 'Alta', 'Alta', 'Leve Alta'), 'EB'): 232
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 232
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 224
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 219
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 217
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 216
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 209
# (('Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 202
# (('Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 199
# (('Alta', 'Alta', 'Alta', 'Leve Alta'), 'NS'): 194
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 188
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 187
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 186
# (('Baixa', 'Baixa', 'Baixa', 'Baixa'), 'NS'): 185
# (('Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'PS'): 185
# (('Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 181
# (('Baixa', 'Baixa', 'Baixa', 'Alta'), 'EA'): 177
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 175
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 175
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 170
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 165
# (('Alta', 'Alta', 'Alta', 'Leve Baixa'), 'EA'): 164
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 160
# (('Alta', 'Alta', 'Alta', 'Leve Alta'), 'PS'): 158
# (('Alta', 'Alta', 'Alta', 'Leve Baixa'), 'PS'): 153
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 152
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 148
# (('Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'EA'): 147
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 145
# (('Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'EB'): 145
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'NS'): 144
# (('Alta', 'Alta', 'Alta', 'Leve Baixa'), 'EB'): 139
# (('Leve Baixa', 'Baixa', 'Baixa', 'Baixa'), 'EA'): 138
# (('Leve Alta', 'Alta', 'Alta', 'Alta'), 'EA'): 138
# (('Leve Alta', 'Alta', 'Alta', 'Alta'), 'NS'): 137
# (('Alta', 'Alta', 'Alta', 'Baixa'), 'EA'): 137
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 135
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 126
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 123
# (('Leve Alta', 'Alta', 'Alta', 'Alta'), 'EB'): 121
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 120
# (('Baixa', 'Baixa', 'Baixa', 'Alta'), 'EB'): 120
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 117
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 117
# (('Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'NS'): 117
# (('Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 113
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 109
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 108
# (('Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 108
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 104
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 104
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 102
# (('Alta', 'Alta', 'Alta', 'Leve Baixa'), 'NS'): 101
# (('Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 100
# (('Leve Baixa', 'Baixa', 'Baixa', 'Baixa'), 'EB'): 100
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 99
# (('Leve Alta', 'Leve Alta', 'Alta', 'Alta'), 'NS'): 98
# (('Leve Alta', 'Leve Alta', 'Alta', 'Alta'), 'EA'): 98
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'EA'): 94
# (('Leve Baixa', 'Baixa', 'Baixa', 'Baixa'), 'PS'): 93
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 93
# (('Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 92
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 92
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 88
# (('Alta', 'Alta', 'Alta', 'Baixa'), 'EB'): 88
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 88
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'NS'): 87
# (('Alta', 'Alta', 'Leve Alta', 'Alta'), 'EA'): 87
# (('Alta', 'Alta', 'Leve Alta', 'Alta'), 'EB'): 85
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 84
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 84
# (('Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 81
# (('Leve Alta', 'Alta', 'Alta', 'Leve Alta'), 'NS'): 80
# (('Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 80
# (('Leve Alta', 'Alta', 'Alta', 'Alta'), 'PS'): 79
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 79
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 79
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 79
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'PS'): 78
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 77
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'PS'): 77
# (('Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 77
# (('Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'EA'): 76
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 74
# (('Leve Alta', 'Leve Alta', 'Alta', 'Alta'), 'EB'): 73
# (('Leve Alta', 'Alta', 'Alta', 'Leve Baixa'), 'NS'): 70
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 70
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 67
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 67
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 67
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 67
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 67
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'EB'): 67
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 67
# (('Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 67
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 67
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 65
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 64
# (('Leve Alta', 'Baixa', 'Baixa', 'Baixa'), 'EB'): 64
# (('Leve Alta', 'Leve Alta', 'Alta', 'Alta'), 'PS'): 64
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 64
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'EB'): 64
# (('Leve Alta', 'Baixa', 'Baixa', 'Baixa'), 'EA'): 62
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'PS'): 61
# (('Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'EA'): 61
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 60
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 60
# (('Leve Alta', 'Alta', 'Alta', 'Leve Alta'), 'EA'): 59
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 59
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 59
# (('Alta', 'Leve Alta', 'Alta', 'Alta'), 'EB'): 58
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 58
# (('Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 57
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 57
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 57
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'EA'): 57
# (('Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 57
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 57
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 57
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 56
# (('Alta', 'Leve Alta', 'Alta', 'Alta'), 'EA'): 56
# (('Leve Alta', 'Alta', 'Alta', 'Leve Baixa'), 'PS'): 55
# (('Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 55
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'PS'): 55
# (('Alta', 'Alta', 'Leve Alta', 'Alta'), 'NS'): 55
# (('Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 54
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 53
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 53
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 53
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 52
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 52
# (('Leve Alta', 'Alta', 'Alta', 'Leve Baixa'), 'EA'): 51
# (('Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'EB'): 51
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 51
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 51
# (('Leve Alta', 'Alta', 'Alta', 'Leve Alta'), 'PS'): 50
# (('Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 50
# (('Alta', 'Alta', 'Alta', 'Baixa'), 'PS'): 49
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'PS'): 48
# (('Leve Baixa', 'Alta', 'Alta', 'Alta'), 'EA'): 48
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 47
# (('Leve Baixa', 'Baixa', 'Baixa', 'Baixa'), 'NS'): 47
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 47
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Alta'), 'EA'): 47
# (('Baixa', 'Baixa', 'Baixa', 'Alta'), 'PS'): 47
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 46
# (('Alta', 'Alta', 'Leve Alta', 'Baixa'), 'EA'): 46
# (('Leve Alta', 'Alta', 'Alta', 'Leve Alta'), 'EB'): 46
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 45
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 45
# (('Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'EB'): 45
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 45
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 44
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 44
# (('Alta', 'Leve Alta', 'Alta', 'Alta'), 'NS'): 44
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 44
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 44
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 44
# (('Baixa', 'Baixa', 'Baixa', 'Alta'), 'NS'): 44
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'NS'): 44
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 44
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 43
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'PS'): 43
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 43
# (('Baixa', 'Baixa', 'Alta', 'Alta'), 'EA'): 43
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 43
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 43
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 42
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'EA'): 42
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'NS'): 42
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 42
# (('Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'EA'): 42
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 42
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 42
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'NS'): 42
# (('Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'EA'): 42
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 41
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 41
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 40
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 40
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 40
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 40
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 40
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'PS'): 40
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 40
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 40
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 40
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 40
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 40
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'EB'): 39
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'EA'): 39
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 39
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'NS'): 39
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 39
# (('Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'EA'): 39
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 39
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 39
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 38
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 38
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 38
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 38
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 38
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EA'): 38
# (('Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 38
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 38
# (('Alta', 'Alta', 'Baixa', 'Baixa'), 'EA'): 38
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'PS'): 37
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 37
# (('Alta', 'Alta', 'Alta', 'Baixa'), 'NS'): 37
# (('Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'NS'): 37
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'EA'): 37
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 37
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 36
# (('Leve Alta', 'Alta', 'Leve Alta', 'Alta'), 'EA'): 36
# (('Leve Alta', 'Alta', 'Leve Alta', 'Alta'), 'NS'): 36
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 36
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 36
# (('Alta', 'Alta', 'Leve Alta', 'Baixa'), 'EB'): 35
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 35
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 35
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'NS'): 35
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'NS'): 35
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 35
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'PS'): 35
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 35
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Alta'), 'NS'): 35
# (('Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 35
# (('Baixa', 'Alta', 'Alta', 'Alta'), 'EA'): 35
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 35
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'EB'): 35
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'EB'): 35
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 35
# (('Leve Baixa', 'Alta', 'Alta', 'Alta'), 'EB'): 35
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'PS'): 34
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'EA'): 34
# (('Alta', 'Baixa', 'Baixa', 'Baixa'), 'EA'): 34
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 34
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 34
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 34
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 34
# (('Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'EA'): 34
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 33
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 33
# (('Alta', 'Alta', 'Leve Alta', 'Baixa'), 'NS'): 33
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EB'): 33
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 33
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 33
# (('Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'EB'): 33
# (('Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 32
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 32
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'EA'): 32
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 32
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 32
# (('Alta', 'Alta', 'Leve Baixa', 'Alta'), 'EA'): 32
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'NS'): 32
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 31
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'NS'): 31
# (('Leve Baixa', 'Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 31
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EB'): 31
# (('Leve Alta', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 31
# (('Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EA'): 31
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EA'): 30
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'NS'): 30
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 30
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 30
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'PS'): 30
# (('Leve Alta', 'Alta', 'Alta', 'Leve Baixa'), 'EB'): 30
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 30
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EB'): 30
# (('Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'NS'): 29
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 29
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Alta'), 'EB'): 29
# (('Leve Alta', 'Baixa', 'Baixa', 'Baixa'), 'PS'): 28
# (('Alta', 'Baixa', 'Baixa', 'Baixa'), 'EB'): 28
# (('Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'PS'): 28
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'EA'): 28
# (('Baixa', 'Baixa', 'Alta', 'Baixa'), 'EA'): 28
# (('Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'EB'): 28
# (('Baixa', 'Alta', 'Alta', 'Alta'), 'EB'): 28
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 28
# (('Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'EA'): 28
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 27
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 27
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EA'): 27
# (('Baixa', 'Baixa', 'Alta', 'Alta'), 'EB'): 27
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'PS'): 27
# (('Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'PS'): 27
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'EB'): 27
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 27
# (('Leve Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EB'): 27
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 27
# (('Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'EA'): 27
# (('Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'EB'): 27
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 27
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 26
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 26
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'PS'): 26
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 26
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 26
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 26
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EA'): 26
# (('Leve Baixa', 'Baixa', 'Baixa', 'Alta'), 'EA'): 26
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 25
# (('Leve Alta', 'Alta', 'Leve Alta', 'Alta'), 'EB'): 25
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Alta'), 'NS'): 25
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'EA'): 25
# (('Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'EB'): 25
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'EB'): 25
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 25
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EA'): 24
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 24
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 24
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Alta'), 'PS'): 24
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EB'): 24
# (('Baixa', 'Leve Alta', 'Alta', 'Alta'), 'EB'): 24
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EA'): 24
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 24
# (('Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'EA'): 24
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'PS'): 24
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'PS'): 24
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 24
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 24
# (('Alta', 'Alta', 'Leve Baixa', 'Alta'), 'EB'): 23
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'NS'): 23
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 23
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 23
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EB'): 23
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'PS'): 23
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EA'): 23
# (('Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EA'): 23
# (('Leve Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EA'): 23
# (('Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'EB'): 23
# (('Alta', 'Alta', 'Baixa', 'Baixa'), 'EB'): 23
# (('Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'EB'): 23
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'NS'): 22
# (('Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 22
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EB'): 22
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 22
# (('Alta', 'Alta', 'Leve Alta', 'Alta'), 'PS'): 22
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EB'): 22
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 22
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EA'): 22
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EB'): 22
# (('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EB'): 22
# (('Alta', 'Alta', 'Leve Alta', 'Baixa'), 'PS'): 22
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EA'): 22
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'PS'): 22
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 22
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'PS'): 21
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 21
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'NS'): 21
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EA'): 21
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EB'): 21
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 21
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 21
# (('Baixa', 'Leve Alta', 'Alta', 'Alta'), 'EA'): 21
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EA'): 21
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EB'): 21
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EB'): 21
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 21
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 21
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'NS'): 21
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 20
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 20
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 20
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'PS'): 20
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'EA'): 20
# (('Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'EA'): 20
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 20
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Alta'), 'EB'): 20
# (('Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'EA'): 20
# (('Leve Alta', 'Alta', 'Alta', 'Baixa'), 'EA'): 20
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'PS'): 20
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EA'): 19
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'NS'): 19
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 19
# (('Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'PS'): 19
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 19
# (('Leve Alta', 'Alta', 'Leve Alta', 'Alta'), 'PS'): 19
# (('Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EB'): 19
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EA'): 19
# (('Alta', 'Leve Alta', 'Alta', 'Alta'), 'PS'): 19
# (('Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'NS'): 19
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 19
# (('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'PS'): 19
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EA'): 19
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EB'): 18
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Alta'), 'NS'): 18
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 18
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 18
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 18
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EB'): 18
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'EB'): 18
# (('Leve Baixa', 'Baixa', 'Baixa', 'Alta'), 'EB'): 18
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EA'): 18
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'EA'): 18
# (('Leve Baixa', 'Alta', 'Alta', 'Alta'), 'NS'): 18
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 18
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 17
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EA'): 17
# (('Alta', 'Leve Alta', 'Alta', 'Leve Alta'), 'PS'): 17
# (('Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'NS'): 17
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 17
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EB'): 17
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'EA'): 17
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 17
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'PS'): 17
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'NS'): 17
# (('Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'EA'): 17
# (('Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'EB'): 17
# (('Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'EA'): 17
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EB'): 17
# (('Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'NS'): 17
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 17
# (('Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EB'): 17
# (('Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'PS'): 16
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'NS'): 16
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'PS'): 16
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 16
# (('Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'EB'): 16
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EA'): 16
# (('Alta', 'Leve Alta', 'Alta', 'Baixa'), 'EA'): 16
# (('Leve Alta', 'Alta', 'Baixa', 'Baixa'), 'EA'): 16
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 16
# (('Leve Alta', 'Alta', 'Alta', 'Baixa'), 'EB'): 16
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 16
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'EA'): 16
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EA'): 16
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 16
# (('Leve Alta', 'Alta', 'Leve Alta', 'Baixa'), 'EA'): 15
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EB'): 15
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 15
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Alta'), 'EA'): 15
# (('Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'PS'): 15
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EB'): 15
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'NS'): 15
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 15
# (('Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'EA'): 15
# (('Alta', 'Baixa', 'Baixa', 'Alta'), 'EA'): 15
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EB'): 15
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Alta'), 'EB'): 15
# (('Alta', 'Alta', 'Baixa', 'Alta'), 'EA'): 15
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EA'): 15
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 15
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'PS'): 15
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EA'): 15
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 15
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EA'): 15
# (('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'PS'): 15
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'EB'): 15
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 15
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 14
# (('Alta', 'Leve Alta', 'Leve Alta', 'Baixa'), 'NS'): 14
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 14
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'NS'): 14
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'NS'): 14
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 14
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'NS'): 14
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'EB'): 14
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 14
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EA'): 14
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'PS'): 14
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 14
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 14
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 14
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 14
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 14
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'EA'): 14
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 14
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 14
# (('Leve Alta', 'Baixa', 'Baixa', 'Alta'), 'EB'): 13
# (('Leve Alta', 'Alta', 'Leve Alta', 'Baixa'), 'PS'): 13
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 13
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 13
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'PS'): 13
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EA'): 13
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EA'): 13
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'EB'): 13
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 13
# (('Leve Alta', 'Baixa', 'Baixa', 'Baixa'), 'NS'): 13
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Alta'), 'EA'): 13
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'PS'): 13
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EB'): 13
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'NS'): 13
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EB'): 13
# (('Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'PS'): 13
# (('Leve Alta', 'Alta', 'Alta', 'Baixa'), 'PS'): 13
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 13
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'EB'): 13
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'NS'): 12
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'PS'): 12
# (('Alta', 'Leve Alta', 'Leve Alta', 'Alta'), 'PS'): 12
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 12
# (('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'NS'): 12
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Alta'), 'EB'): 12
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EA'): 12
# (('Baixa', 'Leve Baixa', 'Baixa', 'Baixa'), 'NS'): 12
# (('Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'EA'): 12
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EB'): 12
# (('Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'EA'): 12
# (('Leve Alta', 'Baixa', 'Baixa', 'Alta'), 'EA'): 12
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 12
# (('Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'EB'): 12
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'NS'): 12
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 12
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Alta'), 'EA'): 12
# (('Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'EB'): 12
# (('Leve Alta', 'Leve Alta', 'Alta', 'Baixa'), 'PS'): 12
# (('Baixa', 'Alta', 'Alta', 'Leve Alta'), 'EA'): 12
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EA'): 11
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'NS'): 11
# (('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EA'): 11
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 11
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 11
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'NS'): 11
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 11
# (('Baixa', 'Alta', 'Leve Alta', 'Alta'), 'EA'): 11
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'), 'PS'): 11
# (('Baixa', 'Alta', 'Alta', 'Baixa'), 'EA'): 11
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Alta'), 'EA'): 11
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EB'): 11
# (('Alta', 'Leve Alta', 'Alta', 'Baixa'), 'EB'): 11
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EA'): 11
# (('Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'PS'): 11
# (('Alta', 'Leve Alta', 'Alta', 'Leve Baixa'), 'PS'): 11
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Alta'), 'EA'): 11
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 11
# (('Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'PS'): 11
# (('Leve Baixa', 'Alta', 'Alta', 'Alta'), 'PS'): 11
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'PS'): 11
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EA'): 11
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 11
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'EB'): 11
# (('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EA'): 11
# (('Leve Alta', 'Alta', 'Leve Alta', 'Baixa'), 'EB'): 11
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 11
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'NS'): 10
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'EB'): 10
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 10
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'NS'): 10
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'EB'): 10
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 10
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 10
# (('Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'EA'): 10
# (('Leve Alta', 'Leve Alta', 'Alta', 'Baixa'), 'EB'): 10
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'EA'): 10
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'EA'): 10
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 10
# (('Leve Baixa', 'Baixa', 'Leve Baixa', 'Alta'), 'EA'): 10
# (('Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EB'): 10
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EA'): 10
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EA'): 10
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 10
# (('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EB'): 10
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'EB'): 10
# (('Leve Baixa', 'Alta', 'Baixa', 'Baixa'), 'EA'): 10
# (('Leve Baixa', 'Alta', 'Alta', 'Baixa'), 'EB'): 10
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 9
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'EA'): 9
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'PS'): 9
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'NS'): 9
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Alta'), 'PS'): 9
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'PS'): 9
# (('Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'EB'): 9
# (('Leve Baixa', 'Alta', 'Alta', 'Baixa'), 'EA'): 9
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EA'): 9
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 9
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 9
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 9
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Alta'), 'NS'): 9
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'NS'): 9
# (('Baixa', 'Leve Alta', 'Alta', 'Alta'), 'NS'): 9
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'EB'): 9
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 9
# (('Alta', 'Leve Baixa', 'Alta', 'Alta'), 'EB'): 9
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'EA'): 9
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'EB'): 9
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 9
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'), 'PS'): 9
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 9
# (('Leve Baixa', 'Baixa', 'Baixa', 'Alta'), 'PS'): 9
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'), 'EA'): 9
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EA'): 9
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Alta'), 'NS'): 9
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Alta'), 'EA'): 9
# (('Leve Alta', 'Leve Alta', 'Alta', 'Baixa'), 'EA'): 9
# (('Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'EA'): 9
# (('Alta', 'Leve Baixa', 'Alta', 'Alta'), 'EA'): 9
# (('Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'EB'): 9
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'EB'): 9
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Alta'), 'EB'): 8
# (('Alta', 'Alta', 'Leve Baixa', 'Alta'), 'NS'): 8
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'NS'): 8
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'NS'): 8
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 8
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EB'): 8
# (('Baixa', 'Leve Alta', 'Alta', 'Alta'), 'PS'): 8
# (('Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'EA'): 8
# (('Leve Baixa', 'Baixa', 'Alta', 'Alta'), 'EA'): 8
# (('Baixa', 'Alta', 'Baixa', 'Baixa'), 'EA'): 8
# (('Alta', 'Baixa', 'Baixa', 'Alta'), 'EB'): 8
# (('Alta', 'Leve Baixa', 'Baixa', 'Alta'), 'EA'): 8
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'PS'): 8
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'NS'): 8
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'NS'): 8
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EB'): 8
# (('Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'EB'): 8
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'PS'): 8
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EA'): 8
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'NS'): 8
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'PS'): 8
# (('Baixa', 'Alta', 'Alta', 'Alta'), 'PS'): 8
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'NS'): 8
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'EB'): 8
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'EB'): 8
# (('Leve Alta', 'Alta', 'Alta', 'Baixa'), 'NS'): 8
# (('Baixa', 'Baixa', 'Alta', 'Alta'), 'PS'): 8
# (('Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'NS'): 8
# (('Alta', 'Leve Alta', 'Baixa', 'Alta'), 'EB'): 8
# (('Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'EA'): 8
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EA'): 8
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Alta'), 'PS'): 8
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EA'): 8
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'EA'): 8
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 8
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'EA'): 8
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EA'): 8
# (('Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'NS'): 7
# (('Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'PS'): 7
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'PS'): 7
# (('Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'EB'): 7
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EB'): 7
# (('Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'NS'): 7
# (('Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'EA'): 7
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'PS'): 7
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EB'): 7
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Alta'), 'EB'): 7
# (('Baixa', 'Alta', 'Leve Baixa', 'Alta'), 'EA'): 7
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EA'): 7
# (('Alta', 'Baixa', 'Leve Alta', 'Baixa'), 'EA'): 7
# (('Baixa', 'Baixa', 'Alta', 'Baixa'), 'EB'): 7
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'EB'): 7
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EA'): 7
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EA'): 7
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'EB'): 7
# (('Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'NS'): 7
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 7
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Baixa'), 'EA'): 7
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'PS'): 7
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 7
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'PS'): 7
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Alta'), 'EB'): 7
# (('Leve Alta', 'Baixa', 'Baixa', 'Alta'), 'NS'): 7
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'PS'): 7
# (('Baixa', 'Alta', 'Leve Alta', 'Alta'), 'EB'): 7
# (('Alta', 'Alta', 'Baixa', 'Leve Alta'), 'EA'): 7
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'EB'): 7
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EB'): 7
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'PS'): 7
# (('Alta', 'Leve Alta', 'Baixa', 'Alta'), 'EA'): 6
# (('Leve Alta', 'Leve Alta', 'Alta', 'Baixa'), 'NS'): 6
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 6
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Alta'), 'EB'): 6
# (('Leve Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'PS'): 6
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'PS'): 6
# (('Baixa', 'Baixa', 'Alta', 'Alta'), 'NS'): 6
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 6
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'EA'): 6
# (('Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 6
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 6
# (('Baixa', 'Alta', 'Leve Baixa', 'Baixa'), 'EA'): 6
# (('Leve Alta', 'Alta', 'Baixa', 'Baixa'), 'EB'): 6
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Alta'), 'EA'): 6
# (('Leve Alta', 'Baixa', 'Alta', 'Alta'), 'EB'): 6
# (('Alta', 'Alta', 'Baixa', 'Leve Alta'), 'NS'): 6
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 6
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'EB'): 6
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'EB'): 6
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'NS'): 6
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'NS'): 6
# (('Leve Baixa', 'Baixa', 'Baixa', 'Alta'), 'NS'): 6
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'PS'): 6
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EB'): 6
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EA'): 6
# (('Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'EB'): 6
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'PS'): 6
# (('Leve Baixa', 'Baixa', 'Alta', 'Alta'), 'EB'): 6
# (('Leve Alta', 'Leve Baixa', 'Baixa', 'Alta'), 'NS'): 6
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'NS'): 6
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EA'): 6
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'NS'): 6
# (('Baixa', 'Alta', 'Alta', 'Leve Alta'), 'EB'): 6
# (('Leve Alta', 'Alta', 'Leve Alta', 'Baixa'), 'NS'): 6
# (('Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'), 'PS'): 5
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Baixa'), 'EB'): 5
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Alta'), 'NS'): 5
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EA'): 5
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'PS'): 5
# (('Baixa', 'Alta', 'Alta', 'Leve Alta'), 'PS'): 5
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'PS'): 5
# (('Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'NS'): 5
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 5
# (('Alta', 'Baixa', 'Alta', 'Alta'), 'EB'): 5
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Baixa'), 'EA'): 5
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'NS'): 5
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'NS'): 5
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 5
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'NS'): 5
# (('Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EA'): 5
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'PS'): 5
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'PS'): 5
# (('Leve Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'NS'): 5
# (('Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'PS'): 5
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Alta'), 'PS'): 5
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Alta'), 'NS'): 5
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 5
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'EB'): 5
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'PS'): 5
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'NS'): 5
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EA'): 5
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EB'): 5
# (('Alta', 'Alta', 'Baixa', 'Alta'), 'EB'): 5
# (('Leve Baixa', 'Alta', 'Baixa', 'Alta'), 'EA'): 5
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'EA'): 5
# (('Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'EB'): 5
# (('Leve Baixa', 'Baixa', 'Alta', 'Baixa'), 'EA'): 5
# (('Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'EB'): 5
# (('Baixa', 'Alta', 'Alta', 'Alta'), 'NS'): 5
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'EA'): 5
# (('Alta', 'Leve Alta', 'Baixa', 'Baixa'), 'NS'): 5
# (('Alta', 'Leve Baixa', 'Alta', 'Baixa'), 'EA'): 5
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'EA'): 5
# (('Alta', 'Leve Alta', 'Baixa', 'Leve Alta'), 'PS'): 5
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EB'): 4
# (('Alta', 'Leve Baixa', 'Alta', 'Alta'), 'NS'): 4
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'NS'): 4
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'EB'): 4
# (('Alta', 'Alta', 'Leve Baixa', 'Alta'), 'PS'): 4
# (('Alta', 'Baixa', 'Alta', 'Baixa'), 'EA'): 4
# (('Alta', 'Baixa', 'Alta', 'Leve Alta'), 'EB'): 4
# (('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EB'): 4
# (('Baixa', 'Alta', 'Baixa', 'Leve Alta'), 'EA'): 4
# (('Alta', 'Alta', 'Baixa', 'Baixa'), 'NS'): 4
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'EB'): 4
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Alta'), 'PS'): 4
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'EB'): 4
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'PS'): 4
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'), 'NS'): 4
# (('Leve Alta', 'Baixa', 'Alta', 'Baixa'), 'EA'): 4
# (('Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'PS'): 4
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'NS'): 4
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Alta'), 'EB'): 4
# (('Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'NS'): 4
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'NS'): 4
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'PS'): 4
# (('Alta', 'Baixa', 'Leve Alta', 'Alta'), 'EB'): 4
# (('Alta', 'Leve Baixa', 'Baixa', 'Alta'), 'EB'): 4
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'EB'): 4
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'EA'): 4
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'EA'): 4
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'EB'): 4
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EA'): 4
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EB'): 4
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EB'): 4
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 4
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Alta'), 'NS'): 4
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'NS'): 4
# (('Leve Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'NS'): 4
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 4
# (('Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'EB'): 4
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 3
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'EB'): 3
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'NS'): 3
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Alta'), 'PS'): 3
# (('Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'), 'PS'): 3
# (('Leve Alta', 'Alta', 'Baixa', 'Alta'), 'EB'): 3
# (('Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EA'): 3
# (('Leve Alta', 'Baixa', 'Alta', 'Alta'), 'EA'): 3
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'PS'): 3
# (('Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'), 'NS'): 3
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'NS'): 3
# (('Leve Baixa', 'Alta', 'Baixa', 'Leve Baixa'), 'EB'): 3
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'), 'PS'): 3
# (('Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'PS'): 3
# (('Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'EB'): 3
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'NS'): 3
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'PS'): 3
# (('Alta', 'Baixa', 'Alta', 'Leve Baixa'), 'EA'): 3
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EB'): 3
# (('Leve Alta', 'Alta', 'Leve Baixa', 'Baixa'), 'PS'): 3
# (('Alta', 'Baixa', 'Baixa', 'Baixa'), 'NS'): 3
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'EA'): 3
# (('Alta', 'Alta', 'Baixa', 'Leve Alta'), 'EB'): 3
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'EA'): 3
# (('Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'PS'): 3
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'NS'): 3
# (('Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'EA'): 3
# (('Alta', 'Baixa', 'Leve Alta', 'Alta'), 'EA'): 3
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Alta'), 'EB'): 3
# (('Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'), 'PS'): 3
# (('Leve Alta', 'Baixa', 'Alta', 'Leve Baixa'), 'NS'): 3
# (('Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 3
# (('Alta', 'Baixa', 'Alta', 'Baixa'), 'EB'): 3
# (('Alta', 'Leve Alta', 'Baixa', 'Alta'), 'NS'): 3
# (('Leve Baixa', 'Baixa', 'Alta', 'Baixa'), 'EB'): 3
# (('Alta', 'Leve Alta', 'Baixa', 'Alta'), 'PS'): 3
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Baixa'), 'EA'): 3
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'), 'EB'): 3
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Alta'), 'PS'): 3
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'), 'NS'): 3
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'NS'): 3
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'EA'): 3
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'EB'): 3
# (('Baixa', 'Leve Baixa', 'Baixa', 'Alta'), 'NS'): 3
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'NS'): 3
# (('Leve Baixa', 'Baixa', 'Alta', 'Alta'), 'PS'): 3
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'NS'): 3
# (('Alta', 'Leve Alta', 'Alta', 'Baixa'), 'PS'): 3
# (('Alta', 'Alta', 'Baixa', 'Baixa'), 'PS'): 3
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'PS'): 3
# (('Leve Alta', 'Baixa', 'Alta', 'Alta'), 'PS'): 3
# (('Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'EB'): 3
# (('Alta', 'Leve Baixa', 'Alta', 'Alta'), 'PS'): 2
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Alta'), 'PS'): 2
# (('Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'), 'NS'): 2
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'), 'NS'): 2
# (('Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'PS'): 2
# (('Baixa', 'Alta', 'Baixa', 'Alta'), 'EA'): 2
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Baixa'), 'EB'): 2
# (('Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'PS'): 2
# (('Leve Baixa', 'Alta', 'Alta', 'Leve Alta'), 'PS'): 2
# (('Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'PS'): 2
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'EB'): 2
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Baixa'), 'NS'): 2
# (('Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'EA'): 2
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'EB'): 2
# (('Leve Alta', 'Leve Baixa', 'Alta', 'Baixa'), 'PS'): 2
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 2
# (('Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'EA'): 2
# (('Leve Baixa', 'Alta', 'Baixa', 'Leve Baixa'), 'NS'): 2
# (('Leve Alta', 'Alta', 'Baixa', 'Baixa'), 'PS'): 2
# (('Baixa', 'Baixa', 'Leve Alta', 'Baixa'), 'NS'): 2
# (('Alta', 'Leve Baixa', 'Baixa', 'Baixa'), 'NS'): 2
# (('Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'PS'): 2
# (('Alta', 'Baixa', 'Baixa', 'Leve Baixa'), 'PS'): 2
# (('Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'NS'): 2
# (('Baixa', 'Alta', 'Leve Alta', 'Alta'), 'PS'): 2
# (('Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'PS'): 2
# (('Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'EB'): 2
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'), 'PS'): 2
# (('Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'EB'): 2
# (('Leve Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'PS'): 2
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'PS'): 2
# (('Alta', 'Baixa', 'Leve Alta', 'Baixa'), 'EB'): 2
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'EB'): 2
# (('Baixa', 'Alta', 'Baixa', 'Baixa'), 'EB'): 2
# (('Leve Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'NS'): 2
# (('Leve Alta', 'Baixa', 'Alta', 'Leve Alta'), 'EA'): 2
# (('Leve Alta', 'Baixa', 'Alta', 'Leve Alta'), 'EB'): 2
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Alta'), 'EA'): 2
# (('Leve Baixa', 'Leve Alta', 'Alta', 'Baixa'), 'PS'): 2
# (('Leve Alta', 'Baixa', 'Alta', 'Baixa'), 'PS'): 2
# (('Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'), 'NS'): 2
# (('Baixa', 'Alta', 'Leve Baixa', 'Baixa'), 'EB'): 2
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Alta'), 'NS'): 2
# (('Alta', 'Baixa', 'Leve Baixa', 'Baixa'), 'PS'): 2
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'EA'): 2
# (('Leve Alta', 'Alta', 'Baixa', 'Baixa'), 'NS'): 2
# (('Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'PS'): 2
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'PS'): 2
# (('Leve Baixa', 'Alta', 'Alta', 'Baixa'), 'NS'): 2
# (('Leve Alta', 'Alta', 'Baixa', 'Alta'), 'NS'): 2
# (('Alta', 'Leve Alta', 'Alta', 'Baixa'), 'NS'): 2
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Baixa'), 'NS'): 2
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Alta'), 'PS'): 2
# (('Alta', 'Alta', 'Baixa', 'Alta'), 'NS'): 2
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'EB'): 2
# (('Baixa', 'Leve Baixa', 'Alta', 'Alta'), 'NS'): 2
# (('Leve Baixa', 'Alta', 'Alta', 'Baixa'), 'PS'): 2
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'), 'EB'): 2
# (('Alta', 'Baixa', 'Leve Alta', 'Leve Alta'), 'EB'): 2
# (('Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'), 'NS'): 2
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'PS'): 1
# (('Baixa', 'Leve Alta', 'Baixa', 'Baixa'), 'NS'): 1
# (('Leve Baixa', 'Alta', 'Baixa', 'Leve Alta'), 'EB'): 1
# (('Baixa', 'Alta', 'Baixa', 'Leve Baixa'), 'EA'): 1
# (('Alta', 'Baixa', 'Alta', 'Alta'), 'EA'): 1
# (('Leve Alta', 'Baixa', 'Alta', 'Alta'), 'NS'): 1
# (('Leve Alta', 'Baixa', 'Alta', 'Leve Baixa'), 'EA'): 1
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'EB'): 1
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Alta'), 'NS'): 1
# (('Baixa', 'Alta', 'Alta', 'Leve Alta'), 'NS'): 1
# (('Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'), 'NS'): 1
# (('Leve Alta', 'Baixa', 'Baixa', 'Alta'), 'PS'): 1
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'), 'NS'): 1
# (('Alta', 'Baixa', 'Baixa', 'Baixa'), 'PS'): 1
# (('Baixa', 'Alta', 'Baixa', 'Baixa'), 'PS'): 1
# (('Leve Baixa', 'Alta', 'Baixa', 'Leve Alta'), 'PS'): 1
# (('Alta', 'Baixa', 'Leve Alta', 'Alta'), 'NS'): 1
# (('Leve Alta', 'Baixa', 'Alta', 'Baixa'), 'NS'): 1
# (('Baixa', 'Leve Baixa', 'Alta', 'Baixa'), 'PS'): 1
# (('Alta', 'Baixa', 'Alta', 'Leve Alta'), 'EA'): 1
# (('Alta', 'Baixa', 'Alta', 'Leve Alta'), 'NS'): 1
# (('Alta', 'Baixa', 'Alta', 'Leve Baixa'), 'EB'): 1
# (('Leve Baixa', 'Alta', 'Baixa', 'Baixa'), 'EB'): 1
# (('Alta', 'Baixa', 'Leve Alta', 'Baixa'), 'NS'): 1
# (('Leve Alta', 'Baixa', 'Alta', 'Leve Baixa'), 'PS'): 1
# (('Leve Baixa', 'Alta', 'Leve Alta', 'Baixa'), 'NS'): 1
# (('Baixa', 'Baixa', 'Alta', 'Baixa'), 'PS'): 1
# (('Leve Alta', 'Alta', 'Baixa', 'Alta'), 'EA'): 1
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Alta'), 'PS'): 1
# (('Alta', 'Leve Baixa', 'Baixa', 'Alta'), 'PS'): 1
# (('Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'NS'): 1
# (('Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'NS'): 1
# (('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa'), 'PS'): 1
# (('Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'NS'): 1
# (('Baixa', 'Alta', 'Alta', 'Leve Baixa'), 'NS'): 1
# (('Leve Baixa', 'Baixa', 'Alta', 'Alta'), 'NS'): 1
# (('Baixa', 'Alta', 'Leve Baixa', 'Baixa'), 'PS'): 1
# (('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'), 'PS'): 1
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'), 'NS'): 1
# (('Leve Alta', 'Baixa', 'Alta', 'Baixa'), 'EB'): 1
# (('Leve Alta', 'Baixa', 'Leve Alta', 'Alta'), 'NS'): 1
# (('Baixa', 'Alta', 'Leve Baixa', 'Alta'), 'EB'): 1
# (('Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'PS'): 1
# (('Leve Baixa', 'Alta', 'Leve Baixa', 'Baixa'), 'EB'): 1
# (('Alta', 'Baixa', 'Leve Alta', 'Alta'), 'PS'): 1
# (('Leve Alta', 'Leve Alta', 'Baixa', 'Alta'), 'PS'): 1
# (('Alta', 'Baixa', 'Baixa', 'Leve Alta'), 'EB'): 1
# (('Leve Alta', 'Alta', 'Baixa', 'Alta'), 'PS'): 1
# (('Baixa', 'Alta', 'Baixa', 'Leve Alta'), 'NS'): 1
# (('Baixa', 'Alta', 'Alta', 'Baixa'), 'EB'): 1
# (('Leve Baixa', 'Alta', 'Baixa', 'Alta'), 'EB'): 1
# (('Leve Baixa', 'Alta', 'Baixa', 'Leve Alta'), 'NS'): 1
# (('Alta', 'Baixa', 'Leve Baixa', 'Alta'), 'PS'): 1
# (('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'EA'): 1
# (('Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'), 'PS'): 1
# (('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta'), 'NS'): 1
# (('Alta', 'Alta', 'Baixa', 'Leve Alta'), 'PS'): 1
# (('Leve Alta', 'Alta', 'Baixa', 'Leve Baixa'), 'PS'): 1
# (('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'), 'NS'): 1
# (('Leve Alta', 'Baixa', 'Alta', 'Leve Alta'), 'NS'): 1
# (('Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'), 'NS'): 1

# %%
from collections import Counter

# Extrair apenas os estados atuais (primeiro elemento da tupla)
estados_atuais = [estado_atual for estado_atual, _ in tuplas_treino]

# Contar a frequência de cada estado atual
estado_frequencias = Counter(estados_atuais)

# Exibir os estados mais frequentes
print("Estados mais frequentes:")
for estado, frequencia in estado_frequencias.most_common(1000):
    print(f"{estado}: {frequencia}")
# Out:
# Estados mais frequentes:
# ('Baixa', 'Baixa', 'Baixa', 'Baixa'): 2220
# ('Alta', 'Alta', 'Alta', 'Alta'): 2099
# ('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'): 1525
# ('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'): 1196
# ('Leve Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'): 910
# ('Alta', 'Alta', 'Alta', 'Leve Alta'): 842
# ('Baixa', 'Baixa', 'Baixa', 'Leve Baixa'): 695
# ('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'): 679
# ('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'): 623
# ('Baixa', 'Baixa', 'Baixa', 'Leve Alta'): 594
# ('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'): 573
# ('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'): 560
# ('Alta', 'Alta', 'Alta', 'Leve Baixa'): 557
# ('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'): 526
# ('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'): 484
# ('Leve Alta', 'Alta', 'Alta', 'Alta'): 475
# ('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'): 413
# ('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'): 394
# ('Baixa', 'Baixa', 'Baixa', 'Alta'): 388
# ('Leve Alta', 'Leve Alta', 'Leve Alta', 'Alta'): 379
# ('Leve Baixa', 'Baixa', 'Baixa', 'Baixa'): 378
# ('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'): 365
# ('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'): 360
# ('Alta', 'Alta', 'Leve Alta', 'Leve Alta'): 338
# ('Leve Alta', 'Leve Alta', 'Alta', 'Alta'): 333
# ('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'): 323
# ('Alta', 'Alta', 'Alta', 'Baixa'): 311
# ('Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'): 307
# ('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'): 299
# ('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'): 297
# ('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'): 266
# ('Alta', 'Alta', 'Leve Alta', 'Leve Baixa'): 256
# ('Baixa', 'Baixa', 'Leve Baixa', 'Baixa'): 252
# ('Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'): 249
# ('Alta', 'Alta', 'Leve Alta', 'Alta'): 249
# ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Baixa'): 241
# ('Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'): 238
# ('Leve Alta', 'Alta', 'Alta', 'Leve Alta'): 235
# ('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'): 222
# ('Leve Alta', 'Leve Alta', 'Alta', 'Leve Alta'): 216
# ('Leve Alta', 'Alta', 'Alta', 'Leve Baixa'): 206
# ('Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'): 188
# ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'): 184
# ('Leve Alta', 'Alta', 'Leve Alta', 'Leve Alta'): 179
# ('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'): 179
# ('Leve Baixa', 'Baixa', 'Baixa', 'Leve Baixa'): 177
# ('Alta', 'Leve Alta', 'Alta', 'Alta'): 177
# ('Alta', 'Leve Alta', 'Leve Alta', 'Alta'): 170
# ('Leve Alta', 'Baixa', 'Baixa', 'Baixa'): 167
# ('Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'): 166
# ('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'): 165
# ('Baixa', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'): 164
# ('Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'): 162
# ('Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'): 158
# ('Alta', 'Alta', 'Leve Baixa', 'Leve Alta'): 153
# ('Baixa', 'Leve Baixa', 'Baixa', 'Baixa'): 152
# ('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Alta'): 149
# ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'): 148
# ('Leve Baixa', 'Baixa', 'Baixa', 'Leve Alta'): 146
# ('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'): 142
# ('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'): 141
# ('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'): 138
# ('Leve Alta', 'Alta', 'Leve Alta', 'Leve Baixa'): 137
# ('Alta', 'Alta', 'Leve Alta', 'Baixa'): 136
# ('Leve Alta', 'Leve Alta', 'Alta', 'Leve Baixa'): 136
# ('Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'): 135
# ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'): 133
# ('Leve Alta', 'Leve Alta', 'Leve Alta', 'Baixa'): 131
# ('Leve Baixa', 'Leve Alta', 'Alta', 'Alta'): 125
# ('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'): 118
# ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'): 118
# ('Leve Alta', 'Alta', 'Leve Alta', 'Alta'): 116
# ('Alta', 'Leve Alta', 'Alta', 'Leve Alta'): 115
# ('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'): 114
# ('Leve Alta', 'Leve Baixa', 'Baixa', 'Baixa'): 112
# ('Leve Baixa', 'Alta', 'Alta', 'Alta'): 112
# ('Baixa', 'Baixa', 'Leve Baixa', 'Alta'): 111
# ('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'): 109
# ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Baixa'): 109
# ('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'): 105
# ('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Alta'): 97
# ('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'): 95
# ('Alta', 'Alta', 'Leve Baixa', 'Baixa'): 94
# ('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'): 86
# ('Baixa', 'Baixa', 'Leve Alta', 'Alta'): 86
# ('Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'): 86
# ('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'): 85
# ('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'): 85
# ('Baixa', 'Baixa', 'Alta', 'Alta'): 84
# ('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'): 82
# ('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Alta'): 82
# ('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'): 81
# ('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'): 79
# ('Alta', 'Leve Alta', 'Leve Alta', 'Baixa'): 79
# ('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'): 78
# ('Baixa', 'Baixa', 'Leve Alta', 'Baixa'): 77
# ('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'): 76
# ('Baixa', 'Alta', 'Alta', 'Alta'): 76
# ('Leve Alta', 'Leve Alta', 'Baixa', 'Baixa'): 75
# ('Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'): 74
# ('Baixa', 'Leve Alta', 'Leve Alta', 'Alta'): 71
# ('Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'): 70
# ('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'): 70
# ('Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'): 70
# ('Alta', 'Leve Alta', 'Alta', 'Leve Baixa'): 70
# ('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'): 68
# ('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'): 68
# ('Alta', 'Alta', 'Baixa', 'Baixa'): 68
# ('Alta', 'Alta', 'Leve Baixa', 'Alta'): 67
# ('Alta', 'Baixa', 'Baixa', 'Baixa'): 66
# ('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'): 65
# ('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'): 64
# ('Leve Baixa', 'Leve Alta', 'Baixa', 'Baixa'): 64
# ('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'): 63
# ('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Alta'): 63
# ('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Alta'): 62
# ('Baixa', 'Leve Alta', 'Alta', 'Alta'): 62
# ('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'): 61
# ('Leve Baixa', 'Baixa', 'Baixa', 'Alta'): 59
# ('Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'): 57
# ('Leve Alta', 'Alta', 'Alta', 'Baixa'): 57
# ('Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'): 56
# ('Alta', 'Leve Baixa', 'Baixa', 'Baixa'): 56
# ('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'): 55
# ('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'): 54
# ('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'): 54
# ('Baixa', 'Leve Baixa', 'Baixa', 'Alta'): 53
# ('Alta', 'Leve Alta', 'Leve Baixa', 'Alta'): 52
# ('Leve Alta', 'Leve Baixa', 'Alta', 'Alta'): 52
# ('Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'): 52
# ('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'): 52
# ('Leve Alta', 'Baixa', 'Leve Baixa', 'Baixa'): 51
# ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Alta'): 50
# ('Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'): 49
# ('Leve Baixa', 'Alta', 'Alta', 'Leve Alta'): 46
# ('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Alta'): 46
# ('Leve Alta', 'Alta', 'Leve Alta', 'Baixa'): 45
# ('Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'): 45
# ('Alta', 'Leve Alta', 'Baixa', 'Baixa'): 45
# ('Leve Alta', 'Baixa', 'Baixa', 'Leve Baixa'): 45
# ('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'): 42
# ('Leve Baixa', 'Leve Baixa', 'Alta', 'Alta'): 42
# ('Baixa', 'Baixa', 'Alta', 'Leve Alta'): 41
# ('Leve Alta', 'Baixa', 'Baixa', 'Leve Alta'): 40
# ('Baixa', 'Leve Baixa', 'Alta', 'Alta'): 40
# ('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'): 39
# ('Leve Alta', 'Alta', 'Leve Baixa', 'Baixa'): 38
# ('Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'): 38
# ('Leve Alta', 'Leve Alta', 'Alta', 'Baixa'): 37
# ('Baixa', 'Leve Alta', 'Alta', 'Leve Alta'): 37
# ('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'): 36
# ('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'): 36
# ('Baixa', 'Baixa', 'Alta', 'Baixa'): 36
# ('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'): 36
# ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Alta'): 35
# ('Baixa', 'Baixa', 'Alta', 'Leve Baixa'): 34
# ('Leve Alta', 'Baixa', 'Baixa', 'Alta'): 33
# ('Leve Baixa', 'Alta', 'Alta', 'Leve Baixa'): 33
# ('Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'): 33
# ('Leve Baixa', 'Alta', 'Leve Alta', 'Alta'): 33
# ('Alta', 'Leve Alta', 'Alta', 'Baixa'): 32
# ('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Alta'): 30
# ('Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'): 30
# ('Alta', 'Alta', 'Baixa', 'Leve Baixa'): 29
# ('Leve Baixa', 'Baixa', 'Leve Alta', 'Alta'): 29
# ('Leve Alta', 'Alta', 'Leve Baixa', 'Alta'): 28
# ('Baixa', 'Leve Alta', 'Baixa', 'Baixa'): 28
# ('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Alta'): 27
# ('Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'): 27
# ('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Alta'): 27
# ('Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'): 26
# ('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'): 26
# ('Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'): 26
# ('Leve Alta', 'Alta', 'Baixa', 'Baixa'): 26
# ('Leve Alta', 'Leve Baixa', 'Baixa', 'Alta'): 25
# ('Alta', 'Leve Alta', 'Baixa', 'Leve Alta'): 25
# ('Alta', 'Leve Baixa', 'Alta', 'Alta'): 24
# ('Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'): 24
# ('Baixa', 'Alta', 'Alta', 'Leve Alta'): 24
# ('Alta', 'Leve Baixa', 'Leve Alta', 'Alta'): 24
# ('Baixa', 'Alta', 'Leve Alta', 'Leve Alta'): 23
# ('Alta', 'Baixa', 'Baixa', 'Alta'): 23
# ('Leve Baixa', 'Alta', 'Alta', 'Baixa'): 23
# ('Leve Baixa', 'Baixa', 'Leve Alta', 'Baixa'): 23
# ('Baixa', 'Alta', 'Alta', 'Leve Baixa'): 22
# ('Alta', 'Alta', 'Baixa', 'Alta'): 22
# ('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'): 21
# ('Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'): 21
# ('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'): 21
# ('Alta', 'Leve Alta', 'Baixa', 'Alta'): 20
# ('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'): 20
# ('Baixa', 'Alta', 'Leve Alta', 'Alta'): 20
# ('Leve Baixa', 'Alta', 'Leve Alta', 'Baixa'): 20
# ('Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'): 18
# ('Leve Baixa', 'Baixa', 'Alta', 'Alta'): 18
# ('Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'): 18
# ('Baixa', 'Leve Alta', 'Alta', 'Baixa'): 17
# ('Alta', 'Alta', 'Baixa', 'Leve Alta'): 17
# ('Leve Alta', 'Leve Baixa', 'Alta', 'Baixa'): 16
# ('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'): 16
# ('Leve Alta', 'Leve Alta', 'Baixa', 'Alta'): 16
# ('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'): 16
# ('Leve Baixa', 'Leve Alta', 'Alta', 'Baixa'): 16
# ('Baixa', 'Leve Alta', 'Baixa', 'Alta'): 16
# ('Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'): 15
# ('Baixa', 'Alta', 'Leve Alta', 'Baixa'): 15
# ('Leve Alta', 'Baixa', 'Leve Baixa', 'Alta'): 15
# ('Leve Alta', 'Baixa', 'Leve Alta', 'Alta'): 15
# ('Alta', 'Baixa', 'Baixa', 'Leve Baixa'): 15
# ('Baixa', 'Leve Baixa', 'Alta', 'Baixa'): 14
# ('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'): 14
# ('Leve Alta', 'Baixa', 'Alta', 'Alta'): 13
# ('Leve Baixa', 'Leve Baixa', 'Alta', 'Baixa'): 13
# ('Alta', 'Leve Baixa', 'Baixa', 'Alta'): 13
# ('Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'): 12
# ('Alta', 'Leve Baixa', 'Alta', 'Leve Alta'): 12
# ('Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'): 12
# ('Baixa', 'Alta', 'Alta', 'Baixa'): 12
# ('Leve Baixa', 'Baixa', 'Alta', 'Leve Alta'): 12
# ('Leve Alta', 'Alta', 'Baixa', 'Leve Baixa'): 11
# ('Alta', 'Baixa', 'Leve Baixa', 'Baixa'): 11
# ('Baixa', 'Alta', 'Baixa', 'Baixa'): 11
# ('Leve Baixa', 'Alta', 'Baixa', 'Baixa'): 11
# ('Alta', 'Baixa', 'Leve Alta', 'Baixa'): 10
# ('Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'): 10
# ('Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'): 10
# ('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa'): 9
# ('Baixa', 'Alta', 'Leve Baixa', 'Baixa'): 9
# ('Alta', 'Baixa', 'Leve Alta', 'Alta'): 9
# ('Baixa', 'Alta', 'Leve Baixa', 'Alta'): 8
# ('Leve Alta', 'Baixa', 'Alta', 'Baixa'): 8
# ('Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'): 8
# ('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'): 8
# ('Leve Baixa', 'Baixa', 'Alta', 'Baixa'): 8
# ('Alta', 'Baixa', 'Alta', 'Baixa'): 7
# ('Leve Alta', 'Alta', 'Baixa', 'Alta'): 7
# ('Alta', 'Baixa', 'Leve Alta', 'Leve Alta'): 7
# ('Leve Alta', 'Baixa', 'Leve Alta', 'Baixa'): 7
# ('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta'): 7
# ('Alta', 'Baixa', 'Alta', 'Leve Alta'): 6
# ('Alta', 'Baixa', 'Alta', 'Alta'): 6
# ('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'): 6
# ('Leve Alta', 'Alta', 'Baixa', 'Leve Alta'): 6
# ('Alta', 'Baixa', 'Leve Baixa', 'Alta'): 6
# ('Leve Baixa', 'Alta', 'Baixa', 'Alta'): 6
# ('Leve Baixa', 'Alta', 'Leve Baixa', 'Baixa'): 6
# ('Baixa', 'Alta', 'Baixa', 'Leve Alta'): 5
# ('Leve Baixa', 'Alta', 'Baixa', 'Leve Baixa'): 5
# ('Leve Alta', 'Baixa', 'Alta', 'Leve Baixa'): 5
# ('Alta', 'Baixa', 'Baixa', 'Leve Alta'): 5
# ('Leve Alta', 'Baixa', 'Alta', 'Leve Alta'): 5
# ('Alta', 'Leve Baixa', 'Alta', 'Baixa'): 5
# ('Alta', 'Baixa', 'Alta', 'Leve Baixa'): 4
# ('Leve Baixa', 'Alta', 'Baixa', 'Leve Alta'): 3
# ('Baixa', 'Alta', 'Baixa', 'Alta'): 2
# ('Baixa', 'Alta', 'Baixa', 'Leve Baixa'): 1

# %%
df_treino.head()
# Out:
#                   Time     Open     High      Low    Close       Volume  \
# 48 2020-01-03 00:00:00  6965.49  6966.47  6912.88  6937.00  1106.732043
# 49 2020-01-03 01:00:00  6937.00  6946.07  6878.19  6888.85  2402.581684
# 50 2020-01-03 02:00:00  6888.26  6966.80  6871.04  6956.88  2869.993553
# 51 2020-01-03 03:00:00  6957.66  6966.36  6940.00  6952.04  1246.589508
# 52 2020-01-03 04:00:00  6952.04  7264.71  6948.64  7210.19  9560.897697
#
#     var_percentual classificacao classificacao_x  variacao_x classificacao_n  \
# 48       -0.412162         Baixa           Baixa   -3.800017           Baixa
# 49       -0.694104         Baixa           Baixa   -4.201647           Baixa
# 50        0.987538          Alta           Baixa   -2.959121           Baixa
# 51       -0.069571    Leve Baixa           Baixa   -2.490599           Baixa
# 52        3.713299          Alta       Leve Alta    0.951806       Leve Alta
#
#     variacao_n classificacao_p  variacao_p classificacao_z  variacao_z alvos  \
# 48   -3.141716           Baixa   -2.720243           Baixa   -0.583714    PS
# 49   -3.811596           Baixa   -2.317961           Baixa   -1.232293    EA
# 50   -2.561840      Leve Baixa   -0.188808      Leve Baixa   -0.126764    EA
# 51   -2.881275      Leve Baixa   -0.315170       Leve Alta    0.216808    EA
# 52    1.108377            Alta    3.249481            Alta    4.664639    NS
#
#                                           tuplas
# 48            ((Baixa, Baixa, Baixa, Baixa), PS)
# 49            ((Baixa, Baixa, Baixa, Baixa), EA)
# 50  ((Baixa, Baixa, Leve Baixa, Leve Baixa), EA)
# 51   ((Baixa, Baixa, Leve Baixa, Leve Alta), EA)
# 52      ((Leve Alta, Leve Alta, Alta, Alta), NS)

# %%
df_treino.tail()
# Out:
#                      Time      Open      High       Low     Close      Volume  \
# 33872 2023-11-13 16:00:00  36841.90  37031.45  36822.53  36857.73  1588.76273
# 33873 2023-11-13 17:00:00  36857.73  36863.89  36622.57  36670.09  1557.24046
# 33874 2023-11-13 18:00:00  36670.09  36786.84  36601.00  36746.99  1106.40786
# 33875 2023-11-13 19:00:00  36746.99  36844.99  36738.19  36844.98   593.91844
# 33876 2023-11-13 20:00:00  36844.98  36875.00  36743.74  36785.18   866.16686
#
#        var_percentual classificacao classificacao_x  variacao_x  \
# 33872        0.042940     Leve Alta      Leve Baixa   -0.679763
# 33873       -0.509093         Baixa      Leve Baixa   -1.096619
# 33874        0.209708     Leve Alta      Leve Baixa   -1.071903
# 33875        0.266661     Leve Alta      Leve Baixa   -0.700795
# 33876       -0.162302    Leve Baixa      Leve Baixa   -0.933966
#
#       classificacao_n  variacao_n classificacao_p  variacao_p classificacao_z  \
# 33872      Leve Baixa   -0.901326      Leve Baixa   -0.277487       Leve Alta
# 33873           Baixa   -1.270902           Baixa   -0.954101      Leve Baixa
# 33874      Leve Baixa   -0.452457      Leve Baixa   -0.650193      Leve Baixa
# 33875      Leve Baixa   -0.223330      Leve Baixa   -0.351886      Leve Baixa
# 33876      Leve Baixa   -0.356909      Leve Baixa   -0.067482       Leve Alta
#
#        variacao_z alvos                                             tuplas
# 33872    0.082765    NS  ((Leve Baixa, Leve Baixa, Leve Baixa, Leve Alt...
# 33873   -0.318426    PS       ((Leve Baixa, Baixa, Baixa, Leve Baixa), PS)
# 33874   -0.257641    EB  ((Leve Baixa, Leve Baixa, Leve Baixa, Leve Bai...
# 33875   -0.034592    EB  ((Leve Baixa, Leve Baixa, Leve Baixa, Leve Bai...
# 33876    0.313853    EB  ((Leve Baixa, Leve Baixa, Leve Baixa, Leve Alt...

# %%
def montar_matriz_transicao(tuplas):
    """
    Monta a matriz de transição baseada em tuplas com 3 estados e 2 estados como alvo.

    Parâmetros:
        tuplas (list): Lista de tuplas no formato [(estado_atual, alvo), ...].

    Retorna:
        dict: Matriz de transição representada como um dicionário.
    """
    # Criar dicionário para contar as transições
    transicoes = {}
    for estado_atual, alvo in tuplas:
        if estado_atual not in transicoes:
            transicoes[estado_atual] = {}
        if alvo not in transicoes[estado_atual]:
            transicoes[estado_atual][alvo] = 0
        transicoes[estado_atual][alvo] += 1

    # Normalizar para obter probabilidades
    matriz_transicao = {}
    for estado_atual, transicoes_proximas in transicoes.items():
        total_transicoes = sum(transicoes_proximas.values())
        matriz_transicao[estado_atual] = {
            alvo: count / total_transicoes
            for alvo, count in transicoes_proximas.items()
        }
    
    return matriz_transicao

# %%
# Montar a matriz de transição com as tuplas
matriz_transicao = montar_matriz_transicao(tuplas_treino)
matriz_transicao
# Out:
# {('Baixa', 'Baixa', 'Baixa', 'Baixa'): {'PS': 0.1635135135135135,
#   'EA': 0.44504504504504505,
#   'NS': 0.08333333333333333,
#   'EB': 0.3081081081081081},
#  ('Baixa', 'Baixa', 'Leve Baixa', 'Leve Baixa'): {'EA': 0.2182410423452769,
#   'NS': 0.19218241042345277,
#   'EB': 0.25732899022801303,
#   'PS': 0.3322475570032573},
#  ('Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'): {'EA': 0.226890756302521,
#   'PS': 0.29411764705882354,
#   'EB': 0.23949579831932774,
#   'NS': 0.23949579831932774},
#  ('Leve Alta', 'Leve Alta', 'Alta', 'Alta'): {'NS': 0.29429429429429427,
#   'EA': 0.29429429429429427,
#   'PS': 0.1921921921921922,
#   'EB': 0.21921921921921922},
#  ('Leve Alta', 'Alta', 'Alta', 'Leve Baixa'): {'EA': 0.24757281553398058,
#   'PS': 0.2669902912621359,
#   'NS': 0.33980582524271846,
#   'EB': 0.14563106796116504},
#  ('Leve Alta', 'Alta', 'Alta', 'Leve Alta'): {'EA': 0.251063829787234,
#   'NS': 0.3404255319148936,
#   'PS': 0.2127659574468085,
#   'EB': 0.19574468085106383},
#  ('Alta', 'Alta', 'Alta', 'Alta'): {'NS': 0.1743687470223916,
#   'PS': 0.13006193425440685,
#   'EB': 0.2872796569795141,
#   'EA': 0.40828966174368747},
#  ('Alta', 'Alta', 'Alta', 'Leve Baixa'): {'EB': 0.2495511669658887,
#   'EA': 0.29443447037701975,
#   'PS': 0.2746858168761221,
#   'NS': 0.1813285457809695},
#  ('Alta', 'Alta', 'Alta', 'Leve Alta'): {'EB': 0.2755344418052256,
#   'NS': 0.23040380047505937,
#   'PS': 0.1876484560570071,
#   'EA': 0.30641330166270786},
#  ('Leve Alta', 'Alta', 'Leve Alta', 'Baixa'): {'EA': 0.3333333333333333,
#   'PS': 0.28888888888888886,
#   'EB': 0.24444444444444444,
#   'NS': 0.13333333333333333},
#  ('Alta', 'Alta', 'Leve Baixa', 'Leve Alta'): {'EB': 0.20915032679738563,
#   'PS': 0.26143790849673204,
#   'NS': 0.26143790849673204,
#   'EA': 0.2679738562091503},
#  ('Alta', 'Alta', 'Leve Alta', 'Baixa'): {'EB': 0.25735294117647056,
#   'NS': 0.2426470588235294,
#   'EA': 0.3382352941176471,
#   'PS': 0.16176470588235295},
#  ('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'): {'PS': 0.2318840579710145,
#   'EB': 0.2898550724637681,
#   'EA': 0.21739130434782608,
#   'NS': 0.2608695652173913},
#  ('Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'): {'PS': 0.3,
#   'EA': 0.34285714285714286,
#   'EB': 0.2571428571428571,
#   'NS': 0.1},
#  ('Alta', 'Leve Alta', 'Alta', 'Leve Alta'): {'NS': 0.25217391304347825,
#   'PS': 0.14782608695652175,
#   'EA': 0.3652173913043478,
#   'EB': 0.23478260869565218},
#  ('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Alta'): {'PS': 0.25316455696202533,
#   'EA': 0.3291139240506329,
#   'NS': 0.24050632911392406,
#   'EB': 0.17721518987341772},
#  ('Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'): {'PS': 0.06666666666666667,
#   'EA': 0.6,
#   'EB': 0.26666666666666666,
#   'NS': 0.06666666666666667},
#  ('Alta', 'Leve Baixa', 'Leve Baixa', 'Leve Baixa'): {'PS': 0.313953488372093,
#   'NS': 0.20930232558139536,
#   'EA': 0.313953488372093,
#   'EB': 0.16279069767441862},
#  ('Alta', 'Leve Alta', 'Leve Baixa', 'Leve Alta'): {'PS': 0.176056338028169,
#   'NS': 0.30985915492957744,
#   'EB': 0.2323943661971831,
#   'EA': 0.28169014084507044},
#  ('Leve Alta',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Leve Alta'): {'PS': 0.39951573849878935, 'EA': 0.08958837772397095, 'NS': 0.387409200968523, 'EB': 0.1234866828087167},
#  ('Leve Alta',
#   'Leve Alta',
#   'Leve Alta',
#   'Leve Alta'): {'PS': 0.30754098360655735, 'NS': 0.4557377049180328, 'EA': 0.14163934426229507, 'EB': 0.09508196721311475},
#  ('Alta', 'Leve Alta', 'Leve Alta', 'Leve Alta'): {'PS': 0.26907630522088355,
#   'NS': 0.2570281124497992,
#   'EA': 0.21285140562248997,
#   'EB': 0.26104417670682734},
#  ('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Alta'): {'NS': 0.265625,
#   'PS': 0.234375,
#   'EA': 0.28125,
#   'EB': 0.21875},
#  ('Leve Alta',
#   'Leve Baixa',
#   'Leve Alta',
#   'Leve Alta'): {'NS': 0.4222222222222222, 'PS': 0.30277777777777776, 'EB': 0.1638888888888889, 'EA': 0.1111111111111111},
#  ('Leve Alta',
#   'Leve Baixa',
#   'Leve Alta',
#   'Leve Baixa'): {'NS': 0.3622291021671827, 'PS': 0.39009287925696595, 'EB': 0.13622291021671826, 'EA': 0.11145510835913312},
#  ('Leve Baixa',
#   'Leve Alta',
#   'Leve Alta',
#   'Leve Baixa'): {'NS': 0.3287671232876712, 'PS': 0.4054794520547945, 'EA': 0.15616438356164383, 'EB': 0.1095890410958904},
#  ('Leve Baixa',
#   'Leve Alta',
#   'Leve Baixa',
#   'Baixa'): {'PS': 0.35789473684210527, 'EB': 0.23157894736842105, 'NS': 0.17894736842105263, 'EA': 0.23157894736842105},
#  ('Leve Baixa',
#   'Leve Alta',
#   'Leve Baixa',
#   'Leve Baixa'): {'PS': 0.45454545454545453, 'NS': 0.2828282828282828, 'EA': 0.11447811447811448, 'EB': 0.14814814814814814},
#  ('Leve Alta',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Leve Baixa'): {'PS': 0.43455497382198954, 'NS': 0.32809773123909247, 'EB': 0.13787085514834205, 'EA': 0.09947643979057591},
#  ('Leve Baixa',
#   'Leve Alta',
#   'Leve Baixa',
#   'Leve Alta'): {'EA': 0.10150375939849623, 'NS': 0.40601503759398494, 'PS': 0.39097744360902253, 'EB': 0.10150375939849623},
#  ('Leve Baixa',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Leve Alta'): {'EA': 0.1134020618556701, 'PS': 0.41531664212076586, 'NS': 0.34167893961708395, 'EB': 0.12960235640648013},
#  ('Leve Baixa',
#   'Leve Alta',
#   'Leve Alta',
#   'Leve Alta'): {'EB': 0.1187800963081862, 'PS': 0.35152487961476725, 'EA': 0.14125200642054575, 'NS': 0.3884430176565008},
#  ('Leve Baixa',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Leve Baixa'): {'PS': 0.49331103678929766, 'NS': 0.27759197324414714, 'EB': 0.14214046822742474, 'EA': 0.08695652173913043},
#  ('Leve Baixa',
#   'Leve Baixa',
#   'Leve Alta',
#   'Leve Alta'): {'PS': 0.384297520661157, 'NS': 0.38636363636363635, 'EB': 0.12396694214876033, 'EA': 0.10537190082644628},
#  ('Leve Alta', 'Alta', 'Alta', 'Alta'): {'PS': 0.16631578947368422,
#   'NS': 0.28842105263157897,
#   'EA': 0.2905263157894737,
#   'EB': 0.25473684210526315},
#  ('Leve Alta',
#   'Leve Alta',
#   'Leve Alta',
#   'Leve Baixa'): {'NS': 0.4351648351648352, 'EA': 0.1087912087912088, 'PS': 0.35384615384615387, 'EB': 0.1021978021978022},
#  ('Leve Alta', 'Alta', 'Leve Alta', 'Leve Baixa'): {'PS': 0.291970802919708,
#   'EB': 0.23357664233576642,
#   'NS': 0.24817518248175183,
#   'EA': 0.22627737226277372},
#  ('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Baixa'): {'PS': 0.3696969696969697,
#   'NS': 0.21212121212121213,
#   'EA': 0.23030303030303031,
#   'EB': 0.18787878787878787},
#  ('Leve Alta',
#   'Leve Alta',
#   'Leve Baixa',
#   'Leve Baixa'): {'PS': 0.42585551330798477, 'NS': 0.33269961977186313, 'EB': 0.12737642585551331, 'EA': 0.11406844106463879},
#  ('Leve Alta',
#   'Leve Alta',
#   'Leve Baixa',
#   'Leve Alta'): {'PS': 0.3732142857142857, 'EA': 0.11964285714285715, 'NS': 0.3875, 'EB': 0.11964285714285715},
#  ('Leve Alta', 'Baixa', 'Baixa', 'Baixa'): {'PS': 0.16766467065868262,
#   'EB': 0.38323353293413176,
#   'EA': 0.3712574850299401,
#   'NS': 0.07784431137724551},
#  ('Leve Alta', 'Leve Baixa', 'Baixa', 'Baixa'): {'EA': 0.30357142857142855,
#   'PS': 0.24107142857142858,
#   'NS': 0.14285714285714285,
#   'EB': 0.3125},
#  ('Leve Alta', 'Leve Baixa', 'Baixa', 'Leve Alta'): {'EA': 0.26153846153846155,
#   'NS': 0.2153846153846154,
#   'EB': 0.26153846153846155,
#   'PS': 0.26153846153846155},
#  ('Leve Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'): {'EA': 0.2037037037037037,
#   'PS': 0.2222222222222222,
#   'EB': 0.18518518518518517,
#   'NS': 0.3888888888888889},
#  ('Leve Alta', 'Leve Alta', 'Alta', 'Leve Baixa'): {'PS': 0.27205882352941174,
#   'EA': 0.22058823529411764,
#   'NS': 0.3088235294117647,
#   'EB': 0.19852941176470587},
#  ('Leve Alta', 'Leve Alta', 'Alta', 'Leve Alta'): {'NS': 0.4027777777777778,
#   'EA': 0.18055555555555555,
#   'PS': 0.25462962962962965,
#   'EB': 0.16203703703703703},
#  ('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'): {'EA': 0.1794871794871795,
#   'PS': 0.48717948717948717,
#   'NS': 0.21794871794871795,
#   'EB': 0.11538461538461539},
#  ('Leve Alta', 'Alta', 'Leve Alta', 'Leve Alta'): {'EB': 0.19553072625698323,
#   'PS': 0.24022346368715083,
#   'NS': 0.3128491620111732,
#   'EA': 0.25139664804469275},
#  ('Alta', 'Alta', 'Alta', 'Baixa'): {'PS': 0.15755627009646303,
#   'EA': 0.4405144694533762,
#   'NS': 0.1189710610932476,
#   'EB': 0.2829581993569132},
#  ('Alta', 'Alta', 'Leve Baixa', 'Leve Baixa'): {'EA': 0.27710843373493976,
#   'EB': 0.2289156626506024,
#   'NS': 0.24096385542168675,
#   'PS': 0.25301204819277107},
#  ('Alta', 'Alta', 'Leve Alta', 'Leve Baixa'): {'EA': 0.22265625,
#   'EB': 0.21484375,
#   'PS': 0.30078125,
#   'NS': 0.26171875},
#  ('Alta', 'Baixa', 'Baixa', 'Baixa'): {'EA': 0.5151515151515151,
#   'EB': 0.42424242424242425,
#   'NS': 0.045454545454545456,
#   'PS': 0.015151515151515152},
#  ('Alta', 'Leve Alta', 'Leve Alta', 'Alta'): {'EA': 0.4470588235294118,
#   'PS': 0.07058823529411765,
#   'NS': 0.21764705882352942,
#   'EB': 0.2647058823529412},
#  ('Alta', 'Alta', 'Baixa', 'Leve Baixa'): {'NS': 0.2413793103448276,
#   'EA': 0.27586206896551724,
#   'EB': 0.3103448275862069,
#   'PS': 0.1724137931034483},
#  ('Alta', 'Alta', 'Leve Alta', 'Leve Alta'): {'EA': 0.2958579881656805,
#   'EB': 0.23668639053254437,
#   'NS': 0.31952662721893493,
#   'PS': 0.14792899408284024},
#  ('Alta', 'Alta', 'Leve Alta', 'Alta'): {'EB': 0.3413654618473896,
#   'EA': 0.3493975903614458,
#   'PS': 0.08835341365461848,
#   'NS': 0.22088353413654618},
#  ('Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'): {'EB': 0.3333333333333333,
#   'PS': 0.25,
#   'EA': 0.25,
#   'NS': 0.16666666666666666},
#  ('Leve Baixa', 'Baixa', 'Baixa', 'Baixa'): {'EA': 0.36507936507936506,
#   'NS': 0.12433862433862433,
#   'PS': 0.24603174603174602,
#   'EB': 0.26455026455026454},
#  ('Leve Baixa', 'Baixa', 'Baixa', 'Leve Baixa'): {'EB': 0.2655367231638418,
#   'EA': 0.1977401129943503,
#   'PS': 0.3615819209039548,
#   'NS': 0.1751412429378531},
#  ('Leve Alta', 'Baixa', 'Baixa', 'Alta'): {'EB': 0.3939393939393939,
#   'EA': 0.36363636363636365,
#   'PS': 0.030303030303030304,
#   'NS': 0.21212121212121213},
#  ('Leve Baixa', 'Baixa', 'Baixa', 'Leve Alta'): {'EB': 0.2671232876712329,
#   'PS': 0.23972602739726026,
#   'EA': 0.2534246575342466,
#   'NS': 0.23972602739726026},
#  ('Baixa', 'Baixa', 'Baixa', 'Leve Baixa'): {'NS': 0.16258992805755396,
#   'EB': 0.260431654676259,
#   'PS': 0.2906474820143885,
#   'EA': 0.28633093525179854},
#  ('Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'): {'NS': 0.25925925925925924,
#   'EA': 0.29012345679012347,
#   'PS': 0.2345679012345679,
#   'EB': 0.21604938271604937},
#  ('Baixa', 'Leve Baixa', 'Baixa', 'Baixa'): {'PS': 0.18421052631578946,
#   'EA': 0.40131578947368424,
#   'EB': 0.3355263157894737,
#   'NS': 0.07894736842105263},
#  ('Baixa',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Leve Alta'): {'EB': 0.18902439024390244, 'NS': 0.25609756097560976, 'PS': 0.3170731707317073, 'EA': 0.23780487804878048},
#  ('Baixa', 'Baixa', 'Leve Baixa', 'Baixa'): {'EA': 0.36507936507936506,
#   'NS': 0.0873015873015873,
#   'PS': 0.2261904761904762,
#   'EB': 0.32142857142857145},
#  ('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'): {'EA': 0.24770642201834864,
#   'EB': 0.1926605504587156,
#   'PS': 0.27522935779816515,
#   'NS': 0.28440366972477066},
#  ('Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'): {'NS': 0.2972972972972973,
#   'PS': 0.3108108108108108,
#   'EA': 0.25675675675675674,
#   'EB': 0.13513513513513514},
#  ('Baixa',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Leve Baixa'): {'NS': 0.23873873873873874, 'EB': 0.14864864864864866, 'PS': 0.4144144144144144, 'EA': 0.1981981981981982},
#  ('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'): {'NS': 0.2894736842105263,
#   'EB': 0.18421052631578946,
#   'PS': 0.2982456140350877,
#   'EA': 0.22807017543859648},
#  ('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Alta'): {'EA': 0.28187919463087246,
#   'NS': 0.28187919463087246,
#   'PS': 0.2684563758389262,
#   'EB': 0.16778523489932887},
#  ('Alta', 'Leve Alta', 'Leve Alta', 'Baixa'): {'NS': 0.17721518987341772,
#   'PS': 0.189873417721519,
#   'EA': 0.3924050632911392,
#   'EB': 0.24050632911392406},
#  ('Alta', 'Leve Alta', 'Leve Alta', 'Leve Baixa'): {'EB': 0.24050632911392406,
#   'PS': 0.24050632911392406,
#   'EA': 0.2721518987341772,
#   'NS': 0.2468354430379747},
#  ('Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'): {'NS': 0.24489795918367346,
#   'EA': 0.2653061224489796,
#   'EB': 0.3469387755102041,
#   'PS': 0.14285714285714285},
#  ('Alta', 'Leve Baixa', 'Baixa', 'Leve Baixa'): {'PS': 0.2,
#   'EA': 0.4444444444444444,
#   'EB': 0.28888888888888886,
#   'NS': 0.06666666666666667},
#  ('Alta', 'Leve Alta', 'Baixa', 'Baixa'): {'PS': 0.15555555555555556,
#   'EA': 0.5333333333333333,
#   'EB': 0.2,
#   'NS': 0.1111111111111111},
#  ('Leve Alta', 'Baixa', 'Leve Baixa', 'Leve Alta'): {'EA': 0.3333333333333333,
#   'NS': 0.19047619047619047,
#   'EB': 0.23809523809523808,
#   'PS': 0.23809523809523808},
#  ('Alta', 'Leve Baixa', 'Alta', 'Alta'): {'NS': 0.16666666666666666,
#   'PS': 0.08333333333333333,
#   'EB': 0.375,
#   'EA': 0.375},
#  ('Leve Alta', 'Leve Alta', 'Leve Alta', 'Alta'): {'EA': 0.24802110817941952,
#   'NS': 0.37994722955145116,
#   'PS': 0.20316622691292877,
#   'EB': 0.16886543535620052},
#  ('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'): {'EB': 0.2727272727272727,
#   'NS': 0.2545454545454545,
#   'PS': 0.2727272727272727,
#   'EA': 0.2},
#  ('Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'): {'EA': 0.3333333333333333,
#   'PS': 0.25925925925925924,
#   'NS': 0.13333333333333333,
#   'EB': 0.2740740740740741},
#  ('Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'): {'PS': 0.3888888888888889,
#   'EA': 0.3888888888888889,
#   'EB': 0.1111111111111111,
#   'NS': 0.1111111111111111},
#  ('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'): {'NS': 0.19047619047619047,
#   'PS': 0.2857142857142857,
#   'EA': 0.3333333333333333,
#   'EB': 0.19047619047619047},
#  ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Leve Alta'): {'PS': 0.3609022556390977,
#   'EB': 0.16541353383458646,
#   'NS': 0.3308270676691729,
#   'EA': 0.14285714285714285},
#  ('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Alta'): {'NS': 0.4074074074074074,
#   'EB': 0.25925925925925924,
#   'PS': 0.2222222222222222,
#   'EA': 0.1111111111111111},
#  ('Leve Alta', 'Leve Baixa', 'Leve Alta', 'Alta'): {'NS': 0.30927835051546393,
#   'EB': 0.2268041237113402,
#   'EA': 0.21649484536082475,
#   'PS': 0.24742268041237114},
#  ('Leve Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'): {'EA': 0.25,
#   'NS': 0.15789473684210525,
#   'EB': 0.27631578947368424,
#   'PS': 0.3157894736842105},
#  ('Leve Alta',
#   'Leve Baixa',
#   'Leve Baixa',
#   'Baixa'): {'NS': 0.21787709497206703, 'PS': 0.3743016759776536, 'EA': 0.16759776536312848, 'EB': 0.24022346368715083},
#  ('Leve Baixa',
#   'Leve Baixa',
#   'Baixa',
#   'Leve Baixa'): {'PS': 0.45652173913043476, 'EA': 0.13043478260869565, 'NS': 0.22282608695652173, 'EB': 0.19021739130434784},
#  ('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'): {'NS': 0.3333333333333333,
#   'PS': 0.24761904761904763,
#   'EA': 0.20952380952380953,
#   'EB': 0.20952380952380953},
#  ('Leve Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'): {'NS': 0.2235294117647059,
#   'EB': 0.2823529411764706,
#   'EA': 0.27058823529411763,
#   'PS': 0.2235294117647059},
#  ('Leve Baixa', 'Leve Baixa', 'Leve Baixa', 'Baixa'): {'PS': 0.391304347826087,
#   'EB': 0.26421404682274247,
#   'NS': 0.1939799331103679,
#   'EA': 0.1505016722408027},
#  ('Leve Baixa',
#   'Leve Baixa',
#   'Leve Alta',
#   'Leve Baixa'): {'PS': 0.44416243654822335, 'EB': 0.1319796954314721, 'EA': 0.1116751269035533, 'NS': 0.31218274111675126},
#  ('Leve Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'): {'EA': 0.1746031746031746,
#   'PS': 0.31746031746031744,
#   'EB': 0.2857142857142857,
#   'NS': 0.2222222222222222},
#  ('Leve Alta', 'Leve Alta', 'Baixa', 'Baixa'): {'EA': 0.4266666666666667,
#   'EB': 0.36,
#   'PS': 0.10666666666666667,
#   'NS': 0.10666666666666667},
#  ('Leve Alta', 'Baixa', 'Baixa', 'Leve Alta'): {'EA': 0.225,
#   'NS': 0.25,
#   'PS': 0.15,
#   'EB': 0.375},
#  ('Alta', 'Leve Baixa', 'Leve Baixa', 'Alta'): {'PS': 0.19230769230769232,
#   'EA': 0.3076923076923077,
#   'EB': 0.2692307692307692,
#   'NS': 0.23076923076923078},
#  ('Alta', 'Leve Alta', 'Baixa', 'Alta'): {'EA': 0.3,
#   'EB': 0.4,
#   'NS': 0.15,
#   'PS': 0.15},
#  ('Alta', 'Leve Alta', 'Alta', 'Alta'): {'EB': 0.327683615819209,
#   'EA': 0.3163841807909605,
#   'NS': 0.24858757062146894,
#   'PS': 0.10734463276836158},
#  ('Leve Alta', 'Leve Alta', 'Alta', 'Baixa'): {'NS': 0.16216216216216217,
#   'EB': 0.2702702702702703,
#   'PS': 0.32432432432432434,
#   'EA': 0.24324324324324326},
#  ('Leve Alta', 'Leve Baixa', 'Alta', 'Baixa'): {'EB': 0.3125,
#   'NS': 0.125,
#   'EA': 0.4375,
#   'PS': 0.125},
#  ('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'): {'EA': 0.375,
#   'PS': 0.375,
#   'EB': 0.1875,
#   'NS': 0.0625},
#  ('Leve Alta', 'Alta', 'Leve Alta', 'Alta'): {'EB': 0.21551724137931033,
#   'EA': 0.3103448275862069,
#   'PS': 0.16379310344827586,
#   'NS': 0.3103448275862069},
#  ('Leve Alta', 'Alta', 'Leve Baixa', 'Alta'): {'EB': 0.21428571428571427,
#   'EA': 0.4642857142857143,
#   'PS': 0.14285714285714285,
#   'NS': 0.17857142857142858},
#  ('Leve Alta', 'Alta', 'Leve Baixa', 'Leve Alta'): {'EB': 0.1746031746031746,
#   'EA': 0.2222222222222222,
#   'NS': 0.38095238095238093,
#   'PS': 0.2222222222222222},
#  ('Leve Alta', 'Baixa', 'Baixa', 'Leve Baixa'): {'PS': 0.24444444444444444,
#   'EB': 0.2222222222222222,
#   'NS': 0.2,
#   'EA': 0.3333333333333333},
#  ('Leve Alta', 'Leve Baixa', 'Baixa', 'Alta'): {'EB': 0.32,
#   'EA': 0.44,
#   'NS': 0.24},
#  ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Baixa'): {'EA': 0.23651452282157676,
#   'NS': 0.16182572614107885,
#   'EB': 0.27800829875518673,
#   'PS': 0.3236514522821577},
#  ('Leve Baixa', 'Baixa', 'Leve Alta', 'Alta'): {'NS': 0.1724137931034483,
#   'EA': 0.3448275862068966,
#   'EB': 0.2413793103448276,
#   'PS': 0.2413793103448276},
#  ('Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'): {'NS': 0.35638297872340424,
#   'EB': 0.23404255319148937,
#   'EA': 0.20212765957446807,
#   'PS': 0.2074468085106383},
#  ('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Alta'): {'PS': 0.16101694915254236,
#   'NS': 0.3220338983050847,
#   'EA': 0.3389830508474576,
#   'EB': 0.17796610169491525},
#  ('Leve Alta', 'Leve Alta', 'Leve Alta', 'Baixa'): {'PS': 0.3282442748091603,
#   'EB': 0.25190839694656486,
#   'NS': 0.24427480916030533,
#   'EA': 0.17557251908396945},
#  ('Alta', 'Alta', 'Leve Baixa', 'Alta'): {'NS': 0.11940298507462686,
#   'EB': 0.34328358208955223,
#   'PS': 0.05970149253731343,
#   'EA': 0.47761194029850745},
#  ('Alta', 'Leve Baixa', 'Alta', 'Leve Alta'): {'PS': 0.16666666666666666,
#   'EA': 0.5,
#   'EB': 0.3333333333333333},
#  ('Leve Alta', 'Alta', 'Baixa', 'Leve Baixa'): {'EB': 0.36363636363636365,
#   'EA': 0.2727272727272727,
#   'NS': 0.2727272727272727,
#   'PS': 0.09090909090909091},
#  ('Baixa', 'Baixa', 'Baixa', 'Leve Alta'): {'PS': 0.3114478114478115,
#   'NS': 0.19696969696969696,
#   'EA': 0.2474747474747475,
#   'EB': 0.2441077441077441},
#  ('Baixa', 'Baixa', 'Alta', 'Alta'): {'EB': 0.32142857142857145,
#   'NS': 0.07142857142857142,
#   'EA': 0.5119047619047619,
#   'PS': 0.09523809523809523},
#  ('Baixa', 'Baixa', 'Leve Alta', 'Alta'): {'NS': 0.19767441860465115,
#   'EB': 0.32558139534883723,
#   'PS': 0.1511627906976744,
#   'EA': 0.32558139534883723},
#  ('Baixa', 'Baixa', 'Leve Alta', 'Baixa'): {'PS': 0.2077922077922078,
#   'EA': 0.44155844155844154,
#   'EB': 0.3246753246753247,
#   'NS': 0.025974025974025976},
#  ('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Baixa'): {'PS': 0.4444444444444444,
#   'EB': 0.16049382716049382,
#   'EA': 0.19753086419753085,
#   'NS': 0.19753086419753085},
#  ('Baixa', 'Leve Alta', 'Leve Baixa', 'Leve Alta'): {'EB': 0.2073170731707317,
#   'EA': 0.23170731707317074,
#   'PS': 0.2682926829268293,
#   'NS': 0.2926829268292683},
#  ('Baixa', 'Leve Alta', 'Leve Alta', 'Leve Baixa'): {'EB': 0.38235294117647056,
#   'PS': 0.16176470588235295,
#   'EA': 0.25,
#   'NS': 0.20588235294117646},
#  ('Leve Alta', 'Leve Alta', 'Leve Baixa', 'Alta'): {'NS': 0.2804878048780488,
#   'EA': 0.25609756097560976,
#   'EB': 0.2804878048780488,
#   'PS': 0.18292682926829268},
#  ('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Alta'): {'NS': 0.3387096774193548,
#   'EB': 0.16129032258064516,
#   'EA': 0.3225806451612903,
#   'PS': 0.1774193548387097},
#  ('Leve Alta', 'Alta', 'Leve Baixa', 'Baixa'): {'NS': 0.21052631578947367,
#   'EA': 0.42105263157894735,
#   'EB': 0.2894736842105263,
#   'PS': 0.07894736842105263},
#  ('Leve Alta',
#   'Leve Baixa',
#   'Baixa',
#   'Leve Baixa'): {'PS': 0.27058823529411763, 'NS': 0.15294117647058825, 'EA': 0.29411764705882354, 'EB': 0.2823529411764706},
#  ('Baixa', 'Leve Baixa', 'Baixa', 'Leve Baixa'): {'NS': 0.1511627906976744,
#   'PS': 0.3953488372093023,
#   'EB': 0.20930232558139536,
#   'EA': 0.2441860465116279},
#  ('Baixa', 'Baixa', 'Leve Baixa', 'Alta'): {'PS': 0.17117117117117117,
#   'EA': 0.3783783783783784,
#   'EB': 0.2972972972972973,
#   'NS': 0.15315315315315314},
#  ('Baixa', 'Leve Baixa', 'Leve Alta', 'Leve Alta'): {'EB': 0.23404255319148937,
#   'PS': 0.3049645390070922,
#   'EA': 0.16312056737588654,
#   'NS': 0.2978723404255319},
#  ('Leve Baixa', 'Leve Alta', 'Alta', 'Alta'): {'EA': 0.376,
#   'NS': 0.2,
#   'EB': 0.232,
#   'PS': 0.192},
#  ('Leve Baixa', 'Leve Alta', 'Baixa', 'Baixa'): {'NS': 0.125,
#   'PS': 0.203125,
#   'EA': 0.390625,
#   'EB': 0.28125},
#  ('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Alta'): {'NS': 0.36666666666666664,
#   'EB': 0.2,
#   'EA': 0.16666666666666666,
#   'PS': 0.26666666666666666},
#  ('Leve Baixa',
#   'Baixa',
#   'Leve Baixa',
#   'Leve Baixa'): {'PS': 0.3581081081081081, 'EB': 0.21621621621621623, 'EA': 0.23648648648648649, 'NS': 0.1891891891891892},
#  ('Alta', 'Leve Alta', 'Leve Baixa', 'Alta'): {'EA': 0.25,
#   'NS': 0.17307692307692307,
#   'PS': 0.17307692307692307,
#   'EB': 0.40384615384615385},
#  ('Alta', 'Leve Baixa', 'Leve Alta', 'Leve Baixa'): {'EB': 0.37037037037037035,
#   'EA': 0.2962962962962963,
#   'NS': 0.16666666666666666,
#   'PS': 0.16666666666666666},
#  ('Alta', 'Baixa', 'Leve Baixa', 'Baixa'): {'EB': 0.6363636363636364,
#   'EA': 0.18181818181818182,
#   'PS': 0.18181818181818182},
#  ('Alta', 'Baixa', 'Leve Baixa', 'Leve Baixa'): {'EA': 0.23809523809523808,
#   'NS': 0.2857142857142857,
#   'EB': 0.14285714285714285,
#   'PS': 0.3333333333333333},
#  ('Leve Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'): {'EA': 0.3333333333333333,
#   'NS': 0.1388888888888889,
#   'EB': 0.2777777777777778,
#   'PS': 0.25},
#  ('Alta', 'Alta', 'Leve Baixa', 'Baixa'): {'PS': 0.2872340425531915,
#   'NS': 0.05319148936170213,
#   'EA': 0.4148936170212766,
#   'EB': 0.24468085106382978},
#  ('Leve Baixa', 'Leve Alta', 'Baixa', 'Leve Baixa'): {'EB': 0.2222222222222222,
#   'EA': 0.3055555555555556,
#   'PS': 0.3888888888888889,
#   'NS': 0.08333333333333333},
#  ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Baixa'): {'EA': 0.23853211009174313,
#   'PS': 0.3669724770642202,
#   'EB': 0.26605504587155965,
#   'NS': 0.12844036697247707},
#  ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Leve Alta'): {'NS': 0.2542372881355932,
#   'PS': 0.2966101694915254,
#   'EB': 0.2288135593220339,
#   'EA': 0.22033898305084745},
#  ('Baixa', 'Leve Alta', 'Alta', 'Alta'): {'PS': 0.12903225806451613,
#   'EB': 0.3870967741935484,
#   'EA': 0.3387096774193548,
#   'NS': 0.14516129032258066},
#  ('Leve Baixa', 'Alta', 'Alta', 'Leve Alta'): {'NS': 0.391304347826087,
#   'EB': 0.32608695652173914,
#   'PS': 0.043478260869565216,
#   'EA': 0.2391304347826087},
#  ('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'): {'PS': 0.15,
#   'EA': 0.3,
#   'NS': 0.4,
#   'EB': 0.15},
#  ('Leve Baixa', 'Baixa', 'Leve Baixa', 'Alta'): {'NS': 0.2,
#   'EB': 0.2,
#   'EA': 0.2,
#   'PS': 0.4},
#  ('Leve Alta', 'Leve Baixa', 'Alta', 'Alta'): {'EA': 0.28846153846153844,
#   'EB': 0.38461538461538464,
#   'NS': 0.17307692307692307,
#   'PS': 0.15384615384615385},
#  ('Leve Baixa', 'Leve Baixa', 'Baixa', 'Alta'): {'EB': 0.37142857142857144,
#   'EA': 0.2571428571428571,
#   'PS': 0.22857142857142856,
#   'NS': 0.14285714285714285},
#  ('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Baixa'): {'NS': 0.3142857142857143,
#   'EB': 0.22857142857142856,
#   'PS': 0.3,
#   'EA': 0.15714285714285714},
#  ('Leve Baixa', 'Baixa', 'Leve Alta', 'Leve Alta'): {'PS': 0.35294117647058826,
#   'EA': 0.16176470588235295,
#   'NS': 0.3235294117647059,
#   'EB': 0.16176470588235295},
#  ('Baixa', 'Leve Baixa', 'Leve Alta', 'Baixa'): {'PS': 0.17307692307692307,
#   'EB': 0.28846153846153844,
#   'EA': 0.46153846153846156,
#   'NS': 0.07692307692307693},
#  ('Baixa', 'Leve Alta', 'Leve Alta', 'Baixa'): {'NS': 0.08333333333333333,
#   'PS': 0.20833333333333334,
#   'EB': 0.25,
#   'EA': 0.4583333333333333},
#  ('Baixa', 'Alta', 'Leve Alta', 'Leve Alta'): {'NS': 0.2608695652173913,
#   'EA': 0.391304347826087,
#   'EB': 0.21739130434782608,
#   'PS': 0.13043478260869565},
#  ('Baixa', 'Leve Alta', 'Baixa', 'Baixa'): {'NS': 0.03571428571428571,
#   'EA': 0.6071428571428571,
#   'PS': 0.07142857142857142,
#   'EB': 0.2857142857142857},
#  ('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'): {'EB': 0.2692307692307692,
#   'PS': 0.2692307692307692,
#   'NS': 0.15384615384615385,
#   'EA': 0.3076923076923077},
#  ('Baixa', 'Leve Alta', 'Baixa', 'Leve Alta'): {'NS': 0.16666666666666666,
#   'EB': 0.25,
#   'EA': 0.3333333333333333,
#   'PS': 0.25},
#  ('Baixa', 'Leve Baixa', 'Alta', 'Alta'): {'PS': 0.05,
#   'EB': 0.4,
#   'EA': 0.5,
#   'NS': 0.05},
#  ('Baixa', 'Leve Alta', 'Leve Alta', 'Alta'): {'PS': 0.22535211267605634,
#   'EB': 0.16901408450704225,
#   'NS': 0.2112676056338028,
#   'EA': 0.39436619718309857},
#  ('Baixa', 'Leve Baixa', 'Leve Baixa', 'Alta'): {'NS': 0.12280701754385964,
#   'PS': 0.15789473684210525,
#   'EA': 0.45614035087719296,
#   'EB': 0.2631578947368421},
#  ('Baixa', 'Baixa', 'Baixa', 'Alta'): {'EB': 0.30927835051546393,
#   'EA': 0.45618556701030927,
#   'NS': 0.1134020618556701,
#   'PS': 0.1211340206185567},
#  ('Baixa', 'Leve Baixa', 'Alta', 'Baixa'): {'EA': 0.5,
#   'PS': 0.07142857142857142,
#   'EB': 0.42857142857142855},
#  ('Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'): {'EA': 0.4444444444444444,
#   'PS': 0.1111111111111111,
#   'NS': 0.18518518518518517,
#   'EB': 0.25925925925925924},
#  ('Baixa', 'Leve Alta', 'Alta', 'Leve Alta'): {'EA': 0.4594594594594595,
#   'PS': 0.08108108108108109,
#   'NS': 0.21621621621621623,
#   'EB': 0.24324324324324326},
#  ('Baixa', 'Alta', 'Leve Alta', 'Alta'): {'EA': 0.55, 'PS': 0.1, 'EB': 0.35},
#  ('Leve Baixa', 'Baixa', 'Alta', 'Alta'): {'EA': 0.4444444444444444,
#   'EB': 0.3333333333333333,
#   'PS': 0.16666666666666666,
#   'NS': 0.05555555555555555},
#  ('Baixa', 'Alta', 'Alta', 'Leve Alta'): {'PS': 0.20833333333333334,
#   'NS': 0.041666666666666664,
#   'EA': 0.5,
#   'EB': 0.25},
#  ('Leve Baixa', 'Alta', 'Alta', 'Leve Baixa'): {'NS': 0.09090909090909091,
#   'PS': 0.24242424242424243,
#   'EB': 0.24242424242424243,
#   'EA': 0.42424242424242425},
#  ('Leve Baixa', 'Leve Baixa', 'Alta', 'Alta'): {'PS': 0.11904761904761904,
#   'EB': 0.3333333333333333,
#   'NS': 0.11904761904761904,
#   'EA': 0.42857142857142855},
#  ('Leve Alta',
#   'Baixa',
#   'Leve Baixa',
#   'Leve Baixa'): {'EA': 0.28846153846153844, 'PS': 0.23076923076923078, 'EB': 0.28846153846153844, 'NS': 0.19230769230769232},
#  ('Baixa', 'Leve Baixa', 'Leve Alta', 'Alta'): {'PS': 0.15714285714285714,
#   'EA': 0.22857142857142856,
#   'EB': 0.42857142857142855,
#   'NS': 0.18571428571428572},
#  ('Leve Baixa', 'Leve Baixa', 'Alta', 'Leve Alta'): {'PS': 0.1794871794871795,
#   'NS': 0.23076923076923078,
#   'EB': 0.3333333333333333,
#   'EA': 0.2564102564102564},
#  ('Baixa', 'Leve Alta', 'Alta', 'Baixa'): {'EA': 0.7058823529411765,
#   'EB': 0.11764705882352941,
#   'PS': 0.17647058823529413},
#  ('Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'): {'PS': 0.11538461538461539,
#   'NS': 0.23076923076923078,
#   'EB': 0.3076923076923077,
#   'EA': 0.34615384615384615},
#  ('Leve Alta', 'Leve Alta', 'Baixa', 'Alta'): {'EB': 0.4375,
#   'EA': 0.375,
#   'NS': 0.125,
#   'PS': 0.0625},
#  ('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Baixa'): {'EB': 0.19672131147540983,
#   'EA': 0.2459016393442623,
#   'NS': 0.19672131147540983,
#   'PS': 0.36065573770491804},
#  ('Leve Alta', 'Baixa', 'Leve Baixa', 'Baixa'): {'EB': 0.27450980392156865,
#   'PS': 0.23529411764705882,
#   'EA': 0.4117647058823529,
#   'NS': 0.0784313725490196},
#  ('Baixa', 'Baixa', 'Alta', 'Baixa'): {'EA': 0.7777777777777778,
#   'EB': 0.19444444444444445,
#   'PS': 0.027777777777777776},
#  ('Baixa', 'Baixa', 'Alta', 'Leve Alta'): {'EA': 0.2926829268292683,
#   'EB': 0.4146341463414634,
#   'PS': 0.0975609756097561,
#   'NS': 0.1951219512195122},
#  ('Baixa', 'Alta', 'Alta', 'Leve Baixa'): {'EA': 0.6818181818181818,
#   'PS': 0.09090909090909091,
#   'EB': 0.18181818181818182,
#   'NS': 0.045454545454545456},
#  ('Baixa', 'Alta', 'Leve Alta', 'Baixa'): {'EA': 0.6666666666666666,
#   'EB': 0.2,
#   'PS': 0.13333333333333333},
#  ('Baixa', 'Alta', 'Baixa', 'Baixa'): {'EA': 0.7272727272727273,
#   'PS': 0.09090909090909091,
#   'EB': 0.18181818181818182},
#  ('Baixa', 'Alta', 'Baixa', 'Alta'): {'EA': 1.0},
#  ('Baixa', 'Alta', 'Leve Baixa', 'Alta'): {'EA': 0.875, 'EB': 0.125},
#  ('Alta', 'Baixa', 'Alta', 'Baixa'): {'EA': 0.5714285714285714,
#   'EB': 0.42857142857142855},
#  ('Alta', 'Baixa', 'Alta', 'Leve Alta'): {'EB': 0.6666666666666666,
#   'EA': 0.16666666666666666,
#   'NS': 0.16666666666666666},
#  ('Alta', 'Leve Alta', 'Alta', 'Baixa'): {'EA': 0.5,
#   'EB': 0.34375,
#   'PS': 0.09375,
#   'NS': 0.0625},
#  ('Alta', 'Alta', 'Baixa', 'Baixa'): {'EA': 0.5588235294117647,
#   'NS': 0.058823529411764705,
#   'EB': 0.3382352941176471,
#   'PS': 0.04411764705882353},
#  ('Leve Alta', 'Alta', 'Baixa', 'Baixa'): {'EA': 0.6153846153846154,
#   'EB': 0.23076923076923078,
#   'PS': 0.07692307692307693,
#   'NS': 0.07692307692307693},
#  ('Leve Alta', 'Alta', 'Baixa', 'Alta'): {'EB': 0.42857142857142855,
#   'EA': 0.14285714285714285,
#   'NS': 0.2857142857142857,
#   'PS': 0.14285714285714285},
#  ('Alta', 'Baixa', 'Baixa', 'Alta'): {'EA': 0.6521739130434783,
#   'EB': 0.34782608695652173},
#  ('Alta', 'Baixa', 'Leve Alta', 'Leve Alta'): {'EA': 0.42857142857142855,
#   'PS': 0.2857142857142857,
#   'EB': 0.2857142857142857},
#  ('Alta', 'Baixa', 'Alta', 'Alta'): {'EB': 0.8333333333333334,
#   'EA': 0.16666666666666666},
#  ('Baixa', 'Leve Baixa', 'Baixa', 'Alta'): {'EA': 0.5094339622641509,
#   'PS': 0.20754716981132076,
#   'EB': 0.22641509433962265,
#   'NS': 0.05660377358490566},
#  ('Baixa', 'Baixa', 'Alta', 'Leve Baixa'): {'EA': 0.5,
#   'EB': 0.35294117647058826,
#   'PS': 0.08823529411764706,
#   'NS': 0.058823529411764705},
#  ('Leve Alta', 'Baixa', 'Leve Alta', 'Baixa'): {'EA': 0.7142857142857143,
#   'EB': 0.2857142857142857},
#  ('Leve Baixa', 'Alta', 'Alta', 'Alta'): {'EA': 0.42857142857142855,
#   'EB': 0.3125,
#   'PS': 0.09821428571428571,
#   'NS': 0.16071428571428573},
#  ('Leve Baixa', 'Alta', 'Alta', 'Baixa'): {'EA': 0.391304347826087,
#   'EB': 0.43478260869565216,
#   'NS': 0.08695652173913043,
#   'PS': 0.08695652173913043},
#  ('Alta', 'Baixa', 'Leve Alta', 'Baixa'): {'EA': 0.7, 'EB': 0.2, 'NS': 0.1},
#  ('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'): {'EB': 0.6666666666666666,
#   'EA': 0.16666666666666666,
#   'NS': 0.16666666666666666},
#  ('Baixa', 'Alta', 'Alta', 'Alta'): {'EA': 0.4605263157894737,
#   'EB': 0.3684210526315789,
#   'PS': 0.10526315789473684,
#   'NS': 0.06578947368421052},
#  ('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa'): {'EA': 0.6666666666666666,
#   'EB': 0.2222222222222222,
#   'PS': 0.1111111111111111},
#  ('Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'): {'EA': 0.6,
#   'EB': 0.2,
#   'NS': 0.1,
#   'PS': 0.1},
#  ('Baixa', 'Alta', 'Alta', 'Baixa'): {'EA': 0.9166666666666666,
#   'EB': 0.08333333333333333},
#  ('Baixa', 'Alta', 'Leve Baixa', 'Baixa'): {'EA': 0.6666666666666666,
#   'EB': 0.2222222222222222,
#   'PS': 0.1111111111111111},
#  ('Leve Alta', 'Baixa', 'Alta', 'Alta'): {'EA': 0.23076923076923078,
#   'EB': 0.46153846153846156,
#   'NS': 0.07692307692307693,
#   'PS': 0.23076923076923078},
#  ('Baixa', 'Alta', 'Baixa', 'Leve Alta'): {'EA': 0.8, 'NS': 0.2},
#  ('Baixa', 'Leve Alta', 'Leve Baixa', 'Alta'): {'EB': 0.23333333333333334,
#   'NS': 0.1,
#   'EA': 0.5,
#   'PS': 0.16666666666666666},
#  ('Leve Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'): {'EA': 0.3333333333333333,
#   'NS': 0.23809523809523808,
#   'PS': 0.19047619047619047,
#   'EB': 0.23809523809523808},
#  ('Leve Alta', 'Alta', 'Alta', 'Baixa'): {'EB': 0.2807017543859649,
#   'EA': 0.3508771929824561,
#   'NS': 0.14035087719298245,
#   'PS': 0.22807017543859648},
#  ('Alta', 'Alta', 'Baixa', 'Alta'): {'EA': 0.6818181818181818,
#   'EB': 0.22727272727272727,
#   'NS': 0.09090909090909091},
#  ('Leve Baixa', 'Baixa', 'Leve Alta', 'Baixa'): {'EA': 0.43478260869565216,
#   'PS': 0.21739130434782608,
#   'EB': 0.17391304347826086,
#   'NS': 0.17391304347826086},
#  ('Leve Baixa', 'Alta', 'Baixa', 'Leve Alta'): {'EB': 0.3333333333333333,
#   'PS': 0.3333333333333333,
#   'NS': 0.3333333333333333},
#  ('Leve Alta', 'Leve Alta', 'Baixa', 'Leve Alta'): {'EB': 0.2391304347826087,
#   'EA': 0.30434782608695654,
#   'PS': 0.2826086956521739,
#   'NS': 0.17391304347826086},
#  ('Leve Alta', 'Baixa', 'Leve Baixa', 'Alta'): {'PS': 0.2,
#   'EB': 0.4,
#   'NS': 0.13333333333333333,
#   'EA': 0.26666666666666666},
#  ('Leve Baixa', 'Leve Baixa', 'Alta', 'Baixa'): {'NS': 0.23076923076923078,
#   'EB': 0.3076923076923077,
#   'PS': 0.15384615384615385,
#   'EA': 0.3076923076923077},
#  ('Baixa', 'Alta', 'Baixa', 'Leve Baixa'): {'EA': 1.0},
#  ('Leve Baixa', 'Baixa', 'Baixa', 'Alta'): {'EB': 0.3050847457627119,
#   'EA': 0.4406779661016949,
#   'PS': 0.15254237288135594,
#   'NS': 0.1016949152542373},
#  ('Alta', 'Alta', 'Baixa', 'Leve Alta'): {'NS': 0.35294117647058826,
#   'EB': 0.17647058823529413,
#   'EA': 0.4117647058823529,
#   'PS': 0.058823529411764705},
#  ('Alta', 'Leve Baixa', 'Leve Alta', 'Baixa'): {'EA': 0.5454545454545454,
#   'EB': 0.2727272727272727,
#   'NS': 0.09090909090909091,
#   'PS': 0.09090909090909091},
#  ('Leve Baixa', 'Alta', 'Leve Alta', 'Leve Alta'): {'EB': 0.3333333333333333,
#   'PS': 0.25925925925925924,
#   'NS': 0.1111111111111111,
#   'EA': 0.2962962962962963},
#  ('Leve Baixa', 'Alta', 'Baixa', 'Leve Baixa'): {'EB': 0.6, 'NS': 0.4},
#  ('Leve Baixa', 'Alta', 'Leve Alta', 'Alta'): {'NS': 0.2727272727272727,
#   'EA': 0.36363636363636365,
#   'PS': 0.15151515151515152,
#   'EB': 0.21212121212121213},
#  ('Alta', 'Leve Alta', 'Alta', 'Leve Baixa'): {'EB': 0.24285714285714285,
#   'EA': 0.32857142857142857,
#   'PS': 0.15714285714285714,
#   'NS': 0.2714285714285714},
#  ('Alta', 'Leve Baixa', 'Leve Baixa', 'Baixa'): {'EB': 0.35714285714285715,
#   'EA': 0.26785714285714285,
#   'NS': 0.125,
#   'PS': 0.25},
#  ('Alta', 'Leve Baixa', 'Baixa', 'Baixa'): {'EB': 0.4107142857142857,
#   'PS': 0.19642857142857142,
#   'EA': 0.35714285714285715,
#   'NS': 0.03571428571428571},
#  ('Alta', 'Leve Baixa', 'Baixa', 'Alta'): {'EA': 0.6153846153846154,
#   'EB': 0.3076923076923077,
#   'PS': 0.07692307692307693},
#  ('Leve Baixa', 'Alta', 'Leve Alta', 'Baixa'): {'EB': 0.45,
#   'PS': 0.1,
#   'EA': 0.4,
#   'NS': 0.05},
#  ('Leve Baixa', 'Baixa', 'Alta', 'Leve Alta'): {'EB': 0.16666666666666666,
#   'NS': 0.25,
#   'EA': 0.4166666666666667,
#   'PS': 0.16666666666666666},
#  ('Leve Baixa', 'Leve Alta', 'Alta', 'Leve Baixa'): {'EA': 0.4166666666666667,
#   'EB': 0.3611111111111111,
#   'PS': 0.1111111111111111,
#   'NS': 0.1111111111111111},
#  ('Baixa', 'Leve Alta', 'Leve Baixa', 'Baixa'): {'NS': 0.10526315789473684,
#   'EA': 0.42105263157894735,
#   'PS': 0.13157894736842105,
#   'EB': 0.34210526315789475},
#  ('Baixa', 'Leve Baixa', 'Alta', 'Leve Baixa'): {'EB': 0.4444444444444444,
#   'EA': 0.4444444444444444,
#   'PS': 0.1111111111111111},
#  ('Leve Alta', 'Baixa', 'Alta', 'Baixa'): {'EA': 0.5,
#   'NS': 0.125,
#   'PS': 0.25,
#   'EB': 0.125},
#  ('Leve Alta', 'Baixa', 'Alta', 'Leve Baixa'): {'EA': 0.2,
#   'NS': 0.6,
#   'PS': 0.2},
#  ('Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'): {'EA': 0.625, 'EB': 0.375},
#  ('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta'): {'EB': 0.14285714285714285,
#   'EA': 0.7142857142857143,
#   'NS': 0.14285714285714285},
#  ('Leve Alta', 'Alta', 'Baixa', 'Leve Alta'): {'NS': 0.16666666666666666,
#   'EB': 0.5,
#   'EA': 0.3333333333333333},
#  ('Leve Baixa', 'Alta', 'Leve Baixa', 'Leve Alta'): {'PS': 0.125,
#   'EA': 0.375,
#   'NS': 0.25,
#   'EB': 0.25},
#  ('Alta', 'Leve Baixa', 'Leve Alta', 'Alta'): {'EA': 0.4166666666666667,
#   'EB': 0.4166666666666667,
#   'NS': 0.16666666666666666},
#  ('Alta', 'Baixa', 'Leve Baixa', 'Alta'): {'EA': 0.3333333333333333,
#   'EB': 0.5,
#   'PS': 0.16666666666666666},
#  ('Alta', 'Leve Baixa', 'Alta', 'Leve Baixa'): {'NS': 0.1,
#   'EA': 0.5,
#   'PS': 0.2,
#   'EB': 0.2},
#  ('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'): {'EB': 0.625,
#   'EA': 0.25,
#   'PS': 0.125},
#  ('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'): {'EA': 0.6428571428571429,
#   'PS': 0.14285714285714285,
#   'NS': 0.07142857142857142,
#   'EB': 0.14285714285714285},
#  ('Alta', 'Baixa', 'Alta', 'Leve Baixa'): {'EA': 0.75, 'EB': 0.25},
#  ('Leve Alta', 'Baixa', 'Leve Alta', 'Alta'): {'EA': 0.6,
#   'EB': 0.26666666666666666,
#   'PS': 0.06666666666666667,
#   'NS': 0.06666666666666667},
#  ('Alta', 'Baixa', 'Baixa', 'Leve Baixa'): {'PS': 0.13333333333333333,
#   'EA': 0.5333333333333333,
#   'EB': 0.3333333333333333},
#  ('Leve Baixa', 'Leve Alta', 'Alta', 'Baixa'): {'NS': 0.3125,
#   'EB': 0.25,
#   'PS': 0.125,
#   'EA': 0.3125},
#  ('Alta', 'Baixa', 'Baixa', 'Leve Alta'): {'EA': 0.6, 'NS': 0.2, 'EB': 0.2},
#  ('Alta', 'Baixa', 'Leve Alta', 'Alta'): {'EA': 0.3333333333333333,
#   'NS': 0.1111111111111111,
#   'EB': 0.4444444444444444,
#   'PS': 0.1111111111111111},
#  ('Alta', 'Leve Alta', 'Baixa', 'Leve Alta'): {'EA': 0.32,
#   'EB': 0.24,
#   'NS': 0.24,
#   'PS': 0.2},
#  ('Leve Alta', 'Baixa', 'Alta', 'Leve Alta'): {'EA': 0.4,
#   'EB': 0.4,
#   'NS': 0.2},
#  ('Baixa', 'Leve Alta', 'Baixa', 'Alta'): {'EA': 0.5625,
#   'EB': 0.3125,
#   'NS': 0.0625,
#   'PS': 0.0625},
#  ('Leve Baixa', 'Alta', 'Baixa', 'Baixa'): {'EA': 0.9090909090909091,
#   'EB': 0.09090909090909091},
#  ('Leve Baixa', 'Alta', 'Baixa', 'Alta'): {'EA': 0.8333333333333334,
#   'EB': 0.16666666666666666},
#  ('Leve Baixa', 'Baixa', 'Alta', 'Baixa'): {'EB': 0.375, 'EA': 0.625},
#  ('Leve Baixa', 'Alta', 'Leve Baixa', 'Baixa'): {'EA': 0.5,
#   'NS': 0.3333333333333333,
#   'EB': 0.16666666666666666},
#  ('Alta', 'Leve Baixa', 'Alta', 'Baixa'): {'EA': 1.0}}

# %%
def filtrar_transicoes_por_limiar(matriz_transicao, limiar):
    """
    Filtra os estados atuais e seus alvos na matriz de transição que têm probabilidade acima do limiar.

    Parâmetros:
        matriz_transicao (dict): Matriz de transição representada como um dicionário.
        limiar (float): Limiar de probabilidade para filtrar as transições.

    Retorna:
        dict: Estados atuais e seus alvos que atendem ao critério.
    """
    transicoes_filtradas = {}
    
    for estado_atual, transicoes in matriz_transicao.items():
        for alvo, probabilidade in transicoes.items():
            if probabilidade > limiar:
                if estado_atual not in transicoes_filtradas:
                    transicoes_filtradas[estado_atual] = {}
                transicoes_filtradas[estado_atual][alvo] = probabilidade

    return transicoes_filtradas

# Exemplo de uso
limiar = 0.6  # Defina o limiar de probabilidade
transicoes_acima_limiar = filtrar_transicoes_por_limiar(matriz_transicao, limiar)

# Exibir resultados
for estado, alvos in transicoes_acima_limiar.items():
    for alvo, prob in alvos.items():
        print(f" Estado: {estado} | Alvo: {alvo} - Probabilidade: {prob:.2%}")
# Out:
#  Estado: ('Alta', 'Baixa', 'Leve Baixa', 'Baixa') | Alvo: EB - Probabilidade: 63.64%
#  Estado: ('Baixa', 'Leve Alta', 'Baixa', 'Baixa') | Alvo: EA - Probabilidade: 60.71%
#  Estado: ('Baixa', 'Leve Alta', 'Alta', 'Baixa') | Alvo: EA - Probabilidade: 70.59%
#  Estado: ('Baixa', 'Baixa', 'Alta', 'Baixa') | Alvo: EA - Probabilidade: 77.78%
#  Estado: ('Baixa', 'Alta', 'Alta', 'Leve Baixa') | Alvo: EA - Probabilidade: 68.18%
#  Estado: ('Baixa', 'Alta', 'Leve Alta', 'Baixa') | Alvo: EA - Probabilidade: 66.67%
#  Estado: ('Baixa', 'Alta', 'Baixa', 'Baixa') | Alvo: EA - Probabilidade: 72.73%
#  Estado: ('Baixa', 'Alta', 'Baixa', 'Alta') | Alvo: EA - Probabilidade: 100.00%
#  Estado: ('Baixa', 'Alta', 'Leve Baixa', 'Alta') | Alvo: EA - Probabilidade: 87.50%
#  Estado: ('Alta', 'Baixa', 'Alta', 'Leve Alta') | Alvo: EB - Probabilidade: 66.67%
#  Estado: ('Leve Alta', 'Alta', 'Baixa', 'Baixa') | Alvo: EA - Probabilidade: 61.54%
#  Estado: ('Alta', 'Baixa', 'Baixa', 'Alta') | Alvo: EA - Probabilidade: 65.22%
#  Estado: ('Alta', 'Baixa', 'Alta', 'Alta') | Alvo: EB - Probabilidade: 83.33%
#  Estado: ('Leve Alta', 'Baixa', 'Leve Alta', 'Baixa') | Alvo: EA - Probabilidade: 71.43%
#  Estado: ('Alta', 'Baixa', 'Leve Alta', 'Baixa') | Alvo: EA - Probabilidade: 70.00%
#  Estado: ('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa') | Alvo: EB - Probabilidade: 66.67%
#  Estado: ('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa') | Alvo: EA - Probabilidade: 66.67%
#  Estado: ('Baixa', 'Alta', 'Alta', 'Baixa') | Alvo: EA - Probabilidade: 91.67%
#  Estado: ('Baixa', 'Alta', 'Leve Baixa', 'Baixa') | Alvo: EA - Probabilidade: 66.67%
#  Estado: ('Baixa', 'Alta', 'Baixa', 'Leve Alta') | Alvo: EA - Probabilidade: 80.00%
#  Estado: ('Alta', 'Alta', 'Baixa', 'Alta') | Alvo: EA - Probabilidade: 68.18%
#  Estado: ('Baixa', 'Alta', 'Baixa', 'Leve Baixa') | Alvo: EA - Probabilidade: 100.00%
#  Estado: ('Alta', 'Leve Baixa', 'Baixa', 'Alta') | Alvo: EA - Probabilidade: 61.54%
#  Estado: ('Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa') | Alvo: EA - Probabilidade: 62.50%
#  Estado: ('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta') | Alvo: EA - Probabilidade: 71.43%
#  Estado: ('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa') | Alvo: EB - Probabilidade: 62.50%
#  Estado: ('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta') | Alvo: EA - Probabilidade: 64.29%
#  Estado: ('Alta', 'Baixa', 'Alta', 'Leve Baixa') | Alvo: EA - Probabilidade: 75.00%
#  Estado: ('Leve Baixa', 'Alta', 'Baixa', 'Baixa') | Alvo: EA - Probabilidade: 90.91%
#  Estado: ('Leve Baixa', 'Alta', 'Baixa', 'Alta') | Alvo: EA - Probabilidade: 83.33%
#  Estado: ('Leve Baixa', 'Baixa', 'Alta', 'Baixa') | Alvo: EA - Probabilidade: 62.50%
#  Estado: ('Alta', 'Leve Baixa', 'Alta', 'Baixa') | Alvo: EA - Probabilidade: 100.00%

# %%
sum_acima_limir = 0
# Exibir os estados mais frequentes
print("Estados mais frequentes com filtro:")
for estado, frequencia in estado_frequencias.most_common(1000):
    if estado in list(transicoes_acima_limiar.keys()):
        print(f"{estado}: {frequencia}")
        sum_acima_limir += frequencia

print(sum_acima_limir)
# Out:
# Estados mais frequentes com filtro:
# ('Baixa', 'Baixa', 'Alta', 'Baixa'): 36
# ('Baixa', 'Leve Alta', 'Baixa', 'Baixa'): 28
# ('Leve Alta', 'Alta', 'Baixa', 'Baixa'): 26
# ('Alta', 'Baixa', 'Baixa', 'Alta'): 23
# ('Baixa', 'Alta', 'Alta', 'Leve Baixa'): 22
# ('Alta', 'Alta', 'Baixa', 'Alta'): 22
# ('Baixa', 'Leve Alta', 'Alta', 'Baixa'): 17
# ('Baixa', 'Alta', 'Leve Alta', 'Baixa'): 15
# ('Leve Baixa', 'Alta', 'Leve Baixa', 'Alta'): 14
# ('Alta', 'Leve Baixa', 'Baixa', 'Alta'): 13
# ('Baixa', 'Alta', 'Alta', 'Baixa'): 12
# ('Alta', 'Baixa', 'Leve Baixa', 'Baixa'): 11
# ('Baixa', 'Alta', 'Baixa', 'Baixa'): 11
# ('Leve Baixa', 'Alta', 'Baixa', 'Baixa'): 11
# ('Alta', 'Baixa', 'Leve Alta', 'Baixa'): 10
# ('Leve Baixa', 'Baixa', 'Alta', 'Leve Baixa'): 9
# ('Baixa', 'Alta', 'Leve Baixa', 'Baixa'): 9
# ('Baixa', 'Alta', 'Leve Baixa', 'Alta'): 8
# ('Baixa', 'Alta', 'Leve Baixa', 'Leve Baixa'): 8
# ('Baixa', 'Alta', 'Leve Alta', 'Leve Baixa'): 8
# ('Leve Baixa', 'Baixa', 'Alta', 'Baixa'): 8
# ('Leve Alta', 'Baixa', 'Leve Alta', 'Baixa'): 7
# ('Leve Baixa', 'Leve Alta', 'Baixa', 'Alta'): 7
# ('Alta', 'Baixa', 'Alta', 'Leve Alta'): 6
# ('Alta', 'Baixa', 'Alta', 'Alta'): 6
# ('Alta', 'Baixa', 'Leve Alta', 'Leve Baixa'): 6
# ('Leve Baixa', 'Alta', 'Baixa', 'Alta'): 6
# ('Baixa', 'Alta', 'Baixa', 'Leve Alta'): 5
# ('Alta', 'Leve Baixa', 'Alta', 'Baixa'): 5
# ('Alta', 'Baixa', 'Alta', 'Leve Baixa'): 4
# ('Baixa', 'Alta', 'Baixa', 'Alta'): 2
# ('Baixa', 'Alta', 'Baixa', 'Leve Baixa'): 1
# 376

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plotar_matriz_transicao_heatmap(matriz_transicao, titulo="Matriz de Transição com Alvos", largura=20, altura=15):
    """
    Plota um heatmap com a porcentagem de cada transição na matriz de transição com alvos.

    Parâmetros:
        matriz_transicao (dict): Matriz de transição representada como um dicionário.
        titulo (str): Título do gráfico.
        largura (int): Largura da figura.
        altura (int): Altura da figura.
    """
    # Transformar a matriz de transição em DataFrame para facilitar o plot
    data = []
    estados_origem = []
    estados_destino = []

    for estado_atual, transicoes in matriz_transicao.items():
        for alvo, probabilidade in transicoes.items():
            estados_origem.append(estado_atual)
            estados_destino.append(alvo)
            data.append(probabilidade)

    # Criar DataFrame
    df_transicao = pd.DataFrame({
        "Origem": estados_origem,
        "Destino": estados_destino,
        "Probabilidade": data
    })

    # Pivotar o DataFrame para formato adequado ao heatmap
    heatmap_data = df_transicao.pivot(
        index="Origem", 
        columns="Destino", 
        values="Probabilidade"
    ).fillna(0)

    # Plotar o heatmap
    plt.figure(figsize=(largura, altura))
    sns.heatmap(
        heatmap_data,
        annot=True,  # Exibir os valores
        fmt=".2%",   # Mostrar porcentagens
        cmap="Blues",  # Escolher esquema de cores
        cbar_kws={"label": "Probabilidade (%)"}  # Legenda do colorbar
    )

    # Configurações do gráfico
    plt.title(titulo, fontsize=16)
    plt.xlabel("Alvo (Próximos 2 Estados)", fontsize=12)
    plt.ylabel("Estado Atual (Últimos 3 Estados)", fontsize=12)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.yticks(fontsize=10)

    # Ajustar layout para evitar sobreposição
    plt.tight_layout()

    # Salvar a imagem como arquivo, se necessário
    plt.savefig("matriz_transicao_alvo_heatmap.png", dpi=300)
    print("Imagem salva como 'matriz_transicao_alvo_heatmap.png'")

    # Exibir o gráfico
    plt.show()

# %%
# plotar_matriz_transicao_heatmap(
#     matriz_transicao, 
#     titulo="Heatmap da Matriz de Transição",
#     largura=50,  # Aumentar a largura para visualizar melhor os números
#     altura=50    # Ajustar a altura conforme necessário
# )

# %%
def realizar_backtest(matriz_transicao, tuplas_teste, transicoes_acima_limiar = None):
    """
    Realiza um backtest com base na matriz de transição e tuplas de teste.

    Parâmetros:
        matriz_transicao (dict): Matriz de transição baseada nas tuplas de treinamento.
        tuplas_teste (list): Lista de tuplas com 3 estados consecutivos para teste.

    Retorna:
        dict: Métricas do backtest, como precisão.
    """
    acertos = 0
    total_transicoes = 0

    for i in range(len(tuplas_teste)):
        estado_atual = tuplas_teste[i][0]
        estado_real = tuplas_teste[i][1]

        if transicoes_acima_limiar and estado_atual not in list(transicoes_acima_limiar.keys()):
            continue
        
        if estado_atual in matriz_transicao:
            transicoes_proximas = matriz_transicao[estado_atual]
            if transicoes_proximas:
                estado_previsto = max(transicoes_proximas, key=transicoes_proximas.get)  # Estado com maior probabilidade
                if estado_previsto == estado_real:
                    acertos += 1

        total_transicoes += 1
        
    precisao = acertos / total_transicoes if total_transicoes > 0 else 0
    return {
        "acertos": acertos,
        "total": total_transicoes,
        "precisao": precisao
    }

# Realizar o backtest com a matriz de transição e tuplas de teste
resultados_backtest = realizar_backtest(matriz_transicao, tuplas_teste, transicoes_acima_limiar)
print("Resultados do Backtest:", resultados_backtest)
# Out:
# Resultados do Backtest: {'acertos': 21, 'total': 47, 'precisao': 0.44680851063829785}

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

def realizar_backtest_com_matriz_confusao(matriz_transicao, tuplas_teste, transicoes_acima_limiar=None):
    """
    Realiza um backtest com base na matriz de transição e tuplas de teste e calcula a matriz de confusão.

    Parâmetros:
        matriz_transicao (dict): Matriz de transição baseada nas tuplas de treinamento.
        tuplas_teste (list): Lista de tuplas com 3 estados consecutivos para teste.
        transicoes_acima_limiar (dict): Transições filtradas por limiar (opcional).

    Retorna:
        dict: Métricas do backtest, incluindo matriz de confusão e relatório de classificação.
    """
    y_true = []
    y_pred = []

    for i in range(len(tuplas_teste)):
        estado_atual = tuplas_teste[i][0]
        estado_real = tuplas_teste[i][1]

        if transicoes_acima_limiar and estado_atual not in list(transicoes_acima_limiar.keys()):
            continue

        if estado_atual in matriz_transicao:
            transicoes_proximas = matriz_transicao[estado_atual]
            if transicoes_proximas:
                estado_previsto = max(transicoes_proximas, key=transicoes_proximas.get)  # Estado com maior probabilidade
                y_pred.append(estado_previsto)
                y_true.append(estado_real)
            else:
                y_pred.append(None)  # Caso não haja transição válida
                y_true.append(estado_real)
        else:
            y_pred.append(None)  # Caso o estado atual não esteja na matriz
            y_true.append(estado_real)

    # Remover previsões e valores reais inválidos (None)
    y_true = [yt for yt, yp in zip(y_true, y_pred) if yt is not None and yp is not None]
    y_pred = [yp for yt, yp in zip(y_true, y_pred) if yt is not None and yp is not None]

    # Gerar matriz de confusão e relatório de classificação
    labels = list(set(y_true + y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    report = classification_report(y_true, y_pred, target_names=[str(label) for label in labels])

    acertos = np.trace(cm)  # Soma da diagonal principal
    total = np.sum(cm)

    return {
        "acertos": acertos,
        "total": total,
        "precisao": acertos / total if total > 0 else 0,
        "matriz_confusao": cm,
        "rotulos": labels,
        "relatorio": report
    }

# Realizar o backtest com matriz de confusão
resultados_backtest = realizar_backtest_com_matriz_confusao(matriz_transicao, tuplas_teste, transicoes_acima_limiar)

# Exibir resultados
print("Resultados do Backtest:")
print(f"Precisão: {resultados_backtest['precisao']:.2%}")
print("Matriz de Confusão:")
print(resultados_backtest['matriz_confusao'])
print("\nRelatório de Classificação:")
print(resultados_backtest['relatorio'])
# Out:
# Resultados do Backtest:
# Precisão: 44.68%
# Matriz de Confusão:
# [[ 0  3  0  9]
#  [ 0  3  0  9]
#  [ 0  1  0  4]
#  [ 0  0  0 18]]
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#           PS       0.45      1.00      0.62        18
#           EB       0.43      0.25      0.32        12
#           NS       0.00      0.00      0.00         5
#           EA       0.00      0.00      0.00        12
#
#     accuracy                           0.45        47
#    macro avg       0.22      0.31      0.23        47
# weighted avg       0.28      0.45      0.32        47
# /home/jonatas/Documents/fxopen/venv/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jonatas/Documents/fxopen/venv/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jonatas/Documents/fxopen/venv/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
