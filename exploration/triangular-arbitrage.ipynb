# %%
import sys
sys.path.append("../")

# %%
import os
from dotenv import load_dotenv 
load_dotenv("../constants/.env")
# Out:
# True

# %%
api_key = os.environ.get('BINANCE_KEY')
secret_key = os.environ.get('BINANCE_SECRET')

# %%
from binance.client import Client
import pandas as pd

# %%
import time


client = Client(api_key, secret_key)

# %%
from collections import defaultdict

# %%
import itertools
from itertools import permutations

# %%
import math

def check_liquidity(symbol):
    order_book = client.get_order_book(symbol=symbol)
    best_ask_price = float(order_book['asks'][0][0])  # Melhor preço de venda
    total_liquidity = sum([float(ask[1]) for ask in order_book['asks']])
    return total_liquidity
    
def cache_exchange_info():
    """Obtém e armazena localmente as informações de troca."""
    try:
        exchange_info = client.get_exchange_info()
        return exchange_info
    except Exception as e:
        print(f"Erro ao buscar informações da exchange: {e}")
        return None

# Chame esta função uma vez no início
exchange_info = cache_exchange_info()


def get_lot_size(symbol):
    """Obtém os detalhes do filtro LOT_SIZE para o par a partir do cache."""

    if not exchange_info:
        print("Informações da exchange não estão disponíveis.")
        return None
    try:
        for s in exchange_info['symbols']:
            if s['symbol'] == symbol:
                for f in s['filters']:
                    if f['filterType'] == 'LOT_SIZE':
                        return {
                            "minQty": float(f['minQty']),
                            "maxQty": float(f['maxQty']),
                            "stepSize": float(f['stepSize'])
                        }
    except Exception as e:
        print(f"Erro ao obter LOT_SIZE para {symbol}: {e}")
    return None
    
def execute_order(order_type, symbol, quantity):
    """
    Executa uma ordem de mercado.
    Args:
        order_type (str): 'BUY' ou 'SELL'.
        symbol (str): Par de negociação (ex.: 'BTCUSDT').
        quantity (float): Quantidade do ativo a negociar.
    Returns:
        dict: Detalhes da ordem executada ou None em caso de erro.
    """
    try:
        if order_type == 'BUY':
            order = client.order_market_buy(symbol=symbol, quantity=quantity)
        elif order_type == 'SELL':
            order = client.order_market_sell(symbol=symbol, quantity=quantity)
        else:
            raise ValueError("Tipo de ordem inválido.")
        print(f"Ordem executada: {order}")
        return order
    except Exception as e:
        print(f"Erro ao executar ordem {order_type} para {symbol}: {e}")
        return None


def get_balance(asset):
    """Obtém o saldo atual de um ativo."""
    try:
        account_info = client.get_account()
        balances = {item['asset']: float(item['free']) for item in account_info['balances']}
        return balances.get(asset, 0.0)
    except Exception as e:
        print(f"Erro ao obter saldo de {asset}: {e}")
        return 0.0
        
def adjust_quantity(quantity, step_size):
    """
    Ajusta a quantidade para o múltiplo mais próximo permitido pelo stepSize.
    
    Args:
        quantity (float): Quantidade desejada.
        step_size (float): Incremento permitido pelo LOT_SIZE.

    Returns:
        float: Quantidade ajustada.
    """
    return math.floor(quantity / step_size) * step_size

def fetch_prices(symbols):
    """Obtém os preços dos pares fornecidos."""
    prices = {}
    for symbol in symbols:
        try:
            ticker = client.get_ticker(symbol=symbol)
            prices[symbol] = float(ticker['lastPrice'])
        except Exception as e:
            print(f"Erro ao buscar preço para {symbol}: {e}")
            prices[symbol] = None
    return prices

def triangular_arbitrage(brl_balance, steps_size, pair_prices, fee_rate=0.002):
    """Calcula lucro potencial na arbitragem triangular, ajustando pelas taxas."""

    # Etapa 1: Converter BRL para o ativo do primeiro par
    first_conversion = brl_balance / pair_prices[0]
    first_conversion *= (1 - fee_rate)
    first_conversion = adjust_quantity(first_conversion, steps_size[0])

    # Etapa 2: Converter ativo do segundo par
    second_conversion = first_conversion / pair_prices[1]
    second_conversion *= (1 - fee_rate)
    second_conversion = adjust_quantity(second_conversion, steps_size[1])

    # Etapa 3: Converter ativo do terceiro par de volta para BRL
    final_brl = second_conversion * pair_prices[2]
    final_brl *= (1 - fee_rate)
    final_brl = adjust_quantity(final_brl, steps_size[2])

    # Lucro estimado
    profit = final_brl - brl_balance
    return profit, final_brl, first_conversion, second_conversion, final_brl
        
# Lista de pares de arbitragem
arbitrage_opportunities = [
    ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'),
    ('USDTBRL', 'POLUSDT', 'POLBRL'),
    ('USDTBRL', 'ENAUSDT', 'ENABRL'),
    ('USDTBRL', 'SOLUSDT', 'SOLBRL'),
    ('USDTBRL', 'LINKUSDT', 'LINKBRL'),
    ('USDTBRL', 'XRPUSDT', 'XRPBRL'),
    ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'),
    ('USDTBRL', 'NEARUSDT', 'NEARBRL'),
    ('USDTBRL', 'ADAUSDT', 'ADABRL'),
    ('USDTBRL', 'CATIUSDT', 'CATIBRL'),
    ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'),
    ('USDTBRL', 'NOTUSDT', 'NOTBRL'),
    ('USDTBRL', 'BNBUSDT', 'BNBBRL'),
    ('USDTBRL', 'FETUSDT', 'FETBRL'),
    ('USDTBRL', 'DOTUSDT', 'DOTBRL'),
    ('USDTBRL', 'SUIUSDT', 'SUIBRL'),
    # ('USDTBRL', 'GALAUSDT', 'GALABRL'),
    ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'),
    ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'),
    ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'),
]

# Saldo inicial em BRL
brl_balance = 500

while True:
    # Itera sobre cada combinação de pares na lista
    for opportunity in arbitrage_opportunities:
        try:
            

            # Obter lot sizes para cada par
            lot_size1 = get_lot_size(opportunity[0])
            lot_size2 = get_lot_size(opportunity[1])
            lot_size3 = get_lot_size(opportunity[2])

            if not lot_size1 or not lot_size2 or not lot_size3:
                print(f"Erro: Não foi possível obter lot sizes para os pares {opportunity}.")
                break
        
            # Extrair step sizes
            steps_size = []
            steps_size.append(lot_size1['stepSize'])
            steps_size.append(lot_size2['stepSize'])
            steps_size.append(lot_size3['stepSize'])

            # Obtém os preços dos três pares
            prices = fetch_prices(opportunity)

                
            if all(prices.values()):  # Certifica-se de que todos os preços foram obtidos
                
                pair_prices = []
                pair_prices.append(prices[opportunity[0]])
                pair_prices.append(prices[opportunity[1]])
                pair_prices.append(prices[opportunity[2]])

                # Calcula o lucro potencial ajustado pelas taxas
                profit, final_usdt, first_conversion, second_conversion, final_brl = triangular_arbitrage(
                    brl_balance, steps_size, pair_prices
                )

                # print(f"liquidity: {check_liquidity(opportunity[0])}, {check_liquidity(opportunity[1])}, {check_liquidity(opportunity[2])}")

                
                if profit > 1:  # Se há lucro potencial
                    print(f"\nPreços atuais para {opportunity}: {prices}")
                    print(f"Lucro: ${profit:.2f}")
                    print(f"Saldo final estimado (após taxas): ${final_usdt:.2f}")
                    # Adicione a lógica para executar as ordens, se necessário.
                else:
                    print(f"Sem oportunidades para {opportunity}. Lucro: ${profit:.2f}")

            else:
                print(f"Erro ao obter preços para os pares {opportunity}.")
        except Exception as e:
            print(f"Erro ao processar a arbitragem para {opportunity}: {e}")

    # Espera antes de buscar preços novamente
    time.sleep(1)
# Out:
# liquidity: 838171.2, 40682.27, 2205.15
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-3.80
# liquidity: 938791.6, 628411.4, 50032.6
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-3.80
# liquidity: 938791.6, 606309.45, 29915.89
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $0.20
# liquidity: 928786.2, 17829.402, 551.8
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-4.30
# liquidity: 940603.1, 126389.88, 1049.52
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-3.66
# liquidity: 941570.0, 1192259.0, 86957.0
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-15.00
# liquidity: 942523.6, 4219068.0, 220375.0
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-6.00
# liquidity: 941735.5, 69987.9, 11563.5
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.90
# liquidity: 941788.7, 1496688.5, 74564.0
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-2.70
# liquidity: 941770.5, 1239563.2, 7264.1
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-3.30
# liquidity: 941724.3, 88983819323.0, 1669074120.0
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-4.00
# liquidity: 941714.4, 41898767.0, 1074331.0
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-8.00
# liquidity: 941714.4, 1713.444, 86.6549
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-5.66
# liquidity: 941688.6, 674313.9, 28600.9
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-5.50
# liquidity: 941523.2, 75321.27, 12315.95
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-4.61
# liquidity: 930523.2, 104822.2, 4627.7
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-5.20
# liquidity: 941522.0, 302955742629.0, 15996255250.0
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-2.00
# liquidity: 930135.1, 63567323.0, 22544581.0
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-3.00
# liquidity: 940911.2, 413825.6, 13854.0
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-4.80
# liquidity: 954136.5, 38627.52, 2402.82
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-3.53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 187
#     182 # Calcula o lucro potencial ajustado pelas taxas
#     183 profit, final_usdt, first_conversion, second_conversion, final_brl = triangular_arbitrage(
#     184     brl_balance, steps_size, pair_prices
#     185 )
# --> 187 print(f"liquidity: {check_liquidity(opportunity[0])}, {check_liquidity(opportunity[1])}, {check_liquidity(opportunity[2])}")
#     190 if profit > 1:  # Se há lucro potencial
#     191     print(f"\nPreços atuais para {opportunity}: {prices}")
#
# Cell In[8], line 4, in check_liquidity(symbol)
#       3 def check_liquidity(symbol):
# ----> 4     order_book = client.get_order_book(symbol=symbol)
#       5     best_ask_price = float(order_book['asks'][0][0])  # Melhor preço de venda
#       6     total_liquidity = sum([float(ask[1]) for ask in order_book['asks']])
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/client.py:693, in Client.get_order_book(self, **params)
#     658 def get_order_book(self, **params) -> Dict:
#     659     """Get the Order Book for the market
#     660
#     661     https://binance-docs.github.io/apidocs/spot/en/#order-book
#    (...)
#     691
#     692     """
# --> 693     return self._get('depth', data=params, version=self.PRIVATE_API_VERSION)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/client.py:415, in Client._get(self, path, signed, version, **kwargs)
#     414 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 415     return self._request_api('get', path, signed, version, **kwargs)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/client.py:378, in Client._request_api(self, method, path, signed, version, **kwargs)
#     374 def _request_api(
#     375     self, method, path: str, signed: bool = False, version=BaseClient.PUBLIC_API_VERSION, **kwargs
#     376 ):
#     377     uri = self._create_api_uri(path, signed, version)
# --> 378     return self._request(method, uri, signed, **kwargs)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/binance/client.py:358, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     354 def _request(self, method, uri: str, signed: bool, force_params: bool = False, **kwargs):
#     356     kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
# --> 358     self.response = getattr(self.session, method)(uri, **kwargs)
#     359     return self._handle_response(self.response)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib64/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /usr/lib64/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/lib64/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/lib64/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /usr/lib64/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib64/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import math
import decimal 

def fetch_prices_with_best(symbols):
    """Obtém os melhores preços de compra (bid) e venda (ask) para os pares fornecidos."""
    prices = {}
    for symbol in symbols:
        try:
            best_bid, best_ask = fetch_best_prices(symbol)
            prices[symbol] = {'bid': best_bid, 'ask': best_ask}
        except Exception as e:
            print(f"Erro ao buscar preços para {symbol}: {e}")
            prices[symbol] = None
    return prices
    
def cache_exchange_info():
    """Obtém e armazena localmente as informações de troca."""
    try:
        exchange_info = client.get_exchange_info()
        return exchange_info
    except Exception as e:
        print(f"Erro ao buscar informações da exchange: {e}")
        return None

# Chame esta função uma vez no início
exchange_info = cache_exchange_info()


def get_lot_size(symbol):
    """Obtém os detalhes do filtro LOT_SIZE para o par a partir do cache."""

    if not exchange_info:
        print("Informações da exchange não estão disponíveis.")
        return None
    try:
        for s in exchange_info['symbols']:
            if s['symbol'] == symbol:
                for f in s['filters']:
                    if f['filterType'] == 'LOT_SIZE':
                        return {
                            "minQty": float(f['minQty']),
                            "maxQty": float(f['maxQty']),
                            "stepSize": float(f['stepSize'])
                        }
    except Exception as e:
        print(f"Erro ao obter LOT_SIZE para {symbol}: {e}")
    return None
    
def execute_order(order_type, symbol, quantity):
    """
    Executa uma ordem de mercado.
    Args:
        order_type (str): 'BUY' ou 'SELL'.
        symbol (str): Par de negociação (ex.: 'BTCUSDT').
        quantity (float): Quantidade do ativo a negociar.
    Returns:
        dict: Detalhes da ordem executada ou None em caso de erro.
    """
    try:
        if order_type == 'BUY':
            order = client.order_market_buy(symbol=symbol, quantity=quantity)
        elif order_type == 'SELL':
            order = client.order_market_sell(symbol=symbol, quantity=quantity)
        else:
            raise ValueError("Tipo de ordem inválido.")
        print(f"Ordem executada: {order}")
        return order
    except Exception as e:
        print(f"Erro ao executar ordem {order_type} para {symbol}: {e}")
        return None


def get_balance(asset):
    """Obtém o saldo atual de um ativo."""
    try:
        account_info = client.get_account()
        balances = {item['asset']: float(item['free']) for item in account_info['balances']}
        return balances.get(asset, 0.0)
    except Exception as e:
        print(f"Erro ao obter saldo de {asset}: {e}")
        return 0.0
        
def adjust_quantity(quantity, step_size):
    """
    Ajusta a quantidade para o múltiplo mais próximo permitido pelo stepSize,
    respeitando a precisão do step_size.

    Args:
        quantity (float): Quantidade desejada.
        step_size (float): Incremento permitido pelo LOT_SIZE.

    Returns:
        float: Quantidade ajustada.
    """
    # Determinar o número de casas decimais com base no step_size
    precision = abs(decimal.Decimal(str(step_size)).as_tuple().exponent)
    
    # Ajustar a quantidade para o múltiplo permitido
    adjusted_quantity = math.floor(quantity / step_size) * step_size

    # Retornar o valor ajustado com a precisão correta
    return round(adjusted_quantity, precision)

def fetch_best_prices(symbol):
    """Obtém os melhores preços de compra (bid) e venda (ask) do livro de ordens."""
    try:
        order_book = client.get_order_book(symbol=symbol)
        best_bid = float(order_book['bids'][0][0])  # Melhor preço de compra
        best_ask = float(order_book['asks'][0][0])  # Melhor preço de venda
        return best_bid, best_ask
    except Exception as e:
        print(f"Erro ao obter preços para {symbol}: {e}")
        return None, None
        
def fetch_prices(symbols):
    """Obtém os preços dos pares fornecidos."""
    prices = {}
    for symbol in symbols:
        try:
            ticker = client.get_ticker(symbol=symbol)
            prices[symbol] = float(ticker['lastPrice'])
        except Exception as e:
            print(f"Erro ao buscar preço para {symbol}: {e}")
            prices[symbol] = None
    return prices

def triangular_arbitrage(brl_balance, steps_size, pair_prices, fee_rate=0.001):
    """Calcula lucro potencial na arbitragem triangular, ajustando pelas taxas."""

    # Etapa 1: Converter BRL para o ativo do primeiro par
    first_conversion = brl_balance / pair_prices[0]
    first_conversion *= (1 - fee_rate)
    # first_conversion = adjust_quantity(first_conversion, steps_size[0])

    # Etapa 2: Converter ativo do segundo par
    second_conversion = first_conversion / pair_prices[1]
    second_conversion *= (1 - fee_rate)
    # second_conversion = adjust_quantity(second_conversion, steps_size[1])

    # Etapa 3: Converter ativo do terceiro par de volta para BRL
    final_brl = second_conversion * pair_prices[2]
    final_brl *= (1 - fee_rate)
    # final_brl = adjust_quantity(final_brl, steps_size[2])

    # Lucro estimado
    profit = final_brl - brl_balance
    return profit, final_brl
    
def triangular_arbitrage_best_prices(brl_balance, steps_size, pair_prices, fee_rate=0.001):
    """
    Calcula lucro potencial na arbitragem triangular usando bid/ask para preços.
    Args:
        brl_balance (float): Saldo inicial em BRL.
        steps_size (list): Step sizes para os pares.
        pair_prices (list): Lista de dicionários com preços bid/ask para os pares.
        fee_rate (float): Taxa aplicada em cada operação.

    Returns:
        tuple: Lucro estimado e saldo final.
    """
    # Etapa 1: Comprar o ativo do primeiro par (USDT com BRL)
    first_conversion = brl_balance / pair_prices[0]['ask']  # Compra (usa ask)
    first_conversion *= (1 - fee_rate)
    first_conversion = adjust_quantity(first_conversion, steps_size[0])

    # Etapa 2: Comprar o ativo do segundo par
    second_conversion = first_conversion / pair_prices[1]['ask']  # Compra (usa ask)
    second_conversion *= (1 - fee_rate)
    second_conversion = adjust_quantity(second_conversion, steps_size[1])

    # Etapa 3: Vender o ativo do terceiro par para BRL
    final_brl = second_conversion * pair_prices[2]['bid']  # Venda (usa bid)
    final_brl *= (1 - fee_rate)
    final_brl = adjust_quantity(final_brl, steps_size[2])

    # Lucro estimado
    profit = final_brl - brl_balance
    return profit, final_brl


# Lista de pares de arbitragem
arbitrage_opportunities = [
    ('USDTBRL', 'POLUSDT', 'POLBRL'),
    ('USDTBRL', 'SOLUSDT', 'SOLBRL'),
    ('USDTBRL', 'LINKUSDT', 'LINKBRL'),
    ('USDTBRL', 'XRPUSDT', 'XRPBRL'),
    ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'),
    ('USDTBRL', 'NEARUSDT', 'NEARBRL'),
    ('USDTBRL', 'ADAUSDT', 'ADABRL'),
    ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'),
    ('USDTBRL', 'BNBUSDT', 'BNBBRL'),
    ('USDTBRL', 'DOTUSDT', 'DOTBRL'),
    ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'),
    ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'),
    ('USDTBRL', 'ENAUSDT', 'ENABRL'),
    ('USDTBRL', 'CATIUSDT', 'CATIBRL'),
    ('USDTBRL', 'NOTUSDT', 'NOTBRL'),
    ('USDTBRL', 'SUIUSDT', 'SUIBRL'),
    ('USDTBRL', 'FETUSDT', 'FETBRL'),
    ############## ('USDTBRL', 'GALAUSDT', 'GALABRL'),
    ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'),
    ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'),
]


# Saldo inicial em BRL
brl_balance = 50

while True:
    # Itera sobre cada combinação de pares na lista
    for opportunity in arbitrage_opportunities:
        try:
            
            # Obter lot sizes para cada par
            lot_size1 = get_lot_size(opportunity[0])
            lot_size2 = get_lot_size(opportunity[1])
            lot_size3 = get_lot_size(opportunity[2])

            if not lot_size1 or not lot_size2 or not lot_size3:
                print(f"Erro: Não foi possível obter lot sizes para os pares {opportunity}.")
                break
        
            # Extrair step sizes
            steps_size = []
            steps_size.append(lot_size1['stepSize'])
            steps_size.append(lot_size2['stepSize'])
            steps_size.append(lot_size3['stepSize'])

            # Obter preços bid/ask para os pares
            prices = fetch_prices_with_best(opportunity)
            # prices = fetch_prices(opportunity)
            
            if all(prices.values()):  # Certifica-se de que todos os preços foram obtidos
                pair_prices = [
                    prices[opportunity[0]],
                    prices[opportunity[1]],
                    prices[opportunity[2]]
                ]
        
                # Calcula o lucro potencial ajustado pelas taxas
                # profit, final_usdt = triangular_arbitrage(
                #     brl_balance, steps_size, pair_prices
                # )

                profit, final_usdt = triangular_arbitrage_best_prices(
                    brl_balance, steps_size, pair_prices
                )

                
                if profit > 0:  # Se há lucro potencial
                    print(f"Lucro: ${profit:.2f}")
                    print(f"Saldo final estimado (após taxas): ${final_usdt:.2f}")

                    # Verifica saldo inicial
                    initial_asset = 'BRL'
                    initial_balance = get_balance(initial_asset)
                    print(f"Esse é o saldo total e o valor investido de BRL: {initial_balance} e {brl_balance}")
                    if initial_balance >= brl_balance-0.5:
                        # Etapa 1: Converter USDT para o ativo do primeiro par
                        symbol1 = opportunity[0]
                        first_conversion_quantity = brl_balance / pair_prices[0]
                        print(f"Esse é o valor convertido de BRL para USDT: {first_conversion_quantity}")
                        first_conversion_quantity = adjust_quantity(first_conversion_quantity, steps_size[0])
                        print(f"Esse é a quantidade USDT atualizado para compra: {first_conversion_quantity}")
                        
                        print("Comprando primeiro ativo.....")
                        execute_order('BUY', symbol1, first_conversion_quantity)
                        print("Comprado!!!!!")
                        
                        print(" ")
                        # print("Descansa meio segundo apos primeira compra.....................")
                        # time.sleep(0.5)
                        print(" ")
                        
                        # Etapa 2: Converter ativo do segundo par
                        second_asset = 'USDT'
                        second_balance = get_balance(second_asset)
                        print(f"Esse é o valor atualizado de USDT: {second_balance}")
                        if second_balance >= first_conversion_quantity-0.5:
                            symbol2 = opportunity[1]
                            second_quantity = second_balance/pair_prices[1]
                            print(f"Esse é a quantidade de {symbol2} que sera comprado: {second_quantity}")
                            second_quantity_adjusted = adjust_quantity(second_quantity*(1-0.001), steps_size[1])
                            print(f"Esse é a quantidade ajustada de {symbol2} que sera comprado: {second_quantity_adjusted}")
                            
                            print("Comprando segundo ativo.....")
                            execute_order('BUY', symbol2, second_quantity_adjusted)
                            print("Comprado!!!!!")
                            
                            print(" ")
                            # print("Descansa meio segundo apos segunda compra.....................")
                            # time.sleep(0.5)
                            print(" ")
                            
                            # Etapa 3: Converter ativo do terceiro par para USDT
                            third_asset = symbol2[:-4]
                            third_balance = get_balance(third_asset)
                            print(f"Esse é a quantidade de {third_asset} que tem no saldo: {third_balance}")
                            if third_balance > 0:
                                symbol3 = opportunity[2]
                                third_balance = adjust_quantity(third_balance, steps_size[2])
                                print(f"Esse é a quantidade {third_balance} comprado para: {symbol3}")

                                print("Comprando terceiro ativo.....")
                                execute_order('SELL', symbol3, third_balance)
                                print("Comprado!!!!")

                                print(" ")
                                print(f"Arbitragem completa para {opportunity}.")

                                break
                            else:
                                print(f"Saldo insuficiente para a etapa final: {third_asset}")
                                break

                        else:
                            print(f"Saldo insuficiente para o segundo ativo: {second_asset}")
                            break
                    else:
                        print("Saldo inicial insuficiente para começar a arbitragem.")
                        break
                
                else:
                    print(f"Sem oportunidades para {opportunity}. Lucro: ${profit:.2f}")

            else:
                print(f"Erro ao obter preços para os pares {opportunity}.")
        except Exception as e:
            print(f"Erro ao processar a arbitragem para {opportunity}: {e}")
    
    else:
        # Espera antes de buscar preços novamente
        time.sleep(1)
        # Este bloco else será executado se nenhum break for acionado no loop for
        continue

    # Se o break for acionado no loop for, ele sai do loop while
    break
# Out:
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.19
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.72
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.50
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.14
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.87
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.05
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.16
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.50
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.13
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.87
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.05
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.40
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.13
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.69
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.50
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.18
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.86
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.02
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.64
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.12
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.69
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.15
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.85
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.98
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.67
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.10
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.15
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.74
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.50
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.14
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.85
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.02
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.17
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.78
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.60
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.15
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.79
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.02
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.15
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.74
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.60
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.20
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.88
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.56
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.25
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.86
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.80
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.22
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.21
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.63
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.20
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.26
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.81
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.80
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.20
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.19
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.13
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.75
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.10
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.27
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.81
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.18
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.18
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.58
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.64
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.10
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.50
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.28
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.87
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.20
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.16
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.66
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.58
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.10
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.19
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.71
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.58
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.33
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.80
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.22
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.74
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.76
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.66
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.40
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.37
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.11
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.22
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.74
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.76
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.56
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.40
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.36
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.06
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.22
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.76
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.69
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.40
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.33
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.06
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.22
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.72
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.76
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.63
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.40
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.32
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.19
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.71
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.69
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.69
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.40
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.26
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.06
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.13
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.71
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.63
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.75
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.20
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.21
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.99
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.13
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.20
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.22
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.03
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.90
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.10
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.66
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.54
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.19
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.01
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.80
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.10
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.63
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.20
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.50
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.17
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.95
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.80
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.09
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.11
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.64
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.20
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.50
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.16
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.91
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.09
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.52
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.53
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.16
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.92
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.08
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.07
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.59
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.15
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.02
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.10
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.07
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.59
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.14
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.02
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.70
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.07
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-1.04
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.23
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.71
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.04
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.82
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.50
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.07
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.11
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.71
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.05
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.79
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.03
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-1.11
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.71
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.03
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.05
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.98
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.72
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.01
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.05
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.95
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.67
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.04
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.05
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.95
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.63
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.30
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.02
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.67
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.05
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.64
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.95
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.98
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.66
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.01
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.64
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.93
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.56
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.96
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-0.65
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.02
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.69
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.91
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.56
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.13
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-6.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-3.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-3.30
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.05
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.75
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.98
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.61
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-3.20
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# ...
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.48
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.47
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.45
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.73
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.83
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.91
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.45
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.20
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.45
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.45
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.60
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.69
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.84
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.55
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.35
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.28
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.50
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.60
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.77
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.35
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.37
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.19
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.59
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.66
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.51
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.32
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.25
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.55
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.55
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.51
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.63
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.18
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.30
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.50
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.57
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.56
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.39
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.62
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.18
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.57
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.75
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.81
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.29
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.10
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-0.32
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.29
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-2.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.40
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.58
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.75
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.73
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.47
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.63
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.21
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.30
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.57
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.62
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.72
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.44
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.58
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.17
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.20
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.50
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.52
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.54
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.72
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.50
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.70
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.56
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.15
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'NEARUSDT', 'NEARBRL'). Lucro: $-4.20
# Sem oportunidades para ('USDTBRL', 'ADAUSDT', 'ADABRL'). Lucro: $-0.40
# Sem oportunidades para ('USDTBRL', 'SHIBUSDT', 'SHIBBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'BNBUSDT', 'BNBBRL'). Lucro: $-2.46
# Sem oportunidades para ('USDTBRL', 'DOTUSDT', 'DOTBRL'). Lucro: $-0.47
# Sem oportunidades para ('USDTBRL', 'PEPEUSDT', 'PEPEBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL'). Lucro: $-0.68
# Sem oportunidades para ('USDTBRL', 'ENAUSDT', 'ENABRL'). Lucro: $-0.50
# Sem oportunidades para ('USDTBRL', 'CATIUSDT', 'CATIBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'NOTUSDT', 'NOTBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'SUIUSDT', 'SUIBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'FETUSDT', 'FETBRL'). Lucro: $-0.90
# Sem oportunidades para ('USDTBRL', 'NEIROUSDT', 'NEIROBRL'). Lucro: $-1.00
# Sem oportunidades para ('USDTBRL', 'PNUTUSDT', 'PNUTBRL'). Lucro: $-0.80
# Sem oportunidades para ('USDTBRL', 'POLUSDT', 'POLBRL'). Lucro: $-0.60
# Sem oportunidades para ('USDTBRL', 'SOLUSDT', 'SOLBRL'). Lucro: $-1.48
# Sem oportunidades para ('USDTBRL', 'LINKUSDT', 'LINKBRL'). Lucro: $-1.13
# Sem oportunidades para ('USDTBRL', 'XRPUSDT', 'XRPBRL'). Lucro: $-7.00
# Sem oportunidades para ('USDTBRL', 'DOGEUSDT', 'DOGEBRL'). Lucro: $-1.00

# %%
# depth = client.get_order_book(symbol='ENAUSDT')
# print(depth)

# %%
symbol2[:-4]
# Out:
# 'ENA'

# %%
third_asset = symbol2[:-4]
get_balance(third_asset)
# Out:
# 81.736371

# %%
symbol3 = opportunity[2]
print(third_asset, steps_size[2])
adjust_quantity(third_asset, steps_size[2])
# Out:
# ENA 0.01
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 symbol3 = opportunity[2]
#       2 print(third_asset, steps_size[2])
# ----> 3 adjust_quantity(third_asset, steps_size[2])
#
# Cell In[42], line 81, in adjust_quantity(quantity, step_size)
#      70 def adjust_quantity(quantity, step_size):
#      71     """
#      72     Ajusta a quantidade para o múltiplo mais próximo permitido pelo stepSize.
#      73
#    (...)
#      79         float: Quantidade ajustada.
#      80     """
# ---> 81     return math.floor(quantity / step_size) * step_size
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
adjust_quantity(first_conversion_quantity, steps_size[0])

# %%
steps_size[0]
# Out:
# 0.1

# %%
second_asset = 'USDT'
ss = get_balance(second_asset)
ss
# Out:
# 81.88074736

# %%
adjust_quantity(ss, steps_size[0])
# Out:
# 81.80000000000001

# %%
def get_lot_size(symbol):
    """Obtém os detalhes do filtro LOT_SIZE para o par."""
    try:
        exchange_info = client.get_exchange_info()
        for s in exchange_info['symbols']:
            if s['symbol'] == symbol:
                for f in s['filters']:
                    if f['filterType'] == 'LOT_SIZE':
                        return {
                            "minQty": float(f['minQty']),
                            "maxQty": float(f['maxQty']),
                            "stepSize": float(f['stepSize'])
                        }
    except Exception as e:
        print(f"Erro ao obter LOT_SIZE para {symbol}: {e}")
    return None

# Exemplo de uso
lot_size = get_lot_size('USDTBRL')
print(f"LOT_SIZE para USDTBRL: {lot_size}")
# Out:
# LOT_SIZE para USDTBRL: {'minQty': 0.1, 'maxQty': 9222449.0, 'stepSize': 0.1}

# %%
def get_balance(asset):
    """Obtém o saldo atual de um ativo."""
    try:
        account_info = client.get_account()
        balances = {item['asset']: float(item['free']) for item in account_info['balances']}
        return balances.get(asset, 0.0)
    except Exception as e:
        print(f"Erro ao obter saldo de {asset}: {e}")
        return 0.0

# %%
def execute_order(order_type, symbol, quantity):
    """
    Executa uma ordem de mercado.
    Args:
        order_type (str): 'BUY' ou 'SELL'.
        symbol (str): Par de negociação (ex.: 'BTCUSDT').
        quantity (float): Quantidade do ativo a negociar.
    Returns:
        dict: Detalhes da ordem executada ou None em caso de erro.
    """
    try:
        if order_type == 'BUY':
            order = client.order_market_buy(symbol=symbol, quantity=quantity)
        elif order_type == 'SELL':
            order = client.order_market_sell(symbol=symbol, quantity=quantity)
        else:
            raise ValueError("Tipo de ordem inválido.")
        print(f"Ordem executada: {order}")
        return order
    except Exception as e:
        print(f"Erro ao executar ordem {order_type} para {symbol}: {e}")
        return None

# %%
opportunity = arbitrage_opportunities[0]
opportunity
# Out:
# ('USDTBRL', 'ENAUSDT', 'ENABRL')

# %%
prices = fetch_prices(arbitrage_opportunities[0])
pair1_price = prices[opportunity[0]]
pair2_price = prices[opportunity[1]]
pair3_price = prices[opportunity[2]]

# %%
profit, final_usdt = triangular_arbitrage(
    brl_balance, pair1_price, pair2_price, pair3_price
)

# %%
profit, final_usdt
# Out:
# (-0.17991999999999564, 99.82008)

# %%
# Verifica saldo inicial
initial_asset = 'BRL'
initial_balance = get_balance(initial_asset)
initial_balance
# Out:
# 979.64541772

# %%
symbol1 = opportunity[0]
symbol1
# Out:
# 'USDTBRL'

# %%
first_conversion_quantity = brl_balance / pair1_price
symbol1, first_conversion_quantity
# Out:
# ('USDTBRL', 16.420361247947454)

# %%
execute_order('BUY', symbol1, round(first_conversion_quantity, 4))
# Out:
# Erro ao executar ordem BUY para USDTBRL: APIError(code=-1013): Filter failure: LOT_SIZE

# %%
# Etapa 2: Converter ativo do segundo par
second_asset = 'USDT'
second_balance = get_balance(second_asset)
second_asset, second_balance
# Out:
# ('USDT', 16.48311736)

# %%
quantity2 = second_balance/pair2_price
quantity2
# Out:
# 2.0175174247246024

# %%
symbol2 = opportunity[1]
symbol2
# Out:
# 'RENDERUSDT'

# %%
if second_balance >= first_conversion_quantity:
    symbol2 = opportunity[1]
    execute_order('BUY', symbol2, round(quantity2,2))
# Out:
# Ordem executada: {'symbol': 'RENDERUSDT', 'orderId': 381743119, 'orderListId': -1, 'clientOrderId': '80hTed6GOWbp2F1GCfBQBy', 'transactTime': 1733854367596, 'price': '0.00000000', 'origQty': '2.02000000', 'executedQty': '2.02000000', 'cummulativeQuoteQty': '16.42866000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1733854367596, 'fills': [{'price': '8.13300000', 'qty': '2.02000000', 'commission': '0.00202000', 'commissionAsset': 'RENDER', 'tradeId': 21135125}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
# Etapa 3: Converter ativo do terceiro par para BRL
third_asset = "RENDER"
third_balance = get_balance(third_asset)
symbol3 = opportunity[2]
third_asset, third_balance, symbol3
# Out:
# ('RENDER', 2.024765, 'RENDERBRL')

# %%
if third_balance > 0:
    symbol3 = opportunity[2]
    execute_order('SELL', symbol3, round(third_balance, 2))
    print(f"Arbitragem completa para {opportunity}.")
# Out:
# Ordem executada: {'symbol': 'RENDERBRL', 'orderId': 9501516, 'orderListId': -1, 'clientOrderId': '4Uac9qHd0T3ovVscEwgJXm', 'transactTime': 1733854633715, 'price': '0.00000000', 'origQty': '2.02000000', 'executedQty': '2.02000000', 'cummulativeQuoteQty': '100.91920000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'workingTime': 1733854633715, 'fills': [{'price': '49.96000000', 'qty': '2.02000000', 'commission': '0.10091920', 'commissionAsset': 'BRL', 'tradeId': 63973}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
# Arbitragem completa para ('USDTBRL', 'RENDERUSDT', 'RENDERBRL').
