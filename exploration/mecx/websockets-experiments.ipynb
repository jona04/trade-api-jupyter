# %%
import websocket
import json

def on_message(ws, message):
    """Função chamada quando uma mensagem é recebida."""
    data = json.loads(message)
    print("Mensagem recebida:", json.dumps(data, indent=4))

def on_error(ws, error):
    """Função chamada quando um erro ocorre."""
    print("Erro:", error)

def on_close(ws, close_status_code, close_msg):
    """Função chamada quando a conexão é fechada."""
    print("Conexão encerrada")

def on_open(ws):
    """Função chamada ao abrir a conexão."""
    # Exemplo de assinatura de um canal de dados de mercado
    params = {
        "method":"sub.depth.full",
        "param":{
            "symbol":"VIDT_USDT",
            "limit":5
        }
    }
    ws.send(json.dumps(params))
    print("Inscrito no canal de mercado para VIDT/USDT.")

# URL do WebSocket da MEXC
socket_url = "wss://contract.mexc.com/edge"

# Criando a conexão WebSocket
ws = websocket.WebSocketApp(
    socket_url,
    on_message=on_message,
    on_error=on_error,
    on_close=on_close
)

# Adicionando a função de on_open
ws.on_open = on_open

# Iniciando o loop do WebSocket
ws.run_forever()
# Out:
# Inscrito no canal de mercado para VIDT/USDT.
# Mensagem recebida: {
#     "channel": "rs.sub.depth.full",
#     "data": "success",
#     "ts": 1736001993899
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 3525,
#                 1
#             ],
#             [
#                 0.03469,
#                 5906,
#                 1
#             ],
#             [
#                 0.0347,
#                 10143,
#                 1
#             ],
#             [
#                 0.03471,
#                 1905,
#                 2
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 1990,
#                 1
#             ],
#             [
#                 0.03464,
#                 6304,
#                 1
#             ],
#             [
#                 0.03463,
#                 14893,
#                 2
#             ],
#             [
#                 0.03462,
#                 8269,
#                 2
#             ]
#         ],
#         "version": 533358255
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001994080
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 3525,
#                 1
#             ],
#             [
#                 0.03469,
#                 5906,
#                 1
#             ],
#             [
#                 0.0347,
#                 15109,
#                 3
#             ],
#             [
#                 0.03471,
#                 1377,
#                 1
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 1990,
#                 1
#             ],
#             [
#                 0.03464,
#                 6304,
#                 1
#             ],
#             [
#                 0.03463,
#                 10429,
#                 1
#             ],
#             [
#                 0.03462,
#                 5895,
#                 1
#             ]
#         ],
#         "version": 533358270
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001994359
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 3525,
#                 1
#             ],
#             [
#                 0.03469,
#                 5906,
#                 1
#             ],
#             [
#                 0.0347,
#                 13423,
#                 2
#             ],
#             [
#                 0.03471,
#                 1377,
#                 1
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 2506,
#                 2
#             ],
#             [
#                 0.03464,
#                 6304,
#                 1
#             ],
#             [
#                 0.03463,
#                 10429,
#                 1
#             ],
#             [
#                 0.03462,
#                 8261,
#                 2
#             ]
#         ],
#         "version": 533358275
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001994627
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 3525,
#                 1
#             ],
#             [
#                 0.03469,
#                 7323,
#                 2
#             ],
#             [
#                 0.0347,
#                 13237,
#                 2
#             ],
#             [
#                 0.03471,
#                 1377,
#                 1
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 1990,
#                 1
#             ],
#             [
#                 0.03464,
#                 6304,
#                 1
#             ],
#             [
#                 0.03463,
#                 10429,
#                 1
#             ],
#             [
#                 0.03462,
#                 5895,
#                 1
#             ]
#         ],
#         "version": 533358280
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001994890
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 3525,
#                 1
#             ],
#             [
#                 0.03469,
#                 8358,
#                 2
#             ],
#             [
#                 0.0347,
#                 10143,
#                 1
#             ],
#             [
#                 0.03471,
#                 1523,
#                 2
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 1990,
#                 1
#             ],
#             [
#                 0.03464,
#                 9003,
#                 2
#             ],
#             [
#                 0.03463,
#                 11500,
#                 2
#             ],
#             [
#                 0.03462,
#                 5895,
#                 1
#             ]
#         ],
#         "version": 533358370
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001995426
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 3525,
#                 1
#             ],
#             [
#                 0.03469,
#                 7502,
#                 2
#             ],
#             [
#                 0.0347,
#                 14857,
#                 2
#             ],
#             [
#                 0.03471,
#                 1377,
#                 1
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 1990,
#                 1
#             ],
#             [
#                 0.03464,
#                 6304,
#                 1
#             ],
#             [
#                 0.03463,
#                 11500,
#                 2
#             ],
#             [
#                 0.03462,
#                 5895,
#                 1
#             ]
#         ],
#         "version": 533358375
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001995964
# }
# Mensagem recebida: {
#     "symbol": "VIDT_USDT",
#     "data": {
#         "asks": [
#             [
#                 0.03467,
#                 150,
#                 1
#             ],
#             [
#                 0.03468,
#                 4590,
#                 2
#             ],
#             [
#                 0.03469,
#                 7535,
#                 2
#             ],
#             [
#                 0.0347,
#                 10143,
#                 1
#             ],
#             [
#                 0.03471,
#                 1377,
#                 1
#             ]
#         ],
#         "bids": [
#             [
#                 0.03466,
#                 1010,
#                 1
#             ],
#             [
#                 0.03465,
#                 1990,
#                 1
#             ],
#             [
#                 0.03464,
#                 6304,
#                 1
#             ],
#             [
#                 0.03463,
#                 17725,
#                 3
#             ],
#             [
#                 0.03462,
#                 5895,
#                 1
#             ]
#         ],
#         "version": 533358382
#     },
#     "channel": "push.depth.full",
#     "ts": 1736001996229
# }
# Erro:
# Conexão encerrada
# True

# %%
import requests
import time

def fetch_order_book(symbol):
    """Obtém os dados de profundidade do order book para o símbolo fornecido."""
    url = f"https://contract.mexc.com/api/v1/contract/depth/{symbol}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Levanta uma exceção para erros HTTP
        data = response.json()['data']

        # Extraindo melhor bid e ask
        bids = data["bids"]
        asks = data["asks"]
        
        if bids and asks:
            best_bid = bids[0]  # Melhor preço de compra
            best_ask = asks[0]  # Melhor preço de venda
            print(f"Best Bid: Price = {best_bid[0]}, Volume = {best_bid[1]}")
            print(f"Best Ask: Price = {best_ask[0]}, Volume = {best_ask[1]}")
        else:
            print("Nenhum dado de bid/ask disponível.")
    except requests.RequestException as e:
        print(f"Erro ao obter dados: {e}")
    except ValueError as e:
        print(f"Erro ao processar a resposta: {e}")

def main():
    """Obtém dados do order book a cada 2 segundos."""
    symbol = "APT_USDT"  # Substitua pelo símbolo desejado
    while True:
        fetch_order_book(symbol)
        time.sleep(1)  # Espera 2 segundos antes da próxima requisição

if __name__ == "__main__":
    main()
# Out:
# Best Bid: Price = 10.6044, Volume = 30578
# Best Ask: Price = 10.6045, Volume = 43911
# Best Bid: Price = 10.6019, Volume = 42332
# Best Ask: Price = 10.602, Volume = 47564
# Best Bid: Price = 10.6019, Volume = 41332
# Best Ask: Price = 10.602, Volume = 37601
# Best Bid: Price = 10.6007, Volume = 39133
# Best Ask: Price = 10.6008, Volume = 58794
# Best Bid: Price = 10.6007, Volume = 30523
# Best Ask: Price = 10.6008, Volume = 58794
# Best Bid: Price = 10.5993, Volume = 46769
# Best Ask: Price = 10.5994, Volume = 40849
# Best Bid: Price = 10.5993, Volume = 46769
# Best Ask: Price = 10.5994, Volume = 40848
# Best Bid: Price = 10.592, Volume = 33550
# Best Ask: Price = 10.5921, Volume = 38691
# Best Bid: Price = 10.5907, Volume = 37632
# Best Ask: Price = 10.5908, Volume = 40678
# Best Bid: Price = 10.5881, Volume = 61343
# Best Ask: Price = 10.5882, Volume = 43397
# Best Bid: Price = 10.5858, Volume = 33893
# Best Ask: Price = 10.5859, Volume = 9323
# Best Bid: Price = 10.5858, Volume = 22978
# Best Bid: Price = 10.5869, Volume = 51030
# Best Ask: Price = 10.587, Volume = 38912
# Best Bid: Price = 10.5869, Volume = 31220
# Best Ask: Price = 10.587, Volume = 38912
# Best Bid: Price = 10.5869, Volume = 9002
# Best Ask: Price = 10.587, Volume = 38912
# Best Bid: Price = 10.5859, Volume = 52329
# Best Ask: Price = 10.586, Volume = 61168
# Best Bid: Price = 10.5871, Volume = 51890
# Best Ask: Price = 10.5872, Volume = 14720
# Best Bid: Price = 10.5871, Volume = 49964
# Best Ask: Price = 10.5872, Volume = 14720
# Best Bid: Price = 10.5884, Volume = 50502
# Best Ask: Price = 10.5885, Volume = 39650
# Best Bid: Price = 10.5884, Volume = 11102
# Best Ask: Price = 10.5885, Volume = 26152
# Best Bid: Price = 10.5884, Volume = 11102
# Best Ask: Price = 10.5885, Volume = 26052
# Best Bid: Price = 10.5884, Volume = 10347
# Best Ask: Price = 10.5885, Volume = 26052
# Best Bid: Price = 10.587, Volume = 44934
# Best Ask: Price = 10.5871, Volume = 60922
# Best Bid: Price = 10.5859, Volume = 39016
# Best Ask: Price = 10.586, Volume = 23914
# Best Bid: Price = 10.5848, Volume = 32631
# Best Ask: Price = 10.5849, Volume = 61222
# Best Bid: Price = 10.5799, Volume = 46254
# Best Ask: Price = 10.58, Volume = 39973
# Best Bid: Price = 10.5764, Volume = 52488
# Best Ask: Price = 10.5765, Volume = 34519
# Best Bid: Price = 10.5764, Volume = 36399
# Best Ask: Price = 10.5765, Volume = 15115
# Best Bid: Price = 10.5781, Volume = 48856
# Best Ask: Price = 10.5782, Volume = 61088
# Best Bid: Price = 10.5755, Volume = 42522
# Best Ask: Price = 10.5756, Volume = 51616
# Best Bid: Price = 10.5755, Volume = 42522
# Best Ask: Price = 10.5756, Volume = 51616
# Best Bid: Price = 10.5755, Volume = 42522
# Best Ask: Price = 10.5756, Volume = 50866
# Best Bid: Price = 10.5755, Volume = 36030
# Best Ask: Price = 10.5756, Volume = 50765
# Best Bid: Price = 10.5777, Volume = 53035
# Best Ask: Price = 10.5778, Volume = 58265
# Best Bid: Price = 10.5777, Volume = 52488
# Best Ask: Price = 10.5778, Volume = 51191
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 36
#      33         time.sleep(1)  # Espera 2 segundos antes da próxima requisição
#      35 if __name__ == "__main__":
# ---> 36     main()
#
# Cell In[1], line 33, in main()
#      31 while True:
#      32     fetch_order_book(symbol)
# ---> 33     time.sleep(1)
#
# KeyboardInterrupt:

# %%
import ccxt
import time

def fetch_bid_ask(exchange, symbol):
    """Obtém o preço bid e ask para o ativo fornecido."""
    try:
        ticker = exchange.fetch_ticker(symbol)
        bid = ticker['bid']  # Melhor preço de compra
        ask = ticker['ask']  # Melhor preço de venda
        print(f"Ativo: {symbol}")
        print(f"Bid (compra): {bid}")
        print(f"Ask (venda): {ask}")
    except ccxt.BaseError as e:
        print(f"Erro ao obter preços: {e}")

def main():
    # Inicializa a exchange MEXC
    exchange = ccxt.mexc({
        'rateLimit': 2000,  # Respeita o limite de requisições
    })

    symbol = 'VIDT/USDT'  # Substitua pelo ativo desejado

    while True:
        fetch_bid_ask(exchange, symbol)
        time.sleep(0.5)  # Aguarda 2 segundos antes de buscar novamente

if __name__ == "__main__":
    main()
# Out:
# Ativo: VIDT/USDT
# Bid (compra): 0.03395
# Ask (venda): 0.03397
# Ativo: VIDT/USDT
# Bid (compra): 0.03395
# Ask (venda): 0.03397
# Ativo: VIDT/USDT
# Bid (compra): 0.03395
# Ask (venda): 0.03397
# Ativo: VIDT/USDT
# Bid (compra): 0.03395
# Ask (venda): 0.03397
# Ativo: VIDT/USDT
# Bid (compra): 0.03397
# Ask (venda): 0.03399
# Ativo: VIDT/USDT
# Bid (compra): 0.03397
# Ask (venda): 0.03399
# Ativo: VIDT/USDT
# Bid (compra): 0.03397
# Ask (venda): 0.03399
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 29
#      26         time.sleep(0.5)  # Aguarda 2 segundos antes de buscar novamente
#      28 if __name__ == "__main__":
# ---> 29     main()
#
# Cell In[3], line 25, in main()
#      22 symbol = 'VIDT/USDT'  # Substitua pelo ativo desejado
#      24 while True:
# ---> 25     fetch_bid_ask(exchange, symbol)
#      26     time.sleep(0.5)
#
# Cell In[3], line 7, in fetch_bid_ask(exchange, symbol)
#       5 """Obtém o preço bid e ask para o ativo fornecido."""
#       6 try:
# ----> 7     ticker = exchange.fetch_ticker(symbol)
#       8     bid = ticker['bid']  # Melhor preço de compra
#       9     ask = ticker['ask']  # Melhor preço de venda
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/ccxt/mexc.py:1970, in mexc.fetch_ticker(self, symbol, params)
#    1966 request: dict = {
#    1967     'symbol': market['id'],
#    1968 }
#    1969 if marketType == 'spot':
# -> 1970     ticker = self.spotPublicGetTicker24hr(self.extend(request, query))
#    1971     #
#    1972     #     {
#    1973     #         "symbol": "BTCUSDT",
#    (...)
#    1991     #     }
#    1992     #
#    1993 elif marketType == 'swap':
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/ccxt/base/types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/ccxt/base/exchange.py:4244, in Exchange.request(self, path, api, method, params, headers, body, config)
#    4243 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 4244     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/ccxt/base/exchange.py:4219, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    4217 if self.enableRateLimit:
#    4218     cost = self.calculate_rate_limiter_cost(api, method, path, params, config)
# -> 4219     self.throttle(cost)
#    4220 self.lastRestRequestTimestamp = self.milliseconds()
#    4221 request = self.sign(path, api, method, params, headers, body)
#
# File ~/Documents/fxopen/venv/lib64/python3.12/site-packages/ccxt/base/exchange.py:466, in Exchange.throttle(self, cost)
#     464 if elapsed < sleep_time:
#     465     delay = sleep_time - elapsed
# --> 466     time.sleep(delay / 1000.0)
#
# KeyboardInterrupt:
